# %% [markdown]
# <a href="https://colab.research.google.com/github/Anil1331/YOLOv2/blob/master/YOLOv2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget -q http://pjreddie.com/media/files/VOCtrainval_06-Nov-2007.tar
# !tar -xf VOCtrainval_06-Nov-2007.tar

# %%
classes = {'chair': 1432, 'car': 1644, 'horse': 406, 'person': 5447, 'bicycle': 418, 'cat': 389, 'dog': 538, 'head': 439, 'foot': 434, 'hand': 681, 'train': 328, 'aeroplane': 331, 'diningtable': 310, 'tvmonitor': 367, 'bird': 599, 'bottle': 634, 'motorbike': 390, 'pottedplant': 625, 'boat': 398, 'sofa': 425, 'sheep': 353, 'cow': 356, 'bus': 272}
LABELS = list(classes.keys())

# %%
import os
import cv2
import copy
import numpy as np
import imgaug as ia
from imgaug import augmenters as iaa
from keras.utils import Sequence
import xml.etree.ElementTree as ET
import random 
def get_images(ann_dir, img_dir, ann, labels, all_imgs, seen_labels):
  img = {'object':[]}

  tree = ET.parse(ann_dir + ann)

  for elem in tree.iter():
      if 'filename' in elem.tag:
          img['filename'] = img_dir + elem.text
      if 'width' in elem.tag:
          img['width'] = int(elem.text)
      if 'height' in elem.tag:
          img['height'] = int(elem.text)
      if 'object' in elem.tag or 'part' in elem.tag:
          obj = {}

          for attr in list(elem):
              if 'name' in attr.tag:
                  obj['name'] = attr.text

                  if obj['name'] in seen_labels:
                      seen_labels[obj['name']] += 1
                  else:
                      seen_labels[obj['name']] = 1

                  if len(labels) > 0 and obj['name'] not in labels:
                      break
                  else:
                      img['object'] += [obj]

              if 'bndbox' in attr.tag:
                  for dim in list(attr):
                      if 'xmin' in dim.tag:
                          obj['xmin'] = int(round(float(dim.text)))
                      if 'ymin' in dim.tag:
                          obj['ymin'] = int(round(float(dim.text)))
                      if 'xmax' in dim.tag:
                          obj['xmax'] = int(round(float(dim.text)))
                      if 'ymax' in dim.tag:
                          obj['ymax'] = int(round(float(dim.text)))

  if len(img['object']) > 0:
      all_imgs += [img] 
  return all_imgs, seen_labels    

def parse_annotation(ann_dir, img_dir, labels=[]):
    files = os.listdir(ann_dir)
    train = random.sample(files, int((len(files)*4)/5))
    test = [x for x in files if x not in train]
    print(len(train), len(test))
    train_imgs, train_labels, val_imgs, val_labels = [], {}, [], {}
    for ann in sorted(train):
        get_images(ann_dir, img_dir, ann, labels, train_imgs, train_labels)
    for ann in sorted(test):
        get_images(ann_dir, img_dir, ann, labels, val_imgs, val_labels)        
    return train_imgs, train_labels, val_imgs, val_labels

class BatchGenerator(Sequence):
    def __init__(self, images, 
                       config, 
                       shuffle=True, 
                       jitter=True, 
                       norm=None):
        self.generator = None

        self.images = images
        self.config = config

        self.shuffle = shuffle
        self.jitter  = jitter
        self.norm    = norm

        self.anchors = [BoundBox(0, 0, config['ANCHORS'][2*i], config['ANCHORS'][2*i+1]) for i in range(int(len(config['ANCHORS'])//2))]

        ### augmentors by https://github.com/aleju/imgaug
        sometimes = lambda aug: iaa.Sometimes(0.5, aug)

        # Define our sequence of augmentation steps that will be applied to every image
        # All augmenters with per_channel=0.5 will sample one value _per image_
        # in 50% of all cases. In all other cases they will sample new values
        # _per channel_.
        self.aug_pipe = iaa.Sequential(
            [
                # apply the following augmenters to most images
                #iaa.Fliplr(0.5), # horizontally flip 50% of all images
                #iaa.Flipud(0.2), # vertically flip 20% of all images
                #sometimes(iaa.Crop(percent=(0, 0.1))), # crop images by 0-10% of their height/width
                sometimes(iaa.Affine(
                    #scale={"x": (0.8, 1.2), "y": (0.8, 1.2)}, # scale images to 80-120% of their size, individually per axis
                    #translate_percent={"x": (-0.2, 0.2), "y": (-0.2, 0.2)}, # translate by -20 to +20 percent (per axis)
                    #rotate=(-5, 5), # rotate by -45 to +45 degrees
                    #shear=(-5, 5), # shear by -16 to +16 degrees
                    #order=[0, 1], # use nearest neighbour or bilinear interpolation (fast)
                    #cval=(0, 255), # if mode is constant, use a cval between 0 and 255
                    #mode=ia.ALL # use any of scikit-image's warping modes (see 2nd image from the top for examples)
                )),
                # execute 0 to 5 of the following (less important) augmenters per image
                # don't execute all of them, as that would often be way too strong
                iaa.SomeOf((0, 5),
                    [
                        #sometimes(iaa.Superpixels(p_replace=(0, 1.0), n_segments=(20, 200))), # convert images into their superpixel representation
                        iaa.OneOf([
                            iaa.GaussianBlur((0, 3.0)), # blur images with a sigma between 0 and 3.0
                            iaa.AverageBlur(k=(2, 7)), # blur image using local means with kernel sizes between 2 and 7
                            iaa.MedianBlur(k=(3, 11)), # blur image using local medians with kernel sizes between 2 and 7
                        ]),
                        iaa.Sharpen(alpha=(0, 1.0), lightness=(0.75, 1.5)), # sharpen images
                        #iaa.Emboss(alpha=(0, 1.0), strength=(0, 2.0)), # emboss images
                        # search either for all edges or for directed edges
                        #sometimes(iaa.OneOf([
                        #    iaa.EdgeDetect(alpha=(0, 0.7)),
                        #    iaa.DirectedEdgeDetect(alpha=(0, 0.7), direction=(0.0, 1.0)),
                        #])),
                        iaa.AdditiveGaussianNoise(loc=0, scale=(0.0, 0.05*255), per_channel=0.5), # add gaussian noise to images
                        iaa.OneOf([
                            iaa.Dropout((0.01, 0.1), per_channel=0.5), # randomly remove up to 10% of the pixels
                            #iaa.CoarseDropout((0.03, 0.15), size_percent=(0.02, 0.05), per_channel=0.2),
                        ]),
                        #iaa.Invert(0.05, per_channel=True), # invert color channels
                        iaa.Add((-10, 10), per_channel=0.5), # change brightness of images (by -10 to 10 of original value)
                        iaa.Multiply((0.5, 1.5), per_channel=0.5), # change brightness of images (50-150% of original value)
                        iaa.ContrastNormalization((0.5, 2.0), per_channel=0.5), # improve or worsen the contrast
                        #iaa.Grayscale(alpha=(0.0, 1.0)),
                        #sometimes(iaa.ElasticTransformation(alpha=(0.5, 3.5), sigma=0.25)), # move pixels locally around (with random strengths)
                        #sometimes(iaa.PiecewiseAffine(scale=(0.01, 0.05))) # sometimes move parts of the image around
                    ],
                    random_order=True
                )
            ],
            random_order=True
        )

        if shuffle: np.random.shuffle(self.images)

    def __len__(self):
        return int(np.ceil(float(len(self.images))/self.config['BATCH_SIZE']))   

    def num_classes(self):
        return len(self.config['LABELS'])

    def size(self):
        return len(self.images)    

    def load_annotation(self, i):
        annots = []

        for obj in self.images[i]['object']:
            annot = [obj['xmin'], obj['ymin'], obj['xmax'], obj['ymax'], self.config['LABELS'].index(obj['name'])]
            annots += [annot]

        if len(annots) == 0: annots = [[]]

        return np.array(annots)

    def load_image(self, i):
        return cv2.imread(self.images[i]['filename'])

    def __getitem__(self, idx):
        l_bound = idx*self.config['BATCH_SIZE']
        r_bound = (idx+1)*self.config['BATCH_SIZE']

        if r_bound > len(self.images):
            r_bound = len(self.images)
            l_bound = r_bound - self.config['BATCH_SIZE']

        instance_count = 0

        x_batch = np.zeros((r_bound - l_bound, self.config['IMAGE_H'], self.config['IMAGE_W'], 3))                         # input images
        b_batch = np.zeros((r_bound - l_bound, 1     , 1     , 1    ,  self.config['TRUE_BOX_BUFFER'], 4))   # list of self.config['TRUE_self.config['BOX']_BUFFER'] GT boxes
        y_batch = np.zeros((r_bound - l_bound, self.config['GRID_H'],  self.config['GRID_W'], self.config['BOX'], 4+1+len(self.config['LABELS'])))                # desired network output

        for train_instance in self.images[l_bound:r_bound]:
            # augment input image and fix object's position and size
            img, all_objs = self.aug_image(train_instance, jitter=self.jitter)
            
            # construct output from object's x, y, w, h
            true_box_index = 0
            
            for obj in all_objs:
                if obj['xmax'] > obj['xmin'] and obj['ymax'] > obj['ymin'] and obj['name'] in self.config['LABELS']:
                    center_x = .5*(obj['xmin'] + obj['xmax'])
                    center_x = center_x / (float(self.config['IMAGE_W']) / self.config['GRID_W'])
                    center_y = .5*(obj['ymin'] + obj['ymax'])
                    center_y = center_y / (float(self.config['IMAGE_H']) / self.config['GRID_H'])

                    grid_x = int(np.floor(center_x))
                    grid_y = int(np.floor(center_y))

                    if grid_x < self.config['GRID_W'] and grid_y < self.config['GRID_H']:
                        obj_indx  = self.config['LABELS'].index(obj['name'])
                        
                        center_w = (obj['xmax'] - obj['xmin']) / (float(self.config['IMAGE_W']) / self.config['GRID_W']) # unit: grid cell
                        center_h = (obj['ymax'] - obj['ymin']) / (float(self.config['IMAGE_H']) / self.config['GRID_H']) # unit: grid cell
                        
                        box = [center_x, center_y, center_w, center_h]

                        # find the anchor that best predicts this box
                        best_anchor = -1
                        max_iou     = -1
                        
                        shifted_box = BoundBox(0, 
                                               0,
                                               center_w,                                                
                                               center_h)
                        
                        for i in range(len(self.anchors)):
                            anchor = self.anchors[i]
                            iou    = bbox_iou(shifted_box, anchor)
                            
                            if max_iou < iou:
                                best_anchor = i
                                max_iou     = iou
                                
                        # assign ground truth x, y, w, h, confidence and class probs to y_batch
                        y_batch[instance_count, grid_y, grid_x, best_anchor, 0:4] = box
                        y_batch[instance_count, grid_y, grid_x, best_anchor, 4  ] = 1.
                        y_batch[instance_count, grid_y, grid_x, best_anchor, 5+obj_indx] = 1
                        
                        # assign the true box to b_batch
                        b_batch[instance_count, 0, 0, 0, true_box_index] = box
                        
                        true_box_index += 1
                        true_box_index = true_box_index % self.config['TRUE_BOX_BUFFER']
                            
            # assign input image to x_batch
            if self.norm != None: 
                x_batch[instance_count] = self.norm(img)
            else:
                # plot image and bounding boxes for sanity check
                for obj in all_objs:
                    if obj['xmax'] > obj['xmin'] and obj['ymax'] > obj['ymin']:
                        cv2.rectangle(img[:,:,::-1], (obj['xmin'],obj['ymin']), (obj['xmax'],obj['ymax']), (255,0,0), 3)
                        cv2.putText(img[:,:,::-1], obj['name'], 
                                    (obj['xmin']+2, obj['ymin']+12), 
                                    0, 1.2e-3 * img.shape[0], 
                                    (0,255,0), 2)
                        
                x_batch[instance_count] = img

            # increase instance counter in current batch
            instance_count += 1  

        #print(' new batch created', idx)

        return [x_batch, b_batch], y_batch

    def on_epoch_end(self):
        if self.shuffle: np.random.shuffle(self.images)

    def aug_image(self, train_instance, jitter):
        image_name = train_instance['filename']
        image = cv2.imread(image_name)

        if image is None: print('Cannot find ', image_name)

        h, w, c = image.shape
        all_objs = copy.deepcopy(train_instance['object'])

        if jitter:
            ### scale the image
            scale = np.random.uniform() / 10. + 1.
            image = cv2.resize(image, (0,0), fx = scale, fy = scale)

            ### translate the image
            max_offx = (scale-1.) * w
            max_offy = (scale-1.) * h
            offx = int(np.random.uniform() * max_offx)
            offy = int(np.random.uniform() * max_offy)
            
            image = image[offy : (offy + h), offx : (offx + w)]

            ### flip the image
            flip = np.random.binomial(1, .5)
            if flip > 0.5: image = cv2.flip(image, 1)
                
            image = self.aug_pipe.augment_image(image)            
            
        # resize the image to standard size
        image = cv2.resize(image, (self.config['IMAGE_H'], self.config['IMAGE_W']))
        image = image[:,:,::-1]

        # fix object's position and size
        for obj in all_objs:
            for attr in ['xmin', 'xmax']:
                if jitter: obj[attr] = int(obj[attr] * scale - offx)
                    
                obj[attr] = int(obj[attr] * float(self.config['IMAGE_W']) / w)
                obj[attr] = max(min(obj[attr], self.config['IMAGE_W']), 0)
                
            for attr in ['ymin', 'ymax']:
                if jitter: obj[attr] = int(obj[attr] * scale - offy)
                    
                obj[attr] = int(obj[attr] * float(self.config['IMAGE_H']) / h)
                obj[attr] = max(min(obj[attr], self.config['IMAGE_H']), 0)

            if jitter and flip > 0.5:
                xmin = obj['xmin']
                obj['xmin'] = self.config['IMAGE_W'] - obj['xmax']
                obj['xmax'] = self.config['IMAGE_W'] - xmin
                
        return image, all_objs
# Out:
# Using TensorFlow backend.

# %%
import numpy as np
import os
import xml.etree.ElementTree as ET
import tensorflow as tf
import copy
import cv2

class BoundBox:
    def __init__(self, xmin, ymin, xmax, ymax, c = None, classes = None):
        self.xmin = xmin
        self.ymin = ymin
        self.xmax = xmax
        self.ymax = ymax
        
        self.c     = c
        self.classes = classes

        self.label = -1
        self.score = -1

    def get_label(self):
        if self.label == -1:
            self.label = np.argmax(self.classes)
        
        return self.label
    
    def get_score(self):
        if self.score == -1:
            self.score = self.classes[self.get_label()]
            
        return self.score

class WeightReader:
    def __init__(self, weight_file):
        self.offset = 4
        self.all_weights = np.fromfile(weight_file, dtype='float32')
        
    def read_bytes(self, size):
        self.offset = self.offset + size
        return self.all_weights[self.offset-size:self.offset]
    
    def reset(self):
        self.offset = 4

def bbox_iou(box1, box2):
    intersect_w = _interval_overlap([box1.xmin, box1.xmax], [box2.xmin, box2.xmax])
    intersect_h = _interval_overlap([box1.ymin, box1.ymax], [box2.ymin, box2.ymax])  
    
    intersect = intersect_w * intersect_h

    w1, h1 = box1.xmax-box1.xmin, box1.ymax-box1.ymin
    w2, h2 = box2.xmax-box2.xmin, box2.ymax-box2.ymin
    
    union = w1*h1 + w2*h2 - intersect
    
    return float(intersect) / union

def draw_boxes(image, boxes, labels):
    image_h, image_w, _ = image.shape

    for box in boxes:
        xmin = int(box.xmin*image_w)
        ymin = int(box.ymin*image_h)
        xmax = int(box.xmax*image_w)
        ymax = int(box.ymax*image_h)

        cv2.rectangle(image, (xmin,ymin), (xmax,ymax), (0,255,0), 3)
        cv2.putText(image, 
                    labels[box.get_label()] + ' ' + str(box.get_score()), 
                    (xmin, ymin - 13), 
                    cv2.FONT_HERSHEY_SIMPLEX, 
                    1e-3 * image_h, 
                    (0,255,0), 2)
        
    return image          
        
def decode_netout(netout, anchors, nb_class, obj_threshold=0.3, nms_threshold=0.3):
    grid_h, grid_w, nb_box = netout.shape[:3]

    boxes = []
    # decode the output by the network
    netout[..., 4]  = _sigmoid(netout[..., 4])
    netout[..., 5:] = netout[..., 4][..., np.newaxis] * _softmax(netout[..., 5:])
    #print(np.max(netout[..., 5:]))
    netout[..., 5:] *= netout[..., 5:] > obj_threshold
    
    for row in range(grid_h):
        for col in range(grid_w):
            for b in range(nb_box):
                # from 4th element onwards are confidence and class classes
                classes = netout[row,col,b,5:]
                if np.sum(classes) > 0:
                    # first 4 elements are x, y, w, and h
                    x, y, w, h = netout[row,col,b,:4]

                    x = (col + _sigmoid(x)) / grid_w # center position, unit: image width
                    y = (row + _sigmoid(y)) / grid_h # center position, unit: image height
                    w = anchors[2 * b + 0] * np.exp(w) / grid_w # unit: image width
                    h = anchors[2 * b + 1] * np.exp(h) / grid_h # unit: image height
                    confidence = netout[row,col,b,4]
                    
                    box = BoundBox(x-w/2, y-h/2, x+w/2, y+h/2, confidence, classes)
                    
                    boxes.append(box)
    #print(boxes)
    # suppress non-maximal boxes
    for c in range(nb_class):
        sorted_indices = list(reversed(np.argsort([box.classes[c] for box in boxes])))

        for i in range(len(sorted_indices)):
            index_i = sorted_indices[i]
            
            if boxes[index_i].classes[c] == 0: 
                continue
            else:
                for j in range(i+1, len(sorted_indices)):
                    index_j = sorted_indices[j]
                    
                    if bbox_iou(boxes[index_i], boxes[index_j]) >= nms_threshold:
                        boxes[index_j].classes[c] = 0
                        
    #print([box.get_score() for box in boxes])                    
    # remove the boxes which are less likely than a obj_threshold
    boxes = [box for box in boxes if box.get_score() > obj_threshold]
    
    return boxes    

def compute_overlap(a, b):
    """
    Code originally from https://github.com/rbgirshick/py-faster-rcnn.
    Parameters
    ----------
    a: (N, 4) ndarray of float
    b: (K, 4) ndarray of float
    Returns
    -------
    overlaps: (N, K) ndarray of overlap between boxes and query_boxes
    """
    area = (b[:, 2] - b[:, 0]) * (b[:, 3] - b[:, 1])

    iw = np.minimum(np.expand_dims(a[:, 2], axis=1), b[:, 2]) - np.maximum(np.expand_dims(a[:, 0], 1), b[:, 0])
    ih = np.minimum(np.expand_dims(a[:, 3], axis=1), b[:, 3]) - np.maximum(np.expand_dims(a[:, 1], 1), b[:, 1])

    iw = np.maximum(iw, 0)
    ih = np.maximum(ih, 0)

    ua = np.expand_dims((a[:, 2] - a[:, 0]) * (a[:, 3] - a[:, 1]), axis=1) + area - iw * ih

    ua = np.maximum(ua, np.finfo(float).eps)

    intersection = iw * ih

    return intersection / ua  
    
def compute_ap(recall, precision):
    """ Compute the average precision, given the recall and precision curves.
    Code originally from https://github.com/rbgirshick/py-faster-rcnn.

    # Arguments
        recall:    The recall curve (list).
        precision: The precision curve (list).
    # Returns
        The average precision as computed in py-faster-rcnn.
    """
    # correct AP calculation
    # first append sentinel values at the end
    mrec = np.concatenate(([0.], recall, [1.]))
    mpre = np.concatenate(([0.], precision, [0.]))

    # compute the precision envelope
    for i in range(mpre.size - 1, 0, -1):
        mpre[i - 1] = np.maximum(mpre[i - 1], mpre[i])

    # to calculate area under PR curve, look for points
    # where X axis (recall) changes value
    i = np.where(mrec[1:] != mrec[:-1])[0]

    # and sum (\Delta recall) * prec
    ap = np.sum((mrec[i + 1] - mrec[i]) * mpre[i + 1])
    return ap      
        
def _interval_overlap(interval_a, interval_b):
    x1, x2 = interval_a
    x3, x4 = interval_b

    if x3 < x1:
        if x4 < x1:
            return 0
        else:
            return min(x2,x4) - x1
    else:
        if x2 < x3:
             return 0
        else:
            return min(x2,x4) - x3          

def _sigmoid(x):
    return 1. / (1. + np.exp(-x))

def _softmax(x, axis=-1, t=-100.):
    x = x - np.max(x)
    
    if np.min(x) < t:
        x = x/np.min(x)*t
        
    e_x = np.exp(x)
    
    return e_x / e_x.sum(axis, keepdims=True)

# %%
import cv2

def normalize(image):
  return image / 255.

'''
def normalize(image):
    image = image[..., ::-1]
    image = image.astype('float')

    image[..., 0] -= 103.939
    image[..., 1] -= 116.779
    image[..., 2] -= 123.68

    return image
'''

def predict(image):
  image_h, image_w, _ = image.shape
  image = cv2.resize(image, (IMAGE_H, IMAGE_W))
  image = normalize(image)
  input_image = image[:,:,::-1]
  input_image = np.expand_dims(input_image, 0)
  dummy_array = np.zeros((1,1,1,1,TRUE_BOX_BUFFER,4))

  netout = model.predict([input_image, dummy_array])[0]
  boxes  = decode_netout(netout, ANCHORS, CLASS)

  return boxes

def evaluate(generator, 
			 iou_threshold=0.3,
			 score_threshold=0.3,
			 max_detections=100,
			 save_path=None):
	""" Evaluate a given dataset using a given model.
	code originally from https://github.com/fizyr/keras-retinanet
	# Arguments
		generator       : The generator that represents the dataset to evaluate.
		model           : The model to evaluate.
		iou_threshold   : The threshold used to consider when a detection is positive or negative.
		score_threshold : The score confidence threshold to use for detections.
		max_detections  : The maximum number of detections to use per image.
		save_path       : The path to save images with visualized detections to.
	# Returns
		A dict mapping class names to mAP scores.
	"""    
	# gather all detections and annotations
	all_detections     = [[None for i in range(generator.num_classes())] for j in range(generator.size())]
	all_annotations    = [[None for i in range(generator.num_classes())] for j in range(generator.size())]
	for i in range(generator.size()):
		raw_image = generator.load_image(i)
		raw_height, raw_width, raw_channels = raw_image.shape

		# make the boxes and the labels
		pred_boxes  = predict(raw_image)

		
		score = np.array([box.score for box in pred_boxes])
		pred_labels = np.array([box.label for box in pred_boxes])        
		#print(len(pred_boxes))
		if len(pred_boxes) > 0:
			pred_boxes = np.array([[box.xmin*raw_width, box.ymin*raw_height, box.xmax*raw_width, box.ymax*raw_height, box.score] for box in pred_boxes])
		else:
			pred_boxes = np.array([[]])  
		
		# sort the boxes and the labels according to scores
		score_sort = np.argsort(-score)
		pred_labels = pred_labels[score_sort]
		pred_boxes  = pred_boxes[score_sort]
		
		# copy detections to all_detections
		for label in range(generator.num_classes()):
			all_detections[i][label] = pred_boxes[pred_labels == label, :]
			
		annotations = generator.load_annotation(i)
		
		# copy detections to all_annotations
		for label in range(generator.num_classes()):
			all_annotations[i][label] = annotations[annotations[:, 4] == label, :4].copy()
			
	# compute mAP by comparing all detections and all annotations
	average_precisions = {}
	
	for label in range(generator.num_classes()):
		false_positives = np.zeros((0,))
		true_positives  = np.zeros((0,))
		scores          = np.zeros((0,))
		num_annotations = 0.0

		for i in range(generator.size()):
			detections           = all_detections[i][label]
			annotations          = all_annotations[i][label]
			num_annotations     += annotations.shape[0]
			detected_annotations = []

			for d in detections:
				scores = np.append(scores, d[4])

				if annotations.shape[0] == 0:
					false_positives = np.append(false_positives, 1)
					true_positives  = np.append(true_positives, 0)
					continue

				overlaps            = compute_overlap(np.expand_dims(d, axis=0), annotations)
				assigned_annotation = np.argmax(overlaps, axis=1)
				max_overlap         = overlaps[0, assigned_annotation]

				if max_overlap >= iou_threshold and assigned_annotation not in detected_annotations:
					false_positives = np.append(false_positives, 0)
					true_positives  = np.append(true_positives, 1)
					detected_annotations.append(assigned_annotation)
				else:
					false_positives = np.append(false_positives, 1)
					true_positives  = np.append(true_positives, 0)

		# no annotations -> AP for this class is 0 (is this correct?)
		if num_annotations == 0:
			average_precisions[label] = 0
			continue

		# sort by score
		indices         = np.argsort(-scores)
		false_positives = false_positives[indices]
		true_positives  = true_positives[indices]

		# compute false positives and true positives
		false_positives = np.cumsum(false_positives)
		true_positives  = np.cumsum(true_positives)

		# compute recall and precision
		recall    = true_positives / num_annotations
		precision = true_positives / np.maximum(true_positives + false_positives, np.finfo(np.float64).eps)

		# compute average precision
		average_precision  = compute_ap(recall, precision)  
		average_precisions[label] = average_precision

	return average_precisions

# %%
train_image_folder = 'VOCdevkit/VOC2007/JPEGImages/'
train_annot_folder = 'VOCdevkit/VOC2007/Annotations/'

# %%
IMAGE_H, IMAGE_W = 416, 416
GRID_H,  GRID_W  = 13 , 13
BOX              = 5
CLASS            = len(LABELS)
CLASS_WEIGHTS    = np.ones(CLASS, dtype='float32')
OBJ_THRESHOLD    = 0.3#0.5
NMS_THRESHOLD    = 0.3#0.45
#ANCHORS          = [0.57273, 0.677385, 1.87446, 2.06253, 3.33843, 5.47434, 7.88282, 3.52778, 9.77052, 9.16828]
ANCHORS          = [0.96,1.66, 2.45,3.90, 4.01,8.17, 7.75,5.12, 9.87,10.46]

NO_OBJECT_SCALE  = 1.0
OBJECT_SCALE     = 5.0
COORD_SCALE      = 1
CLASS_SCALE      = 1

BATCH_SIZE       = 16
WARM_UP_BATCHES  = 3
TRUE_BOX_BUFFER  = 50
generator_config = {
    'IMAGE_H'         : IMAGE_H, 
    'IMAGE_W'         : IMAGE_W,
    'GRID_H'          : GRID_H,  
    'GRID_W'          : GRID_W,
    'BOX'             : BOX,
    'LABELS'          : LABELS,
    'CLASS'           : len(LABELS),
    'ANCHORS'         : ANCHORS,
    'BATCH_SIZE'      : BATCH_SIZE,
    'TRUE_BOX_BUFFER' : 50,
}

# %%
train_imgs, seen_train_labels, val_imgs, seen_val_labels = parse_annotation(train_annot_folder, train_image_folder, labels=LABELS)
# Out:
# 4008 1003

# %%
import random
import numpy as np
import json

def IOU(ann, centroids):
    w, h = ann
    similarities = []

    for centroid in centroids:
        c_w, c_h = centroid

        if c_w >= w and c_h >= h:
            similarity = w*h/(c_w*c_h)
        elif c_w >= w and c_h <= h:
            similarity = w*c_h/(w*h + (c_w-w)*c_h)
        elif c_w <= w and c_h >= h:
            similarity = c_w*h/(w*h + c_w*(c_h-h))
        else: #means both w,h are bigger than c_w and c_h respectively
            similarity = (c_w*c_h)/(w*h)
        similarities.append(similarity) # will become (k,) shape

    return np.array(similarities)

def avg_IOU(anns, centroids):
    n,d = anns.shape
    sum = 0.

    for i in range(anns.shape[0]):
        sum+= max(IOU(anns[i], centroids))

    return sum/n

def print_anchors(centroids):
    anchors = centroids.copy()

    widths = anchors[:, 0]
    sorted_indices = np.argsort(widths)

    r = "anchors: ["
    for i in sorted_indices[:-1]:
        r += '%0.2f,%0.2f, ' % (anchors[i,0], anchors[i,1])

    #there should not be comma after last anchor, that's why
    r += '%0.2f,%0.2f' % (anchors[sorted_indices[-1:],0], anchors[sorted_indices[-1:],1])
    r += "]"

    print(r)

def run_kmeans(ann_dims, anchor_num):
    ann_num = ann_dims.shape[0]
    iterations = 0
    prev_assignments = np.ones(ann_num)*(-1)
    iteration = 0
    old_distances = np.zeros((ann_num, anchor_num))

    indices = [random.randrange(ann_dims.shape[0]) for i in range(anchor_num)]
    centroids = ann_dims[indices]
    anchor_dim = ann_dims.shape[1]

    while True:
        distances = []
        iteration += 1
        for i in range(ann_num):
            d = 1 - IOU(ann_dims[i], centroids)
            distances.append(d)
        distances = np.array(distances) # distances.shape = (ann_num, anchor_num)

        print("iteration {}: dists = {}".format(iteration, np.sum(np.abs(old_distances-distances))))

        #assign samples to centroids
        assignments = np.argmin(distances,axis=1)

        if (assignments == prev_assignments).all() :
            return centroids

        #calculate new centroids
        centroid_sums=np.zeros((anchor_num, anchor_dim), np.float)
        for i in range(ann_num):
            centroid_sums[assignments[i]]+=ann_dims[i]
        for j in range(anchor_num):
            centroids[j] = centroid_sums[j]/(np.sum(assignments==j) + 1e-6)

        prev_assignments = assignments.copy()
        old_distances = distances.copy()


num_anchors = 5 
grid_w = IMAGE_W/32
grid_h = IMAGE_H/32
annotation_dims = []
for image in train_imgs:
	cell_w = image['width']/grid_w
	cell_h = image['height']/grid_h

	for obj in image['object']:
		relative_w = (float(obj['xmax']) - float(obj['xmin']))/cell_w
		relatice_h = (float(obj["ymax"]) - float(obj['ymin']))/cell_h
		annotation_dims.append(tuple(map(float, (relative_w,relatice_h))))

annotation_dims = np.array(annotation_dims)
centroids = run_kmeans(annotation_dims, num_anchors)

# write anchors to file
print('\naverage IOU for', num_anchors, 'anchors:', '%0.2f' % avg_IOU(annotation_dims, centroids))
print_anchors(centroids)
# Out:
# iteration 1: dists = 50594.2710869373
# iteration 2: dists = 2806.6178598214306
# iteration 3: dists = 1193.63165800081
# iteration 4: dists = 945.2365676885569
# iteration 5: dists = 829.7617291442896
# iteration 6: dists = 755.4418637021166
# iteration 7: dists = 629.5720321792012
# iteration 8: dists = 517.4768538057162
# iteration 9: dists = 489.55072638441595
# iteration 10: dists = 404.26079280137697
# iteration 11: dists = 290.43377362171526
# iteration 12: dists = 268.1502688522566
# iteration 13: dists = 244.22719880397025
# iteration 14: dists = 200.87215843924668
# iteration 15: dists = 200.6854376291348
# iteration 16: dists = 184.2358061161207
# iteration 17: dists = 153.14438084199236
# iteration 18: dists = 114.10387420768387
# iteration 19: dists = 100.28517154532906
# iteration 20: dists = 108.72841284662726
# iteration 21: dists = 81.07378887346472
# iteration 22: dists = 78.21557329640483
# iteration 23: dists = 79.67142671903954
# iteration 24: dists = 61.961986401230064
# iteration 25: dists = 61.193482765423155
# iteration 26: dists = 52.14394559115895
# iteration 27: dists = 43.04985102520485
# iteration 28: dists = 46.67278227427394
# iteration 29: dists = 37.49736712775371
# iteration 30: dists = 28.52638716584495
# iteration 31: dists = 27.914907076422978
# iteration 32: dists = 19.095197134387366
# iteration 33: dists = 21.275249713989876
# iteration 34: dists = 10.761044166478277
# iteration 35: dists = 11.077904179539845
# iteration 36: dists = 9.313950501435706
# iteration 37: dists = 3.511038423669082
# iteration 38: dists = 3.6584241699710693
# iteration 39: dists = 6.166043154140901
# iteration 40: dists = 7.411221359522486
# iteration 41: dists = 3.7948103319377506
# iteration 42: dists = 7.738855246475623
# iteration 43: dists = 7.637644753461421
# iteration 44: dists = 11.87287057537057
# iteration 45: dists = 11.578466645326191
# iteration 46: dists = 9.080887224913672
# iteration 47: dists = 5.461221067052669
# iteration 48: dists = 4.921667190443507
# iteration 49: dists = 2.466320816762929
# iteration 50: dists = 2.805779160296655
# iteration 51: dists = 1.2460140459639364
# iteration 52: dists = 1.39055274388279
#
# average IOU for 5 anchors: 0.58
# anchors: [0.87,1.38, 2.32,3.32, 3.25,7.06, 6.57,7.56, 10.76,9.94]

# %%
#!wget https://docs.google.com/uc?export=download&id=1Q9WhhRlqQbA4jgBkCDrynvgquRXZA_f8
import requests

def download_file_from_google_drive(id, destination):
    def get_confirm_token(response):
        for key, value in response.cookies.items():
            if key.startswith('download_warning'):
                return value

        return None

    def save_response_content(response, destination):
        CHUNK_SIZE = 32768

        with open(destination, "wb") as f:
            for chunk in response.iter_content(CHUNK_SIZE):
                if chunk: # filter out keep-alive new chunks
                    f.write(chunk)

    URL = "https://docs.google.com/uc?export=download"

    session = requests.Session()

    response = session.get(URL, params = { 'id' : id }, stream = True)
    token = get_confirm_token(response)

    if token:
        params = { 'id' : id, 'confirm' : token }
        response = session.get(URL, params = params, stream = True)

    save_response_content(response, destination)    

download_file_from_google_drive("1Q9WhhRlqQbA4jgBkCDrynvgquRXZA_f8", "weights.h5")

# %%
train_batch = BatchGenerator(train_imgs, generator_config, norm=normalize)
valid_batch = BatchGenerator(val_imgs, generator_config, norm=normalize, jitter=False)

# %%
import sys
f = open("out.txt", "w")
def tf_print(op, tensors, message=None):
    def print_message(x):
        sys.stdout.write(message + " %s\n" % x)
        f.write(message + " %s\n" % x)
        return x

    prints = [tf.py_func(print_message, [tensor], tensor.dtype) for tensor in tensors]
    with tf.control_dependencies(prints):
        op = tf.identity(op)
    return op

def custom_loss(y_true, y_pred):
    mask_shape = tf.shape(y_true)[:4]
    
    cell_x = tf.to_float(tf.reshape(tf.tile(tf.range(GRID_W), [GRID_H]), (1, GRID_H, GRID_W, 1, 1)))
    cell_y = tf.transpose(cell_x, (0,2,1,3,4))

    cell_grid = tf.tile(tf.concat([cell_x,cell_y], -1), [BATCH_SIZE, 1, 1, 5, 1])
    
    coord_mask = tf.zeros(mask_shape)
    conf_mask  = tf.zeros(mask_shape)
    class_mask = tf.zeros(mask_shape)
    
    seen = tf.Variable(0.)
    total_recall = tf.Variable(0.)
    
    """
    Adjust prediction
    """
    ### adjust x and y      
    pred_box_xy = tf.sigmoid(y_pred[..., :2]) + cell_grid
    
    ### adjust w and h
    pred_box_wh = tf.exp(y_pred[..., 2:4]) * np.reshape(ANCHORS, [1,1,1,BOX,2])
    
    ### adjust confidence
    pred_box_conf = tf.sigmoid(y_pred[..., 4])
    
    ### adjust class probabilities
    pred_box_class = y_pred[..., 5:]
    
    """
    Adjust ground truth
    """
    ### adjust x and y
    true_box_xy = y_true[..., 0:2] # relative position to the containing cell
    
    ### adjust w and h
    true_box_wh = y_true[..., 2:4] # number of cells accross, horizontally and vertically
    
    ### adjust confidence
    true_wh_half = true_box_wh / 2.
    true_mins    = true_box_xy - true_wh_half
    true_maxes   = true_box_xy + true_wh_half
    
    pred_wh_half = pred_box_wh / 2.
    pred_mins    = pred_box_xy - pred_wh_half
    pred_maxes   = pred_box_xy + pred_wh_half       
    
    intersect_mins  = tf.maximum(pred_mins,  true_mins)
    intersect_maxes = tf.minimum(pred_maxes, true_maxes)
    intersect_wh    = tf.maximum(intersect_maxes - intersect_mins, 0.)
    intersect_areas = intersect_wh[..., 0] * intersect_wh[..., 1]
    
    true_areas = true_box_wh[..., 0] * true_box_wh[..., 1]
    pred_areas = pred_box_wh[..., 0] * pred_box_wh[..., 1]

    union_areas = pred_areas + true_areas - intersect_areas
    iou_scores  = tf.truediv(intersect_areas, union_areas)
    
    true_box_conf = iou_scores * y_true[..., 4]
    
    ### adjust class probabilities
    true_box_class = tf.argmax(y_true[..., 5:], -1)
    
    """
    Determine the masks
    """
    ### coordinate mask: simply the position of the ground truth boxes (the predictors)
    coord_mask = tf.expand_dims(y_true[..., 4], axis=-1) * COORD_SCALE
    
    ### confidence mask: penelize predictors + penalize boxes with low IOU
    # penalize the confidence of the boxes, which have IOU with some ground truth box < 0.6
    true_xy = true_boxes[..., 0:2]
    true_wh = true_boxes[..., 2:4]
    
    true_wh_half = true_wh / 2.
    true_mins    = true_xy - true_wh_half
    true_maxes   = true_xy + true_wh_half
    
    pred_xy = tf.expand_dims(pred_box_xy, 4)
    pred_wh = tf.expand_dims(pred_box_wh, 4)
    
    pred_wh_half = pred_wh / 2.
    pred_mins    = pred_xy - pred_wh_half
    pred_maxes   = pred_xy + pred_wh_half    
    
    intersect_mins  = tf.maximum(pred_mins,  true_mins)
    intersect_maxes = tf.minimum(pred_maxes, true_maxes)
    intersect_wh    = tf.maximum(intersect_maxes - intersect_mins, 0.)
    intersect_areas = intersect_wh[..., 0] * intersect_wh[..., 1]
    
    true_areas = true_wh[..., 0] * true_wh[..., 1]
    pred_areas = pred_wh[..., 0] * pred_wh[..., 1]

    union_areas = pred_areas + true_areas - intersect_areas
    iou_scores  = tf.truediv(intersect_areas, union_areas)

    best_ious = tf.reduce_max(iou_scores, axis=4)
    conf_mask = conf_mask + tf.to_float(best_ious < 0.6) * (1 - y_true[..., 4]) * NO_OBJECT_SCALE
    
    # penalize the confidence of the boxes, which are reponsible for corresponding ground truth box
    conf_mask = conf_mask + y_true[..., 4] * OBJECT_SCALE
    
    ### class mask: simply the position of the ground truth boxes (the predictors)
    class_mask = y_true[..., 4] * tf.gather(CLASS_WEIGHTS, true_box_class) * CLASS_SCALE       
    
    """
    Warm-up training
    """
    no_boxes_mask = tf.to_float(coord_mask < COORD_SCALE/2.)
    seen = tf.assign_add(seen, 1.)
    
    true_box_xy, true_box_wh, coord_mask = tf.cond(tf.less(seen, WARM_UP_BATCHES), 
                          lambda: [true_box_xy + (0.5 + cell_grid) * no_boxes_mask, 
                                   true_box_wh + tf.ones_like(true_box_wh) * np.reshape(ANCHORS, [1,1,1,BOX,2]) * no_boxes_mask, 
                                   tf.ones_like(coord_mask)],
                          lambda: [true_box_xy, 
                                   true_box_wh,
                                   coord_mask])
    
    """
    Finalize the loss
    """
    nb_coord_box = tf.reduce_sum(tf.to_float(coord_mask > 0.0))
    nb_conf_box  = tf.reduce_sum(tf.to_float(conf_mask  > 0.0))
    nb_class_box = tf.reduce_sum(tf.to_float(class_mask > 0.0))
    
    loss_xy    = tf.reduce_sum(tf.square(true_box_xy-pred_box_xy)     * coord_mask) / (nb_coord_box + 1e-6) / 2.
    loss_wh    = tf.reduce_sum(tf.square(true_box_wh-pred_box_wh)     * coord_mask) / (nb_coord_box + 1e-6) / 2.
    loss_conf  = tf.reduce_sum(tf.square(true_box_conf-pred_box_conf) * conf_mask)  / (nb_conf_box  + 1e-6) / 2.
    loss_class = tf.nn.sparse_softmax_cross_entropy_with_logits(labels=true_box_class, logits=pred_box_class)
    loss_class = tf.reduce_sum(loss_class * class_mask) / (nb_class_box + 1e-6)
    
    loss_xy = tf.clip_by_value(loss_xy, 0, 10000000)
    loss_wh = tf.clip_by_value(loss_wh, 0, 10000000)  
    loss_conf = tf.clip_by_value(loss_conf, 0, 10000000)
    loss_class = tf.clip_by_value(loss_class, 0, 10000000)
    loss = loss_xy + loss_wh + loss_conf + loss_class
    
    nb_true_box = tf.reduce_sum(y_true[..., 4])
    nb_pred_box = tf.reduce_sum(tf.to_float(true_box_conf > 0.5) * tf.to_float(pred_box_conf > 0.3))

    """
    Debugging code
    """    
    current_recall = nb_pred_box/(nb_true_box + 1e-6)
    total_recall = tf.assign_add(total_recall, current_recall) 

    loss = tf_print(loss, [tf.zeros((1))], message='Dummy Line \t')
    loss = tf_print(loss, [loss_xy], message='Loss XY \t')
    loss = tf_print(loss, [loss_wh], message='Loss WH \t')
    loss = tf_print(loss, [loss_conf], message='Loss Conf \t')
    loss = tf_print(loss, [loss_class], message='Loss Class \t')
    loss = tf_print(loss, [loss], message='Total Loss \t')
    loss = tf_print(loss, [current_recall], message='Current Recall \t')
    loss = tf_print(loss, [total_recall/seen], message='Average Recall \t')
    
    return loss

# %%
from keras.callbacks import EarlyStopping, ModelCheckpoint, TensorBoard
early_stop = EarlyStopping(monitor='val_loss', 
                           min_delta=0.001, 
                           patience=3, 
                           mode='min', 
                           verbose=1)

checkpoint = ModelCheckpoint('weights_coco.h5', 
                             monitor='val_loss', 
                             verbose=1, 
                             save_best_only=True, 
                             mode='min', 
                             period=1)

# %%
from keras.models import Sequential, Model
from keras.layers.advanced_activations import LeakyReLU
from keras.layers.merge import concatenate
from keras.layers import Reshape, Activation, Conv2D, Input, MaxPooling2D, BatchNormalization, Flatten, Dense, Lambda
def space_to_depth_x2(x):
    return tf.space_to_depth(x, block_size=2)
input_image = Input(shape=(IMAGE_H, IMAGE_W, 3))
true_boxes  = Input(shape=(1, 1, 1, TRUE_BOX_BUFFER , 4))

# Layer 1
x = Conv2D(32, (3,3), strides=(1,1), padding='same', name='conv_1', use_bias=False)(input_image)
x = BatchNormalization(name='norm_1')(x)
x = LeakyReLU(alpha=0.1)(x)
x = MaxPooling2D(pool_size=(2, 2))(x)

# Layer 2
x = Conv2D(64, (3,3), strides=(1,1), padding='same', name='conv_2', use_bias=False)(x)
x = BatchNormalization(name='norm_2')(x)
x = LeakyReLU(alpha=0.1)(x)
x = MaxPooling2D(pool_size=(2, 2))(x)

# Layer 3
x = Conv2D(128, (3,3), strides=(1,1), padding='same', name='conv_3', use_bias=False)(x)
x = BatchNormalization(name='norm_3')(x)
x = LeakyReLU(alpha=0.1)(x)

# Layer 4
x = Conv2D(64, (1,1), strides=(1,1), padding='same', name='conv_4', use_bias=False)(x)
x = BatchNormalization(name='norm_4')(x)
x = LeakyReLU(alpha=0.1)(x)

# Layer 5
x = Conv2D(128, (3,3), strides=(1,1), padding='same', name='conv_5', use_bias=False)(x)
x = BatchNormalization(name='norm_5')(x)
x = LeakyReLU(alpha=0.1)(x)
x = MaxPooling2D(pool_size=(2, 2))(x)

# Layer 6
x = Conv2D(256, (3,3), strides=(1,1), padding='same', name='conv_6', use_bias=False)(x)
x = BatchNormalization(name='norm_6')(x)
x = LeakyReLU(alpha=0.1)(x)

# Layer 7
x = Conv2D(128, (1,1), strides=(1,1), padding='same', name='conv_7', use_bias=False)(x)
x = BatchNormalization(name='norm_7')(x)
x = LeakyReLU(alpha=0.1)(x)

# Layer 8
x = Conv2D(256, (3,3), strides=(1,1), padding='same', name='conv_8', use_bias=False)(x)
x = BatchNormalization(name='norm_8')(x)
x = LeakyReLU(alpha=0.1)(x)
x = MaxPooling2D(pool_size=(2, 2))(x)

# Layer 9
x = Conv2D(512, (3,3), strides=(1,1), padding='same', name='conv_9', use_bias=False)(x)
x = BatchNormalization(name='norm_9')(x)
x = LeakyReLU(alpha=0.1)(x)

# Layer 10
x = Conv2D(256, (1,1), strides=(1,1), padding='same', name='conv_10', use_bias=False)(x)
x = BatchNormalization(name='norm_10')(x)
x = LeakyReLU(alpha=0.1)(x)

# Layer 11
x = Conv2D(512, (3,3), strides=(1,1), padding='same', name='conv_11', use_bias=False)(x)
x = BatchNormalization(name='norm_11')(x)
x = LeakyReLU(alpha=0.1)(x)

# Layer 12
x = Conv2D(256, (1,1), strides=(1,1), padding='same', name='conv_12', use_bias=False)(x)
x = BatchNormalization(name='norm_12')(x)
x = LeakyReLU(alpha=0.1)(x)

# Layer 13
x = Conv2D(512, (3,3), strides=(1,1), padding='same', name='conv_13', use_bias=False)(x)
x = BatchNormalization(name='norm_13')(x)
x = LeakyReLU(alpha=0.1)(x)

skip_connection = x

x = MaxPooling2D(pool_size=(2, 2))(x)

# Layer 14
x = Conv2D(1024, (3,3), strides=(1,1), padding='same', name='conv_14', use_bias=False)(x)
x = BatchNormalization(name='norm_14')(x)
x = LeakyReLU(alpha=0.1)(x)

# Layer 15
x = Conv2D(512, (1,1), strides=(1,1), padding='same', name='conv_15', use_bias=False)(x)
x = BatchNormalization(name='norm_15')(x)
x = LeakyReLU(alpha=0.1)(x)

# Layer 16
x = Conv2D(1024, (3,3), strides=(1,1), padding='same', name='conv_16', use_bias=False)(x)
x = BatchNormalization(name='norm_16')(x)
x = LeakyReLU(alpha=0.1)(x)

# Layer 17
x = Conv2D(512, (1,1), strides=(1,1), padding='same', name='conv_17', use_bias=False)(x)
x = BatchNormalization(name='norm_17')(x)
x = LeakyReLU(alpha=0.1)(x)

# Layer 18
x = Conv2D(1024, (3,3), strides=(1,1), padding='same', name='conv_18', use_bias=False)(x)
x = BatchNormalization(name='norm_18')(x)
x = LeakyReLU(alpha=0.1)(x)

# Layer 19
x = Conv2D(1024, (3,3), strides=(1,1), padding='same', name='conv_19', use_bias=False)(x)
x = BatchNormalization(name='norm_19')(x)
x = LeakyReLU(alpha=0.1)(x)

# Layer 20
x = Conv2D(1024, (3,3), strides=(1,1), padding='same', name='conv_20', use_bias=False)(x)
x = BatchNormalization(name='norm_20')(x)
x = LeakyReLU(alpha=0.1)(x)

# Layer 21
skip_connection = Conv2D(64, (1,1), strides=(1,1), padding='same', name='conv_21', use_bias=False)(skip_connection)
skip_connection = BatchNormalization(name='norm_21')(skip_connection)
skip_connection = LeakyReLU(alpha=0.1)(skip_connection)
skip_connection = Lambda(space_to_depth_x2)(skip_connection)

x = concatenate([skip_connection, x])

# Layer 22
x = Conv2D(1024, (3,3), strides=(1,1), padding='same', name='conv_22', use_bias=False)(x)
x = BatchNormalization(name='norm_22')(x)
x = LeakyReLU(alpha=0.1)(x)
model = Model(input_image, x)  
feature_extractor = Model(model.layers[0].input, model.layers[-1].output)
feature_extractor.load_weights("weights.h5")
for layer in feature_extractor.layers:
    layer.trainable = False
# Layer 23
x = Conv2D(BOX * (4 + 1 + CLASS), (1,1), strides=(1,1), padding='same', name='conv_23')(feature_extractor.layers[-1].output)
output = Reshape((GRID_H, GRID_W, BOX, 4 + 1 + CLASS))(x)

# small hack to allow true_boxes to be registered when Keras build the model 
# for more information: https://github.com/fchollet/keras/issues/2790
output = Lambda(lambda args: args[0])([output, true_boxes])

model = Model([input_image, true_boxes], output)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
from keras.optimizers import SGD, Adam, RMSprop
optimizer = Adam(lr=0.5e-4, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
#optimizer = SGD(lr=1e-4, decay=0.0005, momentum=0.9)
#optimizer = RMSprop(lr=1e-4, rho=0.9, epsilon=1e-08, decay=0.0)
tb_counter  = len([log for log in os.listdir(os.path.expanduser('~/logs/')) if 'coco_' in log]) + 1
tensorboard = TensorBoard(log_dir=os.path.expanduser('~/logs/') + 'coco_' + '_' + str(tb_counter), 
                          histogram_freq=0, 
                          write_graph=True, 
                          write_images=False)
model.compile(loss=custom_loss, optimizer=optimizer)

model.fit_generator(generator        = train_batch, 
                    steps_per_epoch  = len(train_batch), 
                    epochs           = 3, 
                    verbose          = 1,
                    validation_data  = valid_batch,
                    validation_steps = len(valid_batch),
                    callbacks        = [checkpoint], 
                    max_queue_size   = 3)
model.save_weights("warmup.h5")
# Out:
# '\nmodel.compile(loss=custom_loss, optimizer=optimizer)\n\nmodel.fit_generator(generator        = train_batch, \n                    steps_per_epoch  = len(train_batch), \n                    epochs           = 3, \n                    verbose          = 1,\n                    validation_data  = valid_batch,\n                    validation_steps = len(valid_batch),\n                    callbacks        = [checkpoint], \n                    max_queue_size   = 3)\nmodel.save_weights("warmup.h5")\n'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !cp warmup.h5 drive/'My Drive'/

# %%
model.load_weights("warmup.h5")
model.compile(loss=custom_loss, optimizer=optimizer)

model.fit_generator(initial_epoch    = 3,
                    generator        = train_batch, 
                    steps_per_epoch  = len(train_batch), 
                    epochs           = 25, 
                    verbose          = 1,
                    validation_data  = valid_batch,
                    validation_steps = len(valid_batch),
                    callbacks        = [checkpoint], 
                    max_queue_size   = 3)
model.save_weights("weights_25.h5")

# %%
model.load_weights("weights_25.h5")
model.compile(loss=custom_loss, optimizer=optimizer)
model.fit_generator(initial_epoch    = 25,
                    generator        = train_batch, 
                    steps_per_epoch  = len(train_batch), 
                    epochs           = 50, 
                    verbose          = 1,
                    validation_data  = valid_batch,
                    validation_steps = len(valid_batch),
                    callbacks        = [checkpoint], 
                    max_queue_size   = 3)
model.save_weights("weights_50.h5")

# %%
model.load_weights("weights_50.h5")
model.compile(loss=custom_loss, optimizer=optimizer)
model.fit_generator(initial_epoch    = 50,
                    generator        = train_batch, 
                    steps_per_epoch  = len(train_batch), 
                    epochs           = 75, 
                    verbose          = 1,
                    validation_data  = valid_batch,
                    validation_steps = len(valid_batch),
                    callbacks        = [checkpoint], 
                    max_queue_size   = 3)
model.save_weights("weights_75.h5")
# !cp weights_75.h5 drive/'My Drive'/

# %%
model.load_weights("weights_75.h5")
model.compile(loss=custom_loss, optimizer=optimizer)
model.fit_generator(initial_epoch    = 75,
                    generator        = train_batch, 
                    steps_per_epoch  = len(train_batch), 
                    epochs           = 100, 
                    verbose          = 1,
                    validation_data  = valid_batch,
                    validation_steps = len(valid_batch),
                    callbacks        = [checkpoint], 
                    max_queue_size   = 3)
model.save_weights("weights_100.h5")
# !cp weights_100.h5 drive/'My Drive'/
# Out:
# Dummy Line 	 [0.]
# Loss XY 	 0.035482034
# Loss WH 	 1.195786
# Loss Conf 	 0.001969253
# Average Recall 	 0.50110877
# Current Recall 	 0.54
# Loss Class 	 0.29544613
# Total Loss 	 1.5286834
# 171/251 [===================>..........] - ETA: 36s - loss: 1.4913Dummy Line 	 [0.]
# Loss WH 	 1.0352868
# Loss XY 	 0.04986511
# Current Recall 	 0.38235295
# Average Recall 	 0.5010859
# Loss Conf 	 0.0021140033
# Loss Class 	 0.71620774
# Total Loss 	 1.8034737
# 172/251 [===================>..........] - ETA: 35s - loss: 1.4931Dummy Line 	 [0.]
# Loss WH 	 1.906614
# Loss XY 	 0.03946885
# Current Recall 	 0.75757575
# Average Recall 	 0.50113523
# Loss Conf 	 0.001039912
# Loss Class 	 0.46807697
# Total Loss 	 2.4151998
# 173/251 [===================>..........] - ETA: 35s - loss: 1.4984Dummy Line 	 [0.]
# Loss XY 	 0.04151685
# Loss WH 	 0.94910324
# Average Recall 	 0.50115967
# Loss Conf 	 0.0012846004
# Current Recall 	 0.627907
# Loss Class 	 0.3137126
# Total Loss 	 1.3056173
# 174/251 [===================>..........] - ETA: 35s - loss: 1.4973Dummy Line 	 [0.]
# Loss WH 	 0.52653223
# Loss XY 	 0.033642966
# Current Recall 	 0.6486486
# Average Recall 	 0.50118804
# Loss Conf 	 0.0012509117
# Loss Class 	 0.3218619
# Total Loss 	 0.883288
# 175/251 [===================>..........] - ETA: 34s - loss: 1.4938Dummy Line 	 [0.]
# Loss XY 	 0.04319883
# Loss WH 	 0.8610468
# Loss Conf 	 0.0021811733
# Average Recall 	 0.5011915
# Current Recall 	 0.5192308
# Loss Class 	 0.46160907
# Total Loss 	 1.3680358
# 176/251 [====================>.........] - ETA: 34s - loss: 1.4931Dummy Line 	 [0.]
# Current Recall 	 0.54545456
# Average Recall 	 0.5012
# Loss XY 	 0.04631002
# Loss WH 	 1.7083592
# Loss Conf 	 0.0012613363
# Loss Class 	 0.23092799
# Total Loss 	 1.9868586
# 177/251 [====================>.........] - ETA: 33s - loss: 1.4959Dummy Line 	 [0.]
# Loss WH 	 0.8525408
# Loss XY 	 0.044592503
# Current Recall 	 0.475
# Average Recall 	 0.501195
# Loss Conf 	 0.0014335106
# Loss Class 	 0.6739279
# Total Loss 	 1.5724947
# 178/251 [====================>.........] - ETA: 33s - loss: 1.4963Dummy Line 	 [0.]
# Loss XY 	 0.037391372
# Current Recall 	 0.48214287
# Average Recall 	 0.5011913
# Loss WH 	 0.94786125
# Loss Conf 	 0.0019422385
# Loss Class 	 0.38196406
# Total Loss 	 1.3691589
# 179/251 [====================>.........] - ETA: 32s - loss: 1.4956Dummy Line 	 [0.]
# Loss WH 	 0.85535365
# Loss XY 	 0.0388434
# Current Recall 	 0.5294118
# Average Recall 	 0.50119674
# Loss Conf 	 0.0017170442
# Loss Class 	 0.15395507
# Total Loss 	 1.0498692
# 180/251 [====================>.........] - ETA: 32s - loss: 1.4931Dummy Line 	 [0.]
# Loss WH 	 1.4697466
# Loss XY 	 0.05951464
# Current Recall 	 0.79999995
# Average Recall 	 0.50125414
# Loss Conf 	 0.0008296067
# Loss Class 	 0.30148938
# Total Loss 	 1.8315802
# 181/251 [====================>.........] - ETA: 31s - loss: 1.4950Dummy Line 	 [0.]
# Loss WH 	 0.95405084
# Loss XY 	 0.051475253
# Current Recall 	 0.33802816
# Average Recall 	 0.5012228
# Loss Conf 	 0.0033721374
# Loss Class 	 0.61160415
# Total Loss 	 1.6205025
# 182/251 [====================>.........] - ETA: 31s - loss: 1.4957Dummy Line 	 [0.]
# Loss WH 	 0.91395164
# Loss XY 	 0.048041873
# Current Recall 	 0.4680851
# Average Recall 	 0.5012164
# Loss Conf 	 0.0012849781
# Loss Class 	 0.4911313
# Total Loss 	 1.4544098
# 183/251 [====================>.........] - ETA: 30s - loss: 1.4954Dummy Line 	 [0.]
# Loss WH 	 1.255931
# Loss XY 	 0.040008
# Loss Conf 	 0.0015249061
# Current Recall 	 0.4893617
# Average Recall 	 0.50121415
# Loss Class 	 0.37207583
# Total Loss 	 1.6695397
# 184/251 [====================>.........] - ETA: 30s - loss: 1.4964Dummy Line 	 [0.]
# Loss WH 	 0.8857213
# Loss XY 	 0.050844163
# Current Recall 	 0.36842105
# Average Recall 	 0.50118864
# Loss Conf 	 0.0023276308
# Loss Class 	 0.59066653
# Total Loss 	 1.5295596
# 185/251 [=====================>........] - ETA: 29s - loss: 1.4966Dummy Line 	 [0.]
# Loss WH 	 1.1190189
# Loss XY 	 0.060977392
# Current Recall 	 0.3220339
# Average Recall 	 0.50115424
# Loss Conf 	 0.002399549
# Loss Class 	 0.47205794
# Total Loss 	 1.6544538
# 186/251 [=====================>........] - ETA: 29s - loss: 1.4974Dummy Line 	 [0.]
# Loss XY 	 0.04695544
# Loss WH 	 1.2879007
# Average Recall 	 0.501143
# Loss Conf 	 0.0020602525
# Current Recall 	 0.44230768
# Loss Class 	 0.55155003
# Total Loss 	 1.8884665
# 187/251 [=====================>........] - ETA: 29s - loss: 1.4995Dummy Line 	 [0.]
# Loss WH 	 1.1831092
# Loss XY 	 0.040947285
# Current Recall 	 0.4680851
# Average Recall 	 0.5011366
# Loss Conf 	 0.0020588196
# Loss Class 	 0.39367107
# Total Loss 	 1.6197864
# 188/251 [=====================>........] - ETA: 28s - loss: 1.5002Dummy Line 	 [0.]
# Loss WH 	 0.7075275
# Loss XY 	 0.043004498
# Current Recall 	 0.5441176
# Average Recall 	 0.5011449
# Loss Conf 	 0.00228232
# Total Loss 	 0.973599
# Loss Class 	 0.22078468
# 189/251 [=====================>........] - ETA: 28s - loss: 1.4974Dummy Line 	 [0.]
# Loss WH 	 1.1610341
# Loss XY 	 0.05421691
# Current Recall 	 0.41666666
# Loss Conf 	 0.0017965457
# Average Recall 	 0.5011287
# Loss Class 	 0.6247334
# Total Loss 	 1.8417809
# 190/251 [=====================>........] - ETA: 27s - loss: 1.4992Dummy Line 	 [0.]
# Loss WH 	 0.7859734
# Loss XY 	 0.047711607
# Current Recall 	 0.5510204
# Average Recall 	 0.50113827
# Loss Conf 	 0.0015131269
# Loss Class 	 0.48856673
# Total Loss 	 1.3237649
# 191/251 [=====================>........] - ETA: 27s - loss: 1.4983Dummy Line 	 [0.]
# Loss WH 	 1.7642623
# Loss XY 	 0.03193098
# Loss Conf 	 0.0010605875
# Average Recall 	 0.5011758
# Current Recall 	 0.6969697
# Loss Class 	 0.3039963
# Total Loss 	 2.1012502
# 192/251 [=====================>........] - ETA: 26s - loss: 1.5014Dummy Line 	 [0.]
# Loss WH 	 1.020614
# Current Recall 	 0.4915254
# Average Recall 	 0.501174
# Loss Conf 	 0.0023686062
# Loss XY 	 0.03600789
# Loss Class 	 0.23335351
# Total Loss 	 1.292344
# 193/251 [======================>.......] - ETA: 26s - loss: 1.5003Dummy Line 	 [0.]
# Loss XY 	 0.048666544
# Current Recall 	 0.5
# Loss WH 	 1.0086818
# Average Recall 	 0.50117373
# Loss Conf 	 0.0017351396
# Loss Class 	 0.33589673
# Total Loss 	 1.3949802
# 194/251 [======================>.......] - ETA: 25s - loss: 1.4998Dummy Line 	 [0.]
# Loss XY 	 0.03438568
# Current Recall 	 0.47619048
# Average Recall 	 0.5011689
# Loss WH 	 1.9024187
# Loss Conf 	 0.0014733503
# Loss Class 	 0.56934917
# Total Loss 	 2.507627
# 195/251 [======================>.......] - ETA: 25s - loss: 1.5049Dummy Line 	 [0.]
# Loss WH 	 1.2420322
# Loss XY 	 0.053723276
# Current Recall 	 0.45454547
# Average Recall 	 0.50115997
# Loss Conf 	 0.0013415416
# Loss Class 	 0.50622696
# Total Loss 	 1.803324
# 196/251 [======================>.......] - ETA: 24s - loss: 1.5065Dummy Line 	 [0.]
# Loss WH 	 0.6423642
# Loss XY 	 0.04364832
# Current Recall 	 0.3181818
# Average Recall 	 0.5011249
# Loss Conf 	 0.0031052846
# Loss Class 	 0.30186698
# Total Loss 	 0.9909848
# 197/251 [======================>.......] - ETA: 24s - loss: 1.5038Dummy Line 	 [0.]
# Loss XY 	 0.03890241
# Loss WH 	 0.8140073
# Current Recall 	 0.63414633
# Average Recall 	 0.50115037
# Loss Conf 	 0.0015087827
# Loss Class 	 0.9759994
# Total Loss 	 1.8304179
# 198/251 [======================>.......] - ETA: 24s - loss: 1.5055Dummy Line 	 [0.]
# Loss WH 	 1.0634863
# Loss XY 	 0.033501923
# Current Recall 	 0.52459013
# Average Recall 	 0.5011549
# Loss Conf 	 0.0020198184
# Loss Class 	 0.26702017
# Total Loss 	 1.3660281
# 199/251 [======================>.......] - ETA: 23s - loss: 1.5048Dummy Line 	 [0.]
# Loss WH 	 0.9845156
# Loss XY 	 0.047216833
# Current Recall 	 0.6666667
# Average Recall 	 0.5011866
# Loss Conf 	 0.0011756286
# Loss Class 	 0.33528483
# Total Loss 	 1.3681929
# 200/251 [======================>.......] - ETA: 23s - loss: 1.5041Dummy Line 	 [0.]
# Loss WH 	 0.84528136
# Loss XY 	 0.061407797
# Current Recall 	 0.35849056
# Average Recall 	 0.50115925
# Loss Conf 	 0.0021639613
# Loss Class 	 0.65559393
# Total Loss 	 1.564447
# 201/251 [=======================>......] - ETA: 22s - loss: 1.5044Dummy Line 	 [0.]
# Loss WH 	 1.3948303
# Loss XY 	 0.051114578
# Current Recall 	 0.38
# Average Recall 	 0.50113606
# Loss Conf 	 0.0015648408
# Loss Class 	 0.3634453
# Total Loss 	 1.810955
# 202/251 [=======================>......] - ETA: 22s - loss: 1.5059Dummy Line 	 [0.]
# Loss WH 	 0.90628934
# Loss XY 	 0.051120713
# Current Recall 	 0.4909091
# Average Recall 	 0.5011341
# Loss Conf 	 0.0016977497
# Loss Class 	 0.25728634
# Total Loss 	 1.2163942
# 203/251 [=======================>......] - ETA: 21s - loss: 1.5045Dummy Line 	 [0.]
# Loss XY 	 0.046735387
# Average Recall 	 0.5011386
# Loss Conf 	 0.0012999478
# Loss WH 	 0.9786972
# Current Recall 	 0.525
# Loss Class 	 0.5603136
# Total Loss 	 1.5870461
# 204/251 [=======================>......] - ETA: 21s - loss: 1.5049Dummy Line 	 [0.]
# Loss XY 	 0.037662454
# Loss WH 	 1.2069466
# Loss Conf 	 0.002116468
# Average Recall 	 0.50111765
# Current Recall 	 0.39130434
# Loss Class 	 0.38428405
# Total Loss 	 1.6310096
# 205/251 [=======================>......] - ETA: 20s - loss: 1.5055Dummy Line 	 [0.]
# Loss WH 	 1.2319971
# Loss XY 	 0.04029713
# Current Recall 	 0.56363636
# Average Recall 	 0.5011296
# Loss Conf 	 0.0020001503
# Loss Class 	 0.2229728
# Total Loss 	 1.4972671
# 206/251 [=======================>......] - ETA: 20s - loss: 1.5055Dummy Line 	 [0.]
# Loss WH 	 1.0251726
# Loss XY 	 0.031764574
# Current Recall 	 0.53333336
# Loss Conf 	 0.0017454284
# Loss Class 	 0.2858644
# Average Recall 	 0.5011358
# Total Loss 	 1.344547
# 207/251 [=======================>......] - ETA: 19s - loss: 1.5047Dummy Line 	 [0.]
# Loss WH 	 1.1527764
# Loss XY 	 0.05227064
# Current Recall 	 0.4181818
# Average Recall 	 0.50112
# Loss Conf 	 0.0019573425
# Loss Class 	 0.5279619
# Total Loss 	 1.7349663
# 208/251 [=======================>......] - ETA: 19s - loss: 1.5058Dummy Line 	 [0.]
# Loss WH 	 0.6706006
# Loss XY 	 0.054068986
# Current Recall 	 0.37254903
# Average Recall 	 0.5010954
# Loss Conf 	 0.002278817
# Total Loss 	 1.2814722
# Loss Class 	 0.5545239
# 209/251 [=======================>......] - ETA: 19s - loss: 1.5047Dummy Line 	 [0.]
# Loss WH 	 1.2796264
# Loss XY 	 0.04874467
# Average Recall 	 0.5011033
# Current Recall 	 0.5423729
# Loss Conf 	 0.0018332696
# Loss Class 	 0.4094121
# Total Loss 	 1.7396164
# 210/251 [========================>.....] - ETA: 18s - loss: 1.5059Dummy Line 	 [0.]
# Loss WH 	 0.83387303
# Loss XY 	 0.039800677
# Average Recall 	 0.5011147
# Loss Conf 	 0.0015053232
# Current Recall 	 0.5609756
# Loss Class 	 0.3906372
# Total Loss 	 1.2658162
# 211/251 [========================>.....] - ETA: 18s - loss: 1.5047Dummy Line 	 [0.]
# Loss WH 	 1.2075678
# Loss XY 	 0.04166655
# Loss Class 	 0.46149728
# Current Recall 	 0.47457626
# Loss Conf 	 0.0024944933
# Total Loss 	 1.7132261
# Average Recall 	 0.50110966
# 212/251 [========================>.....] - ETA: 17s - loss: 1.5057Dummy Line 	 [0.]
# Loss XY 	 0.030644905
# Loss WH 	 0.8990673
# Current Recall 	 0.46666667
# Average Recall 	 0.5011031
# Loss Conf 	 0.0013947939
# Loss Class 	 0.223321
# Total Loss 	 1.154428
# 213/251 [========================>.....] - ETA: 17s - loss: 1.5041Dummy Line 	 [0.]
# Loss XY 	 0.05436252
# Loss WH 	 0.76013947
# Average Recall 	 0.5010768
# Current Recall 	 0.36363637
# Loss Conf 	 0.002476327
# Loss Class 	 0.49405405
# Total Loss 	 1.3110324
# 214/251 [========================>.....] - ETA: 16s - loss: 1.5032Dummy Line 	 [0.]
# Loss WH 	 0.6399224
# Loss XY 	 0.036328156
# Current Recall 	 0.5074627
# Average Recall 	 0.50107807
# Loss Conf 	 0.0024121648
# Loss Class 	 0.2356135
# Total Loss 	 0.9142761
# 215/251 [========================>.....] - ETA: 16s - loss: 1.5004Dummy Line 	 [0.]
# Loss WH 	 0.7074254
# Loss XY 	 0.047673687
# Current Recall 	 0.5
# Average Recall 	 0.50107783
# Loss Conf 	 0.0017691824
# Loss Class 	 0.7133067
# Total Loss 	 1.470175
# 216/251 [========================>.....] - ETA: 15s - loss: 1.5003Dummy Line 	 [0.]
# Loss Conf 	 0.0024945429
# Average Recall 	 0.5010644
# Current Recall 	 0.43076923
# Loss XY 	 0.0455588
# Loss WH 	 1.0408387
# Loss Class 	 0.4136377
# Total Loss 	 1.5025299
# 217/251 [========================>.....] - ETA: 15s - loss: 1.5003Dummy Line 	 [0.]
# Loss WH 	 1.1494466
# Loss XY 	 0.052890588
# Current Recall 	 0.48
# Average Recall 	 0.50106037
# Loss Conf 	 0.0017884148
# Loss Class 	 0.2825694
# Total Loss 	 1.4866949
# 218/251 [=========================>....] - ETA: 14s - loss: 1.5002Dummy Line 	 [0.]
# Loss WH 	 0.9592557
# Loss XY 	 0.041870575
# Loss Conf 	 0.0018086169
# Average Recall 	 0.5010478
# Current Recall 	 0.4347826
# Loss Class 	 0.38274118
# Total Loss 	 1.3856761
# 219/251 [=========================>....] - ETA: 14s - loss: 1.4997Loss WH 	 1.1379151
# Loss XY 	 0.050794713
# Current Recall 	 0.4651163
# Average Recall 	 0.5010409
# Dummy Line 	 [0.]
# Loss Class 	 0.45622045
# Loss Conf 	 0.0013028926
# Total Loss 	 1.6462331
# 220/251 [=========================>....] - ETA: 14s - loss: 1.5004Dummy Line 	 [0.]
# Loss WH 	 1.1678149
# Loss XY 	 0.04155103
# Average Recall 	 0.50102293
# Loss Conf 	 0.0023870543
# Current Recall 	 0.40677965
# Loss Class 	 0.32909915
# Total Loss 	 1.5408521
# 221/251 [=========================>....] - ETA: 13s - loss: 1.5005Dummy Line 	 [0.]
# Loss WH 	 1.2529392
# Loss XY 	 0.04302164
# Current Recall 	 0.54545456
# Average Recall 	 0.5010314
# Loss Conf 	 0.0013016352
# Loss Class 	 0.3647492
# Total Loss 	 1.6620117
# 222/251 [=========================>....] - ETA: 13s - loss: 1.5013Dummy Line 	 [0.]
# Loss WH 	 0.9009583
# Loss XY 	 0.044333216
# Average Recall 	 0.501017
# Loss Conf 	 0.0017951924
# Current Recall 	 0.42553192
# Loss Class 	 0.5250846
# Total Loss 	 1.4721713
# 223/251 [=========================>....] - ETA: 12s - loss: 1.5011Dummy Line 	 [0.]
# Loss WH 	 0.9899983
# Loss XY 	 0.05615025
# Current Recall 	 0.47457626
# Average Recall 	 0.50101197
# Loss Conf 	 0.002487953
# Loss Class 	 0.42270264
# Total Loss 	 1.4713391
# 224/251 [=========================>....] - ETA: 12s - loss: 1.5010Dummy Line 	 [0.]
# Loss WH 	 1.2252147
# Loss XY 	 0.03887955
# Current Recall 	 0.46
# Loss Conf 	 0.0015841239
# Loss Class 	 0.42680982
# Average Recall 	 0.50100416
# Total Loss 	 1.6924882
# 225/251 [=========================>....] - ETA: 11s - loss: 1.5019Dummy Line 	 [0.]
# Loss WH 	 0.6885202
# Loss XY 	 0.04341297
# Current Recall 	 0.49253732
# Average Recall 	 0.5010025
# Loss Conf 	 0.0024467276
# Loss Class 	 0.47752336
# Total Loss 	 1.2119032
# 226/251 [==========================>...] - ETA: 11s - loss: 1.5006Dummy Line 	 [0.]
# Loss WH 	 1.4155973
# Loss XY 	 0.044622466
# Current Recall 	 0.4722222
# Average Recall 	 0.500997
# Loss Conf 	 0.0014094063
# Loss Class 	 0.5936091
# Total Loss 	 2.0552382
# 227/251 [==========================>...] - ETA: 10s - loss: 1.5030Dummy Line 	 [0.]
# Loss WH 	 0.7334595
# Loss XY 	 0.059628166
# Current Recall 	 0.47727272
# Average Recall 	 0.50099254
# Loss Conf 	 0.002044559
# Loss Class 	 0.27493975
# Total Loss 	 1.0700719
# 228/251 [==========================>...] - ETA: 10s - loss: 1.5011Dummy Line 	 [0.]
# Loss WH 	 1.333608
# Loss XY 	 0.05124996
# Current Recall 	 0.325
# Average Recall 	 0.500959
# Loss Conf 	 0.0027976064
# Loss Class 	 0.3661438
# Total Loss 	 1.7537994
# 229/251 [==========================>...] - ETA: 9s - loss: 1.5022 Dummy Line 	 [0.]
# Loss WH 	 0.8990959
# Loss XY 	 0.03776197
# Average Recall 	 0.50096065
# Loss Conf 	 0.0018080989
# Current Recall 	 0.50980395
# Loss Class 	 0.24885327
# Total Loss 	 1.1875193
# 230/251 [==========================>...] - ETA: 9s - loss: 1.5009Dummy Line 	 [0.]
# Loss WH 	 1.231938
# Loss XY 	 0.0499765
# Loss Conf 	 0.0028724957
# Average Recall 	 0.50092274
# Current Recall 	 0.3015873
# Loss Class 	 0.3083294
# Total Loss 	 1.5931163
# 231/251 [==========================>...] - ETA: 9s - loss: 1.5013Dummy Line 	 [0.]
# Loss WH 	 0.8814399
# Loss XY 	 0.039728586
# Current Recall 	 0.42
# Average Recall 	 0.5009073
# Loss Conf 	 0.0018838984
# Loss Class 	 0.3880938
# Total Loss 	 1.3111463
# 232/251 [==========================>...] - ETA: 8s - loss: 1.5004Dummy Line 	 [0.]
# Loss WH 	 0.81156534
# Loss XY 	 0.0555222
# Current Recall 	 0.55813956
# Average Recall 	 0.5009182
# Loss Conf 	 0.0014463082
# Loss Class 	 0.4198352
# Total Loss 	 1.288369
# 233/251 [==========================>...] - ETA: 8s - loss: 1.4995Dummy Line 	 [0.]
# Loss WH 	 0.92567736
# Loss XY 	 0.043243542
# Current Recall 	 0.4909091
# Average Recall 	 0.5009163
# Loss Conf 	 0.0019497557
# Loss Class 	 0.35161886
# Total Loss 	 1.3224895
# 234/251 [==========================>...] - ETA: 7s - loss: 1.4988Dummy Line 	 [0.]
# Loss WH 	 0.7423727
# Current Recall 	 0.5714286
# Loss XY 	 0.041957684
# Average Recall 	 0.5009297
# Loss Conf 	 0.0017632347
# Loss Class 	 0.31255713
# Total Loss 	 1.0986507
# 235/251 [===========================>..] - ETA: 7s - loss: 1.4971Dummy Line 	 [0.]
# Loss WH 	 1.1322854
# Loss XY 	 0.04727254
# Current Recall 	 0.54545456
# Loss Conf 	 0.0017636234
# Loss Class 	 0.3146262
# Average Recall 	 0.5009382
# Total Loss 	 1.4959477
# 236/251 [===========================>..] - ETA: 6s - loss: 1.4971Dummy Line 	 [0.]
# Loss WH 	 0.9312285
# Loss XY 	 0.05543252
# Current Recall 	 0.49122807
# Average Recall 	 0.5009363
# Loss Conf 	 0.001662941
# Loss Class 	 0.328453
# Total Loss 	 1.316777
# 237/251 [===========================>..] - ETA: 6s - loss: 1.4963Dummy Line 	 [0.]
# Loss WH 	 1.2329633
# Loss XY 	 0.034188367
# Current Recall 	 0.6097561
# Average Recall 	 0.500957
# Loss Conf 	 0.0013441123
# Loss Class 	 0.34594122
# Total Loss 	 1.614437
# 238/251 [===========================>..] - ETA: 5s - loss: 1.4968Dummy Line 	 [0.]
# Loss WH 	 1.3699809
# Loss XY 	 0.04144189
# Current Recall 	 0.50877196
# Average Recall 	 0.5009585
# Loss Conf 	 0.0018998694
# Loss Class 	 0.4654293
# Total Loss 	 1.878752
# 239/251 [===========================>..] - ETA: 5s - loss: 1.4984Dummy Line 	 [0.]
# Loss WH 	 0.78066653
# Loss XY 	 0.037903376
# Average Recall 	 0.5009719
# Loss Conf 	 0.0009773693
# Current Recall 	 0.5714286
# Loss Class 	 0.18380068
# Total Loss 	 1.003348
# 240/251 [===========================>..] - ETA: 4s - loss: 1.4963Dummy Line 	 [0.]
# Loss WH 	 1.063592
# Loss XY 	 0.053691883
# Current Recall 	 0.42857143
# Average Recall 	 0.50095814
# Loss Conf 	 0.0019967514
# Loss Class 	 0.23540895
# Total Loss 	 1.3546895
# 241/251 [===========================>..] - ETA: 4s - loss: 1.4957Dummy Line 	 [0.]
# Loss WH 	 0.66076744
# Average Recall 	 0.5009669
# Loss Conf 	 0.0018112682
# Current Recall 	 0.5471698
# Loss Class 	 0.52378935
# Loss XY 	 0.02991495
# Total Loss 	 1.2162831
# 242/251 [===========================>..] - ETA: 4s - loss: 1.4946Dummy Line 	 [0.]
# Loss WH 	 1.0490807
# Loss XY 	 0.055141274
# Current Recall 	 0.33898306
# Average Recall 	 0.50093615
# Loss Conf 	 0.0024582637
# Loss Class 	 0.60682774
# Total Loss 	 1.713508
# 243/251 [============================>.] - ETA: 3s - loss: 1.4955Dummy Line 	 [0.]
# Loss WH 	 0.7492385
# Average Recall 	 0.50092065
# Loss Class 	 0.6768599
# Current Recall 	 0.41935483
# Loss Conf 	 0.0021797796
# Loss XY 	 0.042623844
# Total Loss 	 1.470902
# 244/251 [============================>.] - ETA: 3s - loss: 1.4954Dummy Line 	 [0.]
# Loss WH 	 1.5703415
# Loss XY 	 0.0400965
# Current Recall 	 0.5283019
# Loss Class 	 0.42945915
# Loss Conf 	 0.0020140395
# Average Recall 	 0.5009259
# Total Loss 	 2.0419111
# 245/251 [============================>.] - ETA: 2s - loss: 1.4976Dummy Line 	 [0.]
# Loss WH 	 0.7333128
# Loss Conf 	 0.0018032911
# Average Recall 	 0.5009092
# Current Recall 	 0.41304347
# Loss XY 	 0.04717196
# Loss Class 	 0.46407977
# Total Loss 	 1.2463678
# 246/251 [============================>.] - ETA: 2s - loss: 1.4966Dummy Line 	 [0.]
# Loss WH 	 1.0087919
# Loss XY 	 0.054041766
# Current Recall 	 0.54
# Average Recall 	 0.5009166
# Loss Conf 	 0.001788502
# Loss Class 	 0.4085264
# Total Loss 	 1.4731486
# 247/251 [============================>.] - ETA: 1s - loss: 1.4965Dummy Line 	 [0.]
# Loss WH 	 0.8968177
# Loss XY 	 0.04289348
# Current Recall 	 0.43636364
# Average Recall 	 0.5009044
# Loss Conf 	 0.001809819
# Loss Class 	 0.5274869
# Total Loss 	 1.469008
# 248/251 [============================>.] - ETA: 1s - loss: 1.4964Dummy Line 	 [0.]
# Loss WH 	 1.5542414
# Loss XY 	 0.043357458
# Current Recall 	 0.4117647
# Average Recall 	 0.50088745
# Loss Conf 	 0.0020761585
# Loss Class 	 0.46930465
# Total Loss 	 2.0689797
# 249/251 [============================>.] - ETA: 0s - loss: 1.4987Dummy Line 	 [0.]
# Loss XY 	 0.041466482
# Loss WH 	 0.7937912
# Current Recall 	 0.6
# Average Recall 	 0.5009063
# Loss Conf 	 0.0012406192
# Loss Class 	 0.30353093
# Total Loss 	 1.1400292
# 250/251 [============================>.] - ETA: 0s - loss: 1.4973Dummy Line 	 [0.]
# Loss XY 	 0.043547485
# Loss WH 	 0.8565844
# Average Recall 	 0.5008988
# Current Recall 	 0.46153846
# Loss Conf 	 0.0021917713
# Loss Class 	 0.59282196
# Total Loss 	 1.4951457
# Dummy Line 	 [0.]
# Current Recall 	 0.8709677
# Loss WH 	 1.2373224
# Loss XY 	 0.034743026
# Loss Conf 	 0.000792349
# Average Recall 	 0.50096893
# Loss Class 	 0.02464655
# Total Loss 	 1.2975044
# Dummy Line 	 [0.]
# Loss WH 	 0.8191041
# Loss XY 	 0.05142486
# Current Recall 	 0.4125
# Average Recall 	 0.5009522
# Loss Conf 	 0.003307807
# Loss Class 	 0.9128358
# Total Loss 	 1.7866726
# Dummy Line 	 [0.]
# Loss WH 	 0.80519533
# Loss XY 	 0.034444682
# Loss Conf 	 0.00127973
# Average Recall 	 0.50097907
# Current Recall 	 0.64285713
# Loss Class 	 0.20945467
# Total Loss 	 1.0503744
# Dummy Line 	 [0.]
# Loss WH 	 1.1149818
# Loss XY 	 0.040897015
# Average Recall 	 0.5009973
# Loss Conf 	 0.0021624768
# Current Recall 	 0.5972222
# Loss Class 	 0.23480566
# Total Loss 	 1.392847
# Dummy Line 	 [0.]
# Loss WH 	 0.8142407
# Loss XY 	 0.052359685
# Current Recall 	 0.5762712
# Loss Conf 	 0.0015850051
# Average Recall 	 0.5010115
# Loss Class 	 0.34782335
# Total Loss 	 1.2160088
# Dummy Line 	 [0.]
# Loss WH 	 1.1438928
# Loss XY 	 0.0366351
# Loss Conf 	 0.0011017321
# Average Recall 	 0.5010442
# Current Recall 	 0.67346936
# Loss Class 	 0.20185968
# Total Loss 	 1.3834894
# Dummy Line 	 [0.]
# Loss XY 	 0.042207
# Loss WH 	 0.71614903
# Current Recall 	 0.6944444
# Average Recall 	 0.5010808
# Loss Conf 	 0.0013278541
# Loss Class 	 0.4588668
# Total Loss 	 1.2185507
# Dummy Line 	 [0.]
# Loss WH 	 0.6337053
# Loss XY 	 0.04270745
# Current Recall 	 0.5810811
# Loss Conf 	 0.0025861538
# Average Recall 	 0.50109595
# Loss Class 	 0.11703687
# Total Loss 	 0.79603577
# Dummy Line 	 [0.]
# Loss WH 	 0.9501854
# Current Recall 	 0.70212764
# Loss XY 	 0.04514329
# Average Recall 	 0.501134
# Loss Conf 	 0.0015079668
# Loss Class 	 0.11335236
# Total Loss 	 1.110189
# Dummy Line 	 [0.]
# Loss XY 	 0.030284116
# Loss WH 	 0.8285303
# Average Recall 	 0.50117975
# Current Recall 	 0.74285716
# Loss Conf 	 0.0011321625
# Loss Class 	 0.20213884
# Total Loss 	 1.0620854
# Dummy Line 	 [0.]
# Loss XY 	 0.037770372
# Loss WH 	 1.0468446
# Current Recall 	 0.6333333
# Average Recall 	 0.5012047
# Loss Conf 	 0.0017393518
# Loss Class 	 0.16906144
# Total Loss 	 1.2554158
# Dummy Line 	 [0.]
# Loss XY 	 0.03858064
# Loss WH 	 0.76961833
# Average Recall 	 0.50122344
# Loss Conf 	 0.0023012862
# Current Recall 	 0.6
# Loss Class 	 0.24257305
# Total Loss 	 1.0530733
# Dummy Line 	 [0.]
# Loss WH 	 0.919915
# Current Recall 	 0.7948718
# Loss Conf 	 0.0011377075
# Average Recall 	 0.501279
# Loss XY 	 0.029937705
# Loss Class 	 0.16291949
# Total Loss 	 1.11391
# Dummy Line 	 [0.]
# Loss WH 	 0.6730421
# Loss XY 	 0.03223971
# Current Recall 	 0.6666667
# Loss Conf 	 0.0015509254
# Average Recall 	 0.5013102
# Loss Class 	 0.1797372
# Total Loss 	 0.88657
# Dummy Line 	 [0.]
# Loss XY 	 0.04241753
# Loss Conf 	 0.0023471217
# Average Recall 	 0.501334
# Loss WH 	 0.8462283
# Loss Class 	 0.19698165
# Current Recall 	 0.6268657
# Total Loss 	 1.0879745
# Dummy Line 	 [0.]
# Loss WH 	 0.9382624
# Loss XY 	 0.037140135
# Loss Conf 	 0.0025643385
# Loss Class 	 0.38842502
# Average Recall 	 0.50134975
# Current Recall 	 0.5846154
# Total Loss 	 1.3663919
# Dummy Line 	 [0.]
# Loss WH 	 0.8629413
# Loss XY 	 0.03544464
# Current Recall 	 0.7906977
# Loss Conf 	 0.0016283495
# Average Recall 	 0.50140446
# Loss Class 	 0.21496981
# Total Loss 	 1.114984
# Dummy Line 	 [0.]
# Loss WH 	 1.2269851
# Loss XY 	 0.051388163
# Loss Conf 	 0.0017392803
# Average Recall 	 0.501406
# Current Recall 	 0.509434
# Loss Class 	 0.24968688
# Total Loss 	 1.5297993
# Dummy Line 	 [0.]
# Loss WH 	 0.8884271
# Loss XY 	 0.04369904
# Current Recall 	 0.5744681
# Average Recall 	 0.5014198
# Loss Conf 	 0.0020519993
# Loss Class 	 0.15999423
# Total Loss 	 1.0941724
# Dummy Line 	 [0.]
# Loss XY 	 0.041012045
# Loss WH 	 0.52924544
# Loss Conf 	 0.0012524801
# Average Recall 	 0.5014261
# Current Recall 	 0.53488374
# Loss Class 	 0.17446075
# Total Loss 	 0.7459707
# Dummy Line 	 [0.]
# Loss WH 	 0.67097586
# Loss Conf 	 0.0021229184
# Current Recall 	 0.5641026
# Average Recall 	 0.50143796
# Loss XY 	 0.036823187
# Loss Class 	 0.29662716
# Total Loss 	 1.0065491
# Dummy Line 	 [0.]
# Loss WH 	 1.1508814
# Loss XY 	 0.04243402
# Current Recall 	 0.76744187
# Average Recall 	 0.50148815
# Loss Conf 	 0.0016124273
# Loss Class 	 0.30135146
# Total Loss 	 1.4962792
# Dummy Line 	 [0.]
# Loss WH 	 1.3864985
# Loss XY 	 0.041401155
# Current Recall 	 0.6666667
# Average Recall 	 0.5015194
# Loss Conf 	 0.0017040161
# Loss Class 	 0.2185051
# Total Loss 	 1.6481087
# Dummy Line 	 [0.]
# Loss WH 	 0.99539
# Loss XY 	 0.03642817
# Loss Conf 	 0.0013251958
# Current Recall 	 0.7735849
# Average Recall 	 0.5015707
# Loss Class 	 0.07801143
# Total Loss 	 1.1111548
# Dummy Line 	 [0.]
# Loss WH 	 0.62699157
# Loss XY 	 0.039320733
# Current Recall 	 0.6857143
# Average Recall 	 0.50160545
# Loss Conf 	 0.0010046909
# Loss Class 	 0.57498264
# Total Loss 	 1.2422996
# Dummy Line 	 [0.]
# Loss WH 	 0.9490374
# Current Recall 	 0.725
# Loss XY 	 0.041727237
# Average Recall 	 0.50164765
# Loss Conf 	 0.0013120677
# Loss Class 	 0.44831195
# Total Loss 	 1.4403887
# Dummy Line 	 [0.]
# Loss WH 	 0.9987762
# Loss XY 	 0.042561855
# Loss Conf 	 0.0015188748
# Average Recall 	 0.5016734
# Current Recall 	 0.63829786
# Loss Class 	 0.09418096
# Total Loss 	 1.1370379
# Dummy Line 	 [0.]
# Loss XY 	 0.033556532
# Current Recall 	 0.68333334
# Average Recall 	 0.5017077
# Loss Conf 	 0.0021059813
# Loss WH 	 1.0359136
# Loss Class 	 0.17744859
# Total Loss 	 1.2490247
# Dummy Line 	 [0.]
# Loss XY 	 0.028724814
# Loss WH 	 1.2480421
# Current Recall 	 0.725
# Average Recall 	 0.50174975
# Loss Conf 	 0.0012192479
# Loss Class 	 0.24384049
# Total Loss 	 1.5218266
# Dummy Line 	 [0.]
# Loss XY 	 0.03112285
# Loss WH 	 0.7132014
# Average Recall 	 0.5017788
# Loss Conf 	 0.0018590611
# Current Recall 	 0.6557377
# Loss Class 	 0.09204727
# Total Loss 	 0.8382306
# Dummy Line 	 [0.]
# Loss WH 	 0.54736066
# Loss XY 	 0.035130598
# Current Recall 	 0.71153843
# Loss Conf 	 0.0018248254
# Average Recall 	 0.5018183
# Loss Class 	 0.17732677
# Total Loss 	 0.7616428
# Dummy Line 	 [0.]
# Loss WH 	 0.6007362
# Loss XY 	 0.027228735
# Current Recall 	 0.67741936
# Average Recall 	 0.50185144
# Loss Conf 	 0.0015078979
# Loss Class 	 0.1485453
# Total Loss 	 0.7780181
# Dummy Line 	 [0.]
# Loss XY 	 0.04437655
# Loss WH 	 1.4389114
# Current Recall 	 0.53333336
# Loss Conf 	 0.0027061163
# Average Recall 	 0.50185734
# Loss Class 	 0.2998943
# Total Loss 	 1.7858884
# Dummy Line 	 [0.]
# Loss XY 	 0.038515817
# Current Recall 	 0.68085104
# Loss WH 	 0.6819769
# Average Recall 	 0.5018911
# Loss Conf 	 0.0016515749
# Loss Class 	 0.36559832
# Total Loss 	 1.0877426
# Dummy Line 	 [0.]
# Loss WH 	 0.84076095
# Loss XY 	 0.04761478
# Current Recall 	 0.6666667
# Loss Conf 	 0.0016313561
# Average Recall 	 0.50192213
# Loss Class 	 0.18411462
# Total Loss 	 1.0741217
# Dummy Line 	 [0.]
# Loss WH 	 0.7414971
# Loss XY 	 0.03477082
# Current Recall 	 0.5714286
# Average Recall 	 0.50193524
# Loss Conf 	 0.0019385669
# Loss Class 	 0.13305056
# Total Loss 	 0.9112571
# Dummy Line 	 [0.]
# Loss WH 	 0.63824904
# Loss XY 	 0.053882893
# Average Recall 	 0.50194067
# Loss Conf 	 0.0018348692
# Loss Class 	 0.26721445
# Current Recall 	 0.5308642
# Total Loss 	 0.9611813
# Dummy Line 	 [0.]
# Loss WH 	 0.56274074
# Loss XY 	 0.023917656
# Average Recall 	 0.5019729
# Loss Conf 	 0.0015101136
# Current Recall 	 0.6730769
# Loss Class 	 0.18378049
# Total Loss 	 0.77194905
# Dummy Line 	 [0.]
# Loss WH 	 1.2614635
# Loss XY 	 0.04198368
# Average Recall 	 0.50198466
# Current Recall 	 0.5645161
# Loss Conf 	 0.0023263583
# Loss Class 	 0.33507034
# Total Loss 	 1.640844
# Dummy Line 	 [0.]
# Loss WH 	 0.62062955
# Loss XY 	 0.044358443
# Average Recall 	 0.50200695
# Current Recall 	 0.62068963
# Loss Conf 	 0.0015396813
# Loss Class 	 0.08356762
# Total Loss 	 0.7500953
# Dummy Line 	 [0.]
# Loss WH 	 1.4469289
# Loss XY 	 0.064699374
# Current Recall 	 0.6216216
# Average Recall 	 0.5020295
# Loss Conf 	 0.0015768457
# Loss Class 	 0.060345314
# Total Loss 	 1.5735505
# Dummy Line 	 [0.]
# Loss WH 	 1.0005527
# Loss XY 	 0.034846798
# Current Recall 	 0.5294118
# Average Recall 	 0.5020346
# Loss Conf 	 0.0015406421
# Loss Class 	 0.29617667
# Total Loss 	 1.3331168
# Dummy Line 	 [0.]
# Loss WH 	 0.7992354
# Current Recall 	 0.4883721
# Loss Conf 	 0.0012435189
# Average Recall 	 0.502032
# Loss XY 	 0.044879608
# Loss Class 	 0.14512554
# Total Loss 	 0.9904841
# Dummy Line 	 [0.]
# Loss WH 	 0.80722094
# Loss XY 	 0.045859225
# Current Recall 	 0.5272727
# Average Recall 	 0.50203675
# Loss Conf 	 0.0020018865
# Loss Class 	 0.621196
# Total Loss 	 1.4762781
# Dummy Line 	 [0.]
# Loss WH 	 0.77484345
# Loss XY 	 0.040984724
# Current Recall 	 0.49275362
# Average Recall 	 0.502035
# Loss Conf 	 0.0018358653
# Loss Class 	 0.2260693
# Total Loss 	 1.0437334
# Dummy Line 	 [0.]
# Loss WH 	 0.70270336
# Loss XY 	 0.04111485
# Average Recall 	 0.50205964
# Loss Conf 	 0.0019648871
# Current Recall 	 0.6333333
# Loss Class 	 0.26249754
# Total Loss 	 1.0082806
# Dummy Line 	 [0.]
# Loss WH 	 1.8989043
# Loss XY 	 0.054216243
# Average Recall 	 0.5020813
# Current Recall 	 0.61702126
# Loss Conf 	 0.0016802739
# Loss Class 	 0.3471645
# Total Loss 	 2.3019652
# Dummy Line 	 [0.]
# Loss WH 	 1.388499
# Loss XY 	 0.028554374
# Average Recall 	 0.5021104
# Current Recall 	 0.6571429
# Loss Conf 	 0.0011268173
# Loss Class 	 0.20188287
# Total Loss 	 1.620063
# Dummy Line 	 [0.]
# Loss WH 	 1.005153
# Loss XY 	 0.024165368
# Current Recall 	 0.73333335
# Average Recall 	 0.5021538
# Loss Conf 	 0.00091098004
# Loss Class 	 0.1610342
# Total Loss 	 1.1912636
# Dummy Line 	 [0.]
# Loss WH 	 1.2169954
# Loss XY 	 0.048421495
# Current Recall 	 0.43939394
# Average Recall 	 0.5021421
# Loss Conf 	 0.0022690482
# Loss Class 	 0.4663042
# Total Loss 	 1.7339901
# Dummy Line 	 [0.]
# Loss XY 	 0.032126684
# Loss WH 	 1.7979757
# Average Recall 	 0.50218976
# Loss Conf 	 0.0013471603
# Current Recall 	 0.75609756
# Loss Class 	 0.19521032
# Total Loss 	 2.0266597
# Dummy Line 	 [0.]
# Loss XY 	 0.03564929
# Loss WH 	 1.3631521
# Current Recall 	 0.78723407
# Average Recall 	 0.5022433
# Loss Conf 	 0.0015455602
# Loss Class 	 0.095205195
# Total Loss 	 1.4955522
# Dummy Line 	 [0.]
# Loss XY 	 0.030646443
# Loss WH 	 0.38547873
# Average Recall 	 0.5022487
# Loss Conf 	 0.0019216097
# Loss Class 	 0.21364179
# Total Loss 	 0.6316886
# Current Recall 	 0.53125
# Dummy Line 	 [0.]
# Loss WH 	 0.8496247
# Loss XY 	 0.037371345
# Current Recall 	 0.6296296
# Average Recall 	 0.5022726
# Loss Conf 	 0.0022870807
# Loss Class 	 0.19728287
# Total Loss 	 1.086566
# Dummy Line 	 [0.]
# Loss WH 	 0.9049183
# Loss XY 	 0.04266358
# Current Recall 	 0.6666667
# Average Recall 	 0.5023035
# Loss Conf 	 0.001584802
# Loss Class 	 0.17034605
# Total Loss 	 1.1195128
# Dummy Line 	 [0.]
# Loss WH 	 0.7562165
# Loss XY 	 0.043606024
# Current Recall 	 0.64705884
# Average Recall 	 0.5023306
# Loss Conf 	 0.0017920888
# Loss Class 	 0.15084097
# Total Loss 	 0.95245564
# Dummy Line 	 [0.]
# Loss WH 	 0.868826
# Loss XY 	 0.0364477
# Current Recall 	 0.7894737
# Average Recall 	 0.5023845
# Loss Conf 	 0.0018249574
# Loss Class 	 0.14080201
# Total Loss 	 1.0479007
# Dummy Line 	 [0.]
# Current Recall 	 0.6511628
# Average Recall 	 0.5024124
# Loss WH 	 1.4675082
# Loss XY 	 0.039830253
# Loss Class 	 0.31554434
# Loss Conf 	 0.0017490801
# Total Loss 	 1.8246318
# Dummy Line 	 [0.]
# Loss WH 	 0.5462871
# Loss XY 	 0.04136725
# Current Recall 	 0.5394737
# Average Recall 	 0.50241935
# Loss Conf 	 0.0023340466
# Loss Class 	 0.19150892
# Total Loss 	 0.78149736
# Dummy Line 	 [0.]
# Loss WH 	 0.8844623
# Loss XY 	 0.04134976
# Current Recall 	 0.6585366
# Average Recall 	 0.5024486
# Loss Conf 	 0.0012297367
# Loss Class 	 0.17973165
# Total Loss 	 1.1067735
# Dummy Line 	 [0.]
# Loss WH 	 0.9816359
# Loss XY 	 0.055786937
# Current Recall 	 0.51724136
# Average Recall 	 0.50245136
# Loss Conf 	 0.002016745
# Loss Class 	 0.20330355
# Total Loss 	 1.2427433
# Dummy Line 	 [0.]
# Average Recall 	 0.5024584
# Loss Conf 	 0.0015595905
# Current Recall 	 0.53968257
# Loss WH 	 0.7156324
# Total Loss 	 0.86494213
# Loss Class 	 0.11224167
# Loss XY 	 0.035508458
# Dummy Line 	 [0.]
# Loss WH 	 0.6806204
# Loss XY 	 0.03307042
# Current Recall 	 0.5647059
# Average Recall 	 0.50247
# Loss Conf 	 0.0018317326
# Loss Class 	 0.14956684
# Total Loss 	 0.86508936
# 251/251 [==============================] - 126s 501ms/step - loss: 1.4973 - val_loss: 1.2078
#
# Epoch 00092: val_loss improved from 1.22847 to 1.20785, saving model to weights_coco.h5
# Epoch 93/100
# Dummy Line 	 [0.]
# Loss WH 	 1.2552949
# Current Recall 	 0.46
# Loss XY 	 0.046187744
# Average Recall 	 0.5024621
# Loss Conf 	 0.0016975348
# Loss Class 	 0.3962368
# Total Loss 	 1.699417
#   1/251 [..............................] - ETA: 45s - loss: 1.6994Dummy Line 	 [0.]
# Current Recall 	 0.45945945
# Average Recall 	 0.50245404
# Loss Class 	 0.29051074
# Loss Conf 	 0.002501173
# Loss XY 	 0.048015684
# Total Loss 	 1.1584867
# Loss WH 	 0.8174591
#   2/251 [..............................] - ETA: 46s - loss: 1.4290Dummy Line 	 [0.]
# Loss XY 	 0.050805215
# Loss WH 	 1.5612477
# Loss Conf 	 0.0013684006
# Average Recall 	 0.5024862
# Current Recall 	 0.6744186
# Loss Class 	 0.083676964
# Total Loss 	 1.6970983
#   3/251 [..............................] - ETA: 45s - loss: 1.5183Dummy Line 	 [0.]
# Loss WH 	 0.9772813
# Loss XY 	 0.042371124
# Current Recall 	 0.43548387
# Loss Conf 	 0.0022930712
# Average Recall 	 0.50247365
# Loss Class 	 0.5077
# Total Loss 	 1.5296454
#   4/251 [..............................] - ETA: 43s - loss: 1.5212Dummy Line 	 [0.]
# Loss XY 	 0.042138174
# Loss WH 	 1.268844
# Average Recall 	 0.5024632
# Loss Conf 	 0.0022728692
# Current Recall 	 0.44680852
# Loss Class 	 0.68994784
# Total Loss 	 2.003203
#   5/251 [..............................] - ETA: 46s - loss: 1.6176Dummy Line 	 [0.]
# Loss WH 	 1.000945
# Loss XY 	 0.050873
# Current Recall 	 0.44117647
# Average Recall 	 0.5024518
# Loss Conf 	 0.0020375475
# Loss Class 	 0.2732265
# Total Loss 	 1.327082
#   6/251 [..............................] - ETA: 57s - loss: 1.5692Dummy Line 	 [0.]
# Loss XY 	 0.05205033
# Loss WH 	 2.8055067
# Current Recall 	 0.55263156
# Loss Conf 	 0.0012550243
# Average Recall 	 0.5024612
# Loss Class 	 0.34509444
# Total Loss 	 3.2039065
#   7/251 [..............................] - ETA: 1:01 - loss: 1.8027Dummy Line 	 [0.]
# Loss WH 	 1.5209093
# Loss XY 	 0.049987823
# Current Recall 	 0.46938777
# Average Recall 	 0.502455
# Loss Conf 	 0.0020541195
# Loss Class 	 0.59431094
# Total Loss 	 2.167262
#   8/251 [..............................] - ETA: 1:06 - loss: 1.8483Dummy Line 	 [0.]
# Loss WH 	 1.3262267
# Current Recall 	 0.6999999
# Average Recall 	 0.50249195
# Loss Conf 	 0.0012702376
# Loss Class 	 0.40670958
# Loss XY 	 0.03729045
# Total Loss 	 1.771497
#   9/251 [>.............................] - ETA: 1:15 - loss: 1.8397Dummy Line 	 [0.]
# Loss WH 	 0.9058196
# Loss XY 	 0.030962676
# Average Recall 	 0.5025082
# Loss Conf 	 0.0013115143
# Current Recall 	 0.58928573
# Loss Class 	 0.30995247
# Total Loss 	 1.2480463
#  10/251 [>.............................] - ETA: 1:17 - loss: 1.7806Dummy Line 	 [0.]
# Loss WH 	 1.0963798
# Loss XY 	 0.031827506
# Current Recall 	 0.5531915
# Loss Conf 	 0.0017893047
# Average Recall 	 0.5025177
# Loss Class 	 0.3601201
# Total Loss 	 1.4901166
#  11/251 [>.............................] - ETA: 1:16 - loss: 1.7542Dummy Line 	 [0.]
# Loss WH 	 0.53310496
# Loss XY 	 0.051447026
# Current Recall 	 0.31343284
# Average Recall 	 0.50248235
# Loss Conf 	 0.0026495648
# Loss Class 	 0.32931906
# Total Loss 	 0.9165206
#  12/251 [>.............................] - ETA: 1:19 - loss: 1.6844Dummy Line 	 [0.]
# Loss XY 	 0.04988648
# Loss WH 	 0.8184474
# Current Recall 	 0.44444445
# Average Recall 	 0.50247145
# Loss Class 	 0.45762417
# Loss Conf 	 0.0030877723
# Total Loss 	 1.3290458
#  13/251 [>.............................] - ETA: 1:21 - loss: 1.6570Dummy Line 	 [0.]
# Loss WH 	 1.2715006
# Loss XY 	 0.053449105
# Current Recall 	 0.5538462
# Average Recall 	 0.5024811
# Loss Conf 	 0.002175319
# Loss Class 	 0.20895703
# Total Loss 	 1.5360821
#  14/251 [>.............................] - ETA: 1:23 - loss: 1.6484Dummy Line 	 [0.]
# Loss XY 	 0.04939866
# Current Recall 	 0.6666667
# Loss WH 	 0.63549274
# Average Recall 	 0.5025118
# Loss Conf 	 0.0015280274
# Loss Class 	 0.28804302
# Total Loss 	 0.97446245
#  15/251 [>.............................] - ETA: 1:24 - loss: 1.6035Dummy Line 	 [0.]
# Loss WH 	 0.68402725
# Loss XY 	 0.05756451
# Current Recall 	 0.3090909
# Average Recall 	 0.5024757
# Loss Conf 	 0.0025761551
# Loss Class 	 0.4027458
# Total Loss 	 1.1469138
#  16/251 [>.............................] - ETA: 1:24 - loss: 1.5749Dummy Line 	 [0.]
# Loss WH 	 1.4744314
# Current Recall 	 0.509434
# Loss XY 	 0.062044736
# Loss Conf 	 0.0019388461
# Average Recall 	 0.502477
# Loss Class 	 0.6540251
# Total Loss 	 2.19244
#  17/251 [=>............................] - ETA: 1:27 - loss: 1.6112Dummy Line 	 [0.]
# Loss WH 	 0.71077234
# Loss XY 	 0.050279777
# Current Recall 	 0.52307695
# Average Recall 	 0.50248086
# Loss Conf 	 0.0022369728
# Loss Class 	 0.37754092
# Total Loss 	 1.14083
#  18/251 [=>............................] - ETA: 1:26 - loss: 1.5851Dummy Line 	 [0.]
# Loss WH 	 1.1437651
# Loss XY 	 0.039901547
# Current Recall 	 0.4642857
# Average Recall 	 0.5024737
# Loss Conf 	 0.001368006
# Loss Class 	 0.23107484
# Total Loss 	 1.4161094
#  19/251 [=>............................] - ETA: 1:27 - loss: 1.5762Dummy Line 	 [0.]
# Loss XY 	 0.05699237
# Loss WH 	 1.3054262
# Current Recall 	 0.5
# Loss Conf 	 0.0018620593
# Average Recall 	 0.50247324
# Loss Class 	 0.5364296
# Total Loss 	 1.9007103
#  20/251 [=>............................] - ETA: 1:27 - loss: 1.5924Dummy Line 	 [0.]
# Loss WH 	 1.4853538
# Loss XY 	 0.03510714
# Current Recall 	 0.39130434
# Average Recall 	 0.5024525
# Loss Conf 	 0.0017911359
# Loss Class 	 0.41598773
# Total Loss 	 1.9382398
#  21/251 [=>............................] - ETA: 1:29 - loss: 1.6089Dummy Line 	 [0.]
# Loss WH 	 0.71810126
# Loss XY 	 0.041874222
# Current Recall 	 0.46551725
# Average Recall 	 0.50244564
# Loss Conf 	 0.001908822
# Loss Class 	 0.2724564
# Total Loss 	 1.0343407
#  22/251 [=>............................] - ETA: 1:28 - loss: 1.5828Dummy Line 	 [0.]
# Loss WH 	 1.1455503
# Loss XY 	 0.050465748
# Current Recall 	 0.4090909
# Average Recall 	 0.50242823
# Loss Conf 	 0.0015895005
# Loss Class 	 0.5872826
# Total Loss 	 1.784888
#  23/251 [=>............................] - ETA: 1:29 - loss: 1.5916Dummy Line 	 [0.]
# Loss WH 	 0.7088544
# Loss XY 	 0.043917492
# Loss Conf 	 0.000786652
# Average Recall 	 0.5024849
# Current Recall 	 0.80645156
# Loss Class 	 0.14138006
# Total Loss 	 0.8949386
#  24/251 [=>............................] - ETA: 1:29 - loss: 1.5626Dummy Line 	 [0.]
# Loss WH 	 0.80494267
# Loss XY 	 0.044357944
# Current Recall 	 0.47826087
# Average Recall 	 0.50248045
# Loss Conf 	 0.0014948559
# Loss Class 	 0.6437265
# Total Loss 	 1.4945221
#  25/251 [=>............................] - ETA: 1:31 - loss: 1.5598Dummy Line 	 [0.]
# Loss WH 	 1.2265584
# Current Recall 	 0.5609756
# Average Recall 	 0.50249135
# Loss Conf 	 0.0012303576
# Loss XY 	 0.040484697
# Loss Class 	 0.30028784
# Total Loss 	 1.5685613
#  26/251 [==>...........................] - ETA: 1:31 - loss: 1.5602Dummy Line 	 [0.]
# Loss WH 	 1.0076131
# Loss XY 	 0.036374535
# Current Recall 	 0.52380955
# Loss Conf 	 0.0016632489
# Average Recall 	 0.50249535
# Loss Class 	 0.43658864
# Total Loss 	 1.4822395
#  27/251 [==>...........................] - ETA: 1:31 - loss: 1.5573Dummy Line 	 [0.]
# Loss WH 	 1.9804202
# Loss XY 	 0.03208284
# Average Recall 	 0.50249064
# Loss Conf 	 0.001987145
# Current Recall 	 0.47727272
# Loss Class 	 0.5731115
# Total Loss 	 2.587602
#  28/251 [==>...........................] - ETA: 1:31 - loss: 1.5941Dummy Line 	 [0.]
# Loss WH 	 0.8373426
# Loss XY 	 0.04412329
# Current Recall 	 0.5102041
# Average Recall 	 0.5024921
# Loss Conf 	 0.0016872548
# Loss Class 	 0.39613312
# Total Loss 	 1.2792863
#  29/251 [==>...........................] - ETA: 1:30 - loss: 1.5832Dummy Line 	 [0.]
# Loss WH 	 0.67894566
# Loss XY 	 0.03907769
# Current Recall 	 0.5535714
# Average Recall 	 0.5025016
# Loss Conf 	 0.0018482838
# Loss Class 	 0.49544117
# Total Loss 	 1.2153128
#  30/251 [==>...........................] - ETA: 1:29 - loss: 1.5710Dummy Line 	 [0.]
# Loss WH 	 0.5414996
# Current Recall 	 0.59183675
# Average Recall 	 0.50251824
# Loss Conf 	 0.001760455
# Loss XY 	 0.032997884
# Loss Class 	 0.334944
# Total Loss 	 0.911202
#  31/251 [==>...........................] - ETA: 1:30 - loss: 1.5497Dummy Line 	 [0.]
# Loss WH 	 0.7767437
# Loss XY 	 0.04169176
# Loss Class 	 0.28346348
# Loss Conf 	 0.0025401823
# Total Loss 	 1.1044391
# Average Recall 	 0.50250363
# Current Recall 	 0.42424244
#  32/251 [==>...........................] - ETA: 1:30 - loss: 1.5358Dummy Line 	 [0.]
# Loss WH 	 1.2656286
# Loss XY 	 0.04528335
# Current Recall 	 0.63414633
# Average Recall 	 0.50252813
# Loss Conf 	 0.0015481424
# Loss Class 	 0.2218554
# Total Loss 	 1.5343155
#  33/251 [==>...........................] - ETA: 1:29 - loss: 1.5357Dummy Line 	 [0.]
# Loss XY 	 0.06285191
# Loss WH 	 0.6792964
# Average Recall 	 0.50251853
# Loss Conf 	 0.0021237398
# Loss Class 	 0.5182019
# Current Recall 	 0.4509804
# Total Loss 	 1.2624738
#  34/251 [===>..........................] - ETA: 1:30 - loss: 1.5277Dummy Line 	 [0.]
# Loss WH 	 0.9172147
# Loss XY 	 0.058600053
# Current Recall 	 0.43589744
# Average Recall 	 0.50250614
# Loss Conf 	 0.0022516376
# Loss Class 	 0.23534232
# Total Loss 	 1.2134087
#  35/251 [===>..........................] - ETA: 1:30 - loss: 1.5187Dummy Line 	 [0.]
# Loss XY 	 0.041815557
# Current Recall 	 0.58181816
# Average Recall 	 0.50252086
# Loss WH 	 1.0668578
# Loss Conf 	 0.0017404823
# Loss Class 	 0.23234947
# Total Loss 	 1.3427633
#  36/251 [===>..........................] - ETA: 1:29 - loss: 1.5138Dummy Line 	 [0.]
# Loss WH 	 1.2352113
# Loss XY 	 0.04706656
# Current Recall 	 0.3617021
# Average Recall 	 0.5024947
# Loss Conf 	 0.0025214257
# Loss Class 	 0.19550678
# Total Loss 	 1.480306
#  37/251 [===>..........................] - ETA: 1:29 - loss: 1.5129Dummy Line 	 [0.]
# Loss WH 	 1.134414
# Loss XY 	 0.045559395
# Current Recall 	 0.47727272
# Average Recall 	 0.50249
# Loss Conf 	 0.0011397267
# Loss Class 	 0.5805403
# Total Loss 	 1.7616534
#  38/251 [===>..........................] - ETA: 1:29 - loss: 1.5195Dummy Line 	 [0.]
# Loss XY 	 0.054962523
# Loss WH 	 1.4797031
# Current Recall 	 0.54545456
# Loss Conf 	 0.0021096158
# Average Recall 	 0.502498
# Loss Class 	 0.6693874
# Total Loss 	 2.2061627
#  39/251 [===>..........................] - ETA: 1:29 - loss: 1.5371Dummy Line 	 [0.]
# Loss WH 	 1.281739
# Loss XY 	 0.027691266
# Current Recall 	 0.5294118
# Average Recall 	 0.502503
# Loss Conf 	 0.0014417993
# Loss Class 	 0.3056931
# Total Loss 	 1.6165652
#  40/251 [===>..........................] - ETA: 1:28 - loss: 1.5391Dummy Line 	 [0.]
# Loss WH 	 0.9652912
# Loss XY 	 0.042709447
# Current Recall 	 0.46551725
# Average Recall 	 0.5024961
# Loss Conf 	 0.0023062273
# Loss Class 	 0.39305878
# Total Loss 	 1.4033656
#  41/251 [===>..........................] - ETA: 1:27 - loss: 1.5357Dummy Line 	 [0.]
# Loss WH 	 0.6517238
# Loss XY 	 0.043759808
# Current Recall 	 0.5254237
# Average Recall 	 0.50250036
# Loss Conf 	 0.0018372488
# Loss Class 	 0.3300654
# Total Loss 	 1.0273863
#  42/251 [====>.........................] - ETA: 1:27 - loss: 1.5236Dummy Line 	 [0.]
# Loss WH 	 1.0419044
# Loss XY 	 0.059030786
# Current Recall 	 0.484375
# Average Recall 	 0.50249696
# Loss Conf 	 0.0017982966
# Loss Class 	 0.18840009
# Total Loss 	 1.2911336
#  43/251 [====>.........................] - ETA: 1:27 - loss: 1.5182Dummy Line 	 [0.]
# Loss XY 	 0.04978613
# Average Recall 	 0.50250685
# Current Recall 	 0.5555556
# Loss Conf 	 0.0018775307
# Loss WH 	 0.91218746
# Loss Class 	 0.69225216
# Total Loss 	 1.6561034
#  44/251 [====>.........................] - ETA: 1:26 - loss: 1.5214Dummy Line 	 [0.]
# Loss WH 	 0.8566048
# Loss XY 	 0.055984806
# Current Recall 	 0.43636364
# Average Recall 	 0.5024946
# Loss Conf 	 0.0024263298
# Loss Class 	 0.25774047
# Total Loss 	 1.1727564
#  45/251 [====>.........................] - ETA: 1:26 - loss: 1.5136Dummy Line 	 [0.]
# Loss WH 	 0.7347876
# Loss XY 	 0.061102096
# Current Recall 	 0.5116279
# Average Recall 	 0.5024963
# Loss Conf 	 0.0012531056
# Loss Class 	 0.5724228
# Total Loss 	 1.3695656
#  46/251 [====>.........................] - ETA: 1:25 - loss: 1.5105Dummy Line 	 [0.]
# Loss WH 	 1.5893509
# Loss XY 	 0.047442775
# Current Recall 	 0.4888889
# Loss Conf 	 0.0013936767
# Average Recall 	 0.50249374
# Loss Class 	 0.44922858
# Total Loss 	 2.087416
#  47/251 [====>.........................] - ETA: 1:25 - loss: 1.5228Dummy Line 	 [0.]
# Loss WH 	 0.5440622
# Loss XY 	 0.053639997
# Current Recall 	 0.45454547
# Average Recall 	 0.50248486
# Loss Conf 	 0.0018525864
# Loss Class 	 0.433924
# Total Loss 	 1.0334787
#  48/251 [====>.........................] - ETA: 1:25 - loss: 1.5126Dummy Line 	 [0.]
# Loss WH 	 0.8577698
# Loss XY 	 0.045512054
# Average Recall 	 0.50245637
# Loss Conf 	 0.0022461903
# Current Recall 	 0.34920636
# Loss Class 	 0.35319293
# Total Loss 	 1.258721
#  49/251 [====>.........................] - ETA: 1:24 - loss: 1.5074Dummy Line 	 [0.]
# Loss WH 	 0.84686565
# Loss XY 	 0.043046206
# Loss Conf 	 0.0021733104
# Current Recall 	 0.5208333
# Average Recall 	 0.50245976
# Loss Class 	 0.24870409
# Total Loss 	 1.1407893
#  50/251 [====>.........................] - ETA: 1:24 - loss: 1.5001Dummy Line 	 [0.]
# Loss WH 	 0.70291424
# Loss XY 	 0.037963994
# Current Recall 	 0.6041667
# Average Recall 	 0.50247866
# Loss Conf 	 0.0014978965
# Loss Class 	 0.3232332
# Total Loss 	 1.0656093
#  51/251 [=====>........................] - ETA: 1:23 - loss: 1.4915Dummy Line 	 [0.]
# Loss WH 	 1.3999393
# Current Recall 	 0.3877551
# Average Recall 	 0.5024573
# Loss Conf 	 0.0018400996
# Loss XY 	 0.05425687
# Loss Class 	 0.39552608
# Total Loss 	 1.8515624
#  52/251 [=====>........................] - ETA: 1:23 - loss: 1.4985Dummy Line 	 [0.]
# Loss WH 	 0.6348428
# Loss XY 	 0.05014317
# Current Recall 	 0.43243244
# Loss Conf 	 0.001980469
# Average Recall 	 0.5024443
# Loss Class 	 0.2645754
# Total Loss 	 0.9515419
#  53/251 [=====>........................] - ETA: 1:23 - loss: 1.4881Dummy Line 	 [0.]
# Loss WH 	 0.97144175
# Loss XY 	 0.050301023
# Current Recall 	 0.37333333
# Average Recall 	 0.5024204
# Loss Conf 	 0.0026282938
# Loss Class 	 0.74769175
# Total Loss 	 1.7720629
#  54/251 [=====>........................] - ETA: 1:23 - loss: 1.4934Dummy Line 	 [0.]
# Loss WH 	 1.6969995
# Loss XY 	 0.03746163
# Current Recall 	 0.51724136
# Loss Conf 	 0.0013879999
# Average Recall 	 0.50242317
# Loss Class 	 1.1481595
# Total Loss 	 2.8840086
#  55/251 [=====>........................] - ETA: 1:23 - loss: 1.5187Dummy Line 	 [0.]
# Loss XY 	 0.054361697
# Loss WH 	 1.7124771
# Current Recall 	 0.375
# Loss Conf 	 0.001997946
# Average Recall 	 0.50239956
# Loss Class 	 0.7832071
# Total Loss 	 2.552044
#  56/251 [=====>........................] - ETA: 1:23 - loss: 1.5371Dummy Line 	 [0.]
# Loss WH 	 0.62072814
# Loss XY 	 0.045558043
# Current Recall 	 0.33846155
# Average Recall 	 0.50236917
# Loss Conf 	 0.0025466962
# Loss Class 	 0.25023997
# Total Loss 	 0.9190728
#  57/251 [=====>........................] - ETA: 1:23 - loss: 1.5263Dummy Line 	 [0.]
# Loss WH 	 1.1761836
# Loss XY 	 0.049203232
# Current Recall 	 0.46296296
# Average Recall 	 0.50236183
# Loss Conf 	 0.0019411215
# Loss Class 	 0.35829693
# Total Loss 	 1.5856249
#  58/251 [=====>........................] - ETA: 1:22 - loss: 1.5273Dummy Line 	 [0.]
# Loss WH 	 0.7983856
# Loss XY 	 0.045554616
# Current Recall 	 0.52272725
# Average Recall 	 0.5023656
# Loss Conf 	 0.0016205345
# Loss Class 	 0.49847066
# Total Loss 	 1.3440315
#  59/251 [======>.......................] - ETA: 1:22 - loss: 1.5242Dummy Line 	 [0.]
# Loss WH 	 0.49661714
# Loss XY 	 0.03126554
# Current Recall 	 0.61538464
# Average Recall 	 0.50238657
# Loss Conf 	 0.000949105
# Loss Class 	 0.23285103
# Total Loss 	 0.7616828
#  60/251 [======>.......................] - ETA: 1:21 - loss: 1.5115Dummy Line 	 [0.]
# Loss WH 	 1.6265221
# Loss XY 	 0.030780442
# Current Recall 	 0.5555555
# Average Recall 	 0.5023964
# Loss Conf 	 0.0010471845
# Loss Class 	 0.1780131
# Total Loss 	 1.8363627
#  61/251 [======>.......................] - ETA: 1:21 - loss: 1.5168Dummy Line 	 [0.]
# Loss WH 	 0.74296063
# Loss XY 	 0.04098866
# Average Recall 	 0.502396
# Current Recall 	 0.5
# Loss Conf 	 0.0016634446
# Loss Class 	 0.10270996
# Total Loss 	 0.8883227
#  62/251 [======>.......................] - ETA: 1:20 - loss: 1.5067Dummy Line 	 [0.]
# Loss WH 	 1.4158274
# Loss XY 	 0.044950075
# Current Recall 	 0.6956521
# Average Recall 	 0.50243175
# Loss Conf 	 0.0010213347
# Loss Class 	 0.3719024
# Total Loss 	 1.8337014
# ...
# Current Recall 	 0.3448276
# Loss Conf 	 0.003166855
# Loss Class 	 0.2310328
# Average Recall 	 0.5101083
# Total Loss 	 1.0201651
# 235/251 [===========================>..] - ETA: 7s - loss: 1.3212Dummy Line 	 [0.]
# Loss WH 	 0.8187568
# Loss XY 	 0.045758847
# Current Recall 	 0.4516129
# Average Recall 	 0.5101008
# Loss Conf 	 0.0022288994
# Loss Class 	 0.68990266
# Total Loss 	 1.5566473
# 236/251 [===========================>..] - ETA: 6s - loss: 1.3222Dummy Line 	 [0.]
# Loss WH 	 1.1679476
# Loss XY 	 0.051719837
# Current Recall 	 0.42647058
# Average Recall 	 0.51009
# Loss Conf 	 0.0023707156
# Loss Class 	 0.22530912
# Total Loss 	 1.4473473
# 237/251 [===========================>..] - ETA: 6s - loss: 1.3227Dummy Line 	 [0.]
# Loss WH 	 0.527291
# Loss XY 	 0.044303995
# Current Recall 	 0.43283582
# Average Recall 	 0.5100801
# Loss Conf 	 0.0030664788
# Loss Class 	 0.22633141
# Total Loss 	 0.8009929
# 238/251 [===========================>..] - ETA: 5s - loss: 1.3205Dummy Line 	 [0.]
# Loss WH 	 0.6187002
# Loss XY 	 0.040114164
# Current Recall 	 0.5263158
# Average Recall 	 0.5100822
# Loss Conf 	 0.0017324605
# Loss Class 	 0.45356923
# Total Loss 	 1.1141161
# 239/251 [===========================>..] - ETA: 5s - loss: 1.3197Dummy Line 	 [0.]
# Loss WH 	 1.2482462
# Loss XY 	 0.059927486
# Current Recall 	 0.52380955
# Average Recall 	 0.510084
# Loss Conf 	 0.0014387931
# Loss Class 	 0.8913512
# Total Loss 	 2.2009635
# 240/251 [===========================>..] - ETA: 4s - loss: 1.3233Dummy Line 	 [0.]
# Loss WH 	 1.0587891
# Average Recall 	 0.51008266
# Loss XY 	 0.039446462
# Loss Conf 	 0.0017663046
# Current Recall 	 0.5
# Loss Class 	 0.49071288
# Total Loss 	 1.5907148
# 241/251 [===========================>..] - ETA: 4s - loss: 1.3245Dummy Line 	 [0.]
# Loss WH 	 0.7902101
# Loss XY 	 0.060605764
# Current Recall 	 0.37704918
# Average Recall 	 0.51006556
# Loss Conf 	 0.002400813
# Loss Class 	 0.1832218
# Total Loss 	 1.0364385
# 242/251 [===========================>..] - ETA: 4s - loss: 1.3233Dummy Line 	 [0.]
# Loss WH 	 0.76561874
# Loss Conf 	 0.0029194409
# Average Recall 	 0.510045
# Current Recall 	 0.35
# Loss XY 	 0.051556934
# Loss Class 	 0.5466418
# Total Loss 	 1.3667369
# 243/251 [============================>.] - ETA: 3s - loss: 1.3234Dummy Line 	 [0.]
# Loss XY 	 0.034814525
# Loss WH 	 0.48630723
# Average Recall 	 0.5100504
# Loss Conf 	 0.0022402618
# Current Recall 	 0.5522388
# Loss Class 	 0.20471251
# Total Loss 	 0.7280745
# 244/251 [============================>.] - ETA: 3s - loss: 1.3210Dummy Line 	 [0.]
# Loss WH 	 0.87863517
# Loss XY 	 0.03869676
# Current Recall 	 0.63333327
# Loss Class 	 0.3627842
# Loss Conf 	 0.0011121387
# Average Recall 	 0.5100663
# Total Loss 	 1.2812283
# 245/251 [============================>.] - ETA: 2s - loss: 1.3208Dummy Line 	 [0.]
# Loss WH 	 0.82400566
# Loss XY 	 0.049960304
# Current Recall 	 0.29577464
# Average Recall 	 0.5100387
# Loss Conf 	 0.0031757483
# Loss Class 	 0.50433636
# Total Loss 	 1.3814781
# 246/251 [============================>.] - ETA: 2s - loss: 1.3211Dummy Line 	 [0.]
# Loss WH 	 1.2069862
# Loss XY 	 0.047306575
# Current Recall 	 0.3529412
# Average Recall 	 0.5100185
# Loss Conf 	 0.0017352672
# Loss Class 	 1.0006729
# Total Loss 	 2.256701
# 247/251 [============================>.] - ETA: 1s - loss: 1.3249Dummy Line 	 [0.]
# Loss WH 	 0.616593
# Loss XY 	 0.05386481
# Current Recall 	 0.29850745
# Average Recall 	 0.50999135
# Loss Conf 	 0.003477437
# Loss Class 	 0.9891799
# Total Loss 	 1.6631153
# 248/251 [============================>.] - ETA: 1s - loss: 1.3262Dummy Line 	 [0.]
# Loss WH 	 0.9875053
# Loss XY 	 0.05063496
# Current Recall 	 0.49253732
# Loss Conf 	 0.0023541683
# Average Recall 	 0.5099891
# Loss Class 	 0.48530135
# Total Loss 	 1.5257958
# 249/251 [============================>.] - ETA: 0s - loss: 1.3270Dummy Line 	 [0.]
# Loss WH 	 0.9488744
# Loss XY 	 0.045465946
# Current Recall 	 0.36363637
# Average Recall 	 0.5099703
# Loss Conf 	 0.0023769685
# Loss Class 	 0.43742794
# Total Loss 	 1.4341452
# 250/251 [============================>.] - ETA: 0s - loss: 1.3275Dummy Line 	 [0.]
# Loss WH 	 1.1910956
# Current Recall 	 0.64285713
# Average Recall 	 0.50998735
# Loss Conf 	 0.0013452532
# Loss XY 	 0.04684209
# Loss Class 	 0.4259452
# Total Loss 	 1.6652281
# Dummy Line 	 [0.]
# Loss WH 	 1.1108569
# Current Recall 	 0.7105263
# Loss Class 	 0.44181275
# Loss Conf 	 0.0013674378
# Loss XY 	 0.048108194
# Average Recall 	 0.5100131
# Total Loss 	 1.6021453
# Dummy Line 	 [0.]
# Loss WH 	 0.76488584
# Current Recall 	 0.8125
# Average Recall 	 0.5100519
# Loss Conf 	 0.0013717222
# Loss XY 	 0.039826248
# Loss Class 	 0.11464556
# Total Loss 	 0.9207294
# Dummy Line 	 [0.]
# Loss WH 	 0.74574333
# Current Recall 	 0.5833333
# Loss XY 	 0.038310636
# Average Recall 	 0.5100613
# Loss Conf 	 0.0017206469
# Loss Class 	 0.10834581
# Total Loss 	 0.89412045
# Dummy Line 	 [0.]
# Loss WH 	 0.6781111
# Loss XY 	 0.036239784
# Current Recall 	 0.625
# Average Recall 	 0.51007605
# Loss Conf 	 0.002286574
# Loss Class 	 0.2740051
# Total Loss 	 0.99064255
# Dummy Line 	 [0.]
# Loss WH 	 0.9656123
# Average Recall 	 0.51008195
# Loss XY 	 0.040725455
# Current Recall 	 0.5555556
# Loss Class 	 0.36722392
# Loss Conf 	 0.001753276
# Total Loss 	 1.375315
# Dummy Line 	 [0.]
# Loss WH 	 0.5132205
# Loss XY 	 0.03410933
# Average Recall 	 0.5100766
# Loss Conf 	 0.002112646
# Current Recall 	 0.46835443
# Loss Class 	 0.23855963
# Total Loss 	 0.78800213
# Dummy Line 	 [0.]
# Loss WH 	 0.9869993
# Loss XY 	 0.0272335
# Loss Conf 	 0.0011360545
# Average Recall 	 0.5101206
# Current Recall 	 0.85294116
# Loss Class 	 0.08297765
# Total Loss 	 1.0983465
# Dummy Line 	 [0.]
# Loss WH 	 0.62665385
# Current Recall 	 0.52380955
# Loss XY 	 0.026522664
# Average Recall 	 0.51012236
# Loss Class 	 0.22311099
# Loss Conf 	 0.001962781
# Total Loss 	 0.87825024
# Dummy Line 	 [0.]
# Loss WH 	 1.0229856
# Loss Conf 	 0.0019827115
# Average Recall 	 0.5101326
# Loss XY 	 0.044649202
# Current Recall 	 0.59016395
# Loss Class 	 0.27514756
# Total Loss 	 1.3447651
# Dummy Line 	 [0.]
# Loss WH 	 0.6329244
# Loss XY 	 0.027911186
# Average Recall 	 0.510149
# Loss Conf 	 0.001646361
# Current Recall 	 0.63793105
# Loss Class 	 0.13439068
# Total Loss 	 0.7968726
# Dummy Line 	 [0.]
# Loss WH 	 0.7747392
# Loss XY 	 0.0273196
# Loss Conf 	 0.0011262058
# Average Recall 	 0.51017517
# Current Recall 	 0.71428573
# Loss Class 	 0.085838
# Total Loss 	 0.88902307
# Dummy Line 	 [0.]
# Loss WH 	 1.131028
# Loss XY 	 0.035539072
# Current Recall 	 0.6923077
# Average Recall 	 0.51019853
# Loss Conf 	 0.0014959663
# Loss Class 	 0.26114362
# Total Loss 	 1.4292066
# Dummy Line 	 [0.]
# Loss WH 	 0.87751544
# Loss XY 	 0.052203506
# Average Recall 	 0.5102024
# Loss Conf 	 0.001442925
# Current Recall 	 0.5405405
# Loss Class 	 0.043738298
# Total Loss 	 0.9749002
# Dummy Line 	 [0.]
# Loss WH 	 0.5452762
# Loss XY 	 0.04723854
# Current Recall 	 0.62068963
# Loss Conf 	 0.0017653727
# Average Recall 	 0.5102166
# Loss Class 	 0.2253115
# Total Loss 	 0.81959164
# Dummy Line 	 [0.]
# Loss WH 	 0.6612417
# Current Recall 	 0.69491524
# Loss XY 	 0.033579938
# Loss Conf 	 0.0016391592
# Average Recall 	 0.51024026
# Loss Class 	 0.16303411
# Total Loss 	 0.8594949
# Dummy Line 	 [0.]
# Loss WH 	 0.90056264
# Loss XY 	 0.038369127
# Loss Conf 	 0.0013659911
# Average Recall 	 0.51025933
# Current Recall 	 0.65909094
# Loss Class 	 0.055619814
# Total Loss 	 0.9959176
# Dummy Line 	 [0.]
# Loss XY 	 0.030475885
# Current Recall 	 0.7
# Average Recall 	 0.51028365
# Loss Conf 	 0.0015720648
# Loss WH 	 0.7994858
# Loss Class 	 0.2781316
# Total Loss 	 1.1096654
# Dummy Line 	 [0.]
# Loss WH 	 0.8747011
# Loss XY 	 0.044190846
# Loss Class 	 0.078144744
# Loss Conf 	 0.0019194564
# Average Recall 	 0.5102794
# Current Recall 	 0.47727272
# Total Loss 	 0.9989561
# Dummy Line 	 [0.]
# Loss WH 	 0.6425462
# Loss XY 	 0.043326125
# Average Recall 	 0.5102858
# Loss Conf 	 0.0026452625
# Current Recall 	 0.56
# Loss Class 	 0.28865987
# Total Loss 	 0.97717744
# Dummy Line 	 [0.]
# Loss WH 	 0.9868269
# Loss XY 	 0.03957722
# Current Recall 	 0.7567568
# Average Recall 	 0.5103174
# Loss Conf 	 0.0012632287
# Loss Class 	 0.045861207
# Total Loss 	 1.0735286
# Dummy Line 	 [0.]
# Loss XY 	 0.035891596
# Average Recall 	 0.5103383
# Loss Conf 	 0.0014105561
# Loss WH 	 0.9994159
# Current Recall 	 0.67391306
# Loss Class 	 0.16083363
# Total Loss 	 1.1975517
# Dummy Line 	 [0.]
# Loss WH 	 0.99955
# Loss XY 	 0.03177354
# Current Recall 	 0.6792453
# Average Recall 	 0.51035994
# Loss Conf 	 0.0016206669
# Loss Class 	 0.15505175
# Total Loss 	 1.1879959
# Dummy Line 	 [0.]
# Loss WH 	 1.004277
# Loss XY 	 0.042709876
# Current Recall 	 0.55172414
# Average Recall 	 0.51036525
# Loss Conf 	 0.0017600793
# Loss Class 	 0.28100434
# Total Loss 	 1.3297513
# Dummy Line 	 [0.]
# Loss XY 	 0.030472001
# Loss WH 	 1.0898454
# Average Recall 	 0.5103863
# Current Recall 	 0.675
# Loss Conf 	 0.0014202071
# Loss Class 	 0.19508027
# Total Loss 	 1.316818
# Dummy Line 	 [0.]
# Loss XY 	 0.037451338
# Loss WH 	 0.50091904
# Average Recall 	 0.5104163
# Loss Class 	 0.15100196
# Loss Conf 	 0.0013424886
# Current Recall 	 0.74509805
# Total Loss 	 0.69071484
# Dummy Line 	 [0.]
# Loss XY 	 0.0554747
# Loss WH 	 1.0626276
# Average Recall 	 0.510431
# Loss Conf 	 0.0012833276
# Current Recall 	 0.625
# Loss Class 	 0.2059664
# Total Loss 	 1.325352
# Dummy Line 	 [0.]
# Loss XY 	 0.045436434
# Loss WH 	 1.0120628
# Current Recall 	 0.6666667
# Average Recall 	 0.510451
# Loss Conf 	 0.0012574669
# Loss Class 	 0.2492904
# Total Loss 	 1.308047
# Dummy Line 	 [0.]
# Loss WH 	 1.5474762
# Loss XY 	 0.04272797
# Average Recall 	 0.51049536
# Current Recall 	 0.8571428
# Loss Conf 	 0.00094447704
# Loss Class 	 0.3373086
# Total Loss 	 1.9284573
# Dummy Line 	 [0.]
# Loss WH 	 0.9156272
# Loss XY 	 0.043017667
# Average Recall 	 0.51050264
# Loss Conf 	 0.002352916
# Current Recall 	 0.5671642
# Loss Class 	 0.24358727
# Total Loss 	 1.2045851
# Dummy Line 	 [0.]
# Loss WH 	 0.49903917
# Loss XY 	 0.04174282
# Current Recall 	 0.64285713
# Loss Conf 	 0.0011886398
# Average Recall 	 0.51051956
# Loss Class 	 0.124039695
# Total Loss 	 0.6660103
# Dummy Line 	 [0.]
# Loss WH 	 0.89558655
# Loss XY 	 0.053758178
# Loss Conf 	 0.001790154
# Average Recall 	 0.5105295
# Current Recall 	 0.5882353
# Loss Class 	 0.14025624
# Total Loss 	 1.0913912
# Dummy Line 	 [0.]
# Loss WH 	 0.5872406
# Loss XY 	 0.04082189
# Current Recall 	 0.47692308
# Average Recall 	 0.51052517
# Loss Conf 	 0.0018509431
# Loss Class 	 0.27769965
# Total Loss 	 0.9076131
# Dummy Line 	 [0.]
# Loss WH 	 0.7701691
# Loss XY 	 0.03073659
# Current Recall 	 0.59090906
# Average Recall 	 0.5105354
# Loss Conf 	 0.0013284713
# Loss Class 	 0.19127274
# Total Loss 	 0.99350685
# Dummy Line 	 [0.]
# Loss XY 	 0.041949786
# Loss WH 	 0.7483836
# Loss Conf 	 0.0021813062
# Average Recall 	 0.5105435
# Current Recall 	 0.57377046
# Loss Class 	 0.14521545
# Total Loss 	 0.93773013
# Dummy Line 	 [0.]
# Loss WH 	 0.5180938
# Loss XY 	 0.055191368
# Current Recall 	 0.47191012
# Average Recall 	 0.5105386
# Loss Conf 	 0.003293511
# Loss Class 	 0.9012672
# Total Loss 	 1.4778459
# Dummy Line 	 [0.]
# Loss WH 	 0.55167997
# Loss XY 	 0.022526244
# Current Recall 	 0.625
# Loss Conf 	 0.0013860775
# Average Recall 	 0.51055324
# Loss Class 	 0.4043567
# Total Loss 	 0.979949
# Dummy Line 	 [0.]
# Loss WH 	 0.8109241
# Loss XY 	 0.042367943
# Current Recall 	 0.6296296
# Average Recall 	 0.51056844
# Loss Conf 	 0.0015399714
# Loss Class 	 0.24746314
# Total Loss 	 1.1022952
# Dummy Line 	 [0.]
# Loss WH 	 0.87297344
# Average Recall 	 0.5105705
# Current Recall 	 0.527027
# Loss Conf 	 0.0020410633
# Loss Class 	 0.23414767
# Loss XY 	 0.0558116
# Total Loss 	 1.1649737
# Dummy Line 	 [0.]
# Loss WH 	 1.4211152
# Current Recall 	 0.74285716
# Average Recall 	 0.51060027
# Loss XY 	 0.047049604
# Loss Conf 	 0.00093422184
# Loss Class 	 0.44093975
# Total Loss 	 1.9100388
# Dummy Line 	 [0.]
# Loss WH 	 0.6440048
# Loss XY 	 0.054456174
# Loss Conf 	 0.0016572009
# Current Recall 	 0.5614035
# Average Recall 	 0.51060677
# Loss Class 	 0.23934247
# Total Loss 	 0.93946064
# Dummy Line 	 [0.]
# Loss WH 	 0.62202454
# Loss XY 	 0.03962543
# Current Recall 	 0.7358491
# Average Recall 	 0.5106355
# Loss Conf 	 0.0011895295
# Loss Class 	 0.21756828
# Total Loss 	 0.88040775
# Dummy Line 	 [0.]
# Loss WH 	 0.73184097
# Loss XY 	 0.03286135
# Current Recall 	 0.625
# Average Recall 	 0.51065016
# Loss Conf 	 0.0017969524
# Loss Class 	 0.34297276
# Total Loss 	 1.109472
# Dummy Line 	 [0.]
# Loss WH 	 0.72993404
# Loss XY 	 0.035639208
# Current Recall 	 0.6666667
# Average Recall 	 0.51067007
# Loss Conf 	 0.00144239
# Loss Class 	 0.19220036
# Total Loss 	 0.959216
# Dummy Line 	 [0.]
# Loss XY 	 0.03479056
# Loss WH 	 0.38612783
# Loss Conf 	 0.0023348243
# Average Recall 	 0.51067835
# Current Recall 	 0.5753425
# Loss Class 	 0.09098568
# Total Loss 	 0.5142389
# Dummy Line 	 [0.]
# Loss XY 	 0.050661094
# Loss WH 	 0.7206472
# Current Recall 	 0.7169811
# Loss Conf 	 0.0016689147
# Average Recall 	 0.5107047
# Loss Class 	 0.15788841
# Total Loss 	 0.93086565
# Dummy Line 	 [0.]
# Loss XY 	 0.03365574
# Loss WH 	 0.6980897
# Loss Conf 	 0.0016829551
# Average Recall 	 0.51071787
# Current Recall 	 0.61403507
# Loss Class 	 0.22389
# Total Loss 	 0.9573184
# Dummy Line 	 [0.]
# Loss WH 	 0.9654458
# Loss XY 	 0.042535942
# Average Recall 	 0.51071924
# Loss Conf 	 0.0027862703
# Current Recall 	 0.52112675
# Loss Class 	 0.4390938
# Total Loss 	 1.4498619
# Dummy Line 	 [0.]
# Loss WH 	 0.8368424
# Loss XY 	 0.030681157
# Current Recall 	 0.5660377
# Average Recall 	 0.5107263
# Loss Conf 	 0.0016266716
# Loss Class 	 0.3613454
# Total Loss 	 1.2304957
# Dummy Line 	 [0.]
# Loss WH 	 0.9910147
# Average Recall 	 0.5107367
# Loss Conf 	 0.0014829085
# Loss Class 	 0.27243072
# Current Recall 	 0.5925926
# Loss XY 	 0.041764572
# Total Loss 	 1.3066931
# Dummy Line 	 [0.]
# Loss XY 	 0.045742117
# Loss WH 	 1.2137223
# Current Recall 	 0.69491524
# Loss Conf 	 0.0018168172
# Average Recall 	 0.5107602
# Loss Class 	 0.2852247
# Total Loss 	 1.546506
# Dummy Line 	 [0.]
# Loss WH 	 0.37941045
# Current Recall 	 0.6944444
# Average Recall 	 0.5107836
# Loss Conf 	 0.0019231085
# Loss XY 	 0.029811425
# Loss Class 	 0.13492411
# Total Loss 	 0.5460691
# Dummy Line 	 [0.]
# Loss WH 	 1.7160484
# Loss XY 	 0.040489703
# Current Recall 	 0.8
# Average Recall 	 0.5108205
# Loss Conf 	 0.0019109487
# Loss Class 	 0.15787774
# Total Loss 	 1.9163268
# Dummy Line 	 [0.]
# Current Recall 	 0.59090906
# Loss WH 	 0.8696327
# Loss XY 	 0.044871643
# Loss Conf 	 0.0025054654
# Average Recall 	 0.5108307
# Loss Class 	 0.3674528
# Total Loss 	 1.2844627
# Dummy Line 	 [0.]
# Loss WH 	 0.8774415
# Loss XY 	 0.037416372
# Average Recall 	 0.5108407
# Loss Conf 	 0.0019833627
# Current Recall 	 0.58928573
# Loss Class 	 0.17725293
# Total Loss 	 1.0940942
# Dummy Line 	 [0.]
# Loss Conf 	 0.00187964
# Loss XY 	 0.037294358
# Current Recall 	 0.64179105
# Average Recall 	 0.51085746
# Loss WH 	 0.5520704
# Loss Class 	 0.33027548
# Total Loss 	 0.9215199
# Dummy Line 	 [0.]
# Loss WH 	 0.44650087
# Loss XY 	 0.03608704
# Current Recall 	 0.6779661
# Average Recall 	 0.51087874
# Loss Conf 	 0.001248961
# Loss Class 	 0.21412317
# Total Loss 	 0.69796
# Dummy Line 	 [0.]
# Loss WH 	 1.1025966
# Loss XY 	 0.036461044
# Current Recall 	 0.6875
# Average Recall 	 0.5109013
# Loss Conf 	 0.00086081127
# Loss Class 	 0.16106991
# Total Loss 	 1.3009883
# Dummy Line 	 [0.]
# Loss WH 	 0.9340677
# Loss XY 	 0.04929586
# Current Recall 	 0.74193543
# Average Recall 	 0.5109307
# Loss Conf 	 0.0011392188
# Loss Class 	 0.25612694
# Total Loss 	 1.2406297
# Dummy Line 	 [0.]
# Loss WH 	 0.7008897
# Loss XY 	 0.036008928
# Average Recall 	 0.5109366
# Loss Conf 	 0.0023374287
# Current Recall 	 0.55737704
# Loss Class 	 0.107145846
# Total Loss 	 0.84638196
# Dummy Line 	 [0.]
# Loss WH 	 0.8308655
# Loss XY 	 0.046072945
# Current Recall 	 0.73134327
# Average Recall 	 0.51096475
# Loss Class 	 0.306888
# Loss Conf 	 0.002187166
# Total Loss 	 1.1860137
# Dummy Line 	 [0.]
# Loss WH 	 1.1373152
# Loss XY 	 0.03467736
# Current Recall 	 0.75
# Average Recall 	 0.5109952
# Loss Conf 	 0.0013459258
# Loss Class 	 0.1251822
# Total Loss 	 1.2985206
# Dummy Line 	 [0.]
# Loss WH 	 1.2590976
# Loss XY 	 0.043690816
# Loss Conf 	 0.0017512033
# Current Recall 	 0.5116279
# Average Recall 	 0.51099527
# Loss Class 	 0.16788393
# Total Loss 	 1.4724236
# Dummy Line 	 [0.]
# Loss XY 	 0.03874818
# Loss WH 	 1.336088
# Average Recall 	 0.51099676
# Current Recall 	 0.52272725
# Loss Conf 	 0.0016221519
# Loss Class 	 0.47905466
# Total Loss 	 1.855513
# 251/251 [==============================] - 124s 494ms/step - loss: 1.3288 - val_loss: 1.1273
#
# Epoch 00100: val_loss improved from 1.12936 to 1.12734, saving model to weights_coco.h5

# %%
g = BatchGenerator(val_imgs, generator_config, norm=normalize, jitter=False)
evaluate(g)
# Out:
# {0: 0.5027604464185125,
#  1: 0.8007360002875297,
#  2: 0.8706157899339715,
#  3: 0.7343230217257609,
#  4: 0.7037026780613848,
#  5: 0.8679007689651812,
#  6: 0.8107863497898022,
#  7: 0.0,
#  8: 0.0,
#  9: 0.0,
#  10: 0.7297817819177944,
#  11: 0.8858266360680971,
#  12: 0.5933405852799194,
#  13: 0.48357583782759894,
#  14: 0.6622770399779285,
#  15: 0.3691869948162688,
#  16: 0.8036591317847356,
#  17: 0.42651611296864717,
#  18: 0.5103276625598058,
#  19: 0.6726497427496113,
#  20: 0.6802771488820143,
#  21: 0.8219347712136933,
#  22: 0.7493133913725977}
