# %% [markdown]
# <a href="https://colab.research.google.com/github/Anil1331/YOLOv2/blob/master/YOLOv2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget -q http://pjreddie.com/media/files/VOCtrainval_06-Nov-2007.tar
# !tar -xf VOCtrainval_06-Nov-2007.tar

# %%
classes = {'chair': 1432, 'car': 1644, 'horse': 406, 'person': 5447, 'bicycle': 418, 'cat': 389, 'dog': 538, 'head': 439, 'foot': 434, 'hand': 681, 'train': 328, 'aeroplane': 331, 'diningtable': 310, 'tvmonitor': 367, 'bird': 599, 'bottle': 634, 'motorbike': 390, 'pottedplant': 625, 'boat': 398, 'sofa': 425, 'sheep': 353, 'cow': 356, 'bus': 272}
LABELS = list(classes.keys())

# %%
import os
import cv2
import copy
import numpy as np
import imgaug as ia
from imgaug import augmenters as iaa
from keras.utils import Sequence
import xml.etree.ElementTree as ET
import random 
def get_images(ann_dir, img_dir, ann, labels, all_imgs, seen_labels):
  img = {'object':[]}

  tree = ET.parse(ann_dir + ann)

  for elem in tree.iter():
      if 'filename' in elem.tag:
          img['filename'] = img_dir + elem.text
      if 'width' in elem.tag:
          img['width'] = int(elem.text)
      if 'height' in elem.tag:
          img['height'] = int(elem.text)
      if 'object' in elem.tag or 'part' in elem.tag:
          obj = {}

          for attr in list(elem):
              if 'name' in attr.tag:
                  obj['name'] = attr.text

                  if obj['name'] in seen_labels:
                      seen_labels[obj['name']] += 1
                  else:
                      seen_labels[obj['name']] = 1

                  if len(labels) > 0 and obj['name'] not in labels:
                      break
                  else:
                      img['object'] += [obj]

              if 'bndbox' in attr.tag:
                  for dim in list(attr):
                      if 'xmin' in dim.tag:
                          obj['xmin'] = int(round(float(dim.text)))
                      if 'ymin' in dim.tag:
                          obj['ymin'] = int(round(float(dim.text)))
                      if 'xmax' in dim.tag:
                          obj['xmax'] = int(round(float(dim.text)))
                      if 'ymax' in dim.tag:
                          obj['ymax'] = int(round(float(dim.text)))

  if len(img['object']) > 0:
      all_imgs += [img] 
  return all_imgs, seen_labels    

def parse_annotation(ann_dir, img_dir, labels=[]):
    files = os.listdir(ann_dir)
    train = random.sample(files, int((len(files)*4)/5))
    test = [x for x in files if x not in train]
    print(len(train), len(test))
    train_imgs, train_labels, val_imgs, val_labels = [], {}, [], {}
    for ann in sorted(train):
        get_images(ann_dir, img_dir, ann, labels, train_imgs, train_labels)
    for ann in sorted(test):
        get_images(ann_dir, img_dir, ann, labels, val_imgs, val_labels)        
    return train_imgs, train_labels, val_imgs, val_labels

class BatchGenerator(Sequence):
    def __init__(self, images, 
                       config, 
                       shuffle=True, 
                       jitter=True, 
                       norm=None):
        self.generator = None

        self.images = images
        self.config = config

        self.shuffle = shuffle
        self.jitter  = jitter
        self.norm    = norm

        self.anchors = [BoundBox(0, 0, config['ANCHORS'][2*i], config['ANCHORS'][2*i+1]) for i in range(int(len(config['ANCHORS'])//2))]

        ### augmentors by https://github.com/aleju/imgaug
        sometimes = lambda aug: iaa.Sometimes(0.5, aug)

        # Define our sequence of augmentation steps that will be applied to every image
        # All augmenters with per_channel=0.5 will sample one value _per image_
        # in 50% of all cases. In all other cases they will sample new values
        # _per channel_.
        self.aug_pipe = iaa.Sequential(
            [
                # apply the following augmenters to most images
                #iaa.Fliplr(0.5), # horizontally flip 50% of all images
                #iaa.Flipud(0.2), # vertically flip 20% of all images
                #sometimes(iaa.Crop(percent=(0, 0.1))), # crop images by 0-10% of their height/width
                sometimes(iaa.Affine(
                    #scale={"x": (0.8, 1.2), "y": (0.8, 1.2)}, # scale images to 80-120% of their size, individually per axis
                    #translate_percent={"x": (-0.2, 0.2), "y": (-0.2, 0.2)}, # translate by -20 to +20 percent (per axis)
                    #rotate=(-5, 5), # rotate by -45 to +45 degrees
                    #shear=(-5, 5), # shear by -16 to +16 degrees
                    #order=[0, 1], # use nearest neighbour or bilinear interpolation (fast)
                    #cval=(0, 255), # if mode is constant, use a cval between 0 and 255
                    #mode=ia.ALL # use any of scikit-image's warping modes (see 2nd image from the top for examples)
                )),
                # execute 0 to 5 of the following (less important) augmenters per image
                # don't execute all of them, as that would often be way too strong
                iaa.SomeOf((0, 5),
                    [
                        #sometimes(iaa.Superpixels(p_replace=(0, 1.0), n_segments=(20, 200))), # convert images into their superpixel representation
                        iaa.OneOf([
                            iaa.GaussianBlur((0, 3.0)), # blur images with a sigma between 0 and 3.0
                            iaa.AverageBlur(k=(2, 7)), # blur image using local means with kernel sizes between 2 and 7
                            iaa.MedianBlur(k=(3, 11)), # blur image using local medians with kernel sizes between 2 and 7
                        ]),
                        iaa.Sharpen(alpha=(0, 1.0), lightness=(0.75, 1.5)), # sharpen images
                        #iaa.Emboss(alpha=(0, 1.0), strength=(0, 2.0)), # emboss images
                        # search either for all edges or for directed edges
                        #sometimes(iaa.OneOf([
                        #    iaa.EdgeDetect(alpha=(0, 0.7)),
                        #    iaa.DirectedEdgeDetect(alpha=(0, 0.7), direction=(0.0, 1.0)),
                        #])),
                        iaa.AdditiveGaussianNoise(loc=0, scale=(0.0, 0.05*255), per_channel=0.5), # add gaussian noise to images
                        iaa.OneOf([
                            iaa.Dropout((0.01, 0.1), per_channel=0.5), # randomly remove up to 10% of the pixels
                            #iaa.CoarseDropout((0.03, 0.15), size_percent=(0.02, 0.05), per_channel=0.2),
                        ]),
                        #iaa.Invert(0.05, per_channel=True), # invert color channels
                        iaa.Add((-10, 10), per_channel=0.5), # change brightness of images (by -10 to 10 of original value)
                        iaa.Multiply((0.5, 1.5), per_channel=0.5), # change brightness of images (50-150% of original value)
                        iaa.ContrastNormalization((0.5, 2.0), per_channel=0.5), # improve or worsen the contrast
                        #iaa.Grayscale(alpha=(0.0, 1.0)),
                        #sometimes(iaa.ElasticTransformation(alpha=(0.5, 3.5), sigma=0.25)), # move pixels locally around (with random strengths)
                        #sometimes(iaa.PiecewiseAffine(scale=(0.01, 0.05))) # sometimes move parts of the image around
                    ],
                    random_order=True
                )
            ],
            random_order=True
        )

        if shuffle: np.random.shuffle(self.images)

    def __len__(self):
        return int(np.ceil(float(len(self.images))/self.config['BATCH_SIZE']))   

    def num_classes(self):
        return len(self.config['LABELS'])

    def size(self):
        return len(self.images)    

    def load_annotation(self, i):
        annots = []

        for obj in self.images[i]['object']:
            annot = [obj['xmin'], obj['ymin'], obj['xmax'], obj['ymax'], self.config['LABELS'].index(obj['name'])]
            annots += [annot]

        if len(annots) == 0: annots = [[]]

        return np.array(annots)

    def load_image(self, i):
        return cv2.imread(self.images[i]['filename'])

    def __getitem__(self, idx):
        l_bound = idx*self.config['BATCH_SIZE']
        r_bound = (idx+1)*self.config['BATCH_SIZE']

        if r_bound > len(self.images):
            r_bound = len(self.images)
            l_bound = r_bound - self.config['BATCH_SIZE']

        instance_count = 0

        x_batch = np.zeros((r_bound - l_bound, self.config['IMAGE_H'], self.config['IMAGE_W'], 3))                         # input images
        b_batch = np.zeros((r_bound - l_bound, 1     , 1     , 1    ,  self.config['TRUE_BOX_BUFFER'], 4))   # list of self.config['TRUE_self.config['BOX']_BUFFER'] GT boxes
        y_batch = np.zeros((r_bound - l_bound, self.config['GRID_H'],  self.config['GRID_W'], self.config['BOX'], 4+1+len(self.config['LABELS'])))                # desired network output

        for train_instance in self.images[l_bound:r_bound]:
            # augment input image and fix object's position and size
            img, all_objs = self.aug_image(train_instance, jitter=self.jitter)
            
            # construct output from object's x, y, w, h
            true_box_index = 0
            
            for obj in all_objs:
                if obj['xmax'] > obj['xmin'] and obj['ymax'] > obj['ymin'] and obj['name'] in self.config['LABELS']:
                    center_x = .5*(obj['xmin'] + obj['xmax'])
                    center_x = center_x / (float(self.config['IMAGE_W']) / self.config['GRID_W'])
                    center_y = .5*(obj['ymin'] + obj['ymax'])
                    center_y = center_y / (float(self.config['IMAGE_H']) / self.config['GRID_H'])

                    grid_x = int(np.floor(center_x))
                    grid_y = int(np.floor(center_y))

                    if grid_x < self.config['GRID_W'] and grid_y < self.config['GRID_H']:
                        obj_indx  = self.config['LABELS'].index(obj['name'])
                        
                        center_w = (obj['xmax'] - obj['xmin']) / (float(self.config['IMAGE_W']) / self.config['GRID_W']) # unit: grid cell
                        center_h = (obj['ymax'] - obj['ymin']) / (float(self.config['IMAGE_H']) / self.config['GRID_H']) # unit: grid cell
                        
                        box = [center_x, center_y, center_w, center_h]

                        # find the anchor that best predicts this box
                        best_anchor = -1
                        max_iou     = -1
                        
                        shifted_box = BoundBox(0, 
                                               0,
                                               center_w,                                                
                                               center_h)
                        
                        for i in range(len(self.anchors)):
                            anchor = self.anchors[i]
                            iou    = bbox_iou(shifted_box, anchor)
                            
                            if max_iou < iou:
                                best_anchor = i
                                max_iou     = iou
                                
                        # assign ground truth x, y, w, h, confidence and class probs to y_batch
                        y_batch[instance_count, grid_y, grid_x, best_anchor, 0:4] = box
                        y_batch[instance_count, grid_y, grid_x, best_anchor, 4  ] = 1.
                        y_batch[instance_count, grid_y, grid_x, best_anchor, 5+obj_indx] = 1
                        
                        # assign the true box to b_batch
                        b_batch[instance_count, 0, 0, 0, true_box_index] = box
                        
                        true_box_index += 1
                        true_box_index = true_box_index % self.config['TRUE_BOX_BUFFER']
                            
            # assign input image to x_batch
            if self.norm != None: 
                x_batch[instance_count] = self.norm(img)
            else:
                # plot image and bounding boxes for sanity check
                for obj in all_objs:
                    if obj['xmax'] > obj['xmin'] and obj['ymax'] > obj['ymin']:
                        cv2.rectangle(img[:,:,::-1], (obj['xmin'],obj['ymin']), (obj['xmax'],obj['ymax']), (255,0,0), 3)
                        cv2.putText(img[:,:,::-1], obj['name'], 
                                    (obj['xmin']+2, obj['ymin']+12), 
                                    0, 1.2e-3 * img.shape[0], 
                                    (0,255,0), 2)
                        
                x_batch[instance_count] = img

            # increase instance counter in current batch
            instance_count += 1  

        #print(' new batch created', idx)

        return [x_batch, b_batch], y_batch

    def on_epoch_end(self):
        if self.shuffle: np.random.shuffle(self.images)

    def aug_image(self, train_instance, jitter):
        image_name = train_instance['filename']
        image = cv2.imread(image_name)

        if image is None: print('Cannot find ', image_name)

        h, w, c = image.shape
        all_objs = copy.deepcopy(train_instance['object'])

        if jitter:
            ### scale the image
            scale = np.random.uniform() / 10. + 1.
            image = cv2.resize(image, (0,0), fx = scale, fy = scale)

            ### translate the image
            max_offx = (scale-1.) * w
            max_offy = (scale-1.) * h
            offx = int(np.random.uniform() * max_offx)
            offy = int(np.random.uniform() * max_offy)
            
            image = image[offy : (offy + h), offx : (offx + w)]

            ### flip the image
            flip = np.random.binomial(1, .5)
            if flip > 0.5: image = cv2.flip(image, 1)
                
            image = self.aug_pipe.augment_image(image)            
            
        # resize the image to standard size
        image = cv2.resize(image, (self.config['IMAGE_H'], self.config['IMAGE_W']))
        image = image[:,:,::-1]

        # fix object's position and size
        for obj in all_objs:
            for attr in ['xmin', 'xmax']:
                if jitter: obj[attr] = int(obj[attr] * scale - offx)
                    
                obj[attr] = int(obj[attr] * float(self.config['IMAGE_W']) / w)
                obj[attr] = max(min(obj[attr], self.config['IMAGE_W']), 0)
                
            for attr in ['ymin', 'ymax']:
                if jitter: obj[attr] = int(obj[attr] * scale - offy)
                    
                obj[attr] = int(obj[attr] * float(self.config['IMAGE_H']) / h)
                obj[attr] = max(min(obj[attr], self.config['IMAGE_H']), 0)

            if jitter and flip > 0.5:
                xmin = obj['xmin']
                obj['xmin'] = self.config['IMAGE_W'] - obj['xmax']
                obj['xmax'] = self.config['IMAGE_W'] - xmin
                
        return image, all_objs
# Out:
# Using TensorFlow backend.

# %%
import numpy as np
import os
import xml.etree.ElementTree as ET
import tensorflow as tf
import copy
import cv2

class BoundBox:
    def __init__(self, xmin, ymin, xmax, ymax, c = None, classes = None):
        self.xmin = xmin
        self.ymin = ymin
        self.xmax = xmax
        self.ymax = ymax
        
        self.c     = c
        self.classes = classes

        self.label = -1
        self.score = -1

    def get_label(self):
        if self.label == -1:
            self.label = np.argmax(self.classes)
        
        return self.label
    
    def get_score(self):
        if self.score == -1:
            self.score = self.classes[self.get_label()]
            
        return self.score

class WeightReader:
    def __init__(self, weight_file):
        self.offset = 4
        self.all_weights = np.fromfile(weight_file, dtype='float32')
        
    def read_bytes(self, size):
        self.offset = self.offset + size
        return self.all_weights[self.offset-size:self.offset]
    
    def reset(self):
        self.offset = 4

def bbox_iou(box1, box2):
    intersect_w = _interval_overlap([box1.xmin, box1.xmax], [box2.xmin, box2.xmax])
    intersect_h = _interval_overlap([box1.ymin, box1.ymax], [box2.ymin, box2.ymax])  
    
    intersect = intersect_w * intersect_h

    w1, h1 = box1.xmax-box1.xmin, box1.ymax-box1.ymin
    w2, h2 = box2.xmax-box2.xmin, box2.ymax-box2.ymin
    
    union = w1*h1 + w2*h2 - intersect
    
    return float(intersect) / union

def draw_boxes(image, boxes, labels):
    image_h, image_w, _ = image.shape

    for box in boxes:
        xmin = int(box.xmin*image_w)
        ymin = int(box.ymin*image_h)
        xmax = int(box.xmax*image_w)
        ymax = int(box.ymax*image_h)

        cv2.rectangle(image, (xmin,ymin), (xmax,ymax), (0,255,0), 3)
        cv2.putText(image, 
                    labels[box.get_label()] + ' ' + str(box.get_score()), 
                    (xmin, ymin - 13), 
                    cv2.FONT_HERSHEY_SIMPLEX, 
                    1e-3 * image_h, 
                    (0,255,0), 2)
        
    return image          
        
def decode_netout(netout, anchors, nb_class, obj_threshold=0.3, nms_threshold=0.3):
    grid_h, grid_w, nb_box = netout.shape[:3]

    boxes = []
    # decode the output by the network
    netout[..., 4]  = _sigmoid(netout[..., 4])
    netout[..., 5:] = netout[..., 4][..., np.newaxis] * _softmax(netout[..., 5:])
    #print(np.max(netout[..., 5:]))
    netout[..., 5:] *= netout[..., 5:] > obj_threshold
    
    for row in range(grid_h):
        for col in range(grid_w):
            for b in range(nb_box):
                # from 4th element onwards are confidence and class classes
                classes = netout[row,col,b,5:]
                if np.sum(classes) > 0:
                    # first 4 elements are x, y, w, and h
                    x, y, w, h = netout[row,col,b,:4]

                    x = (col + _sigmoid(x)) / grid_w # center position, unit: image width
                    y = (row + _sigmoid(y)) / grid_h # center position, unit: image height
                    w = anchors[2 * b + 0] * np.exp(w) / grid_w # unit: image width
                    h = anchors[2 * b + 1] * np.exp(h) / grid_h # unit: image height
                    confidence = netout[row,col,b,4]
                    
                    box = BoundBox(x-w/2, y-h/2, x+w/2, y+h/2, confidence, classes)
                    
                    boxes.append(box)
    #print(boxes)
    # suppress non-maximal boxes
    for c in range(nb_class):
        sorted_indices = list(reversed(np.argsort([box.classes[c] for box in boxes])))

        for i in range(len(sorted_indices)):
            index_i = sorted_indices[i]
            
            if boxes[index_i].classes[c] == 0: 
                continue
            else:
                for j in range(i+1, len(sorted_indices)):
                    index_j = sorted_indices[j]
                    
                    if bbox_iou(boxes[index_i], boxes[index_j]) >= nms_threshold:
                        boxes[index_j].classes[c] = 0
                        
    #print([box.get_score() for box in boxes])                    
    # remove the boxes which are less likely than a obj_threshold
    boxes = [box for box in boxes if box.get_score() > obj_threshold]
    
    return boxes    

def compute_overlap(a, b):
    """
    Code originally from https://github.com/rbgirshick/py-faster-rcnn.
    Parameters
    ----------
    a: (N, 4) ndarray of float
    b: (K, 4) ndarray of float
    Returns
    -------
    overlaps: (N, K) ndarray of overlap between boxes and query_boxes
    """
    area = (b[:, 2] - b[:, 0]) * (b[:, 3] - b[:, 1])

    iw = np.minimum(np.expand_dims(a[:, 2], axis=1), b[:, 2]) - np.maximum(np.expand_dims(a[:, 0], 1), b[:, 0])
    ih = np.minimum(np.expand_dims(a[:, 3], axis=1), b[:, 3]) - np.maximum(np.expand_dims(a[:, 1], 1), b[:, 1])

    iw = np.maximum(iw, 0)
    ih = np.maximum(ih, 0)

    ua = np.expand_dims((a[:, 2] - a[:, 0]) * (a[:, 3] - a[:, 1]), axis=1) + area - iw * ih

    ua = np.maximum(ua, np.finfo(float).eps)

    intersection = iw * ih

    return intersection / ua  
    
def compute_ap(recall, precision):
    """ Compute the average precision, given the recall and precision curves.
    Code originally from https://github.com/rbgirshick/py-faster-rcnn.

    # Arguments
        recall:    The recall curve (list).
        precision: The precision curve (list).
    # Returns
        The average precision as computed in py-faster-rcnn.
    """
    # correct AP calculation
    # first append sentinel values at the end
    mrec = np.concatenate(([0.], recall, [1.]))
    mpre = np.concatenate(([0.], precision, [0.]))

    # compute the precision envelope
    for i in range(mpre.size - 1, 0, -1):
        mpre[i - 1] = np.maximum(mpre[i - 1], mpre[i])

    # to calculate area under PR curve, look for points
    # where X axis (recall) changes value
    i = np.where(mrec[1:] != mrec[:-1])[0]

    # and sum (\Delta recall) * prec
    ap = np.sum((mrec[i + 1] - mrec[i]) * mpre[i + 1])
    return ap      
        
def _interval_overlap(interval_a, interval_b):
    x1, x2 = interval_a
    x3, x4 = interval_b

    if x3 < x1:
        if x4 < x1:
            return 0
        else:
            return min(x2,x4) - x1
    else:
        if x2 < x3:
             return 0
        else:
            return min(x2,x4) - x3          

def _sigmoid(x):
    return 1. / (1. + np.exp(-x))

def _softmax(x, axis=-1, t=-100.):
    x = x - np.max(x)
    
    if np.min(x) < t:
        x = x/np.min(x)*t
        
    e_x = np.exp(x)
    
    return e_x / e_x.sum(axis, keepdims=True)

# %%
import cv2

def normalize(image):
  return image / 255.

'''
def normalize(image):
    image = image[..., ::-1]
    image = image.astype('float')

    image[..., 0] -= 103.939
    image[..., 1] -= 116.779
    image[..., 2] -= 123.68

    return image
'''

def predict(image):
  image_h, image_w, _ = image.shape
  image = cv2.resize(image, (IMAGE_H, IMAGE_W))
  image = normalize(image)
  input_image = image[:,:,::-1]
  input_image = np.expand_dims(input_image, 0)
  dummy_array = np.zeros((1,1,1,1,TRUE_BOX_BUFFER,4))

  netout = model.predict([input_image, dummy_array])[0]
  boxes  = decode_netout(netout, ANCHORS, CLASS)

  return boxes

def evaluate(generator, 
			 iou_threshold=0.3,
			 score_threshold=0.3,
			 max_detections=100,
			 save_path=None):
	""" Evaluate a given dataset using a given model.
	code originally from https://github.com/fizyr/keras-retinanet
	# Arguments
		generator       : The generator that represents the dataset to evaluate.
		model           : The model to evaluate.
		iou_threshold   : The threshold used to consider when a detection is positive or negative.
		score_threshold : The score confidence threshold to use for detections.
		max_detections  : The maximum number of detections to use per image.
		save_path       : The path to save images with visualized detections to.
	# Returns
		A dict mapping class names to mAP scores.
	"""    
	# gather all detections and annotations
	all_detections     = [[None for i in range(generator.num_classes())] for j in range(generator.size())]
	all_annotations    = [[None for i in range(generator.num_classes())] for j in range(generator.size())]
	for i in range(generator.size()):
		raw_image = generator.load_image(i)
		raw_height, raw_width, raw_channels = raw_image.shape

		# make the boxes and the labels
		pred_boxes  = predict(raw_image)

		
		score = np.array([box.score for box in pred_boxes])
		pred_labels = np.array([box.label for box in pred_boxes])        
		#print(len(pred_boxes))
		if len(pred_boxes) > 0:
			pred_boxes = np.array([[box.xmin*raw_width, box.ymin*raw_height, box.xmax*raw_width, box.ymax*raw_height, box.score] for box in pred_boxes])
		else:
			pred_boxes = np.array([[]])  
		
		# sort the boxes and the labels according to scores
		score_sort = np.argsort(-score)
		pred_labels = pred_labels[score_sort]
		pred_boxes  = pred_boxes[score_sort]
		
		# copy detections to all_detections
		for label in range(generator.num_classes()):
			all_detections[i][label] = pred_boxes[pred_labels == label, :]
			
		annotations = generator.load_annotation(i)
		
		# copy detections to all_annotations
		for label in range(generator.num_classes()):
			all_annotations[i][label] = annotations[annotations[:, 4] == label, :4].copy()
			
	# compute mAP by comparing all detections and all annotations
	average_precisions = {}
	
	for label in range(generator.num_classes()):
		false_positives = np.zeros((0,))
		true_positives  = np.zeros((0,))
		scores          = np.zeros((0,))
		num_annotations = 0.0

		for i in range(generator.size()):
			detections           = all_detections[i][label]
			annotations          = all_annotations[i][label]
			num_annotations     += annotations.shape[0]
			detected_annotations = []

			for d in detections:
				scores = np.append(scores, d[4])

				if annotations.shape[0] == 0:
					false_positives = np.append(false_positives, 1)
					true_positives  = np.append(true_positives, 0)
					continue

				overlaps            = compute_overlap(np.expand_dims(d, axis=0), annotations)
				assigned_annotation = np.argmax(overlaps, axis=1)
				max_overlap         = overlaps[0, assigned_annotation]

				if max_overlap >= iou_threshold and assigned_annotation not in detected_annotations:
					false_positives = np.append(false_positives, 0)
					true_positives  = np.append(true_positives, 1)
					detected_annotations.append(assigned_annotation)
				else:
					false_positives = np.append(false_positives, 1)
					true_positives  = np.append(true_positives, 0)

		# no annotations -> AP for this class is 0 (is this correct?)
		if num_annotations == 0:
			average_precisions[label] = 0
			continue

		# sort by score
		indices         = np.argsort(-scores)
		false_positives = false_positives[indices]
		true_positives  = true_positives[indices]

		# compute false positives and true positives
		false_positives = np.cumsum(false_positives)
		true_positives  = np.cumsum(true_positives)

		# compute recall and precision
		recall    = true_positives / num_annotations
		precision = true_positives / np.maximum(true_positives + false_positives, np.finfo(np.float64).eps)

		# compute average precision
		average_precision  = compute_ap(recall, precision)  
		average_precisions[label] = average_precision

	return average_precisions

# %%
train_image_folder = 'VOCdevkit/VOC2007/JPEGImages/'
train_annot_folder = 'VOCdevkit/VOC2007/Annotations/'

# %%
IMAGE_H, IMAGE_W = 416, 416
GRID_H,  GRID_W  = 13 , 13
BOX              = 5
CLASS            = len(LABELS)
CLASS_WEIGHTS    = np.ones(CLASS, dtype='float32')
OBJ_THRESHOLD    = 0.3#0.5
NMS_THRESHOLD    = 0.3#0.45
#ANCHORS          = [0.57273, 0.677385, 1.87446, 2.06253, 3.33843, 5.47434, 7.88282, 3.52778, 9.77052, 9.16828]
ANCHORS          = [0.96,1.66, 2.45,3.90, 4.01,8.17, 7.75,5.12, 9.87,10.46]

NO_OBJECT_SCALE  = 1.0
OBJECT_SCALE     = 5.0
COORD_SCALE      = 1
CLASS_SCALE      = 1

BATCH_SIZE       = 16
WARM_UP_BATCHES  = 3
TRUE_BOX_BUFFER  = 50
generator_config = {
    'IMAGE_H'         : IMAGE_H, 
    'IMAGE_W'         : IMAGE_W,
    'GRID_H'          : GRID_H,  
    'GRID_W'          : GRID_W,
    'BOX'             : BOX,
    'LABELS'          : LABELS,
    'CLASS'           : len(LABELS),
    'ANCHORS'         : ANCHORS,
    'BATCH_SIZE'      : BATCH_SIZE,
    'TRUE_BOX_BUFFER' : 50,
}

# %%
train_imgs, seen_train_labels, val_imgs, seen_val_labels = parse_annotation(train_annot_folder, train_image_folder, labels=LABELS)
# Out:
# 4008 1003

# %%
import random
import numpy as np
import json

def IOU(ann, centroids):
    w, h = ann
    similarities = []

    for centroid in centroids:
        c_w, c_h = centroid

        if c_w >= w and c_h >= h:
            similarity = w*h/(c_w*c_h)
        elif c_w >= w and c_h <= h:
            similarity = w*c_h/(w*h + (c_w-w)*c_h)
        elif c_w <= w and c_h >= h:
            similarity = c_w*h/(w*h + c_w*(c_h-h))
        else: #means both w,h are bigger than c_w and c_h respectively
            similarity = (c_w*c_h)/(w*h)
        similarities.append(similarity) # will become (k,) shape

    return np.array(similarities)

def avg_IOU(anns, centroids):
    n,d = anns.shape
    sum = 0.

    for i in range(anns.shape[0]):
        sum+= max(IOU(anns[i], centroids))

    return sum/n

def print_anchors(centroids):
    anchors = centroids.copy()

    widths = anchors[:, 0]
    sorted_indices = np.argsort(widths)

    r = "anchors: ["
    for i in sorted_indices[:-1]:
        r += '%0.2f,%0.2f, ' % (anchors[i,0], anchors[i,1])

    #there should not be comma after last anchor, that's why
    r += '%0.2f,%0.2f' % (anchors[sorted_indices[-1:],0], anchors[sorted_indices[-1:],1])
    r += "]"

    print(r)

def run_kmeans(ann_dims, anchor_num):
    ann_num = ann_dims.shape[0]
    iterations = 0
    prev_assignments = np.ones(ann_num)*(-1)
    iteration = 0
    old_distances = np.zeros((ann_num, anchor_num))

    indices = [random.randrange(ann_dims.shape[0]) for i in range(anchor_num)]
    centroids = ann_dims[indices]
    anchor_dim = ann_dims.shape[1]

    while True:
        distances = []
        iteration += 1
        for i in range(ann_num):
            d = 1 - IOU(ann_dims[i], centroids)
            distances.append(d)
        distances = np.array(distances) # distances.shape = (ann_num, anchor_num)

        print("iteration {}: dists = {}".format(iteration, np.sum(np.abs(old_distances-distances))))

        #assign samples to centroids
        assignments = np.argmin(distances,axis=1)

        if (assignments == prev_assignments).all() :
            return centroids

        #calculate new centroids
        centroid_sums=np.zeros((anchor_num, anchor_dim), np.float)
        for i in range(ann_num):
            centroid_sums[assignments[i]]+=ann_dims[i]
        for j in range(anchor_num):
            centroids[j] = centroid_sums[j]/(np.sum(assignments==j) + 1e-6)

        prev_assignments = assignments.copy()
        old_distances = distances.copy()


num_anchors = 5 
grid_w = IMAGE_W/32
grid_h = IMAGE_H/32
annotation_dims = []
for image in train_imgs:
	cell_w = image['width']/grid_w
	cell_h = image['height']/grid_h

	for obj in image['object']:
		relative_w = (float(obj['xmax']) - float(obj['xmin']))/cell_w
		relatice_h = (float(obj["ymax"]) - float(obj['ymin']))/cell_h
		annotation_dims.append(tuple(map(float, (relative_w,relatice_h))))

annotation_dims = np.array(annotation_dims)
centroids = run_kmeans(annotation_dims, num_anchors)

# write anchors to file
print('\naverage IOU for', num_anchors, 'anchors:', '%0.2f' % avg_IOU(annotation_dims, centroids))
print_anchors(centroids)
# Out:
# iteration 1: dists = 51506.4003815373
# iteration 2: dists = 2806.6039222702234
# iteration 3: dists = 1063.1462957722372
# iteration 4: dists = 699.3495961222055
# iteration 5: dists = 443.0589516840853
# iteration 6: dists = 360.31139478325696
# iteration 7: dists = 305.23297312583657
# iteration 8: dists = 269.6443349687039
# iteration 9: dists = 265.58681328514314
# iteration 10: dists = 266.3314543239605
# iteration 11: dists = 247.14845768067948
# iteration 12: dists = 209.52474149731694
# iteration 13: dists = 221.76976010033798
# iteration 14: dists = 216.77367827824918
# iteration 15: dists = 189.47083002312337
# iteration 16: dists = 164.89884215659612
# iteration 17: dists = 146.40462687263792
# iteration 18: dists = 147.06667887455708
# iteration 19: dists = 104.38060142146811
# iteration 20: dists = 80.90008122318342
# iteration 21: dists = 65.90704143126744
# iteration 22: dists = 57.42972917220072
# iteration 23: dists = 43.708406608359255
# iteration 24: dists = 42.19003233109828
# iteration 25: dists = 24.145368814971775
# iteration 26: dists = 17.627366760074178
# iteration 27: dists = 18.7328201278129
# iteration 28: dists = 16.192971363528184
# iteration 29: dists = 10.407499161191252
# iteration 30: dists = 6.959492284933354
# iteration 31: dists = 2.7363162361449636
#
# average IOU for 5 anchors: 0.58
# anchors: [0.89,1.39, 2.22,3.67, 3.80,7.99, 7.28,4.90, 9.76,10.29]

# %%
#!wget https://docs.google.com/uc?export=download&id=1Q9WhhRlqQbA4jgBkCDrynvgquRXZA_f8
import requests

def download_file_from_google_drive(id, destination):
    def get_confirm_token(response):
        for key, value in response.cookies.items():
            if key.startswith('download_warning'):
                return value

        return None

    def save_response_content(response, destination):
        CHUNK_SIZE = 32768

        with open(destination, "wb") as f:
            for chunk in response.iter_content(CHUNK_SIZE):
                if chunk: # filter out keep-alive new chunks
                    f.write(chunk)

    URL = "https://docs.google.com/uc?export=download"

    session = requests.Session()

    response = session.get(URL, params = { 'id' : id }, stream = True)
    token = get_confirm_token(response)

    if token:
        params = { 'id' : id, 'confirm' : token }
        response = session.get(URL, params = params, stream = True)

    save_response_content(response, destination)    

download_file_from_google_drive("1Q9WhhRlqQbA4jgBkCDrynvgquRXZA_f8", "weights.h5")

# %%
train_batch = BatchGenerator(train_imgs, generator_config, norm=normalize)
valid_batch = BatchGenerator(val_imgs, generator_config, norm=normalize, jitter=False)

# %%
import sys
f = open("out.txt", "w")
def tf_print(op, tensors, message=None):
    def print_message(x):
        sys.stdout.write(message + " %s\n" % x)
        f.write(message + " %s\n" % x)
        return x

    prints = [tf.py_func(print_message, [tensor], tensor.dtype) for tensor in tensors]
    with tf.control_dependencies(prints):
        op = tf.identity(op)
    return op

def custom_loss(y_true, y_pred):
    mask_shape = tf.shape(y_true)[:4]
    
    cell_x = tf.to_float(tf.reshape(tf.tile(tf.range(GRID_W), [GRID_H]), (1, GRID_H, GRID_W, 1, 1)))
    cell_y = tf.transpose(cell_x, (0,2,1,3,4))

    cell_grid = tf.tile(tf.concat([cell_x,cell_y], -1), [BATCH_SIZE, 1, 1, 5, 1])
    
    coord_mask = tf.zeros(mask_shape)
    conf_mask  = tf.zeros(mask_shape)
    class_mask = tf.zeros(mask_shape)
    
    seen = tf.Variable(0.)
    total_recall = tf.Variable(0.)
    
    """
    Adjust prediction
    """
    ### adjust x and y      
    pred_box_xy = tf.sigmoid(y_pred[..., :2]) + cell_grid
    
    ### adjust w and h
    pred_box_wh = tf.exp(y_pred[..., 2:4]) * np.reshape(ANCHORS, [1,1,1,BOX,2])
    
    ### adjust confidence
    pred_box_conf = tf.sigmoid(y_pred[..., 4])
    
    ### adjust class probabilities
    pred_box_class = y_pred[..., 5:]
    
    """
    Adjust ground truth
    """
    ### adjust x and y
    true_box_xy = y_true[..., 0:2] # relative position to the containing cell
    
    ### adjust w and h
    true_box_wh = y_true[..., 2:4] # number of cells accross, horizontally and vertically
    
    ### adjust confidence
    true_wh_half = true_box_wh / 2.
    true_mins    = true_box_xy - true_wh_half
    true_maxes   = true_box_xy + true_wh_half
    
    pred_wh_half = pred_box_wh / 2.
    pred_mins    = pred_box_xy - pred_wh_half
    pred_maxes   = pred_box_xy + pred_wh_half       
    
    intersect_mins  = tf.maximum(pred_mins,  true_mins)
    intersect_maxes = tf.minimum(pred_maxes, true_maxes)
    intersect_wh    = tf.maximum(intersect_maxes - intersect_mins, 0.)
    intersect_areas = intersect_wh[..., 0] * intersect_wh[..., 1]
    
    true_areas = true_box_wh[..., 0] * true_box_wh[..., 1]
    pred_areas = pred_box_wh[..., 0] * pred_box_wh[..., 1]

    union_areas = pred_areas + true_areas - intersect_areas
    iou_scores  = tf.truediv(intersect_areas, union_areas)
    
    true_box_conf = iou_scores * y_true[..., 4]
    
    ### adjust class probabilities
    true_box_class = tf.argmax(y_true[..., 5:], -1)
    
    """
    Determine the masks
    """
    ### coordinate mask: simply the position of the ground truth boxes (the predictors)
    coord_mask = tf.expand_dims(y_true[..., 4], axis=-1) * COORD_SCALE
    
    ### confidence mask: penelize predictors + penalize boxes with low IOU
    # penalize the confidence of the boxes, which have IOU with some ground truth box < 0.6
    true_xy = true_boxes[..., 0:2]
    true_wh = true_boxes[..., 2:4]
    
    true_wh_half = true_wh / 2.
    true_mins    = true_xy - true_wh_half
    true_maxes   = true_xy + true_wh_half
    
    pred_xy = tf.expand_dims(pred_box_xy, 4)
    pred_wh = tf.expand_dims(pred_box_wh, 4)
    
    pred_wh_half = pred_wh / 2.
    pred_mins    = pred_xy - pred_wh_half
    pred_maxes   = pred_xy + pred_wh_half    
    
    intersect_mins  = tf.maximum(pred_mins,  true_mins)
    intersect_maxes = tf.minimum(pred_maxes, true_maxes)
    intersect_wh    = tf.maximum(intersect_maxes - intersect_mins, 0.)
    intersect_areas = intersect_wh[..., 0] * intersect_wh[..., 1]
    
    true_areas = true_wh[..., 0] * true_wh[..., 1]
    pred_areas = pred_wh[..., 0] * pred_wh[..., 1]

    union_areas = pred_areas + true_areas - intersect_areas
    iou_scores  = tf.truediv(intersect_areas, union_areas)

    best_ious = tf.reduce_max(iou_scores, axis=4)
    conf_mask = conf_mask + tf.to_float(best_ious < 0.6) * (1 - y_true[..., 4]) * NO_OBJECT_SCALE
    
    # penalize the confidence of the boxes, which are reponsible for corresponding ground truth box
    conf_mask = conf_mask + y_true[..., 4] * OBJECT_SCALE
    
    ### class mask: simply the position of the ground truth boxes (the predictors)
    class_mask = y_true[..., 4] * tf.gather(CLASS_WEIGHTS, true_box_class) * CLASS_SCALE       
    
    """
    Warm-up training
    """
    no_boxes_mask = tf.to_float(coord_mask < COORD_SCALE/2.)
    seen = tf.assign_add(seen, 1.)
    
    true_box_xy, true_box_wh, coord_mask = tf.cond(tf.less(seen, WARM_UP_BATCHES), 
                          lambda: [true_box_xy + (0.5 + cell_grid) * no_boxes_mask, 
                                   true_box_wh + tf.ones_like(true_box_wh) * np.reshape(ANCHORS, [1,1,1,BOX,2]) * no_boxes_mask, 
                                   tf.ones_like(coord_mask)],
                          lambda: [true_box_xy, 
                                   true_box_wh,
                                   coord_mask])
    
    """
    Finalize the loss
    """
    nb_coord_box = tf.reduce_sum(tf.to_float(coord_mask > 0.0))
    nb_conf_box  = tf.reduce_sum(tf.to_float(conf_mask  > 0.0))
    nb_class_box = tf.reduce_sum(tf.to_float(class_mask > 0.0))
    
    loss_xy    = tf.reduce_sum(tf.square(true_box_xy-pred_box_xy)     * coord_mask) / (nb_coord_box + 1e-6) / 2.
    loss_wh    = tf.reduce_sum(tf.square(true_box_wh-pred_box_wh)     * coord_mask) / (nb_coord_box + 1e-6) / 2.
    loss_conf  = tf.reduce_sum(tf.square(true_box_conf-pred_box_conf) * conf_mask)  / (nb_conf_box  + 1e-6) / 2.
    loss_class = tf.nn.sparse_softmax_cross_entropy_with_logits(labels=true_box_class, logits=pred_box_class)
    loss_class = tf.reduce_sum(loss_class * class_mask) / (nb_class_box + 1e-6)
    
    loss_xy = tf.clip_by_value(loss_xy, 0, 10000000)
    loss_wh = tf.clip_by_value(loss_wh, 0, 10000000)  
    loss_conf = tf.clip_by_value(loss_conf, 0, 10000000)
    loss_class = tf.clip_by_value(loss_class, 0, 10000000)
    loss = loss_xy + loss_wh + loss_conf + loss_class
    
    nb_true_box = tf.reduce_sum(y_true[..., 4])
    nb_pred_box = tf.reduce_sum(tf.to_float(true_box_conf > 0.5) * tf.to_float(pred_box_conf > 0.3))

    """
    Debugging code
    """    
    current_recall = nb_pred_box/(nb_true_box + 1e-6)
    total_recall = tf.assign_add(total_recall, current_recall) 

    loss = tf_print(loss, [tf.zeros((1))], message='Dummy Line \t')
    loss = tf_print(loss, [loss_xy], message='Loss XY \t')
    loss = tf_print(loss, [loss_wh], message='Loss WH \t')
    loss = tf_print(loss, [loss_conf], message='Loss Conf \t')
    loss = tf_print(loss, [loss_class], message='Loss Class \t')
    loss = tf_print(loss, [loss], message='Total Loss \t')
    loss = tf_print(loss, [current_recall], message='Current Recall \t')
    loss = tf_print(loss, [total_recall/seen], message='Average Recall \t')
    
    return loss

# %%
from keras.callbacks import EarlyStopping, ModelCheckpoint, TensorBoard
early_stop = EarlyStopping(monitor='val_loss', 
                           min_delta=0.001, 
                           patience=3, 
                           mode='min', 
                           verbose=1)

checkpoint = ModelCheckpoint('weights_coco.h5', 
                             monitor='val_loss', 
                             verbose=1, 
                             save_best_only=True, 
                             mode='min', 
                             period=1)

# %%
from keras.models import Sequential, Model
from keras.layers.advanced_activations import LeakyReLU
from keras.layers.merge import concatenate
from keras.layers import Reshape, Activation, Conv2D, Input, MaxPooling2D, BatchNormalization, Flatten, Dense, Lambda
def space_to_depth_x2(x):
    return tf.space_to_depth(x, block_size=2)
input_image = Input(shape=(IMAGE_H, IMAGE_W, 3))
true_boxes  = Input(shape=(1, 1, 1, TRUE_BOX_BUFFER , 4))

# Layer 1
x = Conv2D(32, (3,3), strides=(1,1), padding='same', name='conv_1', use_bias=False)(input_image)
x = BatchNormalization(name='norm_1')(x)
x = LeakyReLU(alpha=0.1)(x)
x = MaxPooling2D(pool_size=(2, 2))(x)

# Layer 2
x = Conv2D(64, (3,3), strides=(1,1), padding='same', name='conv_2', use_bias=False)(x)
x = BatchNormalization(name='norm_2')(x)
x = LeakyReLU(alpha=0.1)(x)
x = MaxPooling2D(pool_size=(2, 2))(x)

# Layer 3
x = Conv2D(128, (3,3), strides=(1,1), padding='same', name='conv_3', use_bias=False)(x)
x = BatchNormalization(name='norm_3')(x)
x = LeakyReLU(alpha=0.1)(x)

# Layer 4
x = Conv2D(64, (1,1), strides=(1,1), padding='same', name='conv_4', use_bias=False)(x)
x = BatchNormalization(name='norm_4')(x)
x = LeakyReLU(alpha=0.1)(x)

# Layer 5
x = Conv2D(128, (3,3), strides=(1,1), padding='same', name='conv_5', use_bias=False)(x)
x = BatchNormalization(name='norm_5')(x)
x = LeakyReLU(alpha=0.1)(x)
x = MaxPooling2D(pool_size=(2, 2))(x)

# Layer 6
x = Conv2D(256, (3,3), strides=(1,1), padding='same', name='conv_6', use_bias=False)(x)
x = BatchNormalization(name='norm_6')(x)
x = LeakyReLU(alpha=0.1)(x)

# Layer 7
x = Conv2D(128, (1,1), strides=(1,1), padding='same', name='conv_7', use_bias=False)(x)
x = BatchNormalization(name='norm_7')(x)
x = LeakyReLU(alpha=0.1)(x)

# Layer 8
x = Conv2D(256, (3,3), strides=(1,1), padding='same', name='conv_8', use_bias=False)(x)
x = BatchNormalization(name='norm_8')(x)
x = LeakyReLU(alpha=0.1)(x)
x = MaxPooling2D(pool_size=(2, 2))(x)

# Layer 9
x = Conv2D(512, (3,3), strides=(1,1), padding='same', name='conv_9', use_bias=False)(x)
x = BatchNormalization(name='norm_9')(x)
x = LeakyReLU(alpha=0.1)(x)

# Layer 10
x = Conv2D(256, (1,1), strides=(1,1), padding='same', name='conv_10', use_bias=False)(x)
x = BatchNormalization(name='norm_10')(x)
x = LeakyReLU(alpha=0.1)(x)

# Layer 11
x = Conv2D(512, (3,3), strides=(1,1), padding='same', name='conv_11', use_bias=False)(x)
x = BatchNormalization(name='norm_11')(x)
x = LeakyReLU(alpha=0.1)(x)

# Layer 12
x = Conv2D(256, (1,1), strides=(1,1), padding='same', name='conv_12', use_bias=False)(x)
x = BatchNormalization(name='norm_12')(x)
x = LeakyReLU(alpha=0.1)(x)

# Layer 13
x = Conv2D(512, (3,3), strides=(1,1), padding='same', name='conv_13', use_bias=False)(x)
x = BatchNormalization(name='norm_13')(x)
x = LeakyReLU(alpha=0.1)(x)

skip_connection = x

x = MaxPooling2D(pool_size=(2, 2))(x)

# Layer 14
x = Conv2D(1024, (3,3), strides=(1,1), padding='same', name='conv_14', use_bias=False)(x)
x = BatchNormalization(name='norm_14')(x)
x = LeakyReLU(alpha=0.1)(x)

# Layer 15
x = Conv2D(512, (1,1), strides=(1,1), padding='same', name='conv_15', use_bias=False)(x)
x = BatchNormalization(name='norm_15')(x)
x = LeakyReLU(alpha=0.1)(x)

# Layer 16
x = Conv2D(1024, (3,3), strides=(1,1), padding='same', name='conv_16', use_bias=False)(x)
x = BatchNormalization(name='norm_16')(x)
x = LeakyReLU(alpha=0.1)(x)

# Layer 17
x = Conv2D(512, (1,1), strides=(1,1), padding='same', name='conv_17', use_bias=False)(x)
x = BatchNormalization(name='norm_17')(x)
x = LeakyReLU(alpha=0.1)(x)

# Layer 18
x = Conv2D(1024, (3,3), strides=(1,1), padding='same', name='conv_18', use_bias=False)(x)
x = BatchNormalization(name='norm_18')(x)
x = LeakyReLU(alpha=0.1)(x)

# Layer 19
x = Conv2D(1024, (3,3), strides=(1,1), padding='same', name='conv_19', use_bias=False)(x)
x = BatchNormalization(name='norm_19')(x)
x = LeakyReLU(alpha=0.1)(x)

# Layer 20
x = Conv2D(1024, (3,3), strides=(1,1), padding='same', name='conv_20', use_bias=False)(x)
x = BatchNormalization(name='norm_20')(x)
x = LeakyReLU(alpha=0.1)(x)

# Layer 21
skip_connection = Conv2D(64, (1,1), strides=(1,1), padding='same', name='conv_21', use_bias=False)(skip_connection)
skip_connection = BatchNormalization(name='norm_21')(skip_connection)
skip_connection = LeakyReLU(alpha=0.1)(skip_connection)
skip_connection = Lambda(space_to_depth_x2)(skip_connection)

x = concatenate([skip_connection, x])

# Layer 22
x = Conv2D(1024, (3,3), strides=(1,1), padding='same', name='conv_22', use_bias=False)(x)
x = BatchNormalization(name='norm_22')(x)
x = LeakyReLU(alpha=0.1)(x)
model = Model(input_image, x)  
feature_extractor = Model(model.layers[0].input, model.layers[-1].output)
feature_extractor.load_weights("weights.h5")
for layer in feature_extractor.layers:
    layer.trainable = False
# Layer 23
x = Conv2D(BOX * (4 + 1 + CLASS), (1,1), strides=(1,1), padding='same', name='conv_23')(feature_extractor.layers[-1].output)
output = Reshape((GRID_H, GRID_W, BOX, 4 + 1 + CLASS))(x)

# small hack to allow true_boxes to be registered when Keras build the model 
# for more information: https://github.com/fchollet/keras/issues/2790
output = Lambda(lambda args: args[0])([output, true_boxes])

model = Model([input_image, true_boxes], output)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
from keras.optimizers import SGD, Adam, RMSprop
optimizer = Adam(lr=0.5e-4, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
#optimizer = SGD(lr=1e-4, decay=0.0005, momentum=0.9)
#optimizer = RMSprop(lr=1e-4, rho=0.9, epsilon=1e-08, decay=0.0)
tb_counter  = len([log for log in os.listdir(os.path.expanduser('~/logs/')) if 'coco_' in log]) + 1
tensorboard = TensorBoard(log_dir=os.path.expanduser('~/logs/') + 'coco_' + '_' + str(tb_counter), 
                          histogram_freq=0, 
                          write_graph=True, 
                          write_images=False)
model.compile(loss=custom_loss, optimizer=optimizer)

model.fit_generator(generator        = train_batch, 
                    steps_per_epoch  = len(train_batch), 
                    epochs           = 3, 
                    verbose          = 1,
                    validation_data  = valid_batch,
                    validation_steps = len(valid_batch),
                    callbacks        = [checkpoint], 
                    max_queue_size   = 3)
model.save_weights("warmup.h5")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !cp warmup.h5 drive/'My Drive'/

# %%
model.load_weights("warmup.h5")
model.compile(loss=custom_loss, optimizer=optimizer)

model.fit_generator(initial_epoch    = 3,
                    generator        = train_batch, 
                    steps_per_epoch  = len(train_batch), 
                    epochs           = 25, 
                    verbose          = 1,
                    validation_data  = valid_batch,
                    validation_steps = len(valid_batch),
                    callbacks        = [checkpoint], 
                    max_queue_size   = 3)
model.save_weights("weights_25.h5")

# %%
model.load_weights("weights_25.h5")
model.fit_generator(initial_epoch    = 25,
                    generator        = train_batch, 
                    steps_per_epoch  = len(train_batch), 
                    epochs           = 50, 
                    verbose          = 1,
                    validation_data  = valid_batch,
                    validation_steps = len(valid_batch),
                    callbacks        = [checkpoint], 
                    max_queue_size   = 3)
model.save_weights("weights_50.h5")
# Out:
# Dummy Line 	 [0.]
# Loss WH 	 3.272522
# Loss XY 	 0.058539648
# Current Recall 	 0.083333336
# Average Recall 	 0.049984176
# Loss Conf 	 0.002222541
# Loss Class 	 0.6381945
# Total Loss 	 3.9714787
#  56/251 [=====>........................] - ETA: 1:23 - loss: 4.7950Dummy Line 	 [0.]
# Loss XY 	 0.055739693
# Loss WH 	 4.2380795
# Loss Conf 	 0.0032389862
# Current Recall 	 0.013888889
# Average Recall 	 0.049976606
# Loss Class 	 0.8534503
# Total Loss 	 5.150509
#  57/251 [=====>........................] - ETA: 1:23 - loss: 4.8012Dummy Line 	 [0.]
# Loss WH 	 4.837302
# Loss XY 	 0.07188034
# Current Recall 	 0.071428575
# Average Recall 	 0.049981102
# Loss Conf 	 0.0018218752
# Loss Class 	 0.57114154
# Total Loss 	 5.4821463
#  58/251 [=====>........................] - ETA: 1:22 - loss: 4.8129Dummy Line 	 [0.]
# Loss WH 	 3.6375084
# Loss XY 	 0.06489125
# Current Recall 	 0.03773585
# Average Recall 	 0.049978536
# Loss Conf 	 0.0021606872
# Loss Class 	 0.76515615
# Total Loss 	 4.4697165
#  59/251 [======>.......................] - ETA: 1:23 - loss: 4.8071Dummy Line 	 [0.]
# Loss WH 	 3.6684763
# Loss XY 	 0.073121876
# Average Recall 	 0.049972337
# Loss Conf 	 0.0026684066
# Current Recall 	 0.020408163
# Loss Class 	 0.8261536
# Total Loss 	 4.5704203
#  60/251 [======>.......................] - ETA: 1:23 - loss: 4.8032Dummy Line 	 [0.]
# Loss WH 	 4.62873
# Loss XY 	 0.045251206
# Current Recall 	 0.04761905
# Average Recall 	 0.049971845
# Loss Conf 	 0.0019335498
# Loss Class 	 0.542418
# Total Loss 	 5.218333
#  61/251 [======>.......................] - ETA: 1:22 - loss: 4.8100Dummy Line 	 [0.]
# Loss WH 	 3.345641
# Loss XY 	 0.055687625
# Current Recall 	 0.015151516
# Average Recall 	 0.049964547
# Loss Conf 	 0.0028407283
# Loss Class 	 0.4744588
# Total Loss 	 3.8786283
#  62/251 [======>.......................] - ETA: 1:23 - loss: 4.7950Dummy Line 	 [0.]
# Loss WH 	 2.3389397
# Current Recall 	 0.10169491
# Average Recall 	 0.049975384
# Loss Conf 	 0.002878259
# Loss XY 	 0.055586442
# Loss Class 	 0.64395785
# Total Loss 	 3.041362
#  63/251 [======>.......................] - ETA: 1:23 - loss: 4.7671Dummy Line 	 [0.]
# Loss WH 	 3.381336
# Current Recall 	 0.125
# Loss XY 	 0.04865949
# Average Recall 	 0.049991097
# Loss Class 	 0.8354702
# Loss Conf 	 0.0026458541
# Total Loss 	 4.2681117
#  64/251 [======>.......................] - ETA: 1:23 - loss: 4.7593Dummy Line 	 [0.]
# Loss XY 	 0.060358353
# Loss WH 	 4.7490253
# Loss Conf 	 0.0021082927
# Average Recall 	 0.04998063
# Current Recall 	 0.0
# Loss Class 	 0.40561163
# Total Loss 	 5.2171035
#  65/251 [======>.......................] - ETA: 1:22 - loss: 4.7664Dummy Line 	 [0.]
# Loss WH 	 4.1618643
# Loss XY 	 0.04544391
# Current Recall 	 0.03846154
# Average Recall 	 0.04997822
# Loss Conf 	 0.0021467055
# Loss Class 	 1.2168273
# Total Loss 	 5.4262824
#  66/251 [======>.......................] - ETA: 1:22 - loss: 4.7764Dummy Line 	 [0.]
# Loss Conf 	 0.0014523071
# Average Recall 	 0.050001834
# Current Recall 	 0.1627907
# Loss XY 	 0.04812142
# Loss WH 	 5.597588
# Loss Class 	 0.54186577
# Total Loss 	 6.189028
#  67/251 [=======>......................] - ETA: 1:22 - loss: 4.7975Dummy Line 	 [0.]
# Loss XY 	 0.060032774
# Average Recall 	 0.05001039
# Loss Conf 	 0.0016863627
# Current Recall 	 0.09090909
# Loss Class 	 0.86446494
# Loss WH 	 3.2038658
# Total Loss 	 4.1300497
#  68/251 [=======>......................] - ETA: 1:22 - loss: 4.7876Dummy Line 	 [0.]
# Loss XY 	 0.05224327
# Loss WH 	 4.6655784
# Current Recall 	 0.12820514
# Average Recall 	 0.050026752
# Loss Conf 	 0.001882846
# Loss Class 	 0.45518923
# Total Loss 	 5.174894
#  69/251 [=======>......................] - ETA: 1:22 - loss: 4.7932Dummy Line 	 [0.]
# Loss WH 	 4.2006326
# Loss XY 	 0.047963597
# Current Recall 	 0.08064516
# Average Recall 	 0.050033156
# Loss Class 	 0.6285699
# Loss Conf 	 0.00256404
# Total Loss 	 4.87973
#  70/251 [=======>......................] - ETA: 1:22 - loss: 4.7945Dummy Line 	 [0.]
# Loss XY 	 0.060079996
# Loss WH 	 3.3579798
# Current Recall 	 0.01923077
# Average Recall 	 0.05002671
# Loss Conf 	 0.0020708118
# Loss Class 	 0.80519867
# Total Loss 	 4.2253294
#  71/251 [=======>......................] - ETA: 1:22 - loss: 4.7865Dummy Line 	 [0.]
# Loss WH 	 2.7510462
# Loss XY 	 0.05904037
# Current Recall 	 0.023529412
# Average Recall 	 0.05002117
# Loss Conf 	 0.003999494
# Loss Class 	 0.45326543
# Total Loss 	 3.2673514
#  72/251 [=======>......................] - ETA: 1:21 - loss: 4.7654Dummy Line 	 [0.]
# Loss WH 	 6.6577225
# Loss XY 	 0.06333768
# Current Recall 	 0.13461539
# Average Recall 	 0.050038856
# Loss Class 	 0.6736088
# Loss Conf 	 0.0019737147
# Total Loss 	 7.3966427
#  73/251 [=======>......................] - ETA: 1:21 - loss: 4.8014Dummy Line 	 [0.]
# Loss WH 	 2.6049893
# Loss XY 	 0.055585433
# Current Recall 	 0.083333336
# Average Recall 	 0.05004581
# Loss Conf 	 0.0029731335
# Loss Class 	 0.5201856
# Total Loss 	 3.1837335
#  74/251 [=======>......................] - ETA: 1:20 - loss: 4.7796Dummy Line 	 [0.]
# Loss WH 	 3.5102086
# Loss XY 	 0.06993879
# Current Recall 	 0.04761905
# Average Recall 	 0.050045304
# Loss Conf 	 0.003029568
# Loss Class 	 0.7738096
# Total Loss 	 4.3569865
#  75/251 [=======>......................] - ETA: 1:20 - loss: 4.7739Dummy Line 	 [0.]
# Loss WH 	 4.5076127
# Loss XY 	 0.054324005
# Current Recall 	 0.06451613
# Average Recall 	 0.05004833
# Loss Conf 	 0.0020893451
# Loss Class 	 0.6215156
# Total Loss 	 5.185542
#  76/251 [========>.....................] - ETA: 1:19 - loss: 4.7793Dummy Line 	 [0.]
# Loss WH 	 8.096044
# Loss XY 	 0.058102675
# Current Recall 	 0.13333333
# Average Recall 	 0.050065722
# Loss Conf 	 0.0013681981
# Loss Class 	 0.56587857
# Total Loss 	 8.721394
#  77/251 [========>.....................] - ETA: 1:19 - loss: 4.8305Dummy Line 	 [0.]
# Loss WH 	 4.938889
# Loss XY 	 0.05819199
# Current Recall 	 0.083333336
# Average Recall 	 0.050072666
# Loss Conf 	 0.0023891984
# Loss Class 	 0.46759686
# Total Loss 	 5.4670672
#  78/251 [========>.....................] - ETA: 1:18 - loss: 4.8387Dummy Line 	 [0.]
# Loss WH 	 4.3069453
# Loss XY 	 0.06879496
# Current Recall 	 0.05479452
# Average Recall 	 0.050073653
# Loss Conf 	 0.0024492773
# Loss Class 	 0.46208504
# Total Loss 	 4.840275
#  79/251 [========>.....................] - ETA: 1:18 - loss: 4.8387Dummy Line 	 [0.]
# Loss WH 	 6.481767
# Loss XY 	 0.044228725
# Current Recall 	 0.18
# Average Recall 	 0.05010077
# Loss Conf 	 0.0020072756
# Loss Class 	 0.63149434
# Total Loss 	 7.1594977
#  80/251 [========>.....................] - ETA: 1:17 - loss: 4.8677Dummy Line 	 [0.]
# Loss WH 	 5.17147
# Loss XY 	 0.054283928
# Current Recall 	 0.027027028
# Average Recall 	 0.050095953
# Loss Conf 	 0.0020471732
# Loss Class 	 0.5718374
# Total Loss 	 5.7996387
#  81/251 [========>.....................] - ETA: 1:17 - loss: 4.8792Dummy Line 	 [0.]
# Loss WH 	 5.4297915
# Current Recall 	 0.13953489
# Loss Conf 	 0.0019621563
# Average Recall 	 0.050114617
# Loss XY 	 0.07426061
# Loss Class 	 0.64373344
# Total Loss 	 6.149748
#  82/251 [========>.....................] - ETA: 1:16 - loss: 4.8947Dummy Line 	 [0.]
# Loss WH 	 3.6237712
# Loss XY 	 0.061711516
# Average Recall 	 0.050114952
# Loss Class 	 1.0276607
# Loss Conf 	 0.0023714483
# Current Recall 	 0.05172414
# Total Loss 	 4.715515
#  83/251 [========>.....................] - ETA: 1:16 - loss: 4.8926Dummy Line 	 [0.]
# Loss WH 	 3.3055522
# Loss XY 	 0.057622775
# Loss Conf 	 0.0023933828
# Average Recall 	 0.050124682
# Current Recall 	 0.09677419
# Loss Class 	 0.6540851
# Total Loss 	 4.0196533
#  84/251 [=========>....................] - ETA: 1:15 - loss: 4.8822Dummy Line 	 [0.]
# Loss WH 	 2.3578134
# Loss XY 	 0.06149901
# Average Recall 	 0.05012292
# Loss Conf 	 0.003578884
# Current Recall 	 0.041666668
# Loss Class 	 0.49062237
# Total Loss 	 2.9135137
#  85/251 [=========>....................] - ETA: 1:15 - loss: 4.8590Dummy Line 	 [0.]
# Loss WH 	 2.61072
# Loss XY 	 0.04492192
# Current Recall 	 0.171875
# Average Recall 	 0.0501483
# Loss Class 	 0.5222629
# Loss Conf 	 0.00288779
# Total Loss 	 3.1807923
#  86/251 [=========>....................] - ETA: 1:14 - loss: 4.8395Dummy Line 	 [0.]
# Loss XY 	 0.068903714
# Loss WH 	 3.3481927
# Average Recall 	 0.050157238
# Loss Conf 	 0.0020088654
# Current Recall 	 0.093023255
# Loss Class 	 0.76572853
# Total Loss 	 4.184834
#  87/251 [=========>....................] - ETA: 1:13 - loss: 4.8320Dummy Line 	 [0.]
# Loss WH 	 3.274023
# Loss XY 	 0.05627607
# Current Recall 	 0.10869565
# Average Recall 	 0.050169434
# Loss Class 	 0.7850085
# Loss Conf 	 0.0019950205
# Total Loss 	 4.117303
#  88/251 [=========>....................] - ETA: 1:13 - loss: 4.8238Dummy Line 	 [0.]
# Loss WH 	 3.9721835
# Loss XY 	 0.059188023
# Current Recall 	 0.12280702
# Average Recall 	 0.050184563
# Loss Conf 	 0.0021206678
# Loss Class 	 0.4708331
# Total Loss 	 4.5043254
#  89/251 [=========>....................] - ETA: 1:12 - loss: 4.8203Dummy Line 	 [0.]
# Loss WH 	 4.7327642
# Loss XY 	 0.06916644
# Current Recall 	 0.10204082
# Loss Conf 	 0.0018957725
# Average Recall 	 0.050195366
# Loss Class 	 0.6786591
# Total Loss 	 5.482486
#  90/251 [=========>....................] - ETA: 1:12 - loss: 4.8276Dummy Line 	 [0.]
# Loss WH 	 7.804756
# Loss XY 	 0.053895276
# Current Recall 	 0.051282052
# Average Recall 	 0.05019559
# Loss Conf 	 0.0016664424
# Loss Class 	 0.5488288
# Total Loss 	 8.409147
#  91/251 [=========>....................] - ETA: 1:11 - loss: 4.8670Dummy Line 	 [0.]
# Loss WH 	 3.8460824
# Loss XY 	 0.05808477
# Loss Conf 	 0.0023355633
# Average Recall 	 0.050189983
# Current Recall 	 0.023255814
# Loss Class 	 0.5823163
# Total Loss 	 4.488819
#  92/251 [=========>....................] - ETA: 1:11 - loss: 4.8629Dummy Line 	 [0.]
# Current Recall 	 0.069767445
# Average Recall 	 0.050194055
# Loss Conf 	 0.0017877944
# Loss WH 	 4.935889
# Loss XY 	 0.046115797
# Loss Class 	 0.4795071
# Total Loss 	 5.4632993
#  93/251 [==========>...................] - ETA: 1:10 - loss: 4.8693Dummy Line 	 [0.]
# Loss WH 	 5.003228
# Loss XY 	 0.05321662
# Current Recall 	 0.05172414
# Average Recall 	 0.050194375
# Loss Conf 	 0.0022013688
# Loss Class 	 0.3202912
# Total Loss 	 5.3789372
#  94/251 [==========>...................] - ETA: 1:10 - loss: 4.8747Dummy Line 	 [0.]
# Loss WH 	 3.2036486
# Loss XY 	 0.054440778
# Current Recall 	 0.05882353
# Average Recall 	 0.05019617
# Loss Conf 	 0.0019411298
# Loss Class 	 0.47630975
# Total Loss 	 3.7363403
#  95/251 [==========>...................] - ETA: 1:09 - loss: 4.8628Dummy Line 	 [0.]
# Loss WH 	 4.105032
# Loss XY 	 0.058838
# Current Recall 	 0.021276595
# Average Recall 	 0.050190154
# Loss Conf 	 0.0020194775
# Loss Class 	 0.7596735
# Total Loss 	 4.925563
#  96/251 [==========>...................] - ETA: 1:09 - loss: 4.8634Dummy Line 	 [0.]
# Loss WH 	 3.0177507
# Loss XY 	 0.066049084
# Current Recall 	 0.06451613
# Average Recall 	 0.050193135
# Loss Conf 	 0.0023643896
# Loss Class 	 0.8625046
# Total Loss 	 3.948669
#  97/251 [==========>...................] - ETA: 1:08 - loss: 4.8540Dummy Line 	 [0.]
# Loss WH 	 6.2381144
# Loss XY 	 0.05203797
# Current Recall 	 0.056603774
# Average Recall 	 0.05019447
# Loss Conf 	 0.0024868697
# Loss Class 	 0.45400208
# Total Loss 	 6.746641
#  98/251 [==========>...................] - ETA: 1:08 - loss: 4.8733Dummy Line 	 [0.]
# Loss WH 	 4.610664
# Loss XY 	 0.052646358
# Loss Conf 	 0.0019596682
# Average Recall 	 0.050201356
# Current Recall 	 0.083333336
# Loss Class 	 0.78685427
# Total Loss 	 5.452124
#  99/251 [==========>...................] - ETA: 1:08 - loss: 4.8791Dummy Line 	 [0.]
# Loss WH 	 3.8103817
# Loss XY 	 0.06090771
# Current Recall 	 0.075
# Average Recall 	 0.05020651
# Loss Conf 	 0.001901624
# Loss Class 	 0.78957516
# Total Loss 	 4.662766
# 100/251 [==========>...................] - ETA: 1:07 - loss: 4.8770Dummy Line 	 [0.]
# Loss WH 	 4.329993
# Loss XY 	 0.052943286
# Current Recall 	 0.11627907
# Average Recall 	 0.05022024
# Loss Conf 	 0.0021370365
# Loss Class 	 0.422095
# Total Loss 	 4.807168
# 101/251 [===========>..................] - ETA: 1:07 - loss: 4.8763Dummy Line 	 [0.]
# Loss WH 	 4.156912
# Loss XY 	 0.06911856
# Current Recall 	 0.013888889
# Average Recall 	 0.05021269
# Loss Conf 	 0.0027563411
# Loss Class 	 0.49031967
# Total Loss 	 4.719106
# 102/251 [===========>..................] - ETA: 1:06 - loss: 4.8747Dummy Line 	 [0.]
# Loss WH 	 2.6862981
# Loss XY 	 0.06035365
# Current Recall 	 0.1
# Average Recall 	 0.050223034
# Loss Conf 	 0.001760125
# Loss Class 	 0.6107555
# Total Loss 	 3.3591673
# 103/251 [===========>..................] - ETA: 1:05 - loss: 4.8600Dummy Line 	 [0.]
# Loss WH 	 4.3853536
# Loss XY 	 0.05387481
# Current Recall 	 0.018518519
# Loss Conf 	 0.0030475543
# Average Recall 	 0.05021645
# Loss Class 	 0.8449511
# Total Loss 	 5.287227
# 104/251 [===========>..................] - ETA: 1:05 - loss: 4.8641Dummy Line 	 [0.]
# Loss WH 	 5.199753
# Loss XY 	 0.06492892
# Current Recall 	 0.0
# Average Recall 	 0.050206024
# Loss Conf 	 0.0021115148
# Loss Class 	 0.7560229
# Total Loss 	 6.022816
# 105/251 [===========>..................] - ETA: 1:04 - loss: 4.8752Dummy Line 	 [0.]
# Loss WH 	 4.2841167
# Loss XY 	 0.061492603
# Current Recall 	 0.048387095
# Average Recall 	 0.050205644
# Loss Conf 	 0.00257905
# Loss Class 	 0.5621144
# Total Loss 	 4.9103026
# 106/251 [===========>..................] - ETA: 1:04 - loss: 4.8755Dummy Line 	 [0.]
# Loss XY 	 0.047167312
# Loss Conf 	 0.0018130004
# Average Recall 	 0.050204877
# Loss Class 	 0.7358813
# Current Recall 	 0.046511628
# Loss WH 	 5.530273
# Total Loss 	 6.3151345
# 107/251 [===========>..................] - ETA: 1:04 - loss: 4.8890Dummy Line 	 [0.]
# Loss WH 	 3.1012943
# Loss XY 	 0.054489292
# Average Recall 	 0.05020411
# Loss Class 	 0.47342184
# Loss Conf 	 0.0020742896
# Current Recall 	 0.046511628
# Total Loss 	 3.6312797
# 108/251 [===========>..................] - ETA: 1:03 - loss: 4.8773Dummy Line 	 [0.]
# Loss WH 	 2.8086054
# Loss XY 	 0.05437849
# Current Recall 	 0.05263158
# Average Recall 	 0.050204612
# Loss Conf 	 0.0016750182
# Loss Class 	 0.33929333
# Total Loss 	 3.2039523
# 109/251 [============>.................] - ETA: 1:03 - loss: 4.8620Dummy Line 	 [0.]
# Loss XY 	 0.056476425
# Current Recall 	 0.0945946
# Average Recall 	 0.05021382
# Loss Conf 	 0.002938312
# Loss WH 	 2.2132375
# Loss Class 	 0.42377812
# Total Loss 	 2.6964302
# 110/251 [============>.................] - ETA: 1:02 - loss: 4.8423Dummy Line 	 [0.]
# Loss WH 	 4.368699
# Loss XY 	 0.058950353
# Current Recall 	 0.09090909
# Average Recall 	 0.05022226
# Loss Conf 	 0.0029270423
# Loss Class 	 0.38610274
# Total Loss 	 4.816679
# 111/251 [============>.................] - ETA: 1:02 - loss: 4.8420Dummy Line 	 [0.]
# Loss WH 	 3.492528
# Loss XY 	 0.06457356
# Current Recall 	 0.057971016
# Average Recall 	 0.050223865
# Loss Conf 	 0.0027027677
# Loss Class 	 0.70039546
# Total Loss 	 4.2601995
# 112/251 [============>.................] - ETA: 1:01 - loss: 4.8369Dummy Line 	 [0.]
# Loss WH 	 4.025634
# Current Recall 	 0.03846154
# Loss Conf 	 0.002167154
# Average Recall 	 0.05022143
# Loss XY 	 0.05940886
# Loss Class 	 0.64820874
# Total Loss 	 4.7354183
# 113/251 [============>.................] - ETA: 1:01 - loss: 4.8360Dummy Line 	 [0.]
# Loss WH 	 4.275847
# Loss XY 	 0.059990305
# Current Recall 	 0.05263158
# Average Recall 	 0.050221927
# Loss Conf 	 0.0020673194
# Loss Class 	 0.49199057
# Total Loss 	 4.829895
# 114/251 [============>.................] - ETA: 1:01 - loss: 4.8359Dummy Line 	 [0.]
# Loss WH 	 5.400337
# Loss XY 	 0.061359122
# Current Recall 	 0.06122449
# Average Recall 	 0.050224207
# Loss Conf 	 0.002065307
# Loss Class 	 0.640151
# Total Loss 	 6.1039124
# 115/251 [============>.................] - ETA: 1:00 - loss: 4.8469Dummy Line 	 [0.]
# Loss WH 	 2.085365
# Loss XY 	 0.07041638
# Current Recall 	 0.050847456
# Average Recall 	 0.050224334
# Loss Conf 	 0.0024151232
# Loss Class 	 0.71791816
# Total Loss 	 2.8761148
# 116/251 [============>.................] - ETA: 1:00 - loss: 4.8299Dummy Line 	 [0.]
# Loss WH 	 3.1801949
# Loss XY 	 0.06456947
# Current Recall 	 0.05
# Loss Conf 	 0.0024629207
# Average Recall 	 0.05022429
# Loss Class 	 0.5197057
# Total Loss 	 3.766933
# 117/251 [============>.................] - ETA: 59s - loss: 4.8209 Dummy Line 	 [0.]
# Loss WH 	 4.397519
# Loss XY 	 0.050985236
# Loss Conf 	 0.0017076489
# Average Recall 	 0.05021389
# Current Recall 	 0.0
# Loss Class 	 0.5603261
# Total Loss 	 5.010538
# 118/251 [=============>................] - ETA: 59s - loss: 4.8225Dummy Line 	 [0.]
# Current Recall 	 0.06666667
# Average Recall 	 0.050217293
# Loss XY 	 0.071163006
# Loss Conf 	 0.0020062947
# Loss Class 	 0.49509954
# Loss WH 	 4.277825
# Total Loss 	 4.846094
# 119/251 [=============>................] - ETA: 58s - loss: 4.8227Dummy Line 	 [0.]
# Loss WH 	 2.885243
# Loss XY 	 0.06453461
# Current Recall 	 0.10344828
# Average Recall 	 0.050228313
# Loss Conf 	 0.0025581804
# Loss Class 	 0.8017156
# Total Loss 	 3.7540514
# 120/251 [=============>................] - ETA: 58s - loss: 4.8138Dummy Line 	 [0.]
# Loss WH 	 3.7589064
# Loss XY 	 0.046428863
# Average Recall 	 0.05023113
# Loss Conf 	 0.0019280547
# Loss Class 	 0.45400342
# Current Recall 	 0.06382979
# Total Loss 	 4.2612667
# 121/251 [=============>................] - ETA: 57s - loss: 4.8092Dummy Line 	 [0.]
# Loss WH 	 3.1962166
# Loss XY 	 0.049467772
# Average Recall 	 0.050238345
# Current Recall 	 0.08510638
# Loss Conf 	 0.002165671
# Loss Class 	 0.60487705
# Total Loss 	 3.852727
# 122/251 [=============>................] - ETA: 57s - loss: 4.8013Dummy Line 	 [0.]
# Loss XY 	 0.057509437
# Current Recall 	 0.092307694
# Average Recall 	 0.050247047
# Loss Class 	 0.334431
# Loss Conf 	 0.002564717
# Loss WH 	 3.722896
# Total Loss 	 4.117401
# 123/251 [=============>................] - ETA: 56s - loss: 4.7958Dummy Line 	 [0.]
# Loss WH 	 6.5147696
# Loss XY 	 0.058537524
# Current Recall 	 0.03508772
# Loss Conf 	 0.002299537
# Loss Class 	 0.6929693
# Average Recall 	 0.050243914
# Total Loss 	 7.2685757
# 124/251 [=============>................] - ETA: 56s - loss: 4.8157Dummy Line 	 [0.]
# Loss XY 	 0.054878335
# Loss WH 	 4.1723657
# Current Recall 	 0.046511628
# Loss Conf 	 0.0018561378
# Average Recall 	 0.05024314
# Loss Class 	 0.6511887
# Total Loss 	 4.880289
# 125/251 [=============>................] - ETA: 56s - loss: 4.8162Dummy Line 	 [0.]
# Loss WH 	 3.061119
# Loss XY 	 0.048335627
# Current Recall 	 0.057692308
# Average Recall 	 0.05024468
# Loss Conf 	 0.0024200303
# Loss Class 	 0.313002
# Total Loss 	 3.4248767
# 126/251 [==============>...............] - ETA: 55s - loss: 4.8052Dummy Line 	 [0.]
# Loss WH 	 3.665869
# Loss XY 	 0.054007124
# Current Recall 	 0.021276595
# Average Recall 	 0.05023869
# Loss Conf 	 0.0019580757
# Loss Class 	 0.49767247
# Total Loss 	 4.2195067
# 127/251 [==============>...............] - ETA: 55s - loss: 4.8006Dummy Line 	 [0.]
# Loss XY 	 0.06595537
# Loss WH 	 4.9318247
# Average Recall 	 0.050232
# Loss Conf 	 0.0026971262
# Current Recall 	 0.017857144
# Loss Class 	 0.4480169
# Total Loss 	 5.448494
# 128/251 [==============>...............] - ETA: 54s - loss: 4.8057Dummy Line 	 [0.]
# Loss WH 	 5.294163
# Loss XY 	 0.039807066
# Current Recall 	 0.09756097
# Average Recall 	 0.05024178
# Loss Conf 	 0.0020247286
# Loss Class 	 0.37004858
# Total Loss 	 5.7060432
# 129/251 [==============>...............] - ETA: 54s - loss: 4.8126Dummy Line 	 [0.]
# Loss WH 	 9.792107
# Loss XY 	 0.04854792
# Current Recall 	 0.038461536
# Average Recall 	 0.050239347
# Loss Conf 	 0.0012699809
# Loss Class 	 0.48763135
# Total Loss 	 10.329556
# 130/251 [==============>...............] - ETA: 53s - loss: 4.8551Dummy Line 	 [0.]
# Loss WH 	 4.526901
# Loss XY 	 0.05314838
# Current Recall 	 0.11111111
# Average Recall 	 0.05025192
# Loss Conf 	 0.001997132
# Loss Class 	 0.64212394
# Total Loss 	 5.2241697
# 131/251 [==============>...............] - ETA: 53s - loss: 4.8579Dummy Line 	 [0.]
# Loss WH 	 3.9154067
# Loss XY 	 0.04330436
# Current Recall 	 0.14285715
# Average Recall 	 0.05027104
# Loss Conf 	 0.0016208229
# Loss Class 	 0.65721846
# Total Loss 	 4.6175504
# 132/251 [==============>...............] - ETA: 52s - loss: 4.8561Dummy Line 	 [0.]
# Loss WH 	 1.9167378
# Loss XY 	 0.047203146
# Current Recall 	 0.12244898
# Average Recall 	 0.050285943
# Loss Conf 	 0.0035395455
# Loss Class 	 0.4580318
# Total Loss 	 2.4255123
# 133/251 [==============>...............] - ETA: 52s - loss: 4.8378Dummy Line 	 [0.]
# Current Recall 	 0.025
# Average Recall 	 0.05028072
# Loss WH 	 4.4678164
# Loss XY 	 0.051487822
# Loss Conf 	 0.0018543538
# Loss Class 	 1.2020515
# Total Loss 	 5.7232103
# 134/251 [===============>..............] - ETA: 51s - loss: 4.8444Dummy Line 	 [0.]
# Loss WH 	 6.38743
# Loss XY 	 0.05553164
# Current Recall 	 0.024390243
# Average Recall 	 0.050275378
# Loss Conf 	 0.0016190879
# Loss Class 	 0.6771095
# Total Loss 	 7.12169
# 135/251 [===============>..............] - ETA: 51s - loss: 4.8613Dummy Line 	 [0.]
# Loss WH 	 2.3171062
# Loss XY 	 0.0592559
# Current Recall 	 0.07594936
# Average Recall 	 0.05028067
# Loss Conf 	 0.0025117365
# Loss Class 	 0.48594037
# Total Loss 	 2.8648143
# 136/251 [===============>..............] - ETA: 50s - loss: 4.8466Dummy Line 	 [0.]
# Loss XY 	 0.063339785
# Loss WH 	 3.1961408
# Current Recall 	 0.08695652
# Loss Conf 	 0.0019455956
# Average Recall 	 0.050288238
# Loss Class 	 0.36550418
# Total Loss 	 3.6269302
# 137/251 [===============>..............] - ETA: 50s - loss: 4.8377Dummy Line 	 [0.]
# Loss WH 	 1.9228816
# Loss XY 	 0.049006917
# Current Recall 	 0.083333336
# Average Recall 	 0.05029505
# Loss Conf 	 0.0028801886
# Loss Class 	 0.5830181
# Total Loss 	 2.557787
# 138/251 [===============>..............] - ETA: 49s - loss: 4.8212Dummy Line 	 [0.]
# Loss WH 	 6.0536447
# Loss XY 	 0.045426793
# Current Recall 	 0.08510638
# Average Recall 	 0.05030223
# Loss Conf 	 0.0020183325
# Loss Class 	 0.56149894
# Total Loss 	 6.662589
# 139/251 [===============>..............] - ETA: 49s - loss: 4.8344Dummy Line 	 [0.]
# Loss WH 	 4.7370877
# Loss XY 	 0.06186121
# Current Recall 	 0.08510638
# Average Recall 	 0.05030941
# Loss Conf 	 0.0023736283
# Loss Class 	 0.60070604
# Total Loss 	 5.4020286
# 140/251 [===============>..............] - ETA: 48s - loss: 4.8385Dummy Line 	 [0.]
# Loss WH 	 3.4987876
# Loss XY 	 0.05241917
# Current Recall 	 0.016949153
# Loss Conf 	 0.0027050695
# Average Recall 	 0.05030253
# Loss Class 	 0.67569745
# Total Loss 	 4.2296095
# 141/251 [===============>..............] - ETA: 48s - loss: 4.8341Dummy Line 	 [0.]
# Loss WH 	 3.6999817
# Loss XY 	 0.058004633
# Current Recall 	 0.0
# Average Recall 	 0.050292168
# Loss Conf 	 0.0021355676
# Loss Class 	 0.76790047
# Total Loss 	 4.5280223
# 142/251 [===============>..............] - ETA: 47s - loss: 4.8320Dummy Line 	 [0.]
# Loss WH 	 9.223292
# Loss XY 	 0.058525465
# Current Recall 	 0.025641026
# Average Recall 	 0.050287087
# Loss Conf 	 0.0019223783
# Loss Class 	 0.7684376
# Total Loss 	 10.052177
# 143/251 [================>.............] - ETA: 47s - loss: 4.8685Dummy Line 	 [0.]
# Loss XY 	 0.046495162
# Loss WH 	 4.048364
# Current Recall 	 0.06
# Average Recall 	 0.050289087
# Loss Conf 	 0.0024154864
# Loss Class 	 0.44009286
# Total Loss 	 4.537368
# 144/251 [================>.............] - ETA: 47s - loss: 4.8662Dummy Line 	 [0.]
# Loss WH 	 3.0615647
# Loss XY 	 0.042355016
# Current Recall 	 0.125
# Average Recall 	 0.050304472
# Loss Conf 	 0.0022121745
# Loss Class 	 0.59557974
# Total Loss 	 3.7017117
# 145/251 [================>.............] - ETA: 46s - loss: 4.8582Dummy Line 	 [0.]
# Loss WH 	 6.2103276
# Loss XY 	 0.051216565
# Current Recall 	 0.08108108
# Average Recall 	 0.05031081
# Loss Conf 	 0.0019443897
# Loss Class 	 0.5595754
# Total Loss 	 6.8230643
# 146/251 [================>.............] - ETA: 46s - loss: 4.8716Dummy Line 	 [0.]
# Loss WH 	 3.8580828
# Loss XY 	 0.052003205
# Current Recall 	 0.09803922
# Average Recall 	 0.050320633
# Loss Conf 	 0.0020215476
# Loss Class 	 0.26439303
# Total Loss 	 4.1765003
# 147/251 [================>.............] - ETA: 45s - loss: 4.8669Dummy Line 	 [0.]
# Loss WH 	 3.8557098
# Loss XY 	 0.05347382
# Current Recall 	 0.050847456
# Loss Class 	 0.5020869
# Loss Conf 	 0.002809197
# Average Recall 	 0.05032074
# Total Loss 	 4.4140797
# 148/251 [================>.............] - ETA: 45s - loss: 4.8638Dummy Line 	 [0.]
# Loss WH 	 3.6349447
# Loss XY 	 0.057901807
# Average Recall 	 0.05031496
# Current Recall 	 0.022222223
# Loss Conf 	 0.0017994195
# Loss Class 	 0.89196336
# Total Loss 	 4.5866094
# 149/251 [================>.............] - ETA: 44s - loss: 4.8620Dummy Line 	 [0.]
# Loss WH 	 4.2455435
# Loss XY 	 0.04894735
# Average Recall 	 0.050323594
# Loss Class 	 0.7697486
# Loss Conf 	 0.0025565124
# Current Recall 	 0.092307694
# Total Loss 	 5.066796
# 150/251 [================>.............] - ETA: 44s - loss: 4.8633Dummy Line 	 [0.]
# Loss XY 	 0.055769816
# Loss WH 	 2.7073452
# Current Recall 	 0.044444446
# Loss Conf 	 0.0031243614
# Average Recall 	 0.050322387
# Loss Class 	 0.90102565
# Total Loss 	 3.6672654
# 151/251 [=================>............] - ETA: 43s - loss: 4.8554Dummy Line 	 [0.]
# Average Recall 	 0.05034895
# Current Recall 	 0.17948718
# Loss WH 	 6.867411
# Loss XY 	 0.04847484
# Loss Conf 	 0.0014636301
# Loss Class 	 0.24954303
# Total Loss 	 7.1668925
# 152/251 [=================>............] - ETA: 43s - loss: 4.8706Dummy Line 	 [0.]
# Loss WH 	 2.8192477
# Loss XY 	 0.04222855
# Current Recall 	 0.0
# Average Recall 	 0.050338596
# Loss Conf 	 0.0025498145
# Loss Class 	 0.493393
# Total Loss 	 3.357419
# 153/251 [=================>............] - ETA: 43s - loss: 4.8607Dummy Line 	 [0.]
# Loss XY 	 0.06036735
# Loss WH 	 4.1107154
# Loss Conf 	 0.0023300555
# Average Recall 	 0.05033907
# Current Recall 	 0.05263158
# Loss Class 	 0.6701381
# Total Loss 	 4.8435507
# 154/251 [=================>............] - ETA: 42s - loss: 4.8606Dummy Line 	 [0.]
# Loss WH 	 5.18983
# Loss XY 	 0.060809042
# Current Recall 	 0.125
# Average Recall 	 0.05035441
# Loss Conf 	 0.0018007428
# Loss Class 	 0.5838367
# Total Loss 	 5.836276
# 155/251 [=================>............] - ETA: 42s - loss: 4.8669Dummy Line 	 [0.]
# Loss WH 	 6.3814363
# Loss XY 	 0.067503355
# Loss Conf 	 0.002131147
# Average Recall 	 0.050362743
# Current Recall 	 0.09090909
# Loss Class 	 0.50991094
# Total Loss 	 6.960982
# 156/251 [=================>............] - ETA: 41s - loss: 4.8803Dummy Line 	 [0.]
# Loss XY 	 0.055117767
# Loss WH 	 3.351651
# Average Recall 	 0.050366327
# Loss Conf 	 0.0021657737
# Loss Class 	 0.63011503
# Current Recall 	 0.06779661
# Total Loss 	 4.0390496
# 157/251 [=================>............] - ETA: 41s - loss: 4.8750Dummy Line 	 [0.]
# Loss WH 	 5.8342986
# Loss XY 	 0.045574263
# Current Recall 	 0.048780486
# Average Recall 	 0.050366
# Loss Conf 	 0.0018607707
# Loss Class 	 0.4833134
# Total Loss 	 6.365047
# 158/251 [=================>............] - ETA: 40s - loss: 4.8844Dummy Line 	 [0.]
# Loss XY 	 0.041651715
# Loss WH 	 6.34297
# Current Recall 	 0.03333333
# Average Recall 	 0.050362505
# Loss Conf 	 0.0015252782
# Loss Class 	 0.7140527
# Total Loss 	 7.1001997
# 159/251 [==================>...........] - ETA: 40s - loss: 4.8984Dummy Line 	 [0.]
# Loss WH 	 3.8998191
# Loss XY 	 0.043588337
# Current Recall 	 0.10526316
# Loss Conf 	 0.0024755613
# Average Recall 	 0.050373778
# Loss Class 	 0.58880436
# Total Loss 	 4.5346875
# 160/251 [==================>...........] - ETA: 39s - loss: 4.8961Dummy Line 	 [0.]
# Loss WH 	 4.3376822
# Loss XY 	 0.06239775
# Current Recall 	 0.016129032
# Loss Class 	 0.75029975
# Loss Conf 	 0.002883314
# Average Recall 	 0.050366748
# Total Loss 	 5.1532636
# 161/251 [==================>...........] - ETA: 39s - loss: 4.8977Dummy Line 	 [0.]
# Loss WH 	 4.6971793
# Loss XY 	 0.05789767
# Current Recall 	 0.055555556
# Loss Conf 	 0.0033114995
# Average Recall 	 0.050367814
# Loss Class 	 0.49007353
# Total Loss 	 5.248462
# 162/251 [==================>...........] - ETA: 39s - loss: 4.8998Dummy Line 	 [0.]
# Loss WH 	 5.0858607
# Loss XY 	 0.053990174
# Current Recall 	 0.022727273
# Loss Conf 	 0.0024197747
# Average Recall 	 0.05036214
# Loss Class 	 0.49693254
# Total Loss 	 5.6392035
# 163/251 [==================>...........] - ETA: 38s - loss: 4.9044Dummy Line 	 [0.]
# Loss WH 	 1.7635617
# Loss XY 	 0.05207864
# Current Recall 	 0.16393442
# Loss Conf 	 0.0022877282
# Average Recall 	 0.050385438
# Loss Class 	 0.39669722
# Total Loss 	 2.2146254
# 164/251 [==================>...........] - ETA: 38s - loss: 4.8880Dummy Line 	 [0.]
# Loss WH 	 2.6058261
# Loss XY 	 0.06926017
# Current Recall 	 0.04761905
# Loss Conf 	 0.0024521933
# Average Recall 	 0.05038487
# Loss Class 	 0.74453855
# Total Loss 	 3.422077
# 165/251 [==================>...........] - ETA: 37s - loss: 4.8791Dummy Line 	 [0.]
# Loss WH 	 4.5611925
# Loss XY 	 0.042030506
# Current Recall 	 0.0
# Average Recall 	 0.05037454
# Loss Conf 	 0.0020487641
# Loss Class 	 0.254458
# Total Loss 	 4.85973
# 166/251 [==================>...........] - ETA: 37s - loss: 4.8790Dummy Line 	 [0.]
# Loss WH 	 3.2409348
# Loss XY 	 0.054699276
# Loss Conf 	 0.0025519317
# Current Recall 	 0.02173913
# Average Recall 	 0.05036867
# Loss Class 	 0.48578572
# Total Loss 	 3.7839718
# 167/251 [==================>...........] - ETA: 36s - loss: 4.8724Dummy Line 	 [0.]
# Loss WH 	 3.5980253
# Loss XY 	 0.059192028
# Current Recall 	 0.06382979
# Average Recall 	 0.05037143
# Loss Conf 	 0.002154981
# Loss Class 	 0.47253597
# Total Loss 	 4.1319084
# 168/251 [===================>..........] - ETA: 36s - loss: 4.8680Dummy Line 	 [0.]
# Loss WH 	 3.2428982
# Loss XY 	 0.06292841
# Current Recall 	 0.048780486
# Average Recall 	 0.050371103
# Loss Conf 	 0.0018124211
# Loss Class 	 0.43568105
# Total Loss 	 3.7433202
# 169/251 [===================>..........] - ETA: 35s - loss: 4.8614Dummy Line 	 [0.]
# Loss WH 	 5.006378
# Loss XY 	 0.046370592
# Current Recall 	 0.11111111
# Loss Conf 	 0.0022213503
# Loss Class 	 0.7722179
# Average Recall 	 0.05038355
# Total Loss 	 5.827188
# 170/251 [===================>..........] - ETA: 35s - loss: 4.8670Dummy Line 	 [0.]
# Loss WH 	 2.5612772
# Loss XY 	 0.06308487
# Current Recall 	 0.0
# Loss Conf 	 0.0025143144
# Average Recall 	 0.05037323
# Loss Class 	 0.40231428
# Total Loss 	 3.0291905
# 171/251 [===================>..........] - ETA: 35s - loss: 4.8563Dummy Line 	 [0.]
# Loss WH 	 3.5850422
# Loss XY 	 0.04000303
# Current Recall 	 0.20833333
# Average Recall 	 0.050405577
# Loss Conf 	 0.001893768
# Loss Class 	 0.5074849
# Total Loss 	 4.134424
# 172/251 [===================>..........] - ETA: 34s - loss: 4.8521Dummy Line 	 [0.]
# Loss WH 	 3.7503994
# Loss XY 	 0.043029528
# Loss Conf 	 0.0015802805
# Average Recall 	 0.050408464
# Current Recall 	 0.06451613
# Loss Class 	 0.6043023
# Total Loss 	 4.3993115
# 173/251 [===================>..........] - ETA: 34s - loss: 4.8495Dummy Line 	 [0.]
# Loss WH 	 2.985882
# Loss XY 	 0.054051105
# Current Recall 	 0.06818182
# Average Recall 	 0.050412104
# Loss Conf 	 0.0017217667
# Loss Class 	 0.7734507
# Total Loss 	 3.8151057
# 174/251 [===================>..........] - ETA: 33s - loss: 4.8435Dummy Line 	 [0.]
# Loss WH 	 5.4417343
# Loss XY 	 0.060288124
# Current Recall 	 0.102564104
# Loss Class 	 0.83990186
# Loss Conf 	 0.0018426159
# Average Recall 	 0.050422776
# Total Loss 	 6.3437667
# 175/251 [===================>..........] - ETA: 33s - loss: 4.8521Dummy Line 	 [0.]
# Loss WH 	 2.4122214
# Loss XY 	 0.053918157
# Current Recall 	 0.11904762
# Average Recall 	 0.05043682
# Loss Conf 	 0.0036946875
# Loss Class 	 0.48272628
# Total Loss 	 2.9525607
# 176/251 [====================>.........] - ETA: 32s - loss: 4.8413Dummy Line 	 [0.]
# Loss WH 	 5.5001616
# Loss XY 	 0.05888751
# Current Recall 	 0.0625
# Average Recall 	 0.050439287
# Loss Conf 	 0.0021009336
# Loss Class 	 0.4194658
# Total Loss 	 5.980616
# 177/251 [====================>.........] - ETA: 32s - loss: 4.8477Dummy Line 	 [0.]
# Loss WH 	 4.2806287
# Loss XY 	 0.05378486
# Current Recall 	 0.09803922
# Average Recall 	 0.050449025
# Loss Conf 	 0.001582648
# Loss Class 	 0.54772544
# Total Loss 	 4.8837214
# 178/251 [====================>.........] - ETA: 31s - loss: 4.8480Dummy Line 	 [0.]
# Loss XY 	 0.055183016
# Loss Conf 	 0.0026091393
# Average Recall 	 0.050445884
# Loss WH 	 9.595679
# Current Recall 	 0.03508772
# Loss Class 	 0.65645814
# Total Loss 	 10.30993
# 179/251 [====================>.........] - ETA: 31s - loss: 4.8785Dummy Line 	 [0.]
# Loss WH 	 1.9848597
# Loss XY 	 0.056635603
# Current Recall 	 0.032786883
# Average Recall 	 0.050442275
# Loss Class 	 0.7261693
# Loss Conf 	 0.0023225686
# Total Loss 	 2.7699873
# 180/251 [====================>.........] - ETA: 31s - loss: 4.8668Dummy Line 	 [0.]
# Loss XY 	 0.061081927
# Loss WH 	 3.247537
# Average Recall 	 0.050447688
# Current Recall 	 0.07692308
# Loss Class 	 0.63033193
# Loss Conf 	 0.002618098
# Total Loss 	 3.9415689
# 181/251 [====================>.........] - ETA: 30s - loss: 4.8616Dummy Line 	 [0.]
# Loss WH 	 7.135804
# Loss XY 	 0.051246442
# Current Recall 	 0.036363635
# Average Recall 	 0.050444808
# Loss Conf 	 0.002447479
# Loss Class 	 0.6120644
# Total Loss 	 7.801563
# 182/251 [====================>.........] - ETA: 30s - loss: 4.8778Dummy Line 	 [0.]
# Loss WH 	 4.261921
# Loss XY 	 0.058730274
# Current Recall 	 0.046511628
# Average Recall 	 0.050444003
# Loss Conf 	 0.0016585817
# Loss Class 	 0.8715667
# Total Loss 	 5.1938763
# 183/251 [====================>.........] - ETA: 29s - loss: 4.8795Dummy Line 	 [0.]
# Loss WH 	 3.5490675
# Loss XY 	 0.06007444
# Current Recall 	 0.14473684
# Average Recall 	 0.050463267
# Loss Conf 	 0.0029249543
# Loss Class 	 0.44974336
# Total Loss 	 4.06181
# 184/251 [====================>.........] - ETA: 29s - loss: 4.8751Dummy Line 	 [0.]
# Loss XY 	 0.05260424
# Loss WH 	 3.5234587
# Loss Conf 	 0.002409344
# Average Recall 	 0.050464742
# Current Recall 	 0.057692308
# Loss Class 	 1.0293733
# Total Loss 	 4.607846
# 185/251 [=====================>........] - ETA: 28s - loss: 4.8736Dummy Line 	 [0.]
# Loss WH 	 2.0766766
# Loss Conf 	 0.002381834
# Loss XY 	 0.06180467
# Average Recall 	 0.050465997
# Current Recall 	 0.056603774
# Loss Class 	 0.7681165
# Total Loss 	 2.9089797
# 186/251 [=====================>........] - ETA: 28s - loss: 4.8631Dummy Line 	 [0.]
# Loss XY 	 0.05685637
# Loss Conf 	 0.0022764609
# Loss WH 	 5.9976387
# Average Recall 	 0.0504746
# Current Recall 	 0.09259259
# Loss Class 	 0.53750604
# Total Loss 	 6.5942774
# 187/251 [=====================>........] - ETA: 28s - loss: 4.8723Dummy Line 	 [0.]
# Loss WH 	 8.631708
# Loss XY 	 0.042636864
# Current Recall 	 0.04347826
# Average Recall 	 0.05047317
# Loss Conf 	 0.0020917486
# Loss Class 	 0.3873801
# Total Loss 	 9.063816
# 188/251 [=====================>........] - ETA: 27s - loss: 4.8946Dummy Line 	 [0.]
# Loss WH 	 4.1968594
# Loss XY 	 0.041482534
# Current Recall 	 0.083333336
# Average Recall 	 0.050479874
# Loss Conf 	 0.0020457972
# Loss Class 	 0.6296831
# Total Loss 	 4.8700705
# 189/251 [=====================>........] - ETA: 27s - loss: 4.8945Dummy Line 	 [0.]
# Loss WH 	 5.099353
# Loss XY 	 0.052470144
# Current Recall 	 0.06666667
# Average Recall 	 0.050483175
# Loss Class 	 0.71590734
# Loss Conf 	 0.0024675985
# Total Loss 	 5.8701982
# 190/251 [=====================>........] - ETA: 26s - loss: 4.8996Dummy Line 	 [0.]
# Loss WH 	 6.0954638
# Loss XY 	 0.05485389
# Current Recall 	 0.030303031
# Average Recall 	 0.05047906
# Loss Conf 	 0.0015528741
# Loss Class 	 0.5933407
# Total Loss 	 6.7452116
# 191/251 [=====================>........] - ETA: 26s - loss: 4.9093Dummy Line 	 [0.]
# Loss XY 	 0.04535387
# Current Recall 	 0.13461539
# Average Recall 	 0.05049622
# Loss Conf 	 0.002596322
# Loss WH 	 3.6957362
# Loss Class 	 0.4476786
# Total Loss 	 4.1913652
# 192/251 [=====================>........] - ETA: 25s - loss: 4.9056Dummy Line 	 [0.]
# Loss WH 	 3.8795357
# Loss XY 	 0.052829683
# Current Recall 	 0.06382979
# Average Recall 	 0.050498936
# Loss Conf 	 0.0024693476
# Loss Class 	 0.52077836
# Total Loss 	 4.455613
# 193/251 [======================>.......] - ETA: 25s - loss: 4.9032Dummy Line 	 [0.]
# Loss WH 	 3.974277
# Loss XY 	 0.047637753
# Current Recall 	 0.06382979
# Average Recall 	 0.050501656
# Loss Class 	 0.51733696
# Loss Conf 	 0.0017768133
# Total Loss 	 4.5410285
# 194/251 [======================>.......] - ETA: 25s - loss: 4.9014Dummy Line 	 [0.]
# Loss XY 	 0.059308194
# Loss Conf 	 0.0017132964
# Current Recall 	 0.08108108
# Average Recall 	 0.05050789
# Loss WH 	 5.2944064
# Loss Class 	 0.76184034
# Total Loss 	 6.117268
# 195/251 [======================>.......] - ETA: 24s - loss: 4.9076Dummy Line 	 [0.]
# Loss WH 	 5.061173
# Loss XY 	 0.05530677
# Current Recall 	 0.15517241
# Average Recall 	 0.050529215
# Loss Conf 	 0.0023416018
# Loss Class 	 0.6513186
# Total Loss 	 5.77014
# 196/251 [======================>.......] - ETA: 24s - loss: 4.9120Dummy Line 	 [0.]
# Loss XY 	 0.058314204
# Loss WH 	 4.194472
# Current Recall 	 0.14
# Average Recall 	 0.050547447
# Loss Conf 	 0.0021703676
# Loss Class 	 0.44010597
# Total Loss 	 4.6950626
# 197/251 [======================>.......] - ETA: 23s - loss: 4.9109Dummy Line 	 [0.]
# Loss WH 	 2.344163
# Loss XY 	 0.053623885
# Average Recall 	 0.05054582
# Current Recall 	 0.04255319
# Loss Conf 	 0.0022507552
# Loss Class 	 0.43310806
# Total Loss 	 2.8331456
# 198/251 [======================>.......] - ETA: 23s - loss: 4.9004Dummy Line 	 [0.]
# Loss WH 	 2.5201433
# Loss XY 	 0.045875374
# Current Recall 	 0.03773585
# Average Recall 	 0.05054321
# Loss Conf 	 0.0022332228
# Loss Class 	 0.5334966
# Total Loss 	 3.1017485
# 199/251 [======================>.......] - ETA: 22s - loss: 4.8914Dummy Line 	 [0.]
# Loss WH 	 2.0926218
# Loss XY 	 0.059879348
# Current Recall 	 0.028571429
# Average Recall 	 0.050538734
# Loss Conf 	 0.003887248
# Loss Class 	 0.88194335
# Total Loss 	 3.0383315
# 200/251 [======================>.......] - ETA: 22s - loss: 4.8821Dummy Line 	 [0.]
# Loss WH 	 3.3418906
# Loss XY 	 0.051751778
# Current Recall 	 0.1
# Average Recall 	 0.050548807
# Loss Conf 	 0.0024831835
# Loss Class 	 0.4191102
# Total Loss 	 3.8152359
# 201/251 [=======================>......] - ETA: 21s - loss: 4.8768Dummy Line 	 [0.]
# Loss XY 	 0.049558338
# Loss WH 	 3.173261
# Current Recall 	 0.13043478
# Loss Conf 	 0.0020483758
# Average Recall 	 0.050565064
# Loss Class 	 0.6549166
# Total Loss 	 3.8797843
# 202/251 [=======================>......] - ETA: 21s - loss: 4.8718Dummy Line 	 [0.]
# Loss WH 	 3.7981129
# Loss XY 	 0.057465218
# Average Recall 	 0.050558224
# Loss Class 	 0.85960966
# Loss Conf 	 0.002051418
# Current Recall 	 0.016949153
# Total Loss 	 4.7172394
# 203/251 [=======================>......] - ETA: 21s - loss: 4.8711Dummy Line 	 [0.]
# Loss WH 	 3.4436536
# Current Recall 	 0.05882353
# Loss XY 	 0.052943934
# Loss Conf 	 0.0018906547
# Average Recall 	 0.050559904
# Loss Class 	 0.6755508
# Total Loss 	 4.174039
# 204/251 [=======================>......] - ETA: 20s - loss: 4.8677Dummy Line 	 [0.]
# Loss WH 	 2.5614514
# Loss XY 	 0.04657927
# Loss Conf 	 0.002430972
# Average Recall 	 0.050564975
# Current Recall 	 0.0754717
# Loss Class 	 0.42847854
# Total Loss 	 3.0389402
# 205/251 [=======================>......] - ETA: 20s - loss: 4.8587Dummy Line 	 [0.]
# Loss WH 	 5.1902843
# Loss XY 	 0.049086027
# Current Recall 	 0.16666666
# Average Recall 	 0.050588585
# Loss Conf 	 0.0014343576
# Loss Class 	 0.5330013
# Total Loss 	 5.773806
# 206/251 [=======================>......] - ETA: 19s - loss: 4.8632Dummy Line 	 [0.]
# Loss WH 	 5.156781
# Loss XY 	 0.052666016
# Current Recall 	 0.08
# Average Recall 	 0.05059457
# Loss Conf 	 0.0018717179
# Loss Class 	 0.53382915
# Total Loss 	 5.745148
# 207/251 [=======================>......] - ETA: 19s - loss: 4.8674Dummy Line 	 [0.]
# Loss WH 	 4.336708
# Loss XY 	 0.055864897
# Current Recall 	 0.0
# Loss Conf 	 0.0019713405
# Average Recall 	 0.050584283
# Loss Class 	 0.6759954
# Total Loss 	 5.0705395
# 208/251 [=======================>......] - ETA: 18s - loss: 4.8684Dummy Line 	 [0.]
# Loss WH 	 6.4927797
# Loss XY 	 0.051925324
# Current Recall 	 0.06382979
# Average Recall 	 0.050586972
# Loss Conf 	 0.0015847113
# Loss Class 	 0.7820913
# Total Loss 	 7.3283806
# 209/251 [=======================>......] - ETA: 18s - loss: 4.8802Dummy Line 	 [0.]
# Loss WH 	 2.8818088
# Loss XY 	 0.05935659
# Current Recall 	 0.03773585
# Average Recall 	 0.05058436
# Loss Conf 	 0.0025772194
# Loss Class 	 0.74098593
# Total Loss 	 3.6847286
# 210/251 [========================>.....] - ETA: 17s - loss: 4.8745Dummy Line 	 [0.]
# Loss XY 	 0.051349383
# Loss WH 	 3.7169454
# Current Recall 	 0.0625
# Loss Conf 	 0.0021388342
# Loss Class 	 0.5358106
# Average Recall 	 0.050586782
# Total Loss 	 4.3062444
# 211/251 [========================>.....] - ETA: 17s - loss: 4.8718Dummy Line 	 [0.]
# Loss WH 	 2.5544927
# Loss XY 	 0.058124308
# Current Recall 	 0.10958904
# Average Recall 	 0.050598767
# Loss Conf 	 0.002678497
# Loss Class 	 0.8746106
# Total Loss 	 3.489906
# 212/251 [========================>.....] - ETA: 17s - loss: 4.8653Dummy Line 	 [0.]
# Loss WH 	 2.7237332
# Loss XY 	 0.040053498
# Loss Conf 	 0.0033357171
# Average Recall 	 0.05060203
# Current Recall 	 0.06666667
# Loss Class 	 0.59208643
# Total Loss 	 3.359209
# 213/251 [========================>.....] - ETA: 16s - loss: 4.8582Dummy Line 	 [0.]
# Loss WH 	 5.2160687
# Loss XY 	 0.046111494
# Current Recall 	 0.114285715
# Average Recall 	 0.05061496
# Loss Conf 	 0.001920804
# Loss Class 	 0.62809974
# Total Loss 	 5.892201
# 214/251 [========================>.....] - ETA: 16s - loss: 4.8631Dummy Line 	 [0.]
# Loss WH 	 5.229043
# Loss XY 	 0.05119726
# Average Recall 	 0.050614588
# Loss Conf 	 0.0016125697
# Current Recall 	 0.048780486
# Loss Class 	 0.4912141
# Total Loss 	 5.773067
# 215/251 [========================>.....] - ETA: 15s - loss: 4.8673Dummy Line 	 [0.]
# Loss WH 	 2.9132335
# Loss XY 	 0.06400515
# Current Recall 	 0.03846154
# Average Recall 	 0.050612126
# Loss Conf 	 0.002934806
# Loss Class 	 0.57021666
# Total Loss 	 3.55039
# 216/251 [========================>.....] - ETA: 15s - loss: 4.8612Dummy Line 	 [0.]
# Loss XY 	 0.061328303
# Loss Conf 	 0.002639672
# Average Recall 	 0.050608195
# Current Recall 	 0.03125
# Loss WH 	 3.5545309
# Loss Class 	 0.70308423
# Total Loss 	 4.3215833
# 217/251 [========================>.....] - ETA: 14s - loss: 4.8587Dummy Line 	 [0.]
# Loss WH 	 4.2466
# Loss XY 	 0.05398751
# Loss Conf 	 0.0028574537
# Current Recall 	 0.06557377
# Loss Class 	 0.48785987
# Average Recall 	 0.05061123
# Total Loss 	 4.791305
# 218/251 [=========================>....] - ETA: 14s - loss: 4.8584Dummy Line 	 [0.]
# Loss WH 	 3.3355293
# Loss XY 	 0.058916822
# Current Recall 	 0.06666667
# Average Recall 	 0.050614487
# Loss Conf 	 0.002471362
# Loss Class 	 0.44988763
# Total Loss 	 3.846805
# 219/251 [=========================>....] - ETA: 14s - loss: 4.8538Dummy Line 	 [0.]
# Loss WH 	 5.9937243
# Loss XY 	 0.048398845
# Current Recall 	 0.07317073
# Average Recall 	 0.05061906
# Loss Conf 	 0.00185469
# Loss Class 	 0.819461
# Total Loss 	 6.863439
# 220/251 [=========================>....] - ETA: 13s - loss: 4.8629Dummy Line 	 [0.]
# Loss WH 	 4.5190578
# Loss Conf 	 0.0023195168
# Average Recall 	 0.050627656
# Current Recall 	 0.093023255
# Loss XY 	 0.049910866
# Loss Class 	 0.40163767
# Total Loss 	 4.9729257
# 221/251 [=========================>....] - ETA: 13s - loss: 4.8634Dummy Line 	 [0.]
# Loss XY 	 0.048755687
# Loss WH 	 2.9632022
# Current Recall 	 0.12280702
# Loss Conf 	 0.0023288655
# Average Recall 	 0.05064229
# Loss Class 	 0.46402594
# Total Loss 	 3.4783127
# 222/251 [=========================>....] - ETA: 12s - loss: 4.8572Dummy Line 	 [0.]
# Loss XY 	 0.056451112
# Loss WH 	 3.1966796
# Average Recall 	 0.050643284
# Loss Conf 	 0.00276276
# Current Recall 	 0.055555556
# Loss Class 	 0.7803619
# Total Loss 	 4.0362554
# 223/251 [=========================>....] - ETA: 12s - loss: 4.8535Dummy Line 	 [0.]
# Loss WH 	 4.2703032
# Loss XY 	 0.042220704
# Current Recall 	 0.083333336
# Average Recall 	 0.050649907
# Loss Class 	 0.55358565
# Loss Conf 	 0.0027089478
# Total Loss 	 4.8688183
# 224/251 [=========================>....] - ETA: 11s - loss: 4.8536Dummy Line 	 [0.]
# Loss WH 	 5.993918
# Current Recall 	 0.0
# Average Recall 	 0.050639644
# Loss Conf 	 0.0023128209
# Loss Class 	 0.7788183
# Loss XY 	 0.05212804
# Total Loss 	 6.8271766
# 225/251 [=========================>....] - ETA: 11s - loss: 4.8623Dummy Line 	 [0.]
# Loss WH 	 2.8307157
# Loss XY 	 0.039094288
# Current Recall 	 0.09090909
# Average Recall 	 0.050647803
# Loss Conf 	 0.003134605
# Loss Class 	 0.6136867
# Total Loss 	 3.486631
# 226/251 [==========================>...] - ETA: 10s - loss: 4.8562Dummy Line 	 [0.]
# Loss WH 	 4.6956606
# Loss XY 	 0.059025295
# Current Recall 	 0.029411765
# Average Recall 	 0.050643504
# Loss Conf 	 0.0016028478
# Loss Class 	 0.71849185
# Total Loss 	 5.4747806
# 227/251 [==========================>...] - ETA: 10s - loss: 4.8590Dummy Line 	 [0.]
# Loss WH 	 2.8399098
# Loss XY 	 0.047572594
# Current Recall 	 0.050847456
# Average Recall 	 0.050643545
# Loss Conf 	 0.002382099
# Loss Class 	 0.8226171
# Total Loss 	 3.7124815
# 228/251 [==========================>...] - ETA: 10s - loss: 4.8539Dummy Line 	 [0.]
# Loss WH 	 3.6182911
# Loss XY 	 0.04869492
# Current Recall 	 0.09259259
# Average Recall 	 0.050652035
# Loss Conf 	 0.0018877775
# Loss Class 	 0.5121377
# Total Loss 	 4.1810117
# 229/251 [==========================>...] - ETA: 9s - loss: 4.8510 Dummy Line 	 [0.]
# Loss WH 	 2.8176765
# Loss XY 	 0.060302246
# Current Recall 	 0.08888889
# Average Recall 	 0.050659772
# Loss Conf 	 0.003520177
# Loss Class 	 0.5012169
# Total Loss 	 3.382716
# 230/251 [==========================>...] - ETA: 9s - loss: 4.8446Dummy Line 	 [0.]
# Loss WH 	 4.7321014
# Loss XY 	 0.0574075
# Current Recall 	 0.07692308
# Average Recall 	 0.050665088
# Loss Conf 	 0.002507471
# Total Loss 	 5.4574094
# Loss Class 	 0.6653927
# 231/251 [==========================>...] - ETA: 8s - loss: 4.8473Dummy Line 	 [0.]
# Loss WH 	 3.4991481
# Average Recall 	 0.050667096
# Loss Conf 	 0.0026751116
# Current Recall 	 0.060606062
# Loss XY 	 0.05358649
# Loss Class 	 0.8471821
# Total Loss 	 4.4025917
# 232/251 [==========================>...] - ETA: 8s - loss: 4.8453Dummy Line 	 [0.]
# Loss WH 	 2.0592768
# Loss XY 	 0.05720046
# Average Recall 	 0.050668746
# Loss Conf 	 0.0022959963
# Loss Class 	 0.43987057
# Current Recall 	 0.05882353
# Total Loss 	 2.5586438
# 233/251 [==========================>...] - ETA: 7s - loss: 4.8355Dummy Line 	 [0.]
# Loss WH 	 4.0356913
# Loss XY 	 0.042712636
# Current Recall 	 0.08510638
# Average Recall 	 0.050675713
# Loss Conf 	 0.0021248793
# Loss Class 	 0.5117822
# Total Loss 	 4.592311
# 234/251 [==========================>...] - ETA: 7s - loss: 4.8345Dummy Line 	 [0.]
# Loss WH 	 3.8970637
# Loss XY 	 0.06993855
# Loss Conf 	 0.002560428
# Current Recall 	 0.056338027
# Average Recall 	 0.050676856
# Loss Class 	 0.77583367
# Total Loss 	 4.7453966
# 235/251 [===========================>..] - ETA: 7s - loss: 4.8341Dummy Line 	 [0.]
# Loss WH 	 3.8494084
# Loss XY 	 0.04588883
# Current Recall 	 0.10869565
# Average Recall 	 0.050688583
# Loss Conf 	 0.0022558519
# Loss Class 	 0.44960454
# Total Loss 	 4.347158
# 236/251 [===========================>..] - ETA: 6s - loss: 4.8321Dummy Line 	 [0.]
# Loss XY 	 0.04212277
# Loss WH 	 4.0636683
# Current Recall 	 0.018181818
# Loss Class 	 0.55408716
# Loss Conf 	 0.0021861487
# Average Recall 	 0.050682016
# Total Loss 	 4.6620646
# 237/251 [===========================>..] - ETA: 6s - loss: 4.8313Dummy Line 	 [0.]
# Loss WH 	 4.6568384
# Loss XY 	 0.056297902
# Loss Conf 	 0.002172408
# Average Recall 	 0.050671775
# Current Recall 	 0.0
# Loss Class 	 0.64407885
# Total Loss 	 5.3593874
# 238/251 [===========================>..] - ETA: 5s - loss: 4.8336Dummy Line 	 [0.]
# Loss WH 	 4.414013
# Loss XY 	 0.05485881
# Current Recall 	 0.10909091
# Average Recall 	 0.050683577
# Loss Conf 	 0.0022111172
# Loss Class 	 0.8939145
# Total Loss 	 5.3649974
# 239/251 [===========================>..] - ETA: 5s - loss: 4.8358Dummy Line 	 [0.]
# Loss WH 	 7.2708564
# Current Recall 	 0.078947365
# Loss Conf 	 0.0016097098
# Loss XY 	 0.04586038
# Average Recall 	 0.050689284
# Loss Class 	 0.5122789
# Total Loss 	 7.8306055
# 240/251 [===========================>..] - ETA: 4s - loss: 4.8483Dummy Line 	 [0.]
# Loss WH 	 2.0454137
# Average Recall 	 0.050681777
# Current Recall 	 0.013513514
# Loss Conf 	 0.0031008038
# Loss Class 	 0.5471056
# Loss XY 	 0.06256222
# Total Loss 	 2.6581824
# 241/251 [===========================>..] - ETA: 4s - loss: 4.8392Dummy Line 	 [0.]
# Loss WH 	 2.319473
# Loss XY 	 0.044381574
# Current Recall 	 0.07575758
# Average Recall 	 0.05068684
# Loss Conf 	 0.003209486
# Loss Class 	 0.5527398
# Total Loss 	 2.919804
# 242/251 [===========================>..] - ETA: 3s - loss: 4.8312Dummy Line 	 [0.]
# Loss WH 	 3.961743
# Loss XY 	 0.06004751
# Average Recall 	 0.05068423
# Loss Conf 	 0.002227068
# Current Recall 	 0.03773585
# Loss Class 	 0.8113045
# Total Loss 	 4.835322
# 243/251 [============================>.] - ETA: 3s - loss: 4.8313Dummy Line 	 [0.]
# Loss WH 	 5.745654
# Loss XY 	 0.061797403
# Current Recall 	 0.071428575
# Average Recall 	 0.050688412
# Loss Conf 	 0.0015291829
# Loss Class 	 0.77576864
# Total Loss 	 6.5847497
# 244/251 [============================>.] - ETA: 3s - loss: 4.8384Dummy Line 	 [0.]
# Loss WH 	 2.888358
# Loss XY 	 0.054749515
# Average Recall 	 0.050693244
# Current Recall 	 0.07462686
# Loss Conf 	 0.0030301441
# Loss Class 	 0.52107763
# Total Loss 	 3.4672153
# 245/251 [============================>.] - ETA: 2s - loss: 4.8328Dummy Line 	 [0.]
# Loss WH 	 3.6568372
# ...
# Loss WH 	 5.7283583
# Loss XY 	 0.056649707
# Current Recall 	 0.175
# Average Recall 	 0.05844451
# Loss Conf 	 0.0015057125
# Loss Class 	 0.43405718
# Total Loss 	 6.220571
#   8/251 [..............................] - ETA: 1:15 - loss: 4.7222Dummy Line 	 [0.]
# Loss WH 	 1.9414542
# Loss XY 	 0.052156057
# Average Recall 	 0.058465887
# Current Recall 	 0.17948718
# Loss Conf 	 0.0026424371
# Loss Class 	 0.55051863
# Total Loss 	 2.5467713
#   9/251 [>.............................] - ETA: 1:15 - loss: 4.4804Dummy Line 	 [0.]
# Loss WH 	 2.5173314
# Loss XY 	 0.038662888
# Current Recall 	 0.1923077
# Average Recall 	 0.058489524
# Loss Conf 	 0.002228128
# Loss Class 	 0.3393346
# Total Loss 	 2.8975568
#  10/251 [>.............................] - ETA: 1:18 - loss: 4.3222Dummy Line 	 [0.]
# Loss WH 	 4.1610246
# Loss XY 	 0.042968646
# Current Recall 	 0.125
# Average Recall 	 0.058501266
# Loss Conf 	 0.001993839
# Loss Class 	 0.58971554
# Total Loss 	 4.7957025
#  11/251 [>.............................] - ETA: 1:23 - loss: 4.3652Dummy Line 	 [0.]
# Loss WH 	 3.0787282
# Loss XY 	 0.04560305
# Current Recall 	 0.057142857
# Average Recall 	 0.058501024
# Loss Conf 	 0.0012235059
# Loss Class 	 0.567229
# Total Loss 	 3.6927838
#  12/251 [>.............................] - ETA: 1:24 - loss: 4.3092Dummy Line 	 [0.]
# Loss WH 	 4.794509
# Loss XY 	 0.044384047
# Current Recall 	 0.17073171
# Average Recall 	 0.058520835
# Loss Conf 	 0.0018893498
# Loss Class 	 0.47837207
# Total Loss 	 5.3191543
#  13/251 [>.............................] - ETA: 1:25 - loss: 4.3869Dummy Line 	 [0.]
# Loss WH 	 4.0244617
# Loss XY 	 0.03691502
# Current Recall 	 0.24324325
# Loss Conf 	 0.0016941789
# Average Recall 	 0.05855343
# Loss Class 	 0.40181538
# Total Loss 	 4.464886
#  14/251 [>.............................] - ETA: 1:25 - loss: 4.3924Dummy Line 	 [0.]
# Loss WH 	 2.6126473
# Loss XY 	 0.05269552
# Current Recall 	 0.30357143
# Average Recall 	 0.058596656
# Loss Conf 	 0.0019302317
# Loss Class 	 0.51857316
# Total Loss 	 3.1858463
#  15/251 [>.............................] - ETA: 1:25 - loss: 4.3120Dummy Line 	 [0.]
# Loss WH 	 5.075902
# Loss XY 	 0.06011268
# Current Recall 	 0.10526316
# Average Recall 	 0.05860489
# Loss Conf 	 0.0023529588
# Loss Class 	 0.3734467
# Total Loss 	 5.511814
#  16/251 [>.............................] - ETA: 1:27 - loss: 4.3870Dummy Line 	 [0.]
# Loss WH 	 2.997956
# Loss XY 	 0.059770934
# Current Recall 	 0.140625
# Average Recall 	 0.058619354
# Loss Conf 	 0.0031830734
# Loss Class 	 0.42002088
# Total Loss 	 3.4809308
#  17/251 [=>............................] - ETA: 1:27 - loss: 4.3337Dummy Line 	 [0.]
# Loss WH 	 1.9641608
# Loss XY 	 0.037063863
# Current Recall 	 0.14545454
# Average Recall 	 0.058634665
# Loss Conf 	 0.0020496547
# Loss Class 	 0.57878613
# Total Loss 	 2.5820606
#  18/251 [=>............................] - ETA: 1:27 - loss: 4.2364Dummy Line 	 [0.]
# Loss WH 	 4.1454105
# Loss XY 	 0.03725201
# Current Recall 	 0.10638298
# Loss Conf 	 0.0021944481
# Average Recall 	 0.058643084
# Loss Class 	 0.47698244
# Total Loss 	 4.6618395
#  19/251 [=>............................] - ETA: 1:26 - loss: 4.2588Dummy Line 	 [0.]
# Loss WH 	 4.9727793
# Loss XY 	 0.055058356
# Loss Conf 	 0.0025617671
# Current Recall 	 0.02
# Average Recall 	 0.05863627
# Loss Class 	 0.6471306
# Total Loss 	 5.67753
#  20/251 [=>............................] - ETA: 1:26 - loss: 4.3297Dummy Line 	 [0.]
# Loss WH 	 2.1231692
# Loss Conf 	 0.0032768676
# Current Recall 	 0.10204082
# Average Recall 	 0.058643922
# Loss XY 	 0.05399432
# Loss Class 	 0.5018741
# Total Loss 	 2.6823144
#  21/251 [=>............................] - ETA: 1:26 - loss: 4.2513Dummy Line 	 [0.]
# Loss WH 	 3.864675
# Loss XY 	 0.07210358
# Current Recall 	 0.0625
# Average Recall 	 0.0586446
# Loss Conf 	 0.0028517458
# Loss Class 	 0.6167443
# Total Loss 	 4.5563745
#  22/251 [=>............................] - ETA: 1:26 - loss: 4.2651Dummy Line 	 [0.]
# Loss WH 	 4.249555
# Loss XY 	 0.04379875
# Current Recall 	 0.23809524
# Average Recall 	 0.058676217
# Loss Conf 	 0.0019424029
# Loss Class 	 0.5128876
# Total Loss 	 4.808184
#  23/251 [=>............................] - ETA: 1:27 - loss: 4.2887Dummy Line 	 [0.]
# Loss WH 	 2.5891535
# Loss XY 	 0.049674317
# Current Recall 	 0.022727273
# Average Recall 	 0.058669884
# Loss Conf 	 0.002019646
# Loss Class 	 0.35750282
# Total Loss 	 2.9983501
#  24/251 [=>............................] - ETA: 1:26 - loss: 4.2350Dummy Line 	 [0.]
# Loss WH 	 4.534332
# Loss XY 	 0.061677594
# Current Recall 	 0.1632653
# Average Recall 	 0.05868831
# Loss Conf 	 0.0020097774
# Loss Class 	 0.4896974
# Total Loss 	 5.0877166
#  25/251 [=>............................] - ETA: 1:26 - loss: 4.2691Dummy Line 	 [0.]
# Loss WH 	 4.4853706
# Loss XY 	 0.055391517
# Average Recall 	 0.058685742
# Current Recall 	 0.04411765
# Loss Conf 	 0.002359736
# Loss Class 	 0.35342196
# Total Loss 	 4.896544
#  26/251 [==>...........................] - ETA: 1:25 - loss: 4.2932Dummy Line 	 [0.]
# Loss WH 	 3.1100712
# Loss XY 	 0.038092464
# Current Recall 	 0.071428575
# Average Recall 	 0.05868799
# Loss Class 	 0.5532815
# Loss Conf 	 0.002194738
# Total Loss 	 3.7036397
#  27/251 [==>...........................] - ETA: 1:26 - loss: 4.2714Dummy Line 	 [0.]
# Loss XY 	 0.06146648
# Average Recall 	 0.058690697
# Current Recall 	 0.074074075
# Loss Conf 	 0.0022453424
# Loss WH 	 3.8916712
# Loss Class 	 0.53749794
# Total Loss 	 4.492881
#  28/251 [==>...........................] - ETA: 1:25 - loss: 4.2793Dummy Line 	 [0.]
# Loss WH 	 2.615132
# Loss XY 	 0.06586832
# Current Recall 	 0.11764706
# Average Recall 	 0.058701072
# Loss Conf 	 0.0025239782
# Loss Class 	 0.6732956
# Total Loss 	 3.35682
#  29/251 [==>...........................] - ETA: 1:25 - loss: 4.2475Dummy Line 	 [0.]
# Loss WH 	 3.1971612
# Loss XY 	 0.05564215
# Loss Class 	 0.5477865
# Current Recall 	 0.11764706
# Average Recall 	 0.058711443
# Loss Conf 	 0.0032292577
# Total Loss 	 3.803819
#  30/251 [==>...........................] - ETA: 1:26 - loss: 4.2327Dummy Line 	 [0.]
# Loss WH 	 4.4417253
# Current Recall 	 0.06122449
# Loss Conf 	 0.0020383804
# Loss XY 	 0.05275925
# Average Recall 	 0.058711886
# Loss Class 	 0.63429993
# Total Loss 	 5.1308227
#  31/251 [==>...........................] - ETA: 1:26 - loss: 4.2617Dummy Line 	 [0.]
# Loss WH 	 2.0507927
# Loss XY 	 0.053706814
# Current Recall 	 0.13333334
# Average Recall 	 0.05872501
# Loss Conf 	 0.0020671203
# Loss Class 	 0.5305472
# Total Loss 	 2.6371138
#  32/251 [==>...........................] - ETA: 1:25 - loss: 4.2109Dummy Line 	 [0.]
# Loss WH 	 2.9839919
# Loss XY 	 0.05427671
# Loss Conf 	 0.0026821967
# Average Recall 	 0.058720447
# Current Recall 	 0.032786883
# Loss Class 	 0.9552272
# Total Loss 	 3.996178
#  33/251 [==>...........................] - ETA: 1:26 - loss: 4.2044Dummy Line 	 [0.]
# Loss WH 	 2.3753543
# Loss XY 	 0.052365504
# Current Recall 	 0.06521739
# Average Recall 	 0.05872159
# Loss Conf 	 0.002301525
# Loss Class 	 0.9298305
# Total Loss 	 3.3598518
#  34/251 [===>..........................] - ETA: 1:26 - loss: 4.1796Dummy Line 	 [0.]
# Loss WH 	 2.8905778
# Loss XY 	 0.046581045
# Current Recall 	 0.071428575
# Average Recall 	 0.058723826
# Loss Conf 	 0.0036420438
# Loss Class 	 0.22777088
# Total Loss 	 3.1685717
#  35/251 [===>..........................] - ETA: 1:25 - loss: 4.1507Dummy Line 	 [0.]
# Loss XY 	 0.05749078
# Loss WH 	 3.415207
# Current Recall 	 0.12962963
# Average Recall 	 0.05873629
# Loss Conf 	 0.0025553908
# Loss Class 	 0.5284703
# Total Loss 	 4.003723
#  36/251 [===>..........................] - ETA: 1:26 - loss: 4.1466Dummy Line 	 [0.]
# Loss WH 	 6.5997834
# Loss XY 	 0.063498296
# Current Recall 	 0.0
# Average Recall 	 0.058725968
# Loss Conf 	 0.0018551493
# Loss Class 	 0.34409374
# Total Loss 	 7.009231
#  37/251 [===>..........................] - ETA: 1:26 - loss: 4.2240Dummy Line 	 [0.]
# Loss WH 	 4.8272095
# Loss XY 	 0.0638418
# Current Recall 	 0.13043478
# Average Recall 	 0.058738567
# Loss Conf 	 0.0016912895
# Loss Class 	 0.72274756
# Total Loss 	 5.61549
#  38/251 [===>..........................] - ETA: 1:27 - loss: 4.2606Dummy Line 	 [0.]
# Loss XY 	 0.054445475
# Loss WH 	 4.734142
# Current Recall 	 0.14583333
# Average Recall 	 0.05875387
# Loss Conf 	 0.0017856502
# Loss Class 	 0.48419222
# Total Loss 	 5.274565
#  39/251 [===>..........................] - ETA: 1:27 - loss: 4.2866Dummy Line 	 [0.]
# Loss WH 	 3.2238193
# Loss XY 	 0.047087025
# Current Recall 	 0.13846155
# Average Recall 	 0.05876787
# Loss Conf 	 0.002648284
# Loss Class 	 0.3708826
# Total Loss 	 3.644437
#  40/251 [===>..........................] - ETA: 1:26 - loss: 4.2705Dummy Line 	 [0.]
# Loss WH 	 6.512957
# Loss XY 	 0.050557822
# Current Recall 	 0.09756097
# Loss Conf 	 0.0015948358
# Average Recall 	 0.058774684
# Loss Class 	 0.88345814
# Total Loss 	 7.448568
#  41/251 [===>..........................] - ETA: 1:26 - loss: 4.3480Dummy Line 	 [0.]
# Loss XY 	 0.054746408
# Loss WH 	 3.738271
# Current Recall 	 0.13513513
# Loss Conf 	 0.0018535972
# Average Recall 	 0.05878809
# Loss Class 	 0.576639
# Total Loss 	 4.37151
#  42/251 [====>.........................] - ETA: 1:26 - loss: 4.3486Dummy Line 	 [0.]
# Loss WH 	 4.089605
# Current Recall 	 0.1590909
# Average Recall 	 0.0588057
# Loss Conf 	 0.0017758149
# Loss XY 	 0.037534084
# Loss Class 	 0.6550835
# Total Loss 	 4.7839985
#  43/251 [====>.........................] - ETA: 1:25 - loss: 4.3587Dummy Line 	 [0.]
# Loss WH 	 3.8057318
# Loss XY 	 0.0546364
# Current Recall 	 0.13636364
# Average Recall 	 0.058819313
# Loss Conf 	 0.0023350944
# Loss Class 	 0.6306156
# Total Loss 	 4.493319
#  44/251 [====>.........................] - ETA: 1:25 - loss: 4.3618Dummy Line 	 [0.]
# Loss WH 	 3.2120056
# Loss XY 	 0.051145587
# Current Recall 	 0.050847456
# Average Recall 	 0.058817912
# Loss Conf 	 0.0028343394
# Loss Class 	 0.799792
# Total Loss 	 4.0657773
#  45/251 [====>.........................] - ETA: 1:24 - loss: 4.3552Dummy Line 	 [0.]
# Loss WH 	 4.9400077
# Loss XY 	 0.05077188
# Current Recall 	 0.093023255
# Loss Conf 	 0.0018039937
# Average Recall 	 0.058823913
# Loss Class 	 0.8703553
# Total Loss 	 5.8629384
#  46/251 [====>.........................] - ETA: 1:25 - loss: 4.3880Dummy Line 	 [0.]
# Loss WH 	 2.376453
# Loss XY 	 0.038218886
# Current Recall 	 0.35416666
# Average Recall 	 0.05887573
# Loss Conf 	 0.0021917645
# Loss Class 	 0.24500044
# Total Loss 	 2.661864
#  47/251 [====>.........................] - ETA: 1:24 - loss: 4.3513Dummy Line 	 [0.]
# Loss XY 	 0.040898036
# Loss WH 	 2.6248217
# Current Recall 	 0.0877193
# Average Recall 	 0.058880784
# Loss Conf 	 0.0022677737
# Loss Class 	 0.556993
# Total Loss 	 3.2249806
#  48/251 [====>.........................] - ETA: 1:24 - loss: 4.3278Dummy Line 	 [0.]
# Loss XY 	 0.04628362
# Loss WH 	 3.3640063
# Current Recall 	 0.057692308
# Loss Conf 	 0.002151121
# Average Recall 	 0.058880575
# Loss Class 	 0.44214112
# Total Loss 	 3.854582
#  49/251 [====>.........................] - ETA: 1:24 - loss: 4.3181Dummy Line 	 [0.]
# Loss WH 	 2.0612237
# Loss XY 	 0.052694667
# Current Recall 	 0.0952381
# Average Recall 	 0.05888695
# Loss Conf 	 0.0023551323
# Loss Class 	 1.0175902
# Total Loss 	 3.1338634
#  50/251 [====>.........................] - ETA: 1:23 - loss: 4.2944Dummy Line 	 [0.]
# Loss XY 	 0.06548137
# Loss WH 	 3.6336124
# Current Recall 	 0.071428575
# Average Recall 	 0.05888915
# Loss Conf 	 0.0025049304
# Loss Class 	 1.1315525
# Total Loss 	 4.833151
#  51/251 [=====>........................] - ETA: 1:23 - loss: 4.3050Dummy Line 	 [0.]
# Loss WH 	 2.631635
# Loss XY 	 0.058432627
# Current Recall 	 0.14285715
# Average Recall 	 0.05890387
# Loss Conf 	 0.0027199008
# Loss Class 	 0.58551717
# Total Loss 	 3.2783046
#  52/251 [=====>........................] - ETA: 1:23 - loss: 4.2853Dummy Line 	 [0.]
# Loss WH 	 4.474818
# Loss XY 	 0.049565557
# Current Recall 	 0.11764706
# Loss Class 	 0.5743174
# Loss Conf 	 0.0022918666
# Average Recall 	 0.058914162
# Total Loss 	 5.100993
#  53/251 [=====>........................] - ETA: 1:23 - loss: 4.3007Dummy Line 	 [0.]
# Loss WH 	 6.8486967
# Loss XY 	 0.046288002
# Current Recall 	 0.14545454
# Average Recall 	 0.058929324
# Loss Conf 	 0.0020754253
# Loss Class 	 0.53894097
# Total Loss 	 7.436001
#  54/251 [=====>........................] - ETA: 1:22 - loss: 4.3587Dummy Line 	 [0.]
# Loss WH 	 4.3906207
# Loss XY 	 0.06828899
# Current Recall 	 0.09803922
# Loss Conf 	 0.0022264468
# Average Recall 	 0.05893618
# Loss Class 	 0.67382234
# Total Loss 	 5.1349583
#  55/251 [=====>........................] - ETA: 1:22 - loss: 4.3728Dummy Line 	 [0.]
# Loss WH 	 3.1367915
# Loss XY 	 0.054539688
# Current Recall 	 0.078125
# Average Recall 	 0.058939543
# Loss Conf 	 0.0026121496
# Loss Class 	 0.5554956
# Total Loss 	 3.7494388
#  56/251 [=====>........................] - ETA: 1:22 - loss: 4.3617Dummy Line 	 [0.]
# Loss WH 	 5.9618196
# Current Recall 	 0.13043478
# Average Recall 	 0.058952063
# Loss Conf 	 0.0023922583
# Loss Class 	 0.27417716
# Loss XY 	 0.041839994
# Total Loss 	 6.280229
#  57/251 [=====>........................] - ETA: 1:21 - loss: 4.3954Dummy Line 	 [0.]
# Loss WH 	 2.7641208
# Loss XY 	 0.050386768
# Current Recall 	 0.03797468
# Average Recall 	 0.058948386
# Loss Conf 	 0.0028478678
# Loss Class 	 0.23737977
# Total Loss 	 3.0547352
#  58/251 [=====>........................] - ETA: 1:21 - loss: 4.3722Dummy Line 	 [0.]
# Loss WH 	 4.676685
# Loss XY 	 0.0569521
# Current Recall 	 0.06557377
# Average Recall 	 0.05894955
# Loss Conf 	 0.0020197155
# Loss Class 	 0.37514588
# Total Loss 	 5.1108027
#  59/251 [======>.......................] - ETA: 1:20 - loss: 4.3848Dummy Line 	 [0.]
# Loss WH 	 4.703579
# Loss XY 	 0.04907882
# Current Recall 	 0.06451613
# Average Recall 	 0.05895052
# Loss Conf 	 0.0024382696
# Loss Class 	 1.0165542
# Total Loss 	 5.7716503
#  60/251 [======>.......................] - ETA: 1:20 - loss: 4.4079Dummy Line 	 [0.]
# Loss XY 	 0.055430654
# Loss WH 	 3.421179
# Average Recall 	 0.058960095
# Current Recall 	 0.11363637
# Loss Conf 	 0.0014754982
# Loss Class 	 0.6923581
# Total Loss 	 4.1704435
#  61/251 [======>.......................] - ETA: 1:19 - loss: 4.4040Dummy Line 	 [0.]
# Loss WH 	 5.184815
# Loss XY 	 0.06842982
# Current Recall 	 0.083333336
# Average Recall 	 0.05896436
# Loss Conf 	 0.002082452
# Loss Class 	 0.5150376
# Total Loss 	 5.7703648
#  62/251 [======>.......................] - ETA: 1:19 - loss: 4.4260Dummy Line 	 [0.]
# Loss WH 	 3.483464
# Loss XY 	 0.048578903
# Current Recall 	 0.11290322
# Average Recall 	 0.0589738
# Loss Conf 	 0.0029446087
# Loss Class 	 0.53848916
# Total Loss 	 4.073477
#  63/251 [======>.......................] - ETA: 1:18 - loss: 4.4204Dummy Line 	 [0.]
# Loss WH 	 3.1640508
# Loss XY 	 0.049363356
# Current Recall 	 0.012820513
# Average Recall 	 0.058965728
# Loss Conf 	 0.0032000092
# Loss Class 	 0.8192446
# Total Loss 	 4.035859
#  64/251 [======>.......................] - ETA: 1:19 - loss: 4.4144Dummy Line 	 [0.]
# Loss XY 	 0.04750756
# Loss WH 	 4.1997643
# Current Recall 	 0.1590909
# Average Recall 	 0.058983237
# Loss Conf 	 0.0018774151
# Loss Class 	 0.5842424
# Total Loss 	 4.8333917
#  65/251 [======>.......................] - ETA: 1:18 - loss: 4.4209Dummy Line 	 [0.]
# Loss WH 	 3.2844293
# Loss Conf 	 0.002005266
# Loss XY 	 0.048920438
# Average Recall 	 0.0589842
# Current Recall 	 0.06451613
# Loss Class 	 0.6649352
# Total Loss 	 4.0002904
#  66/251 [======>.......................] - ETA: 1:18 - loss: 4.4145Dummy Line 	 [0.]
# Loss WH 	 5.155748
# Loss XY 	 0.053382672
# Loss Conf 	 0.0022469861
# Average Recall 	 0.058989223
# Current Recall 	 0.0877193
# Loss Class 	 0.31302974
# Total Loss 	 5.5244074
#  67/251 [=======>......................] - ETA: 1:18 - loss: 4.4311Dummy Line 	 [0.]
# Loss WH 	 4.169432
# Loss XY 	 0.039040077
# Current Recall 	 0.15873016
# Average Recall 	 0.059006657
# Loss Conf 	 0.002268827
# Loss Class 	 0.6869303
# Total Loss 	 4.897671
#  68/251 [=======>......................] - ETA: 1:17 - loss: 4.4379Dummy Line 	 [0.]
# Loss WH 	 4.505284
# Loss XY 	 0.04229553
# Current Recall 	 0.15789473
# Average Recall 	 0.05902394
# Loss Conf 	 0.002284876
# Loss Class 	 0.748675
# Total Loss 	 5.298539
#  69/251 [=======>......................] - ETA: 1:17 - loss: 4.4504Dummy Line 	 [0.]
# Loss WH 	 2.9603477
# Loss XY 	 0.041165803
# Current Recall 	 0.12820514
# Loss Conf 	 0.0016950166
# Average Recall 	 0.059036028
# Loss Class 	 0.40970492
# Total Loss 	 3.4129133
#  70/251 [=======>......................] - ETA: 1:17 - loss: 4.4356

# %%
'''
g = BatchGenerator(train_imgs[3:10], generator_config, jitter=False)
evaluate(g)
image = g.load_image(0)
image_h, image_w, _ = image.shape
image = cv2.resize(image, (IMAGE_H, IMAGE_W))
image = normalize(image)
input_image = image[:,:,::-1]
input_image = np.expand_dims(input_image, 0)
dummy_array = np.zeros((1,1,1,1,TRUE_BOX_BUFFER,4))
netout = model.predict([input_image, dummy_array])[0]
netout[..., 4]  = _sigmoid(netout[..., 4])
netout[..., 5:] = netout[..., 4][..., np.newaxis] * _softmax(netout[..., 5:])
print(np.max(netout[7, 6, 2, 4]))
print(np.max(netout[:, :, :, 5:]))
'''
# Out:
# 0.26544434
# 0.20175305
