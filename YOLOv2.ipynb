# %% [markdown]
# <a href="https://colab.research.google.com/github/Anil1331/YOLOv2/blob/master/YOLOv2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget -q http://pjreddie.com/media/files/VOCtrainval_06-Nov-2007.tar
# !tar -xf VOCtrainval_06-Nov-2007.tar

# %%
classes = {'chair': 1432, 'car': 1644, 'horse': 406, 'person': 5447, 'bicycle': 418, 'cat': 389, 'dog': 538, 'head': 439, 'foot': 434, 'hand': 681, 'train': 328, 'aeroplane': 331, 'diningtable': 310, 'tvmonitor': 367, 'bird': 599, 'bottle': 634, 'motorbike': 390, 'pottedplant': 625, 'boat': 398, 'sofa': 425, 'sheep': 353, 'cow': 356, 'bus': 272}
LABELS = list(classes.keys())

# %%
import os
import cv2
import copy
import numpy as np
import imgaug as ia
from imgaug import augmenters as iaa
from keras.utils import Sequence
import xml.etree.ElementTree as ET
import random 
def get_images(ann_dir, img_dir, ann, labels, all_imgs, seen_labels):
  img = {'object':[]}

  tree = ET.parse(ann_dir + ann)

  for elem in tree.iter():
      if 'filename' in elem.tag:
          img['filename'] = img_dir + elem.text
      if 'width' in elem.tag:
          img['width'] = int(elem.text)
      if 'height' in elem.tag:
          img['height'] = int(elem.text)
      if 'object' in elem.tag or 'part' in elem.tag:
          obj = {}

          for attr in list(elem):
              if 'name' in attr.tag:
                  obj['name'] = attr.text

                  if obj['name'] in seen_labels:
                      seen_labels[obj['name']] += 1
                  else:
                      seen_labels[obj['name']] = 1

                  if len(labels) > 0 and obj['name'] not in labels:
                      break
                  else:
                      img['object'] += [obj]

              if 'bndbox' in attr.tag:
                  for dim in list(attr):
                      if 'xmin' in dim.tag:
                          obj['xmin'] = int(round(float(dim.text)))
                      if 'ymin' in dim.tag:
                          obj['ymin'] = int(round(float(dim.text)))
                      if 'xmax' in dim.tag:
                          obj['xmax'] = int(round(float(dim.text)))
                      if 'ymax' in dim.tag:
                          obj['ymax'] = int(round(float(dim.text)))

  if len(img['object']) > 0:
      all_imgs += [img] 
  return all_imgs, seen_labels    

def parse_annotation(ann_dir, img_dir, labels=[]):
    files = os.listdir(ann_dir)
    train = random.sample(files, int((len(files)*4)/5))
    test = [x for x in files if x not in train]
    print(len(train), len(test))
    train_imgs, train_labels, val_imgs, val_labels = [], {}, [], {}
    for ann in sorted(train):
        get_images(ann_dir, img_dir, ann, labels, train_imgs, train_labels)
    for ann in sorted(test):
        get_images(ann_dir, img_dir, ann, labels, val_imgs, val_labels)        
    return train_imgs, train_labels, val_imgs, val_labels

class BatchGenerator(Sequence):
    def __init__(self, images, 
                       config, 
                       shuffle=True, 
                       jitter=True, 
                       norm=None):
        self.generator = None

        self.images = images
        self.config = config

        self.shuffle = shuffle
        self.jitter  = jitter
        self.norm    = norm

        self.anchors = [BoundBox(0, 0, config['ANCHORS'][2*i], config['ANCHORS'][2*i+1]) for i in range(int(len(config['ANCHORS'])//2))]

        ### augmentors by https://github.com/aleju/imgaug
        sometimes = lambda aug: iaa.Sometimes(0.5, aug)

        # Define our sequence of augmentation steps that will be applied to every image
        # All augmenters with per_channel=0.5 will sample one value _per image_
        # in 50% of all cases. In all other cases they will sample new values
        # _per channel_.
        self.aug_pipe = iaa.Sequential(
            [
                # apply the following augmenters to most images
                #iaa.Fliplr(0.5), # horizontally flip 50% of all images
                #iaa.Flipud(0.2), # vertically flip 20% of all images
                #sometimes(iaa.Crop(percent=(0, 0.1))), # crop images by 0-10% of their height/width
                sometimes(iaa.Affine(
                    #scale={"x": (0.8, 1.2), "y": (0.8, 1.2)}, # scale images to 80-120% of their size, individually per axis
                    #translate_percent={"x": (-0.2, 0.2), "y": (-0.2, 0.2)}, # translate by -20 to +20 percent (per axis)
                    #rotate=(-5, 5), # rotate by -45 to +45 degrees
                    #shear=(-5, 5), # shear by -16 to +16 degrees
                    #order=[0, 1], # use nearest neighbour or bilinear interpolation (fast)
                    #cval=(0, 255), # if mode is constant, use a cval between 0 and 255
                    #mode=ia.ALL # use any of scikit-image's warping modes (see 2nd image from the top for examples)
                )),
                # execute 0 to 5 of the following (less important) augmenters per image
                # don't execute all of them, as that would often be way too strong
                iaa.SomeOf((0, 5),
                    [
                        #sometimes(iaa.Superpixels(p_replace=(0, 1.0), n_segments=(20, 200))), # convert images into their superpixel representation
                        iaa.OneOf([
                            iaa.GaussianBlur((0, 3.0)), # blur images with a sigma between 0 and 3.0
                            iaa.AverageBlur(k=(2, 7)), # blur image using local means with kernel sizes between 2 and 7
                            iaa.MedianBlur(k=(3, 11)), # blur image using local medians with kernel sizes between 2 and 7
                        ]),
                        iaa.Sharpen(alpha=(0, 1.0), lightness=(0.75, 1.5)), # sharpen images
                        #iaa.Emboss(alpha=(0, 1.0), strength=(0, 2.0)), # emboss images
                        # search either for all edges or for directed edges
                        #sometimes(iaa.OneOf([
                        #    iaa.EdgeDetect(alpha=(0, 0.7)),
                        #    iaa.DirectedEdgeDetect(alpha=(0, 0.7), direction=(0.0, 1.0)),
                        #])),
                        iaa.AdditiveGaussianNoise(loc=0, scale=(0.0, 0.05*255), per_channel=0.5), # add gaussian noise to images
                        iaa.OneOf([
                            iaa.Dropout((0.01, 0.1), per_channel=0.5), # randomly remove up to 10% of the pixels
                            #iaa.CoarseDropout((0.03, 0.15), size_percent=(0.02, 0.05), per_channel=0.2),
                        ]),
                        #iaa.Invert(0.05, per_channel=True), # invert color channels
                        iaa.Add((-10, 10), per_channel=0.5), # change brightness of images (by -10 to 10 of original value)
                        iaa.Multiply((0.5, 1.5), per_channel=0.5), # change brightness of images (50-150% of original value)
                        iaa.ContrastNormalization((0.5, 2.0), per_channel=0.5), # improve or worsen the contrast
                        #iaa.Grayscale(alpha=(0.0, 1.0)),
                        #sometimes(iaa.ElasticTransformation(alpha=(0.5, 3.5), sigma=0.25)), # move pixels locally around (with random strengths)
                        #sometimes(iaa.PiecewiseAffine(scale=(0.01, 0.05))) # sometimes move parts of the image around
                    ],
                    random_order=True
                )
            ],
            random_order=True
        )

        if shuffle: np.random.shuffle(self.images)

    def __len__(self):
        return int(np.ceil(float(len(self.images))/self.config['BATCH_SIZE']))   

    def num_classes(self):
        return len(self.config['LABELS'])

    def size(self):
        return len(self.images)    

    def load_annotation(self, i):
        annots = []

        for obj in self.images[i]['object']:
            annot = [obj['xmin'], obj['ymin'], obj['xmax'], obj['ymax'], self.config['LABELS'].index(obj['name'])]
            annots += [annot]

        if len(annots) == 0: annots = [[]]

        return np.array(annots)

    def load_image(self, i):
        return cv2.imread(self.images[i]['filename'])

    def __getitem__(self, idx):
        l_bound = idx*self.config['BATCH_SIZE']
        r_bound = (idx+1)*self.config['BATCH_SIZE']

        if r_bound > len(self.images):
            r_bound = len(self.images)
            l_bound = r_bound - self.config['BATCH_SIZE']

        instance_count = 0

        x_batch = np.zeros((r_bound - l_bound, self.config['IMAGE_H'], self.config['IMAGE_W'], 3))                         # input images
        b_batch = np.zeros((r_bound - l_bound, 1     , 1     , 1    ,  self.config['TRUE_BOX_BUFFER'], 4))   # list of self.config['TRUE_self.config['BOX']_BUFFER'] GT boxes
        y_batch = np.zeros((r_bound - l_bound, self.config['GRID_H'],  self.config['GRID_W'], self.config['BOX'], 4+1+len(self.config['LABELS'])))                # desired network output

        for train_instance in self.images[l_bound:r_bound]:
            # augment input image and fix object's position and size
            img, all_objs = self.aug_image(train_instance, jitter=self.jitter)
            
            # construct output from object's x, y, w, h
            true_box_index = 0
            
            for obj in all_objs:
                if obj['xmax'] > obj['xmin'] and obj['ymax'] > obj['ymin'] and obj['name'] in self.config['LABELS']:
                    center_x = .5*(obj['xmin'] + obj['xmax'])
                    center_x = center_x / (float(self.config['IMAGE_W']) / self.config['GRID_W'])
                    center_y = .5*(obj['ymin'] + obj['ymax'])
                    center_y = center_y / (float(self.config['IMAGE_H']) / self.config['GRID_H'])

                    grid_x = int(np.floor(center_x))
                    grid_y = int(np.floor(center_y))

                    if grid_x < self.config['GRID_W'] and grid_y < self.config['GRID_H']:
                        obj_indx  = self.config['LABELS'].index(obj['name'])
                        
                        center_w = (obj['xmax'] - obj['xmin']) / (float(self.config['IMAGE_W']) / self.config['GRID_W']) # unit: grid cell
                        center_h = (obj['ymax'] - obj['ymin']) / (float(self.config['IMAGE_H']) / self.config['GRID_H']) # unit: grid cell
                        
                        box = [center_x, center_y, center_w, center_h]

                        # find the anchor that best predicts this box
                        best_anchor = -1
                        max_iou     = -1
                        
                        shifted_box = BoundBox(0, 
                                               0,
                                               center_w,                                                
                                               center_h)
                        
                        for i in range(len(self.anchors)):
                            anchor = self.anchors[i]
                            iou    = bbox_iou(shifted_box, anchor)
                            
                            if max_iou < iou:
                                best_anchor = i
                                max_iou     = iou
                                
                        # assign ground truth x, y, w, h, confidence and class probs to y_batch
                        y_batch[instance_count, grid_y, grid_x, best_anchor, 0:4] = box
                        y_batch[instance_count, grid_y, grid_x, best_anchor, 4  ] = 1.
                        y_batch[instance_count, grid_y, grid_x, best_anchor, 5+obj_indx] = 1
                        
                        # assign the true box to b_batch
                        b_batch[instance_count, 0, 0, 0, true_box_index] = box
                        
                        true_box_index += 1
                        true_box_index = true_box_index % self.config['TRUE_BOX_BUFFER']
                            
            # assign input image to x_batch
            if self.norm != None: 
                x_batch[instance_count] = self.norm(img)
            else:
                # plot image and bounding boxes for sanity check
                for obj in all_objs:
                    if obj['xmax'] > obj['xmin'] and obj['ymax'] > obj['ymin']:
                        cv2.rectangle(img[:,:,::-1], (obj['xmin'],obj['ymin']), (obj['xmax'],obj['ymax']), (255,0,0), 3)
                        cv2.putText(img[:,:,::-1], obj['name'], 
                                    (obj['xmin']+2, obj['ymin']+12), 
                                    0, 1.2e-3 * img.shape[0], 
                                    (0,255,0), 2)
                        
                x_batch[instance_count] = img

            # increase instance counter in current batch
            instance_count += 1  

        #print(' new batch created', idx)

        return [x_batch, b_batch], y_batch

    def on_epoch_end(self):
        if self.shuffle: np.random.shuffle(self.images)

    def aug_image(self, train_instance, jitter):
        image_name = train_instance['filename']
        image = cv2.imread(image_name)

        if image is None: print('Cannot find ', image_name)

        h, w, c = image.shape
        all_objs = copy.deepcopy(train_instance['object'])

        if jitter:
            ### scale the image
            scale = np.random.uniform() / 10. + 1.
            image = cv2.resize(image, (0,0), fx = scale, fy = scale)

            ### translate the image
            max_offx = (scale-1.) * w
            max_offy = (scale-1.) * h
            offx = int(np.random.uniform() * max_offx)
            offy = int(np.random.uniform() * max_offy)
            
            image = image[offy : (offy + h), offx : (offx + w)]

            ### flip the image
            flip = np.random.binomial(1, .5)
            if flip > 0.5: image = cv2.flip(image, 1)
                
            image = self.aug_pipe.augment_image(image)            
            
        # resize the image to standard size
        image = cv2.resize(image, (self.config['IMAGE_H'], self.config['IMAGE_W']))
        image = image[:,:,::-1]

        # fix object's position and size
        for obj in all_objs:
            for attr in ['xmin', 'xmax']:
                if jitter: obj[attr] = int(obj[attr] * scale - offx)
                    
                obj[attr] = int(obj[attr] * float(self.config['IMAGE_W']) / w)
                obj[attr] = max(min(obj[attr], self.config['IMAGE_W']), 0)
                
            for attr in ['ymin', 'ymax']:
                if jitter: obj[attr] = int(obj[attr] * scale - offy)
                    
                obj[attr] = int(obj[attr] * float(self.config['IMAGE_H']) / h)
                obj[attr] = max(min(obj[attr], self.config['IMAGE_H']), 0)

            if jitter and flip > 0.5:
                xmin = obj['xmin']
                obj['xmin'] = self.config['IMAGE_W'] - obj['xmax']
                obj['xmax'] = self.config['IMAGE_W'] - xmin
                
        return image, all_objs
# Out:
# Using TensorFlow backend.

# %%
import numpy as np
import os
import xml.etree.ElementTree as ET
import tensorflow as tf
import copy
import cv2

class BoundBox:
    def __init__(self, xmin, ymin, xmax, ymax, c = None, classes = None):
        self.xmin = xmin
        self.ymin = ymin
        self.xmax = xmax
        self.ymax = ymax
        
        self.c     = c
        self.classes = classes

        self.label = -1
        self.score = -1

    def get_label(self):
        if self.label == -1:
            self.label = np.argmax(self.classes)
        
        return self.label
    
    def get_score(self):
        if self.score == -1:
            self.score = self.classes[self.get_label()]
            
        return self.score

class WeightReader:
    def __init__(self, weight_file):
        self.offset = 4
        self.all_weights = np.fromfile(weight_file, dtype='float32')
        
    def read_bytes(self, size):
        self.offset = self.offset + size
        return self.all_weights[self.offset-size:self.offset]
    
    def reset(self):
        self.offset = 4

def bbox_iou(box1, box2):
    intersect_w = _interval_overlap([box1.xmin, box1.xmax], [box2.xmin, box2.xmax])
    intersect_h = _interval_overlap([box1.ymin, box1.ymax], [box2.ymin, box2.ymax])  
    
    intersect = intersect_w * intersect_h

    w1, h1 = box1.xmax-box1.xmin, box1.ymax-box1.ymin
    w2, h2 = box2.xmax-box2.xmin, box2.ymax-box2.ymin
    
    union = w1*h1 + w2*h2 - intersect
    
    return float(intersect) / union

def draw_boxes(image, boxes, labels):
    image_h, image_w, _ = image.shape

    for box in boxes:
        xmin = int(box.xmin*image_w)
        ymin = int(box.ymin*image_h)
        xmax = int(box.xmax*image_w)
        ymax = int(box.ymax*image_h)

        cv2.rectangle(image, (xmin,ymin), (xmax,ymax), (0,255,0), 3)
        cv2.putText(image, 
                    labels[box.get_label()] + ' ' + str(box.get_score()), 
                    (xmin, ymin - 13), 
                    cv2.FONT_HERSHEY_SIMPLEX, 
                    1e-3 * image_h, 
                    (0,255,0), 2)
        
    return image          
        
def decode_netout(netout, anchors, nb_class, obj_threshold=0.3, nms_threshold=0.3):
    grid_h, grid_w, nb_box = netout.shape[:3]

    boxes = []
    # decode the output by the network
    netout[..., 4]  = _sigmoid(netout[..., 4])
    netout[..., 5:] = netout[..., 4][..., np.newaxis] * _softmax(netout[..., 5:])
    #print(np.max(netout[..., 5:]))
    netout[..., 5:] *= netout[..., 5:] > obj_threshold
    
    for row in range(grid_h):
        for col in range(grid_w):
            for b in range(nb_box):
                # from 4th element onwards are confidence and class classes
                classes = netout[row,col,b,5:]
                if np.sum(classes) > 0:
                    # first 4 elements are x, y, w, and h
                    x, y, w, h = netout[row,col,b,:4]

                    x = (col + _sigmoid(x)) / grid_w # center position, unit: image width
                    y = (row + _sigmoid(y)) / grid_h # center position, unit: image height
                    w = anchors[2 * b + 0] * np.exp(w) / grid_w # unit: image width
                    h = anchors[2 * b + 1] * np.exp(h) / grid_h # unit: image height
                    confidence = netout[row,col,b,4]
                    
                    box = BoundBox(x-w/2, y-h/2, x+w/2, y+h/2, confidence, classes)
                    
                    boxes.append(box)
    #print(boxes)
    # suppress non-maximal boxes
    for c in range(nb_class):
        sorted_indices = list(reversed(np.argsort([box.classes[c] for box in boxes])))

        for i in range(len(sorted_indices)):
            index_i = sorted_indices[i]
            
            if boxes[index_i].classes[c] == 0: 
                continue
            else:
                for j in range(i+1, len(sorted_indices)):
                    index_j = sorted_indices[j]
                    
                    if bbox_iou(boxes[index_i], boxes[index_j]) >= nms_threshold:
                        boxes[index_j].classes[c] = 0
                        
    #print([box.get_score() for box in boxes])                    
    # remove the boxes which are less likely than a obj_threshold
    boxes = [box for box in boxes if box.get_score() > obj_threshold]
    
    return boxes    

def compute_overlap(a, b):
    """
    Code originally from https://github.com/rbgirshick/py-faster-rcnn.
    Parameters
    ----------
    a: (N, 4) ndarray of float
    b: (K, 4) ndarray of float
    Returns
    -------
    overlaps: (N, K) ndarray of overlap between boxes and query_boxes
    """
    area = (b[:, 2] - b[:, 0]) * (b[:, 3] - b[:, 1])

    iw = np.minimum(np.expand_dims(a[:, 2], axis=1), b[:, 2]) - np.maximum(np.expand_dims(a[:, 0], 1), b[:, 0])
    ih = np.minimum(np.expand_dims(a[:, 3], axis=1), b[:, 3]) - np.maximum(np.expand_dims(a[:, 1], 1), b[:, 1])

    iw = np.maximum(iw, 0)
    ih = np.maximum(ih, 0)

    ua = np.expand_dims((a[:, 2] - a[:, 0]) * (a[:, 3] - a[:, 1]), axis=1) + area - iw * ih

    ua = np.maximum(ua, np.finfo(float).eps)

    intersection = iw * ih

    return intersection / ua  
    
def compute_ap(recall, precision):
    """ Compute the average precision, given the recall and precision curves.
    Code originally from https://github.com/rbgirshick/py-faster-rcnn.

    # Arguments
        recall:    The recall curve (list).
        precision: The precision curve (list).
    # Returns
        The average precision as computed in py-faster-rcnn.
    """
    # correct AP calculation
    # first append sentinel values at the end
    mrec = np.concatenate(([0.], recall, [1.]))
    mpre = np.concatenate(([0.], precision, [0.]))

    # compute the precision envelope
    for i in range(mpre.size - 1, 0, -1):
        mpre[i - 1] = np.maximum(mpre[i - 1], mpre[i])

    # to calculate area under PR curve, look for points
    # where X axis (recall) changes value
    i = np.where(mrec[1:] != mrec[:-1])[0]

    # and sum (\Delta recall) * prec
    ap = np.sum((mrec[i + 1] - mrec[i]) * mpre[i + 1])
    return ap      
        
def _interval_overlap(interval_a, interval_b):
    x1, x2 = interval_a
    x3, x4 = interval_b

    if x3 < x1:
        if x4 < x1:
            return 0
        else:
            return min(x2,x4) - x1
    else:
        if x2 < x3:
             return 0
        else:
            return min(x2,x4) - x3          

def _sigmoid(x):
    return 1. / (1. + np.exp(-x))

def _softmax(x, axis=-1, t=-100.):
    x = x - np.max(x)
    
    if np.min(x) < t:
        x = x/np.min(x)*t
        
    e_x = np.exp(x)
    
    return e_x / e_x.sum(axis, keepdims=True)

# %%
import cv2

def normalize(image):
  return image / 255.

'''
def normalize(image):
    image = image[..., ::-1]
    image = image.astype('float')

    image[..., 0] -= 103.939
    image[..., 1] -= 116.779
    image[..., 2] -= 123.68

    return image
'''

def predict(image):
  image_h, image_w, _ = image.shape
  image = cv2.resize(image, (IMAGE_H, IMAGE_W))
  image = normalize(image)
  input_image = image[:,:,::-1]
  input_image = np.expand_dims(input_image, 0)
  dummy_array = np.zeros((1,1,1,1,TRUE_BOX_BUFFER,4))

  netout = model.predict([input_image, dummy_array])[0]
  boxes  = decode_netout(netout, ANCHORS, CLASS)

  return boxes

def evaluate(generator, 
			 iou_threshold=0.3,
			 score_threshold=0.3,
			 max_detections=100,
			 save_path=None):
	""" Evaluate a given dataset using a given model.
	code originally from https://github.com/fizyr/keras-retinanet
	# Arguments
		generator       : The generator that represents the dataset to evaluate.
		model           : The model to evaluate.
		iou_threshold   : The threshold used to consider when a detection is positive or negative.
		score_threshold : The score confidence threshold to use for detections.
		max_detections  : The maximum number of detections to use per image.
		save_path       : The path to save images with visualized detections to.
	# Returns
		A dict mapping class names to mAP scores.
	"""    
	# gather all detections and annotations
	all_detections     = [[None for i in range(generator.num_classes())] for j in range(generator.size())]
	all_annotations    = [[None for i in range(generator.num_classes())] for j in range(generator.size())]
	for i in range(generator.size()):
		raw_image = generator.load_image(i)
		raw_height, raw_width, raw_channels = raw_image.shape

		# make the boxes and the labels
		pred_boxes  = predict(raw_image)

		
		score = np.array([box.score for box in pred_boxes])
		pred_labels = np.array([box.label for box in pred_boxes])        
		#print(len(pred_boxes))
		if len(pred_boxes) > 0:
			pred_boxes = np.array([[box.xmin*raw_width, box.ymin*raw_height, box.xmax*raw_width, box.ymax*raw_height, box.score] for box in pred_boxes])
		else:
			pred_boxes = np.array([[]])  
		
		# sort the boxes and the labels according to scores
		score_sort = np.argsort(-score)
		pred_labels = pred_labels[score_sort]
		pred_boxes  = pred_boxes[score_sort]
		
		# copy detections to all_detections
		for label in range(generator.num_classes()):
			all_detections[i][label] = pred_boxes[pred_labels == label, :]
			
		annotations = generator.load_annotation(i)
		
		# copy detections to all_annotations
		for label in range(generator.num_classes()):
			all_annotations[i][label] = annotations[annotations[:, 4] == label, :4].copy()
			
	# compute mAP by comparing all detections and all annotations
	average_precisions = {}
	
	for label in range(generator.num_classes()):
		false_positives = np.zeros((0,))
		true_positives  = np.zeros((0,))
		scores          = np.zeros((0,))
		num_annotations = 0.0

		for i in range(generator.size()):
			detections           = all_detections[i][label]
			annotations          = all_annotations[i][label]
			num_annotations     += annotations.shape[0]
			detected_annotations = []

			for d in detections:
				scores = np.append(scores, d[4])

				if annotations.shape[0] == 0:
					false_positives = np.append(false_positives, 1)
					true_positives  = np.append(true_positives, 0)
					continue

				overlaps            = compute_overlap(np.expand_dims(d, axis=0), annotations)
				assigned_annotation = np.argmax(overlaps, axis=1)
				max_overlap         = overlaps[0, assigned_annotation]

				if max_overlap >= iou_threshold and assigned_annotation not in detected_annotations:
					false_positives = np.append(false_positives, 0)
					true_positives  = np.append(true_positives, 1)
					detected_annotations.append(assigned_annotation)
				else:
					false_positives = np.append(false_positives, 1)
					true_positives  = np.append(true_positives, 0)

		# no annotations -> AP for this class is 0 (is this correct?)
		if num_annotations == 0:
			average_precisions[label] = 0
			continue

		# sort by score
		indices         = np.argsort(-scores)
		false_positives = false_positives[indices]
		true_positives  = true_positives[indices]

		# compute false positives and true positives
		false_positives = np.cumsum(false_positives)
		true_positives  = np.cumsum(true_positives)

		# compute recall and precision
		recall    = true_positives / num_annotations
		precision = true_positives / np.maximum(true_positives + false_positives, np.finfo(np.float64).eps)

		# compute average precision
		average_precision  = compute_ap(recall, precision)  
		average_precisions[label] = average_precision

	return average_precisions

# %%
train_image_folder = 'VOCdevkit/VOC2007/JPEGImages/'
train_annot_folder = 'VOCdevkit/VOC2007/Annotations/'

# %%
IMAGE_H, IMAGE_W = 416, 416
GRID_H,  GRID_W  = 13 , 13
BOX              = 5
CLASS            = len(LABELS)
CLASS_WEIGHTS    = np.ones(CLASS, dtype='float32')
OBJ_THRESHOLD    = 0.3#0.5
NMS_THRESHOLD    = 0.3#0.45
#ANCHORS          = [0.57273, 0.677385, 1.87446, 2.06253, 3.33843, 5.47434, 7.88282, 3.52778, 9.77052, 9.16828]
ANCHORS          = [0.96,1.66, 2.45,3.90, 4.01,8.17, 7.75,5.12, 9.87,10.46]

NO_OBJECT_SCALE  = 1.0
OBJECT_SCALE     = 5.0
COORD_SCALE      = 1
CLASS_SCALE      = 1

BATCH_SIZE       = 16
WARM_UP_BATCHES  = 3
TRUE_BOX_BUFFER  = 50
generator_config = {
    'IMAGE_H'         : IMAGE_H, 
    'IMAGE_W'         : IMAGE_W,
    'GRID_H'          : GRID_H,  
    'GRID_W'          : GRID_W,
    'BOX'             : BOX,
    'LABELS'          : LABELS,
    'CLASS'           : len(LABELS),
    'ANCHORS'         : ANCHORS,
    'BATCH_SIZE'      : BATCH_SIZE,
    'TRUE_BOX_BUFFER' : 50,
}

# %%
train_imgs, seen_train_labels, val_imgs, seen_val_labels = parse_annotation(train_annot_folder, train_image_folder, labels=LABELS)
# Out:
# 4008 1003

# %%
import random
import numpy as np
import json

def IOU(ann, centroids):
    w, h = ann
    similarities = []

    for centroid in centroids:
        c_w, c_h = centroid

        if c_w >= w and c_h >= h:
            similarity = w*h/(c_w*c_h)
        elif c_w >= w and c_h <= h:
            similarity = w*c_h/(w*h + (c_w-w)*c_h)
        elif c_w <= w and c_h >= h:
            similarity = c_w*h/(w*h + c_w*(c_h-h))
        else: #means both w,h are bigger than c_w and c_h respectively
            similarity = (c_w*c_h)/(w*h)
        similarities.append(similarity) # will become (k,) shape

    return np.array(similarities)

def avg_IOU(anns, centroids):
    n,d = anns.shape
    sum = 0.

    for i in range(anns.shape[0]):
        sum+= max(IOU(anns[i], centroids))

    return sum/n

def print_anchors(centroids):
    anchors = centroids.copy()

    widths = anchors[:, 0]
    sorted_indices = np.argsort(widths)

    r = "anchors: ["
    for i in sorted_indices[:-1]:
        r += '%0.2f,%0.2f, ' % (anchors[i,0], anchors[i,1])

    #there should not be comma after last anchor, that's why
    r += '%0.2f,%0.2f' % (anchors[sorted_indices[-1:],0], anchors[sorted_indices[-1:],1])
    r += "]"

    print(r)

def run_kmeans(ann_dims, anchor_num):
    ann_num = ann_dims.shape[0]
    iterations = 0
    prev_assignments = np.ones(ann_num)*(-1)
    iteration = 0
    old_distances = np.zeros((ann_num, anchor_num))

    indices = [random.randrange(ann_dims.shape[0]) for i in range(anchor_num)]
    centroids = ann_dims[indices]
    anchor_dim = ann_dims.shape[1]

    while True:
        distances = []
        iteration += 1
        for i in range(ann_num):
            d = 1 - IOU(ann_dims[i], centroids)
            distances.append(d)
        distances = np.array(distances) # distances.shape = (ann_num, anchor_num)

        print("iteration {}: dists = {}".format(iteration, np.sum(np.abs(old_distances-distances))))

        #assign samples to centroids
        assignments = np.argmin(distances,axis=1)

        if (assignments == prev_assignments).all() :
            return centroids

        #calculate new centroids
        centroid_sums=np.zeros((anchor_num, anchor_dim), np.float)
        for i in range(ann_num):
            centroid_sums[assignments[i]]+=ann_dims[i]
        for j in range(anchor_num):
            centroids[j] = centroid_sums[j]/(np.sum(assignments==j) + 1e-6)

        prev_assignments = assignments.copy()
        old_distances = distances.copy()


num_anchors = 5 
grid_w = IMAGE_W/32
grid_h = IMAGE_H/32
annotation_dims = []
for image in train_imgs:
	cell_w = image['width']/grid_w
	cell_h = image['height']/grid_h

	for obj in image['object']:
		relative_w = (float(obj['xmax']) - float(obj['xmin']))/cell_w
		relatice_h = (float(obj["ymax"]) - float(obj['ymin']))/cell_h
		annotation_dims.append(tuple(map(float, (relative_w,relatice_h))))

annotation_dims = np.array(annotation_dims)
centroids = run_kmeans(annotation_dims, num_anchors)

# write anchors to file
print('\naverage IOU for', num_anchors, 'anchors:', '%0.2f' % avg_IOU(annotation_dims, centroids))
print_anchors(centroids)
# Out:
# iteration 1: dists = 51506.4003815373
# iteration 2: dists = 2806.6039222702234
# iteration 3: dists = 1063.1462957722372
# iteration 4: dists = 699.3495961222055
# iteration 5: dists = 443.0589516840853
# iteration 6: dists = 360.31139478325696
# iteration 7: dists = 305.23297312583657
# iteration 8: dists = 269.6443349687039
# iteration 9: dists = 265.58681328514314
# iteration 10: dists = 266.3314543239605
# iteration 11: dists = 247.14845768067948
# iteration 12: dists = 209.52474149731694
# iteration 13: dists = 221.76976010033798
# iteration 14: dists = 216.77367827824918
# iteration 15: dists = 189.47083002312337
# iteration 16: dists = 164.89884215659612
# iteration 17: dists = 146.40462687263792
# iteration 18: dists = 147.06667887455708
# iteration 19: dists = 104.38060142146811
# iteration 20: dists = 80.90008122318342
# iteration 21: dists = 65.90704143126744
# iteration 22: dists = 57.42972917220072
# iteration 23: dists = 43.708406608359255
# iteration 24: dists = 42.19003233109828
# iteration 25: dists = 24.145368814971775
# iteration 26: dists = 17.627366760074178
# iteration 27: dists = 18.7328201278129
# iteration 28: dists = 16.192971363528184
# iteration 29: dists = 10.407499161191252
# iteration 30: dists = 6.959492284933354
# iteration 31: dists = 2.7363162361449636
#
# average IOU for 5 anchors: 0.58
# anchors: [0.89,1.39, 2.22,3.67, 3.80,7.99, 7.28,4.90, 9.76,10.29]

# %%
#!wget https://docs.google.com/uc?export=download&id=1Q9WhhRlqQbA4jgBkCDrynvgquRXZA_f8
import requests

def download_file_from_google_drive(id, destination):
    def get_confirm_token(response):
        for key, value in response.cookies.items():
            if key.startswith('download_warning'):
                return value

        return None

    def save_response_content(response, destination):
        CHUNK_SIZE = 32768

        with open(destination, "wb") as f:
            for chunk in response.iter_content(CHUNK_SIZE):
                if chunk: # filter out keep-alive new chunks
                    f.write(chunk)

    URL = "https://docs.google.com/uc?export=download"

    session = requests.Session()

    response = session.get(URL, params = { 'id' : id }, stream = True)
    token = get_confirm_token(response)

    if token:
        params = { 'id' : id, 'confirm' : token }
        response = session.get(URL, params = params, stream = True)

    save_response_content(response, destination)    

download_file_from_google_drive("1Q9WhhRlqQbA4jgBkCDrynvgquRXZA_f8", "weights.h5")

# %%
train_batch = BatchGenerator(train_imgs, generator_config, norm=normalize)
valid_batch = BatchGenerator(val_imgs, generator_config, norm=normalize, jitter=False)

# %%
import sys
f = open("out.txt", "w")
def tf_print(op, tensors, message=None):
    def print_message(x):
        sys.stdout.write(message + " %s\n" % x)
        f.write(message + " %s\n" % x)
        return x

    prints = [tf.py_func(print_message, [tensor], tensor.dtype) for tensor in tensors]
    with tf.control_dependencies(prints):
        op = tf.identity(op)
    return op

def custom_loss(y_true, y_pred):
    mask_shape = tf.shape(y_true)[:4]
    
    cell_x = tf.to_float(tf.reshape(tf.tile(tf.range(GRID_W), [GRID_H]), (1, GRID_H, GRID_W, 1, 1)))
    cell_y = tf.transpose(cell_x, (0,2,1,3,4))

    cell_grid = tf.tile(tf.concat([cell_x,cell_y], -1), [BATCH_SIZE, 1, 1, 5, 1])
    
    coord_mask = tf.zeros(mask_shape)
    conf_mask  = tf.zeros(mask_shape)
    class_mask = tf.zeros(mask_shape)
    
    seen = tf.Variable(0.)
    total_recall = tf.Variable(0.)
    
    """
    Adjust prediction
    """
    ### adjust x and y      
    pred_box_xy = tf.sigmoid(y_pred[..., :2]) + cell_grid
    
    ### adjust w and h
    pred_box_wh = tf.exp(y_pred[..., 2:4]) * np.reshape(ANCHORS, [1,1,1,BOX,2])
    
    ### adjust confidence
    pred_box_conf = tf.sigmoid(y_pred[..., 4])
    
    ### adjust class probabilities
    pred_box_class = y_pred[..., 5:]
    
    """
    Adjust ground truth
    """
    ### adjust x and y
    true_box_xy = y_true[..., 0:2] # relative position to the containing cell
    
    ### adjust w and h
    true_box_wh = y_true[..., 2:4] # number of cells accross, horizontally and vertically
    
    ### adjust confidence
    true_wh_half = true_box_wh / 2.
    true_mins    = true_box_xy - true_wh_half
    true_maxes   = true_box_xy + true_wh_half
    
    pred_wh_half = pred_box_wh / 2.
    pred_mins    = pred_box_xy - pred_wh_half
    pred_maxes   = pred_box_xy + pred_wh_half       
    
    intersect_mins  = tf.maximum(pred_mins,  true_mins)
    intersect_maxes = tf.minimum(pred_maxes, true_maxes)
    intersect_wh    = tf.maximum(intersect_maxes - intersect_mins, 0.)
    intersect_areas = intersect_wh[..., 0] * intersect_wh[..., 1]
    
    true_areas = true_box_wh[..., 0] * true_box_wh[..., 1]
    pred_areas = pred_box_wh[..., 0] * pred_box_wh[..., 1]

    union_areas = pred_areas + true_areas - intersect_areas
    iou_scores  = tf.truediv(intersect_areas, union_areas)
    
    true_box_conf = iou_scores * y_true[..., 4]
    
    ### adjust class probabilities
    true_box_class = tf.argmax(y_true[..., 5:], -1)
    
    """
    Determine the masks
    """
    ### coordinate mask: simply the position of the ground truth boxes (the predictors)
    coord_mask = tf.expand_dims(y_true[..., 4], axis=-1) * COORD_SCALE
    
    ### confidence mask: penelize predictors + penalize boxes with low IOU
    # penalize the confidence of the boxes, which have IOU with some ground truth box < 0.6
    true_xy = true_boxes[..., 0:2]
    true_wh = true_boxes[..., 2:4]
    
    true_wh_half = true_wh / 2.
    true_mins    = true_xy - true_wh_half
    true_maxes   = true_xy + true_wh_half
    
    pred_xy = tf.expand_dims(pred_box_xy, 4)
    pred_wh = tf.expand_dims(pred_box_wh, 4)
    
    pred_wh_half = pred_wh / 2.
    pred_mins    = pred_xy - pred_wh_half
    pred_maxes   = pred_xy + pred_wh_half    
    
    intersect_mins  = tf.maximum(pred_mins,  true_mins)
    intersect_maxes = tf.minimum(pred_maxes, true_maxes)
    intersect_wh    = tf.maximum(intersect_maxes - intersect_mins, 0.)
    intersect_areas = intersect_wh[..., 0] * intersect_wh[..., 1]
    
    true_areas = true_wh[..., 0] * true_wh[..., 1]
    pred_areas = pred_wh[..., 0] * pred_wh[..., 1]

    union_areas = pred_areas + true_areas - intersect_areas
    iou_scores  = tf.truediv(intersect_areas, union_areas)

    best_ious = tf.reduce_max(iou_scores, axis=4)
    conf_mask = conf_mask + tf.to_float(best_ious < 0.6) * (1 - y_true[..., 4]) * NO_OBJECT_SCALE
    
    # penalize the confidence of the boxes, which are reponsible for corresponding ground truth box
    conf_mask = conf_mask + y_true[..., 4] * OBJECT_SCALE
    
    ### class mask: simply the position of the ground truth boxes (the predictors)
    class_mask = y_true[..., 4] * tf.gather(CLASS_WEIGHTS, true_box_class) * CLASS_SCALE       
    
    """
    Warm-up training
    """
    no_boxes_mask = tf.to_float(coord_mask < COORD_SCALE/2.)
    seen = tf.assign_add(seen, 1.)
    
    true_box_xy, true_box_wh, coord_mask = tf.cond(tf.less(seen, WARM_UP_BATCHES), 
                          lambda: [true_box_xy + (0.5 + cell_grid) * no_boxes_mask, 
                                   true_box_wh + tf.ones_like(true_box_wh) * np.reshape(ANCHORS, [1,1,1,BOX,2]) * no_boxes_mask, 
                                   tf.ones_like(coord_mask)],
                          lambda: [true_box_xy, 
                                   true_box_wh,
                                   coord_mask])
    
    """
    Finalize the loss
    """
    nb_coord_box = tf.reduce_sum(tf.to_float(coord_mask > 0.0))
    nb_conf_box  = tf.reduce_sum(tf.to_float(conf_mask  > 0.0))
    nb_class_box = tf.reduce_sum(tf.to_float(class_mask > 0.0))
    
    loss_xy    = tf.reduce_sum(tf.square(true_box_xy-pred_box_xy)     * coord_mask) / (nb_coord_box + 1e-6) / 2.
    loss_wh    = tf.reduce_sum(tf.square(true_box_wh-pred_box_wh)     * coord_mask) / (nb_coord_box + 1e-6) / 2.
    loss_conf  = tf.reduce_sum(tf.square(true_box_conf-pred_box_conf) * conf_mask)  / (nb_conf_box  + 1e-6) / 2.
    loss_class = tf.nn.sparse_softmax_cross_entropy_with_logits(labels=true_box_class, logits=pred_box_class)
    loss_class = tf.reduce_sum(loss_class * class_mask) / (nb_class_box + 1e-6)
    
    loss_xy = tf.clip_by_value(loss_xy, 0, 10000000)
    loss_wh = tf.clip_by_value(loss_wh, 0, 10000000)  
    loss_conf = tf.clip_by_value(loss_conf, 0, 10000000)
    loss_class = tf.clip_by_value(loss_class, 0, 10000000)
    loss = loss_xy + loss_wh + loss_conf + loss_class
    
    nb_true_box = tf.reduce_sum(y_true[..., 4])
    nb_pred_box = tf.reduce_sum(tf.to_float(true_box_conf > 0.5) * tf.to_float(pred_box_conf > 0.3))

    """
    Debugging code
    """    
    current_recall = nb_pred_box/(nb_true_box + 1e-6)
    total_recall = tf.assign_add(total_recall, current_recall) 

    loss = tf_print(loss, [tf.zeros((1))], message='Dummy Line \t')
    loss = tf_print(loss, [loss_xy], message='Loss XY \t')
    loss = tf_print(loss, [loss_wh], message='Loss WH \t')
    loss = tf_print(loss, [loss_conf], message='Loss Conf \t')
    loss = tf_print(loss, [loss_class], message='Loss Class \t')
    loss = tf_print(loss, [loss], message='Total Loss \t')
    loss = tf_print(loss, [current_recall], message='Current Recall \t')
    loss = tf_print(loss, [total_recall/seen], message='Average Recall \t')
    
    return loss

# %%
from keras.callbacks import EarlyStopping, ModelCheckpoint, TensorBoard
early_stop = EarlyStopping(monitor='val_loss', 
                           min_delta=0.001, 
                           patience=3, 
                           mode='min', 
                           verbose=1)

checkpoint = ModelCheckpoint('weights_coco.h5', 
                             monitor='val_loss', 
                             verbose=1, 
                             save_best_only=True, 
                             mode='min', 
                             period=1)

# %%
from keras.models import Sequential, Model
from keras.layers.advanced_activations import LeakyReLU
from keras.layers.merge import concatenate
from keras.layers import Reshape, Activation, Conv2D, Input, MaxPooling2D, BatchNormalization, Flatten, Dense, Lambda
def space_to_depth_x2(x):
    return tf.space_to_depth(x, block_size=2)
input_image = Input(shape=(IMAGE_H, IMAGE_W, 3))
true_boxes  = Input(shape=(1, 1, 1, TRUE_BOX_BUFFER , 4))

# Layer 1
x = Conv2D(32, (3,3), strides=(1,1), padding='same', name='conv_1', use_bias=False)(input_image)
x = BatchNormalization(name='norm_1')(x)
x = LeakyReLU(alpha=0.1)(x)
x = MaxPooling2D(pool_size=(2, 2))(x)

# Layer 2
x = Conv2D(64, (3,3), strides=(1,1), padding='same', name='conv_2', use_bias=False)(x)
x = BatchNormalization(name='norm_2')(x)
x = LeakyReLU(alpha=0.1)(x)
x = MaxPooling2D(pool_size=(2, 2))(x)

# Layer 3
x = Conv2D(128, (3,3), strides=(1,1), padding='same', name='conv_3', use_bias=False)(x)
x = BatchNormalization(name='norm_3')(x)
x = LeakyReLU(alpha=0.1)(x)

# Layer 4
x = Conv2D(64, (1,1), strides=(1,1), padding='same', name='conv_4', use_bias=False)(x)
x = BatchNormalization(name='norm_4')(x)
x = LeakyReLU(alpha=0.1)(x)

# Layer 5
x = Conv2D(128, (3,3), strides=(1,1), padding='same', name='conv_5', use_bias=False)(x)
x = BatchNormalization(name='norm_5')(x)
x = LeakyReLU(alpha=0.1)(x)
x = MaxPooling2D(pool_size=(2, 2))(x)

# Layer 6
x = Conv2D(256, (3,3), strides=(1,1), padding='same', name='conv_6', use_bias=False)(x)
x = BatchNormalization(name='norm_6')(x)
x = LeakyReLU(alpha=0.1)(x)

# Layer 7
x = Conv2D(128, (1,1), strides=(1,1), padding='same', name='conv_7', use_bias=False)(x)
x = BatchNormalization(name='norm_7')(x)
x = LeakyReLU(alpha=0.1)(x)

# Layer 8
x = Conv2D(256, (3,3), strides=(1,1), padding='same', name='conv_8', use_bias=False)(x)
x = BatchNormalization(name='norm_8')(x)
x = LeakyReLU(alpha=0.1)(x)
x = MaxPooling2D(pool_size=(2, 2))(x)

# Layer 9
x = Conv2D(512, (3,3), strides=(1,1), padding='same', name='conv_9', use_bias=False)(x)
x = BatchNormalization(name='norm_9')(x)
x = LeakyReLU(alpha=0.1)(x)

# Layer 10
x = Conv2D(256, (1,1), strides=(1,1), padding='same', name='conv_10', use_bias=False)(x)
x = BatchNormalization(name='norm_10')(x)
x = LeakyReLU(alpha=0.1)(x)

# Layer 11
x = Conv2D(512, (3,3), strides=(1,1), padding='same', name='conv_11', use_bias=False)(x)
x = BatchNormalization(name='norm_11')(x)
x = LeakyReLU(alpha=0.1)(x)

# Layer 12
x = Conv2D(256, (1,1), strides=(1,1), padding='same', name='conv_12', use_bias=False)(x)
x = BatchNormalization(name='norm_12')(x)
x = LeakyReLU(alpha=0.1)(x)

# Layer 13
x = Conv2D(512, (3,3), strides=(1,1), padding='same', name='conv_13', use_bias=False)(x)
x = BatchNormalization(name='norm_13')(x)
x = LeakyReLU(alpha=0.1)(x)

skip_connection = x

x = MaxPooling2D(pool_size=(2, 2))(x)

# Layer 14
x = Conv2D(1024, (3,3), strides=(1,1), padding='same', name='conv_14', use_bias=False)(x)
x = BatchNormalization(name='norm_14')(x)
x = LeakyReLU(alpha=0.1)(x)

# Layer 15
x = Conv2D(512, (1,1), strides=(1,1), padding='same', name='conv_15', use_bias=False)(x)
x = BatchNormalization(name='norm_15')(x)
x = LeakyReLU(alpha=0.1)(x)

# Layer 16
x = Conv2D(1024, (3,3), strides=(1,1), padding='same', name='conv_16', use_bias=False)(x)
x = BatchNormalization(name='norm_16')(x)
x = LeakyReLU(alpha=0.1)(x)

# Layer 17
x = Conv2D(512, (1,1), strides=(1,1), padding='same', name='conv_17', use_bias=False)(x)
x = BatchNormalization(name='norm_17')(x)
x = LeakyReLU(alpha=0.1)(x)

# Layer 18
x = Conv2D(1024, (3,3), strides=(1,1), padding='same', name='conv_18', use_bias=False)(x)
x = BatchNormalization(name='norm_18')(x)
x = LeakyReLU(alpha=0.1)(x)

# Layer 19
x = Conv2D(1024, (3,3), strides=(1,1), padding='same', name='conv_19', use_bias=False)(x)
x = BatchNormalization(name='norm_19')(x)
x = LeakyReLU(alpha=0.1)(x)

# Layer 20
x = Conv2D(1024, (3,3), strides=(1,1), padding='same', name='conv_20', use_bias=False)(x)
x = BatchNormalization(name='norm_20')(x)
x = LeakyReLU(alpha=0.1)(x)

# Layer 21
skip_connection = Conv2D(64, (1,1), strides=(1,1), padding='same', name='conv_21', use_bias=False)(skip_connection)
skip_connection = BatchNormalization(name='norm_21')(skip_connection)
skip_connection = LeakyReLU(alpha=0.1)(skip_connection)
skip_connection = Lambda(space_to_depth_x2)(skip_connection)

x = concatenate([skip_connection, x])

# Layer 22
x = Conv2D(1024, (3,3), strides=(1,1), padding='same', name='conv_22', use_bias=False)(x)
x = BatchNormalization(name='norm_22')(x)
x = LeakyReLU(alpha=0.1)(x)
model = Model(input_image, x)  
feature_extractor = Model(model.layers[0].input, model.layers[-1].output)
feature_extractor.load_weights("weights.h5")
for layer in feature_extractor.layers:
    layer.trainable = False
# Layer 23
x = Conv2D(BOX * (4 + 1 + CLASS), (1,1), strides=(1,1), padding='same', name='conv_23')(feature_extractor.layers[-1].output)
output = Reshape((GRID_H, GRID_W, BOX, 4 + 1 + CLASS))(x)

# small hack to allow true_boxes to be registered when Keras build the model 
# for more information: https://github.com/fchollet/keras/issues/2790
output = Lambda(lambda args: args[0])([output, true_boxes])

model = Model([input_image, true_boxes], output)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
from keras.optimizers import SGD, Adam, RMSprop
optimizer = Adam(lr=0.5e-4, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
#optimizer = SGD(lr=1e-4, decay=0.0005, momentum=0.9)
#optimizer = RMSprop(lr=1e-4, rho=0.9, epsilon=1e-08, decay=0.0)
tb_counter  = len([log for log in os.listdir(os.path.expanduser('~/logs/')) if 'coco_' in log]) + 1
tensorboard = TensorBoard(log_dir=os.path.expanduser('~/logs/') + 'coco_' + '_' + str(tb_counter), 
                          histogram_freq=0, 
                          write_graph=True, 
                          write_images=False)
model.compile(loss=custom_loss, optimizer=optimizer)

model.fit_generator(generator        = train_batch, 
                    steps_per_epoch  = len(train_batch), 
                    epochs           = 3, 
                    verbose          = 1,
                    validation_data  = valid_batch,
                    validation_steps = len(valid_batch),
                    callbacks        = [checkpoint], 
                    max_queue_size   = 3)
model.save_weights("warmup.h5")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !cp warmup.h5 drive/'My Drive'/

# %%
model.load_weights("warmup.h5")
model.compile(loss=custom_loss, optimizer=optimizer)

model.fit_generator(initial_epoch    = 3,
                    generator        = train_batch, 
                    steps_per_epoch  = len(train_batch), 
                    epochs           = 25, 
                    verbose          = 1,
                    validation_data  = valid_batch,
                    validation_steps = len(valid_batch),
                    callbacks        = [checkpoint], 
                    max_queue_size   = 3)
model.save_weights("weights_25.h5")

# %%
model.load_weights("weights_25.h5")
model.fit_generator(initial_epoch    = 25,
                    generator        = train_batch, 
                    steps_per_epoch  = len(train_batch), 
                    epochs           = 50, 
                    verbose          = 1,
                    validation_data  = valid_batch,
                    validation_steps = len(valid_batch),
                    callbacks        = [checkpoint], 
                    max_queue_size   = 3)
model.save_weights("weights_50.h5")
# Out:
# Dummy Line 	 [0.]
# Loss WH 	 2.574946
# Loss XY 	 0.07170368
# Current Recall 	 0.10169491
# Average Recall 	 0.07610217
# Loss Conf 	 0.002788683
# Loss Class 	 0.6269831
# Total Loss 	 3.2764215
#   7/251 [..............................] - ETA: 1:00 - loss: 3.1499Dummy Line 	 [0.]
# Loss WH 	 2.4956837
# Loss XY 	 0.06837056
# Current Recall 	 0.11764706
# Average Recall 	 0.07610817
# Loss Conf 	 0.0019915933
# Loss Class 	 0.35832915
# Total Loss 	 2.9243748
#   8/251 [..............................] - ETA: 1:04 - loss: 3.1217Dummy Line 	 [0.]
# Loss WH 	 3.0534954
# Loss XY 	 0.06545298
# Current Recall 	 0.13084112
# Average Recall 	 0.07611609
# Loss Conf 	 0.0030537683
# Loss Class 	 0.5257122
# Total Loss 	 3.6477144
#   9/251 [>.............................] - ETA: 1:06 - loss: 3.1801Dummy Line 	 [0.]
# Loss WH 	 2.3841245
# Loss XY 	 0.05182393
# Loss Conf 	 0.00299885
# Average Recall 	 0.076121144
# Current Recall 	 0.11111111
# Loss Class 	 0.43872404
# Total Loss 	 2.8776712
#  10/251 [>.............................] - ETA: 1:08 - loss: 3.1499Dummy Line 	 [0.]
# Loss WH 	 5.3596897
# Loss XY 	 0.03876074
# Current Recall 	 0.12820514
# Average Recall 	 0.07612868
# Loss Conf 	 0.00193086
# Loss Class 	 0.42762697
# Total Loss 	 5.828008
#  11/251 [>.............................] - ETA: 1:10 - loss: 3.3933Dummy Line 	 [0.]
# Loss XY 	 0.036819313
# Loss WH 	 2.0140262
# Current Recall 	 0.08510638
# Loss Conf 	 0.0019177404
# Average Recall 	 0.076129965
# Loss Class 	 0.32861853
# Total Loss 	 2.3813818
#  12/251 [>.............................] - ETA: 1:13 - loss: 3.3090Dummy Line 	 [0.]
# Loss WH 	 1.6067779
# Loss XY 	 0.040498357
# Current Recall 	 0.18055555
# Average Recall 	 0.07614505
# Loss Conf 	 0.0026101896
# Loss Class 	 0.37857613
# Total Loss 	 2.0284626
#  13/251 [>.............................] - ETA: 1:14 - loss: 3.2105Dummy Line 	 [0.]
# Loss WH 	 2.9827514
# Loss XY 	 0.059319053
# Current Recall 	 0.12244898
# Average Recall 	 0.076151736
# Loss Conf 	 0.0019674546
# Loss Class 	 0.5456621
# Total Loss 	 3.5897
#  14/251 [>.............................] - ETA: 1:15 - loss: 3.2376Dummy Line 	 [0.]
# Loss WH 	 2.1246192
# Loss XY 	 0.052335996
# Current Recall 	 0.2777778
# Loss Conf 	 0.0022061418
# Average Recall 	 0.07618086
# Loss Class 	 0.61499333
# Total Loss 	 2.7941546
#  15/251 [>.............................] - ETA: 1:16 - loss: 3.2080Dummy Line 	 [0.]
# Loss WH 	 2.5486944
# Loss XY 	 0.046256248
# Current Recall 	 0.17460318
# Average Recall 	 0.076195076
# Loss Conf 	 0.0023393687
# Loss Class 	 0.4264778
# Total Loss 	 3.023768
#  16/251 [>.............................] - ETA: 1:17 - loss: 3.1965Dummy Line 	 [0.]
# Loss WH 	 4.0037794
# Loss XY 	 0.0452837
# Average Recall 	 0.07620999
# Loss Conf 	 0.0014051298
# Current Recall 	 0.17948718
# Loss Class 	 0.6725675
# Total Loss 	 4.723036
#  17/251 [=>............................] - ETA: 1:19 - loss: 3.2863Dummy Line 	 [0.]
# Current Recall 	 0.0952381
# Loss Conf 	 0.002015784
# Average Recall 	 0.076212734
# Loss XY 	 0.047171313
# Loss WH 	 2.992735
# Loss Class 	 0.49796757
# Total Loss 	 3.5398896
#  18/251 [=>............................] - ETA: 1:19 - loss: 3.3004Dummy Line 	 [0.]
# Loss XY 	 0.053703744
# Current Recall 	 0.13725491
# Loss WH 	 3.785675
# Average Recall 	 0.07622155
# Loss Conf 	 0.0021590453
# Loss Class 	 0.6574293
# Total Loss 	 4.498967
#  19/251 [=>............................] - ETA: 1:19 - loss: 3.3635Dummy Line 	 [0.]
# Loss WH 	 4.3282785
# Loss XY 	 0.041581362
# Current Recall 	 0.14285715
# Average Recall 	 0.07623117
# Loss Conf 	 0.0015481046
# Loss Class 	 0.5331076
# Total Loss 	 4.9045157
#  20/251 [=>............................] - ETA: 1:20 - loss: 3.4405Dummy Line 	 [0.]
# Loss XY 	 0.04618907
# Loss WH 	 3.267415
# Average Recall 	 0.076245144
# Loss Conf 	 0.0024318872
# Current Recall 	 0.17307693
# Loss Class 	 1.2712115
# Total Loss 	 4.5872474
#  21/251 [=>............................] - ETA: 1:20 - loss: 3.4951Dummy Line 	 [0.]
# Loss XY 	 0.051009506
# Loss WH 	 3.862028
# Current Recall 	 0.24
# Average Recall 	 0.07626877
# Loss Conf 	 0.0019361092
# Loss Class 	 0.5181
# Total Loss 	 4.4330735
#  22/251 [=>............................] - ETA: 1:20 - loss: 3.5378Dummy Line 	 [0.]
# Loss WH 	 2.9983342
# Loss XY 	 0.06744478
# Total Loss 	 3.5692139
# Loss Class 	 0.50206155
# Current Recall 	 0.35
# Average Recall 	 0.07630825
# Loss Conf 	 0.0013731908
#  23/251 [=>............................] - ETA: 1:21 - loss: 3.5391Dummy Line 	 [0.]
# Loss XY 	 0.058664
# Average Recall 	 0.07632032
# Loss Conf 	 0.0016606504
# Current Recall 	 0.16
# Loss WH 	 2.7730415
# Loss Class 	 0.6131395
# Total Loss 	 3.4465055
#  24/251 [=>............................] - ETA: 1:23 - loss: 3.5353Dummy Line 	 [0.]
# Loss WH 	 2.707952
# Loss XY 	 0.044840496
# Current Recall 	 0.21538462
# Average Recall 	 0.07634038
# Loss Conf 	 0.002309677
# Loss Class 	 0.3767539
# Total Loss 	 3.131856
#  25/251 [=>............................] - ETA: 1:24 - loss: 3.5191Dummy Line 	 [0.]
# Loss WH 	 1.9283903
# Loss XY 	 0.06236101
# Current Recall 	 0.125
# Average Recall 	 0.076347396
# Loss Conf 	 0.002925891
# Loss Class 	 0.6457523
# Total Loss 	 2.6394296
#  26/251 [==>...........................] - ETA: 1:25 - loss: 3.4853Dummy Line 	 [0.]
# Loss WH 	 2.6714814
# Current Recall 	 0.22
# Average Recall 	 0.0763681
# Loss Conf 	 0.0019309833
# Loss XY 	 0.041900177
# Loss Class 	 0.37119755
# Total Loss 	 3.08651
#  27/251 [==>...........................] - ETA: 1:24 - loss: 3.4705Dummy Line 	 [0.]
# Loss WH 	 2.4436982
# Loss XY 	 0.053165797
# Current Recall 	 0.18604651
# Average Recall 	 0.07638391
# Loss Conf 	 0.0020852468
# Loss Class 	 0.32013735
# Total Loss 	 2.8190866
#  28/251 [==>...........................] - ETA: 1:24 - loss: 3.4473Dummy Line 	 [0.]
# Loss WH 	 3.4653835
# Loss XY 	 0.053142276
# Current Recall 	 0.12962963
# Average Recall 	 0.076391585
# Loss Conf 	 0.002039603
# Loss Class 	 0.5832217
# Total Loss 	 4.1037874
#  29/251 [==>...........................] - ETA: 1:24 - loss: 3.4699Dummy Line 	 [0.]
# Loss WH 	 3.476576
# Loss XY 	 0.054027442
# Current Recall 	 0.30232558
# Average Recall 	 0.076424144
# Loss Conf 	 0.001916436
# Loss Class 	 0.38040262
# Total Loss 	 3.9129226
#  30/251 [==>...........................] - ETA: 1:24 - loss: 3.4847Dummy Line 	 [0.]
# Loss WH 	 2.4188857
# Loss XY 	 0.05710847
# Current Recall 	 0.13235295
# Average Recall 	 0.0764322
# Loss Conf 	 0.0029702496
# Loss Class 	 0.5448476
# Total Loss 	 3.0238118
#  31/251 [==>...........................] - ETA: 1:24 - loss: 3.4698Dummy Line 	 [0.]
# Loss WH 	 3.4911542
# Loss XY 	 0.04754431
# Current Recall 	 0.19565217
# Average Recall 	 0.07644938
# Loss Conf 	 0.00177391
# Loss Class 	 0.41858193
# Total Loss 	 3.9590542
#  32/251 [==>...........................] - ETA: 1:25 - loss: 3.4851Dummy Line 	 [0.]
# Loss WH 	 2.7698066
# Loss XY 	 0.04559713
# Current Recall 	 0.17021276
# Average Recall 	 0.07646289
# Loss Conf 	 0.0018481426
# Loss Class 	 0.43506354
# Total Loss 	 3.2523155
#  33/251 [==>...........................] - ETA: 1:24 - loss: 3.4780Dummy Line 	 [0.]
# Loss WH 	 4.862166
# Loss XY 	 0.051914457
# Current Recall 	 0.25490198
# Loss Conf 	 0.0019344453
# Average Recall 	 0.076488584
# Loss Class 	 0.41613838
# Total Loss 	 5.3321533
#  34/251 [===>..........................] - ETA: 1:24 - loss: 3.5326Dummy Line 	 [0.]
# Loss WH 	 2.0697665
# Loss XY 	 0.052433454
# Current Recall 	 0.08450704
# Average Recall 	 0.07648975
# Loss Conf 	 0.0028777702
# Loss Class 	 1.0904144
# Total Loss 	 3.2154922
#  35/251 [===>..........................] - ETA: 1:24 - loss: 3.5235Dummy Line 	 [0.]
# Loss WH 	 3.3907802
# Loss XY 	 0.04071423
# Current Recall 	 0.15555556
# Average Recall 	 0.07650113
# Loss Conf 	 0.0018994686
# Loss Class 	 0.6226169
# Total Loss 	 4.0560107
#  36/251 [===>..........................] - ETA: 1:24 - loss: 3.5383Dummy Line 	 [0.]
# Loss WH 	 3.121059
# Loss XY 	 0.03419014
# Current Recall 	 0.2
# Average Recall 	 0.076518916
# Loss Conf 	 0.0016214229
# Loss Class 	 0.59415567
# Total Loss 	 3.7510262
#  37/251 [===>..........................] - ETA: 1:24 - loss: 3.5441Dummy Line 	 [0.]
# Average Recall 	 0.07653005
# Loss WH 	 4.9929857
# Loss XY 	 0.048325576
# Current Recall 	 0.15384616
# Loss Conf 	 0.001863224
# Loss Class 	 0.54387873
# Total Loss 	 5.587053
#  38/251 [===>..........................] - ETA: 1:24 - loss: 3.5978Dummy Line 	 [0.]
# Loss WH 	 4.089455
# Loss XY 	 0.04945097
# Current Recall 	 0.20454545
# Average Recall 	 0.07654847
# Loss Conf 	 0.0016831999
# Loss Class 	 0.38261786
# Total Loss 	 4.523207
#  39/251 [===>..........................] - ETA: 1:24 - loss: 3.6215Dummy Line 	 [0.]
# Loss WH 	 3.1213589
# Loss XY 	 0.060626734
# Current Recall 	 0.2
# Average Recall 	 0.076566234
# Loss Conf 	 0.0023675072
# Loss Class 	 0.5245295
# Total Loss 	 3.7088826
#  40/251 [===>..........................] - ETA: 1:24 - loss: 3.6237Dummy Line 	 [0.]
# Loss WH 	 2.3288722
# Loss XY 	 0.033405103
# Current Recall 	 0.20512821
# Average Recall 	 0.076584734
# Loss Conf 	 0.00177859
# Loss Class 	 0.32994875
# Total Loss 	 2.6940045
#  41/251 [===>..........................] - ETA: 1:24 - loss: 3.6011Dummy Line 	 [0.]
# Current Recall 	 0.25641027
# Loss Conf 	 0.001559238
# Loss WH 	 7.00082
# Average Recall 	 0.07661061
# Loss XY 	 0.05257969
# Loss Class 	 0.36609566
# Total Loss 	 7.421055
#  42/251 [====>.........................] - ETA: 1:24 - loss: 3.6920Dummy Line 	 [0.]
# Loss WH 	 2.9562898
# Loss XY 	 0.06261657
# Current Recall 	 0.16666667
# Average Recall 	 0.07662357
# Loss Conf 	 0.0027122747
# Loss Class 	 0.78808266
# Total Loss 	 3.8097012
#  43/251 [====>.........................] - ETA: 1:25 - loss: 3.6947Dummy Line 	 [0.]
# Loss WH 	 3.071192
# Loss XY 	 0.038920373
# Current Recall 	 0.26229507
# Average Recall 	 0.07665026
# Loss Conf 	 0.002526946
# Loss Class 	 0.32115066
# Total Loss 	 3.4337902
#  44/251 [====>.........................] - ETA: 1:25 - loss: 3.6888Dummy Line 	 [0.]
# Loss WH 	 3.256431
# Loss XY 	 0.05391445
# Current Recall 	 0.2580645
# Loss Conf 	 0.0025443446
# Average Recall 	 0.07667635
# Loss Class 	 0.41786113
# Total Loss 	 3.7307513
#  45/251 [====>.........................] - ETA: 1:25 - loss: 3.6897Dummy Line 	 [0.]
# Loss WH 	 1.6933367
# Loss XY 	 0.051397044
# Current Recall 	 0.23214285
# Average Recall 	 0.0766987
# Loss Conf 	 0.0022208025
# Loss Class 	 0.59542465
# Total Loss 	 2.342379
#  46/251 [====>.........................] - ETA: 1:24 - loss: 3.6605Dummy Line 	 [0.]
# Loss WH 	 3.89887
# Loss XY 	 0.047848634
# Current Recall 	 0.08
# Average Recall 	 0.076699175
# Loss Conf 	 0.0020307165
# Loss Class 	 0.42833918
# Total Loss 	 4.3770885
#  47/251 [====>.........................] - ETA: 1:24 - loss: 3.6757Dummy Line 	 [0.]
# Loss WH 	 2.9013228
# Current Recall 	 0.09090909
# Average Recall 	 0.07670122
# Loss XY 	 0.055603467
# Loss Conf 	 0.003180076
# Loss Class 	 0.4502548
# Total Loss 	 3.4103613
#  48/251 [====>.........................] - ETA: 1:24 - loss: 3.6702Dummy Line 	 [0.]
# Loss XY 	 0.051548857
# Loss WH 	 3.0977843
# Current Recall 	 0.16923077
# Loss Conf 	 0.0024214038
# Average Recall 	 0.076714516
# Loss Class 	 0.52548385
# Total Loss 	 3.6772385
#  49/251 [====>.........................] - ETA: 1:23 - loss: 3.6703Dummy Line 	 [0.]
# Loss WH 	 3.5163097
# Loss XY 	 0.047639724
# Current Recall 	 0.14634146
# Average Recall 	 0.07672452
# Loss Conf 	 0.0016918523
# Loss Class 	 0.68686026
# Total Loss 	 4.2525015
#  50/251 [====>.........................] - ETA: 1:23 - loss: 3.6820Dummy Line 	 [0.]
# Loss WH 	 5.572938
# Loss XY 	 0.044573296
# Current Recall 	 0.18421052
# Average Recall 	 0.07673997
# Loss Conf 	 0.0018910863
# Loss Class 	 0.27251074
# Total Loss 	 5.891913
#  51/251 [=====>........................] - ETA: 1:22 - loss: 3.7253Dummy Line 	 [0.]
# Loss WH 	 3.877118
# Loss XY 	 0.042647798
# Loss Conf 	 0.0015300927
# Current Recall 	 0.099999994
# Average Recall 	 0.076743305
# Loss Class 	 0.24305071
# Total Loss 	 4.1643467
#  52/251 [=====>........................] - ETA: 1:21 - loss: 3.7337Dummy Line 	 [0.]
# Loss WH 	 2.770688
# Loss XY 	 0.051370014
# Current Recall 	 0.16
# Average Recall 	 0.07675526
# Loss Conf 	 0.002083384
# Loss Class 	 0.5674408
# Total Loss 	 3.391582
#  53/251 [=====>........................] - ETA: 1:21 - loss: 3.7273Dummy Line 	 [0.]
# Loss WH 	 4.8042984
# Loss XY 	 0.05351864
# Current Recall 	 0.21568628
# Average Recall 	 0.076775216
# Loss Conf 	 0.0018234426
# Loss Class 	 0.7067734
# Total Loss 	 5.566414
#  54/251 [=====>........................] - ETA: 1:21 - loss: 3.7613Dummy Line 	 [0.]
# Loss WH 	 3.4388587
# Loss XY 	 0.05339823
# Average Recall 	 0.07678261
# Current Recall 	 0.12820514
# Loss Conf 	 0.0019493754
# Loss Class 	 0.75384915
# Total Loss 	 4.2480555
#  55/251 [=====>........................] - ETA: 1:21 - loss: 3.7702Dummy Line 	 [0.]
# Loss XY 	 0.05680556
# Current Recall 	 0.18181819
# Loss Class 	 0.5485555
# Loss Conf 	 0.0026688213
# Average Recall 	 0.07679769
# Loss WH 	 2.8628426
# Total Loss 	 3.4708724
#  56/251 [=====>........................] - ETA: 1:21 - loss: 3.7648Dummy Line 	 [0.]
# Loss WH 	 2.2169428
# Loss XY 	 0.042325992
# Current Recall 	 0.09615385
# Average Recall 	 0.07680046
# Loss Conf 	 0.0021347583
# Loss Class 	 0.4461838
# Total Loss 	 2.7075872
#  57/251 [=====>........................] - ETA: 1:21 - loss: 3.7463Dummy Line 	 [0.]
# Loss WH 	 5.4823003
# Current Recall 	 0.22580644
# Average Recall 	 0.07682185
# Loss Conf 	 0.0018457697
# Loss Class 	 0.71473897
# Total Loss 	 6.2549605
# Loss XY 	 0.05607536
#  58/251 [=====>........................] - ETA: 1:21 - loss: 3.7895Dummy Line 	 [0.]
# Loss WH 	 2.146748
# Loss XY 	 0.06124891
# Average Recall 	 0.07684619
# Current Recall 	 0.24637681
# Loss Conf 	 0.0019430313
# Loss Class 	 0.47658107
# Total Loss 	 2.6865213
#  59/251 [======>.......................] - ETA: 1:21 - loss: 3.7709Dummy Line 	 [0.]
# Loss WH 	 3.0213428
# Loss XY 	 0.0568266
# Current Recall 	 0.10169491
# Average Recall 	 0.07684975
# Loss Conf 	 0.0024420992
# Loss Class 	 0.6779917
# Total Loss 	 3.758603
#  60/251 [======>.......................] - ETA: 1:21 - loss: 3.7706Dummy Line 	 [0.]
# Loss WH 	 3.1644533
# Loss XY 	 0.054354608
# Average Recall 	 0.07685923
# Current Recall 	 0.14285715
# Loss Conf 	 0.0018707986
# Loss Class 	 0.6496795
# Total Loss 	 3.8703582
#  61/251 [======>.......................] - ETA: 1:20 - loss: 3.7723Dummy Line 	 [0.]
# Loss WH 	 3.083032
# Loss XY 	 0.043254714
# Current Recall 	 0.23809524
# Average Recall 	 0.076882355
# Loss Conf 	 0.0015478575
# Loss Class 	 0.5428279
# Total Loss 	 3.6706622
#  62/251 [======>.......................] - ETA: 1:20 - loss: 3.7706Dummy Line 	 [0.]
# Loss WH 	 3.3630478
# Loss XY 	 0.0557467
# Current Recall 	 0.23684211
# Average Recall 	 0.076905295
# Loss Conf 	 0.0015109393
# Loss Class 	 0.38356456
# Total Loss 	 3.80387
#  63/251 [======>.......................] - ETA: 1:19 - loss: 3.7712Dummy Line 	 [0.]
# Loss WH 	 2.0088308
# Loss XY 	 0.06331093
# Current Recall 	 0.036585364
# Average Recall 	 0.076899506
# Loss Conf 	 0.0031922788
# Loss Class 	 0.403156
# Total Loss 	 2.4784899
#  64/251 [======>.......................] - ETA: 1:19 - loss: 3.7510Dummy Line 	 [0.]
# Loss XY 	 0.06510235
# Loss WH 	 4.7811594
# Average Recall 	 0.0769001
# Loss Class 	 0.48322544
# Loss Conf 	 0.0015435225
# Current Recall 	 0.08108108
# Total Loss 	 5.331031
#  65/251 [======>.......................] - ETA: 1:19 - loss: 3.7753Dummy Line 	 [0.]
# Loss WH 	 5.1979084
# Loss XY 	 0.044635516
# Current Recall 	 0.17073171
# Loss Conf 	 0.0016563152
# Average Recall 	 0.07691356
# Loss Class 	 0.26781747
# Total Loss 	 5.5120177
#  66/251 [======>.......................] - ETA: 1:18 - loss: 3.8016Dummy Line 	 [0.]
# Loss WH 	 1.2723471
# Loss XY 	 0.04280014
# Current Recall 	 0.15584415
# Average Recall 	 0.07692487
# Loss Conf 	 0.0028409432
# Loss Class 	 0.5105076
# Total Loss 	 1.8284959
#  67/251 [=======>......................] - ETA: 1:18 - loss: 3.7721Dummy Line 	 [0.]
# Loss WH 	 1.7371575
# Loss XY 	 0.049965315
# Current Recall 	 0.20634921
# Average Recall 	 0.07694342
# Loss Conf 	 0.00233478
# Loss Class 	 0.39380354
# Total Loss 	 2.1832612
#  68/251 [=======>......................] - ETA: 1:17 - loss: 3.7488Dummy Line 	 [0.]
# Loss WH 	 3.5632803
# Loss XY 	 0.059760366
# Current Recall 	 0.13725491
# Average Recall 	 0.07695206
# Loss Conf 	 0.0022120748
# Loss Class 	 0.3416938
# Total Loss 	 3.9669466
#  69/251 [=======>......................] - ETA: 1:17 - loss: 3.7519Dummy Line 	 [0.]
# Loss WH 	 3.2654176
# Loss XY 	 0.054790672
# Average Recall 	 0.0769604
# Loss Conf 	 0.0017876887
# Current Recall 	 0.13513513
# Loss Class 	 0.43837902
# Total Loss 	 3.760375
#  70/251 [=======>......................] - ETA: 1:17 - loss: 3.7521Dummy Line 	 [0.]
# Loss WH 	 2.4087021
# Loss XY 	 0.056739148
# Loss Conf 	 0.0025105479
# Average Recall 	 0.076967
# Loss Class 	 0.71465456
# Current Recall 	 0.12307692
# Total Loss 	 3.1826062
#  71/251 [=======>......................] - ETA: 1:16 - loss: 3.7440Dummy Line 	 [0.]
# Loss XY 	 0.036188375
# Loss Conf 	 0.002196086
# Average Recall 	 0.077000596
# Current Recall 	 0.3114754
# Loss WH 	 2.5308604
# Loss Class 	 0.3395063
# Total Loss 	 2.9087512
#  72/251 [=======>......................] - ETA: 1:16 - loss: 3.7324Dummy Line 	 [0.]
# Loss WH 	 4.380799
# Loss XY 	 0.06419
# Current Recall 	 0.12962963
# Loss Conf 	 0.0015891037
# Average Recall 	 0.07700813
# Loss Class 	 1.2699752
# Total Loss 	 5.716553
#  73/251 [=======>......................] - ETA: 1:16 - loss: 3.7596Dummy Line 	 [0.]
# Loss XY 	 0.047048856
# Loss WH 	 2.739424
# Average Recall 	 0.077033736
# Loss Conf 	 0.0019403106
# Loss Class 	 0.55434585
# Current Recall 	 0.25581396
# Total Loss 	 3.342759
#  74/251 [=======>......................] - ETA: 1:16 - loss: 3.7540Dummy Line 	 [0.]
# Loss WH 	 2.3416147
# Loss XY 	 0.046216477
# Current Recall 	 0.1632653
# Average Recall 	 0.07704608
# Loss Conf 	 0.0016346531
# Loss Class 	 0.6166918
# Total Loss 	 3.0061576
#  75/251 [=======>......................] - ETA: 1:16 - loss: 3.7440Dummy Line 	 [0.]
# Loss WH 	 3.4012506
# Loss XY 	 0.05324129
# Current Recall 	 0.12
# Average Recall 	 0.07705223
# Loss Conf 	 0.0023150933
# Loss Class 	 0.6409587
# Total Loss 	 4.0977654
#  76/251 [========>.....................] - ETA: 1:15 - loss: 3.7487Dummy Line 	 [0.]
# Loss WH 	 3.683126
# Current Recall 	 0.14925373
# Loss Conf 	 0.0027555712
# Loss XY 	 0.036906682
# Average Recall 	 0.07706256
# Loss Class 	 0.3949904
# Total Loss 	 4.117779
#  77/251 [========>.....................] - ETA: 1:15 - loss: 3.7535Dummy Line 	 [0.]
# Loss WH 	 2.7843788
# Loss XY 	 0.040897388
# Current Recall 	 0.14285715
# Average Recall 	 0.07707199
# Loss Conf 	 0.0022626657
# Loss Class 	 0.50150687
# Total Loss 	 3.3290455
#  78/251 [========>.....................] - ETA: 1:14 - loss: 3.7480Dummy Line 	 [0.]
# Loss WH 	 5.4800525
# Loss XY 	 0.05899715
# Current Recall 	 0.19354838
# Loss Conf 	 0.0014513062
# Average Recall 	 0.077088654
# Loss Class 	 0.60168564
# Total Loss 	 6.1421866
#  79/251 [========>.....................] - ETA: 1:14 - loss: 3.7783Dummy Line 	 [0.]
# Loss WH 	 3.4446518
# Loss XY 	 0.070954345
# Current Recall 	 0.11764706
# Average Recall 	 0.07709446
# Loss Conf 	 0.0033637835
# Loss Class 	 0.48133683
# Total Loss 	 4.000307
#  80/251 [========>.....................] - ETA: 1:13 - loss: 3.7811Dummy Line 	 [0.]
# Loss WH 	 4.732137
# Loss XY 	 0.057281367
# Current Recall 	 0.16981132
# Loss Conf 	 0.0019899805
# Average Recall 	 0.07710772
# Loss Class 	 0.50207734
# Total Loss 	 5.2934856
#  81/251 [========>.....................] - ETA: 1:13 - loss: 3.7998Dummy Line 	 [0.]
# Loss WH 	 6.3474464
# Loss XY 	 0.048204817
# Current Recall 	 0.1891892
# Average Recall 	 0.077123754
# Loss Conf 	 0.0016446025
# Loss Class 	 0.5581664
# Total Loss 	 6.9554625
#  82/251 [========>.....................] - ETA: 1:13 - loss: 3.8383Dummy Line 	 [0.]
# Loss WH 	 3.7376866
# Current Recall 	 0.33333334
# Loss Conf 	 0.0012409405
# Average Recall 	 0.077160396
# Loss Class 	 0.39355937
# Loss XY 	 0.040515866
# Total Loss 	 4.1730027
#  83/251 [========>.....................] - ETA: 1:13 - loss: 3.8423Dummy Line 	 [0.]
# Loss WH 	 2.6393406
# Loss XY 	 0.07383027
# Current Recall 	 0.12765957
# Average Recall 	 0.07716762
# Loss Conf 	 0.0020642097
# Loss Class 	 0.5649804
# Total Loss 	 3.2802157
#  84/251 [=========>....................] - ETA: 1:12 - loss: 3.8356Dummy Line 	 [0.]
# Loss WH 	 3.2334847
# Loss XY 	 0.059203032
# Current Recall 	 0.18644068
# Average Recall 	 0.07718325
# Loss Conf 	 0.0023833364
# Loss Class 	 0.6898041
# Total Loss 	 3.9848752
#  85/251 [=========>....................] - ETA: 1:12 - loss: 3.8374Dummy Line 	 [0.]
# Loss WH 	 3.6377993
# Loss XY 	 0.0534423
# Current Recall 	 0.16666667
# Average Recall 	 0.07719605
# Loss Conf 	 0.0021309766
# Loss Class 	 0.35107237
# Total Loss 	 4.044445
#  86/251 [=========>....................] - ETA: 1:12 - loss: 3.8398Dummy Line 	 [0.]
# Loss WH 	 3.729361
# Loss XY 	 0.05004429
# Current Recall 	 0.25
# Average Recall 	 0.077220745
# Loss Conf 	 0.0021057217
# Loss Class 	 0.6267892
# Total Loss 	 4.4083004
#  87/251 [=========>....................] - ETA: 1:12 - loss: 3.8463Dummy Line 	 [0.]
# Loss WH 	 1.7445787
# Loss XY 	 0.054097455
# Current Recall 	 0.23287672
# Average Recall 	 0.077242985
# Loss Class 	 0.35444084
# Loss Conf 	 0.00279031
# Total Loss 	 2.1559074
#  88/251 [=========>....................] - ETA: 1:11 - loss: 3.8271Dummy Line 	 [0.]
# Loss WH 	 1.7806312
# Loss XY 	 0.0647637
# Current Recall 	 0.077922076
# Average Recall 	 0.07724309
# Loss Conf 	 0.0033438283
# Loss Class 	 0.6981683
# Total Loss 	 2.546907
#  89/251 [=========>....................] - ETA: 1:11 - loss: 3.8127Dummy Line 	 [0.]
# Loss WH 	 2.5863729
# Loss XY 	 0.045409653
# Current Recall 	 0.13461539
# Average Recall 	 0.077251285
# Loss Conf 	 0.0023818323
# Loss Class 	 0.5051035
# Total Loss 	 3.139268
#  90/251 [=========>....................] - ETA: 1:11 - loss: 3.8052Dummy Line 	 [0.]
# Loss WH 	 4.1125693
# Loss XY 	 0.056810636
# Current Recall 	 0.125
# Loss Conf 	 0.0021811975
# Average Recall 	 0.07725811
# Loss Class 	 0.6356351
# Total Loss 	 4.807196
#  91/251 [=========>....................] - ETA: 1:10 - loss: 3.8162Dummy Line 	 [0.]
# Loss WH 	 4.0137954
# Loss XY 	 0.06237847
# Loss Conf 	 0.0018504283
# Loss Class 	 0.6303132
# Average Recall 	 0.07726707
# Current Recall 	 0.14
# Total Loss 	 4.708338
#  92/251 [=========>....................] - ETA: 1:10 - loss: 3.8259Dummy Line 	 [0.]
# Loss WH 	 3.839947
# Loss XY 	 0.055131346
# Current Recall 	 0.0862069
# Average Recall 	 0.07726835
# Loss Conf 	 0.0025389136
# Loss Class 	 0.63978064
# Total Loss 	 4.537398
#  93/251 [==========>...................] - ETA: 1:10 - loss: 3.8336Dummy Line 	 [0.]
# Loss WH 	 1.7848997
# Current Recall 	 0.203125
# Loss XY 	 0.062837385
# Loss Conf 	 0.0024803046
# Average Recall 	 0.07728632
# Loss Class 	 0.28277227
# Total Loss 	 2.1329896
#  94/251 [==========>...................] - ETA: 1:09 - loss: 3.8155Dummy Line 	 [0.]
# Loss WH 	 3.763387
# Loss XY 	 0.067775995
# Current Recall 	 0.035714287
# Average Recall 	 0.07728038
# Loss Conf 	 0.002689062
# Loss Class 	 0.35734954
# Total Loss 	 4.1912017
#  95/251 [==========>...................] - ETA: 1:09 - loss: 3.8194Dummy Line 	 [0.]
# Loss WH 	 4.8203554
# Loss XY 	 0.039675634
# Current Recall 	 0.13235295
# Average Recall 	 0.07728824
# Loss Conf 	 0.002812074
# Loss Class 	 0.29776496
# Total Loss 	 5.160608
#  96/251 [==========>...................] - ETA: 1:09 - loss: 3.8334Dummy Line 	 [0.]
# Loss XY 	 0.053786892
# Loss WH 	 2.3607051
# Loss Conf 	 0.0022449973
# Current Recall 	 0.2
# Average Recall 	 0.07730576
# Loss Class 	 0.43701205
# Total Loss 	 2.853749
#  97/251 [==========>...................] - ETA: 1:08 - loss: 3.8233Dummy Line 	 [0.]
# Loss WH 	 3.9108012
# Loss XY 	 0.040373847
# Current Recall 	 0.27027026
# Average Recall 	 0.077333294
# Loss Conf 	 0.001948277
# Loss Class 	 0.25613827
# Total Loss 	 4.2092614
#  98/251 [==========>...................] - ETA: 1:08 - loss: 3.8273Dummy Line 	 [0.]
# Loss WH 	 4.0278573
# Loss XY 	 0.054030254
# Current Recall 	 0.0952381
# Average Recall 	 0.07733584
# Loss Conf 	 0.0019925456
# Loss Class 	 0.576431
# Total Loss 	 4.660311
#  99/251 [==========>...................] - ETA: 1:07 - loss: 3.8357Dummy Line 	 [0.]
# Loss WH 	 1.4451269
# Loss XY 	 0.0488351
# Current Recall 	 0.1981132
# Average Recall 	 0.077353075
# Loss Conf 	 0.0031283004
# Loss Class 	 0.3833701
# Total Loss 	 1.8804605
# 100/251 [==========>...................] - ETA: 1:07 - loss: 3.8161Dummy Line 	 [0.]
# Loss WH 	 4.5791364
# Loss XY 	 0.048678588
# Current Recall 	 0.13793103
# Average Recall 	 0.07736172
# Loss Conf 	 0.0017567324
# Loss Class 	 0.42137206
# Total Loss 	 5.0509434
# 101/251 [===========>..................] - ETA: 1:07 - loss: 3.8283Dummy Line 	 [0.]
# Loss WH 	 3.9407334
# Loss XY 	 0.045520026
# Current Recall 	 0.21428572
# Average Recall 	 0.07738125
# Loss Conf 	 0.0018316633
# Loss Class 	 0.36985794
# Total Loss 	 4.357943
# 102/251 [===========>..................] - ETA: 1:06 - loss: 3.8335Dummy Line 	 [0.]
# Loss WH 	 3.794444
# Loss XY 	 0.054483928
# Average Recall 	 0.07739019
# Loss Conf 	 0.0026422972
# Loss Class 	 0.5077866
# Current Recall 	 0.14
# Total Loss 	 4.359357
# 103/251 [===========>..................] - ETA: 1:06 - loss: 3.8386Dummy Line 	 [0.]
# Loss WH 	 3.065522
# Loss XY 	 0.051463194
# Current Recall 	 0.14285715
# Average Recall 	 0.07739952
# Loss Conf 	 0.0017525747
# Loss Class 	 0.675186
# Total Loss 	 3.7939236
# 104/251 [===========>..................] - ETA: 1:06 - loss: 3.8382Dummy Line 	 [0.]
# Loss WH 	 3.1044927
# Loss XY 	 0.069554165
# Current Recall 	 0.10526316
# Loss Conf 	 0.0020716123
# Average Recall 	 0.0774035
# Loss Class 	 1.114494
# Total Loss 	 4.290612
# 105/251 [===========>..................] - ETA: 1:05 - loss: 3.8425Dummy Line 	 [0.]
# Loss WH 	 3.20043
# Loss XY 	 0.04910105
# Current Recall 	 0.037037037
# Average Recall 	 0.07739775
# Loss Conf 	 0.0021064999
# Loss Class 	 0.46599832
# Total Loss 	 3.7176359
# 106/251 [===========>..................] - ETA: 1:05 - loss: 3.8413Dummy Line 	 [0.]
# Loss XY 	 0.0457173
# Loss WH 	 2.4575403
# Current Recall 	 0.12698413
# Loss Conf 	 0.0025413132
# Average Recall 	 0.07740482
# Loss Class 	 0.6552092
# Total Loss 	 3.161008
# 107/251 [===========>..................] - ETA: 1:04 - loss: 3.8350Dummy Line 	 [0.]
# Loss WH 	 3.1942337
# Loss XY 	 0.055462614
# Current Recall 	 0.19565217
# Average Recall 	 0.07742167
# Loss Conf 	 0.0017147489
# Loss Class 	 0.4126531
# Total Loss 	 3.664064
# 108/251 [===========>..................] - ETA: 1:04 - loss: 3.8334Dummy Line 	 [0.]
# Loss WH 	 2.9047635
# Loss XY 	 0.059394844
# Average Recall 	 0.07742755
# Loss Conf 	 0.0023475462
# Loss Class 	 0.340689
# Current Recall 	 0.118644066
# Total Loss 	 3.3071947
# 109/251 [============>.................] - ETA: 1:04 - loss: 3.8286Dummy Line 	 [0.]
# Loss WH 	 2.7632916
# Loss XY 	 0.051414393
# Current Recall 	 0.18181819
# Average Recall 	 0.07744242
# Loss Conf 	 0.001974954
# Loss Class 	 0.6180146
# Total Loss 	 3.4346957
# 110/251 [============>.................] - ETA: 1:03 - loss: 3.8250Dummy Line 	 [0.]
# Loss WH 	 2.978405
# Loss XY 	 0.06124686
# Current Recall 	 0.1627907
# Average Recall 	 0.07745458
# Loss Conf 	 0.0018116053
# Loss Class 	 0.7223131
# Total Loss 	 3.7637765
# 111/251 [============>.................] - ETA: 1:03 - loss: 3.8244Dummy Line 	 [0.]
# Loss WH 	 2.3015082
# Loss XY 	 0.05395259
# Current Recall 	 0.12962963
# Average Recall 	 0.07746201
# Loss Conf 	 0.0024976397
# Loss Class 	 0.6276759
# Total Loss 	 2.9856343
# 112/251 [============>.................] - ETA: 1:03 - loss: 3.8170Dummy Line 	 [0.]
# Loss WH 	 2.84497
# Loss XY 	 0.04386115
# Loss Conf 	 0.0019894321
# Current Recall 	 0.22
# Average Recall 	 0.077482305
# Loss Class 	 0.52911
# Total Loss 	 3.4199305
# 113/251 [============>.................] - ETA: 1:02 - loss: 3.8134Dummy Line 	 [0.]
# Loss WH 	 2.357872
# Loss XY 	 0.06712237
# Current Recall 	 0.09090909
# Average Recall 	 0.07748421
# Loss Class 	 1.5512724
# Loss Conf 	 0.0025454536
# Total Loss 	 3.9788122
# 114/251 [============>.................] - ETA: 1:02 - loss: 3.8149Dummy Line 	 [0.]
# Loss WH 	 4.754063
# Loss XY 	 0.03873182
# Current Recall 	 0.13461539
# Average Recall 	 0.07749235
# Loss Conf 	 0.0020662567
# Loss Class 	 0.8007443
# Total Loss 	 5.595606
# 115/251 [============>.................] - ETA: 1:02 - loss: 3.8304Dummy Line 	 [0.]
# Loss WH 	 3.9038131
# Loss XY 	 0.06658367
# Current Recall 	 0.11320755
# Average Recall 	 0.07749744
# Loss Conf 	 0.0018850807
# Loss Class 	 0.7397464
# Total Loss 	 4.7120285
# 116/251 [============>.................] - ETA: 1:01 - loss: 3.8380Dummy Line 	 [0.]
# Loss XY 	 0.051172808
# Current Recall 	 0.21568628
# Loss WH 	 4.0750313
# Average Recall 	 0.07751711
# Loss Conf 	 0.0023026448
# Loss Class 	 0.63662535
# Total Loss 	 4.765132
# 117/251 [============>.................] - ETA: 1:01 - loss: 3.8459Dummy Line 	 [0.]
# Loss WH 	 2.5575488
# Average Recall 	 0.07753255
# Current Recall 	 0.18604651
# Loss Class 	 0.4826196
# Loss XY 	 0.059253678
# Loss Conf 	 0.0019396016
# Total Loss 	 3.1013615
# 118/251 [=============>................] - ETA: 1:00 - loss: 3.8396Dummy Line 	 [0.]
# Loss WH 	 2.1056213
# Current Recall 	 0.1627907
# Average Recall 	 0.07754468
# Loss Conf 	 0.0024392363
# Loss XY 	 0.041444603
# Loss Class 	 0.762437
# Total Loss 	 2.911942
# 119/251 [=============>................] - ETA: 1:00 - loss: 3.8318Dummy Line 	 [0.]
# Loss WH 	 2.7424011
# Loss XY 	 0.053064246
# Current Recall 	 0.1923077
# Average Recall 	 0.077561006
# Loss Conf 	 0.0019618412
# Loss Class 	 0.56388754
# Total Loss 	 3.361315
# 120/251 [=============>................] - ETA: 59s - loss: 3.8279 Dummy Line 	 [0.]
# Loss WH 	 2.3690827
# Loss XY 	 0.041327544
# Current Recall 	 0.225
# Loss Conf 	 0.0018724462
# Average Recall 	 0.07758198
# Loss Class 	 0.65491796
# Total Loss 	 3.0672007
# 121/251 [=============>................] - ETA: 59s - loss: 3.8216Dummy Line 	 [0.]
# Loss Class 	 0.6540892
# Loss WH 	 3.0859637
# Loss XY 	 0.05265891
# Current Recall 	 0.078431375
# Average Recall 	 0.0775821
# Loss Conf 	 0.0023949062
# Total Loss 	 3.7951066
# 122/251 [=============>................] - ETA: 58s - loss: 3.8214Dummy Line 	 [0.]
# Loss WH 	 3.9180915
# Loss XY 	 0.046994552
# Current Recall 	 0.16
# Average Recall 	 0.07759382
# Loss Conf 	 0.002511829
# Loss Class 	 0.54035795
# Total Loss 	 4.5079556
# 123/251 [=============>................] - ETA: 58s - loss: 3.8270Dummy Line 	 [0.]
# Loss WH 	 2.2130454
# Loss XY 	 0.039734498
# Current Recall 	 0.29268292
# Average Recall 	 0.077624395
# Loss Conf 	 0.0017428856
# Loss Class 	 0.5179407
# Total Loss 	 2.7724636
# 124/251 [=============>................] - ETA: 57s - loss: 3.8184Dummy Line 	 [0.]
# Loss XY 	 0.056555554
# Loss WH 	 4.4536777
# Current Recall 	 0.125
# Average Recall 	 0.07763113
# Loss Conf 	 0.002121304
# Loss Class 	 0.47515222
# Total Loss 	 4.987507
# 125/251 [=============>................] - ETA: 57s - loss: 3.8278Dummy Line 	 [0.]
# Loss WH 	 2.1535246
# Loss XY 	 0.039973374
# Current Recall 	 0.25862068
# Average Recall 	 0.07765686
# Loss Conf 	 0.0021827603
# Loss Class 	 0.18870975
# Total Loss 	 2.3843904
# 126/251 [==============>...............] - ETA: 56s - loss: 3.8163Dummy Line 	 [0.]
# Loss WH 	 3.9555154
# Loss XY 	 0.059454218
# Current Recall 	 0.13207547
# Average Recall 	 0.07766459
# Loss Conf 	 0.002087529
# Loss Class 	 0.34072718
# Total Loss 	 4.3577847
# 127/251 [==============>...............] - ETA: 56s - loss: 3.8206Dummy Line 	 [0.]
# Loss WH 	 3.8365676
# Loss XY 	 0.059069213
# Current Recall 	 0.055555556
# Average Recall 	 0.07766145
# Loss Conf 	 0.0021221605
# Loss Class 	 0.50302017
# Total Loss 	 4.4007792
# 128/251 [==============>...............] - ETA: 55s - loss: 3.8251Dummy Line 	 [0.]
# Loss WH 	 2.3260212
# Loss XY 	 0.052663393
# Current Recall 	 0.24193548
# Average Recall 	 0.07768479
# Loss Conf 	 0.0020506966
# Loss Class 	 0.70713556
# Total Loss 	 3.0878706
# 129/251 [==============>...............] - ETA: 55s - loss: 3.8194Dummy Line 	 [0.]
# Current Recall 	 0.073529415
# Loss Conf 	 0.00276741
# Average Recall 	 0.0776842
# Loss Class 	 0.8234934
# Loss XY 	 0.060123738
# Loss WH 	 3.4006488
# Total Loss 	 4.287033
# 130/251 [==============>...............] - ETA: 54s - loss: 3.8230Dummy Line 	 [0.]
# Loss WH 	 2.9730647
# Loss XY 	 0.043014806
# Current Recall 	 0.2631579
# Average Recall 	 0.077710554
# Loss Conf 	 0.002192094
# Loss Class 	 0.45082778
# Total Loss 	 3.4690993
# 131/251 [==============>...............] - ETA: 54s - loss: 3.8203Dummy Line 	 [0.]
# Loss WH 	 4.533789
# Loss XY 	 0.044477083
# Current Recall 	 0.15384616
# Average Recall 	 0.077721365
# Loss Conf 	 0.0014601985
# Loss Class 	 0.78281474
# Total Loss 	 5.362541
# 132/251 [==============>...............] - ETA: 53s - loss: 3.8320Dummy Line 	 [0.]
# Loss WH 	 2.8425324
# Loss XY 	 0.049248092
# Current Recall 	 0.171875
# Average Recall 	 0.07773474
# Loss Conf 	 0.0029298326
# Loss Class 	 0.3226799
# Total Loss 	 3.2173903
# 133/251 [==============>...............] - ETA: 53s - loss: 3.8274Dummy Line 	 [0.]
# Loss WH 	 3.2646286
# Loss XY 	 0.053668045
# Current Recall 	 0.114754096
# Average Recall 	 0.07773999
# Loss Conf 	 0.0027037547
# Loss Class 	 0.3128262
# Total Loss 	 3.6338265
# 134/251 [===============>..............] - ETA: 52s - loss: 3.8259Dummy Line 	 [0.]
# Loss WH 	 3.005985
# Loss XY 	 0.03494739
# Loss Class 	 0.7253694
# Loss Conf 	 0.0017402843
# Current Recall 	 0.057142857
# Average Recall 	 0.07773706
# Total Loss 	 3.768042
# 135/251 [===============>..............] - ETA: 52s - loss: 3.8255Dummy Line 	 [0.]
# Loss WH 	 3.3336513
# Loss XY 	 0.04748793
# Loss Conf 	 0.0029520066
# Current Recall 	 0.06944445
# Loss Class 	 0.9956281
# Average Recall 	 0.07773589
# Total Loss 	 4.3797197
# 136/251 [===============>..............] - ETA: 52s - loss: 3.8296Dummy Line 	 [0.]
# Loss WH 	 3.7490597
# Loss XY 	 0.055672716
# Current Recall 	 0.10909091
# Average Recall 	 0.07774034
# Loss Conf 	 0.0022302337
# Loss Class 	 0.62802774
# Total Loss 	 4.4349904
# 137/251 [===============>..............] - ETA: 51s - loss: 3.8340Dummy Line 	 [0.]
# Loss WH 	 3.2321875
# Loss XY 	 0.05327859
# Current Recall 	 0.29268292
# Loss Conf 	 0.001777723
# Loss Class 	 0.5141084
# Average Recall 	 0.07777084
# Total Loss 	 3.8013523
# 138/251 [===============>..............] - ETA: 51s - loss: 3.8338Dummy Line 	 [0.]
# Loss WH 	 4.0982747
# Loss XY 	 0.04968957
# Current Recall 	 0.10909091
# Average Recall 	 0.07777528
# Loss Conf 	 0.002692238
# Loss Class 	 1.0140395
# Total Loss 	 5.164696
# 139/251 [===============>..............] - ETA: 50s - loss: 3.8433Dummy Line 	 [0.]
# Loss WH 	 1.8964248
# Loss XY 	 0.050407294
# Current Recall 	 0.21212122
# Average Recall 	 0.077794336
# Loss Class 	 0.43639535
# Loss Conf 	 0.0016891725
# Total Loss 	 2.3849165
# 140/251 [===============>..............] - ETA: 50s - loss: 3.8329Dummy Line 	 [0.]
# Loss WH 	 3.3041217
# Loss XY 	 0.047341548
# Current Recall 	 0.114754096
# Average Recall 	 0.07779957
# Loss Conf 	 0.0025615178
# Loss Class 	 0.64451873
# Total Loss 	 3.9985437
# 141/251 [===============>..............] - ETA: 50s - loss: 3.8341Dummy Line 	 [0.]
# Loss WH 	 2.967148
# Loss XY 	 0.04954252
# Current Recall 	 0.11764706
# Loss Conf 	 0.0024738964
# Loss Class 	 0.6157769
# Average Recall 	 0.07780523
# Total Loss 	 3.634941
# 142/251 [===============>..............] - ETA: 49s - loss: 3.8327Dummy Line 	 [0.]
# Loss WH 	 3.0601997
# Loss XY 	 0.040904824
# Current Recall 	 0.1632653
# Average Recall 	 0.07781735
# Loss Conf 	 0.0021370063
# Loss Class 	 0.3160652
# Total Loss 	 3.4193068
# 143/251 [================>.............] - ETA: 49s - loss: 3.8298Dummy Line 	 [0.]
# Loss WH 	 3.0957549
# Loss XY 	 0.04294517
# Current Recall 	 0.17073171
# Average Recall 	 0.07783052
# Loss Conf 	 0.001664296
# Loss Class 	 0.4950501
# Total Loss 	 3.6354146
# 144/251 [================>.............] - ETA: 48s - loss: 3.8285Dummy Line 	 [0.]
# Loss WH 	 3.5881875
# Loss XY 	 0.043145783
# Current Recall 	 0.2580645
# Loss Conf 	 0.0011632586
# Average Recall 	 0.07785607
# Loss Class 	 0.39794746
# Total Loss 	 4.030444
# 145/251 [================>.............] - ETA: 48s - loss: 3.8298Dummy Line 	 [0.]
# Loss WH 	 2.5312738
# Loss XY 	 0.043742076
# Current Recall 	 0.22222222
# Average Recall 	 0.07787653
# Loss Conf 	 0.0017394059
# Loss Class 	 0.5066483
# Total Loss 	 3.0834038
# 146/251 [================>.............] - ETA: 47s - loss: 3.8247Dummy Line 	 [0.]
# Loss XY 	 0.049913082
# Loss WH 	 3.780034
# Current Recall 	 0.1923077
# Loss Conf 	 0.001815304
# Average Recall 	 0.07789275
# Loss Class 	 0.5493974
# Total Loss 	 4.38116
# 147/251 [================>.............] - ETA: 47s - loss: 3.8285Dummy Line 	 [0.]
# Loss WH 	 2.289237
# Loss XY 	 0.041925266
# Current Recall 	 0.33333334
# Loss Conf 	 0.0018154166
# Average Recall 	 0.077928945
# Loss Class 	 0.5576938
# Total Loss 	 2.8906713
# 148/251 [================>.............] - ETA: 46s - loss: 3.8222Dummy Line 	 [0.]
# Loss WH 	 3.0464883
# Loss XY 	 0.050883822
# Current Recall 	 0.11111111
# Loss Conf 	 0.0023404614
# Average Recall 	 0.07793365
# Loss Class 	 0.42795327
# Total Loss 	 3.5276659
# 149/251 [================>.............] - ETA: 46s - loss: 3.8202Dummy Line 	 [0.]
# Loss WH 	 5.7371054
# Loss XY 	 0.044220194
# Average Recall 	 0.077939466
# Loss Conf 	 0.001786557
# Loss Class 	 0.4638566
# Current Recall 	 0.11904762
# Total Loss 	 6.2469687
# 150/251 [================>.............] - ETA: 46s - loss: 3.8364Dummy Line 	 [0.]
# Loss WH 	 2.0573502
# Loss XY 	 0.05277674
# Current Recall 	 0.13636364
# Average Recall 	 0.077947736
# Loss Conf 	 0.0027512398
# Loss Class 	 0.54925466
# Total Loss 	 2.662133
# 151/251 [=================>............] - ETA: 45s - loss: 3.8286Dummy Line 	 [0.]
# Loss WH 	 3.5956903
# Loss XY 	 0.04274072
# Current Recall 	 0.23076923
# Loss Conf 	 0.0024472494
# Loss Class 	 0.37048715
# Average Recall 	 0.07796938
# Total Loss 	 4.0113654
# 152/251 [=================>............] - ETA: 45s - loss: 3.8298Dummy Line 	 [0.]
# Loss WH 	 3.8432796
# Loss XY 	 0.043943346
# Current Recall 	 0.225
# Average Recall 	 0.0779902
# Loss Conf 	 0.0018337938
# Loss Class 	 0.5085424
# Total Loss 	 4.397599
# 153/251 [=================>............] - ETA: 44s - loss: 3.8335Dummy Line 	 [0.]
# Loss WH 	 3.4481
# Loss XY 	 0.060218982
# Current Recall 	 0.171875
# Average Recall 	 0.07800349
# Loss Conf 	 0.002770971
# Loss Class 	 0.9205129
# Total Loss 	 4.431603
# 154/251 [=================>............] - ETA: 44s - loss: 3.8374Dummy Line 	 [0.]
# Loss WH 	 2.371578
# Loss XY 	 0.04979826
# Current Recall 	 0.08196721
# Loss Conf 	 0.0023988849
# Average Recall 	 0.078004055
# Loss Class 	 0.66881835
# Total Loss 	 3.0925937
# 155/251 [=================>............] - ETA: 43s - loss: 3.8326Dummy Line 	 [0.]
# Loss WH 	 2.8695133
# Loss XY 	 0.06597336
# Current Recall 	 0.19298245
# Loss Conf 	 0.001669641
# Average Recall 	 0.07802033
# Loss Class 	 0.31558383
# Total Loss 	 3.25274
# 156/251 [=================>............] - ETA: 43s - loss: 3.8289Dummy Line 	 [0.]
# Loss WH 	 2.0442863
# Loss Conf 	 0.002698773
# Loss XY 	 0.043035436
# Current Recall 	 0.109375
# Average Recall 	 0.07802477
# Loss Class 	 0.4750481
# Total Loss 	 2.5650685
# 157/251 [=================>............] - ETA: 42s - loss: 3.8208Dummy Line 	 [0.]
# Loss WH 	 2.655221
# Loss XY 	 0.05234669
# Current Recall 	 0.22580644
# Loss Conf 	 0.00248863
# Loss Class 	 0.34854114
# Average Recall 	 0.07804568
# Total Loss 	 3.0585976
# 158/251 [=================>............] - ETA: 42s - loss: 3.8160Dummy Line 	 [0.]
# Loss WH 	 4.0942917
# Loss XY 	 0.054102156
# Average Recall 	 0.0780475
# Loss Conf 	 0.0015041177
# Current Recall 	 0.09090909
# Loss Class 	 0.41940498
# Total Loss 	 4.5693026
# 159/251 [==================>...........] - ETA: 41s - loss: 3.8207Dummy Line 	 [0.]
# Loss XY 	 0.058856048
# Loss WH 	 4.734862
# Loss Conf 	 0.0018583868
# Average Recall 	 0.07806828
# Current Recall 	 0.225
# Loss Class 	 0.5009227
# Total Loss 	 5.296499
# 160/251 [==================>...........] - ETA: 41s - loss: 3.8300Dummy Line 	 [0.]
# Loss WH 	 2.3408186
# Loss XY 	 0.0582386
# Current Recall 	 0.18965517
# Average Recall 	 0.07808406
# Loss Conf 	 0.0022751635
# Loss Class 	 0.3322874
# Total Loss 	 2.7336197
# 161/251 [==================>...........] - ETA: 40s - loss: 3.8232Dummy Line 	 [0.]
# Loss WH 	 2.514348
# Loss XY 	 0.04624643
# Current Recall 	 0.24489796
# Average Recall 	 0.07810765
# Loss Conf 	 0.0020266834
# Loss Class 	 0.69196695
# Total Loss 	 3.2545884
# 162/251 [==================>...........] - ETA: 40s - loss: 3.8197Dummy Line 	 [0.]
# Loss WH 	 4.806414
# Loss XY 	 0.049852215
# Current Recall 	 0.21052632
# Average Recall 	 0.07812637
# Loss Conf 	 0.002290476
# Loss Class 	 0.5719527
# Total Loss 	 5.4305096
# 163/251 [==================>...........] - ETA: 39s - loss: 3.8295Dummy Line 	 [0.]
# Loss WH 	 3.295264
# Loss XY 	 0.050851125
# Current Recall 	 0.125
# Average Recall 	 0.078133
# Loss Conf 	 0.001839208
# Loss Class 	 0.3147018
# Total Loss 	 3.662656
# 164/251 [==================>...........] - ETA: 39s - loss: 3.8285Dummy Line 	 [0.]
# Current Recall 	 0.23404256
# Average Recall 	 0.07815504
# Loss WH 	 2.795009
# Loss Conf 	 0.0021121905
# Loss XY 	 0.04761466
# Loss Class 	 0.34837854
# Total Loss 	 3.1931143
# 165/251 [==================>...........] - ETA: 39s - loss: 3.8247Dummy Line 	 [0.]
# Loss WH 	 5.2576823
# Loss XY 	 0.04663343
# Current Recall 	 0.21621622
# Average Recall 	 0.078174554
# Loss Conf 	 0.0014726205
# Loss Class 	 0.52446747
# Total Loss 	 5.8302555
# 166/251 [==================>...........] - ETA: 38s - loss: 3.8367Dummy Line 	 [0.]
# Loss WH 	 2.6231177
# Loss XY 	 0.048158415
# Current Recall 	 0.114754096
# Average Recall 	 0.078179725
# Loss Conf 	 0.0024379443
# Loss Class 	 0.50104225
# Total Loss 	 3.174756
# 167/251 [==================>...........] - ETA: 38s - loss: 3.8328Dummy Line 	 [0.]
# Loss WH 	 2.4405684
# Loss XY 	 0.065840475
# Current Recall 	 0.06451613
# Average Recall 	 0.07817779
# Loss Conf 	 0.002246388
# Loss Class 	 0.40701714
# Total Loss 	 2.9156725
# 168/251 [===================>..........] - ETA: 37s - loss: 3.8273Dummy Line 	 [0.]
# Loss WH 	 4.6837015
# Loss XY 	 0.035728056
# Current Recall 	 0.32258064
# Average Recall 	 0.07821232
# Loss Conf 	 0.0015192296
# Loss Class 	 0.46016622
# Total Loss 	 5.181115
# 169/251 [===================>..........] - ETA: 37s - loss: 3.8353Dummy Line 	 [0.]
# Loss XY 	 0.047622863
# Loss WH 	 2.6540577
# Average Recall 	 0.07823266
# Loss Conf 	 0.0018946914
# Current Recall 	 0.22222222
# Loss Class 	 0.40487042
# Total Loss 	 3.108446
# 170/251 [===================>..........] - ETA: 36s - loss: 3.8311Dummy Line 	 [0.]
# Loss WH 	 5.3747435
# Loss XY 	 0.048652902
# Current Recall 	 0.04
# Average Recall 	 0.07822726
# Loss Conf 	 0.0021363527
# Loss Class 	 0.6507269
# Total Loss 	 6.0762596
# 171/251 [===================>..........] - ETA: 36s - loss: 3.8442Dummy Line 	 [0.]
# Loss WH 	 2.3738275
# Loss XY 	 0.045591436
# Current Recall 	 0.14473684
# Average Recall 	 0.07823665
# Loss Conf 	 0.0031013016
# Loss Class 	 0.52641153
# Total Loss 	 2.9489317
# 172/251 [===================>..........] - ETA: 35s - loss: 3.8390Dummy Line 	 [0.]
# Loss WH 	 3.4568675
# Loss XY 	 0.043882884
# Current Recall 	 0.15151516
# Loss Conf 	 0.0014313067
# Average Recall 	 0.078246996
# Loss Class 	 0.41916153
# Total Loss 	 3.921343
# 173/251 [===================>..........] - ETA: 35s - loss: 3.8395Dummy Line 	 [0.]
# Loss WH 	 3.9046998
# Loss XY 	 0.046708487
# Current Recall 	 0.15
# Average Recall 	 0.07825713
# Loss Conf 	 0.0017725395
# Loss Class 	 0.5238768
# Total Loss 	 4.477058
# 174/251 [===================>..........] - ETA: 34s - loss: 3.8431Dummy Line 	 [0.]
# Loss WH 	 2.9917738
# Loss XY 	 0.05146269
# Current Recall 	 0.15789473
# Average Recall 	 0.07826837
# Loss Conf 	 0.0025513861
# Loss Class 	 0.5829128
# Total Loss 	 3.6287007
# 175/251 [===================>..........] - ETA: 34s - loss: 3.8419Dummy Line 	 [0.]
# Loss WH 	 3.6337929
# Loss XY 	 0.05130255
# Current Recall 	 0.09615385
# Average Recall 	 0.07827089
# Loss Conf 	 0.0025599843
# Loss Class 	 0.85987943
# Total Loss 	 4.5475345
# 176/251 [====================>.........] - ETA: 33s - loss: 3.8459Dummy Line 	 [0.]
# Loss WH 	 2.4842944
# Loss XY 	 0.06593225
# Current Recall 	 0.060606062
# Average Recall 	 0.078268394
# Loss Conf 	 0.0025447875
# Loss Class 	 0.7272258
# Total Loss 	 3.2799973
# 177/251 [====================>.........] - ETA: 33s - loss: 3.8427Dummy Line 	 [0.]
# Loss WH 	 3.9661179
# Loss XY 	 0.065177195
# Current Recall 	 0.10869565
# Average Recall 	 0.07827269
# Loss Conf 	 0.0016748223
# Loss Class 	 0.42238027
# Total Loss 	 4.45535
# 178/251 [====================>.........] - ETA: 33s - loss: 3.8462Dummy Line 	 [0.]
# Loss XY 	 0.051345725
# Loss WH 	 2.7532017
# Current Recall 	 0.1904762
# Loss Conf 	 0.001700334
# Average Recall 	 0.078288525
# Loss Class 	 0.8129094
# Total Loss 	 3.6191573
# 179/251 [====================>.........] - ETA: 32s - loss: 3.8449Dummy Line 	 [0.]
# Loss XY 	 0.06284317
# Current Recall 	 0.08888889
# Loss Conf 	 0.0018823532
# Loss WH 	 3.9797425
# Average Recall 	 0.078290015
# Loss Class 	 0.6383794
# Total Loss 	 4.682848
# 180/251 [====================>.........] - ETA: 32s - loss: 3.8495Dummy Line 	 [0.]
# Loss XY 	 0.038691677
# Loss WH 	 3.1420205
# Current Recall 	 0.18181819
# Average Recall 	 0.07830462
# Loss Conf 	 0.002461443
# Loss Class 	 0.42468476
# Total Loss 	 3.6078584
# 181/251 [====================>.........] - ETA: 31s - loss: 3.8482Dummy Line 	 [0.]
# Loss WH 	 2.575416
# Loss XY 	 0.061829474
# Current Recall 	 0.125
# Loss Conf 	 0.0019814007
# Average Recall 	 0.078311205
# Loss Class 	 0.3810744
# Total Loss 	 3.0203016
# 182/251 [====================>.........] - ETA: 31s - loss: 3.8437Dummy Line 	 [0.]
# Loss WH 	 2.8984947
# Loss XY 	 0.054480582
# Current Recall 	 0.21818182
# Average Recall 	 0.07833093
# Loss Conf 	 0.0019491586
# Loss Class 	 0.24602436
# Total Loss 	 3.2009487
# 183/251 [====================>.........] - ETA: 30s - loss: 3.8401Dummy Line 	 [0.]
# Loss WH 	 2.8855925
# Loss XY 	 0.06642977
# Current Recall 	 0.093333334
# Loss Conf 	 0.002344379
# Average Recall 	 0.07833304
# Loss Class 	 0.7382519
# Total Loss 	 3.6926186
# 184/251 [====================>.........] - ETA: 30s - loss: 3.8393Dummy Line 	 [0.]
# Loss WH 	 3.2248292
# Loss XY 	 0.045626488
# Average Recall 	 0.07835117
# Current Recall 	 0.20689656
# Loss Conf 	 0.0020905447
# Loss Class 	 0.48385996
# Total Loss 	 3.756406
# 185/251 [=====================>........] - ETA: 29s - loss: 3.8389Dummy Line 	 [0.]
# Loss WH 	 4.8621874
# Loss XY 	 0.04755232
# Current Recall 	 0.11627907
# Loss Class 	 0.46102434
# Loss Conf 	 0.001852491
# Average Recall 	 0.07835651
# Total Loss 	 5.3726163
# 186/251 [=====================>........] - ETA: 29s - loss: 3.8471Dummy Line 	 [0.]
# Loss XY 	 0.055927772
# Loss WH 	 3.7579408
# Average Recall 	 0.07836946
# Current Recall 	 0.17021276
# Loss Conf 	 0.0016245751
# Loss Class 	 0.68846744
# Total Loss 	 4.5039606
# 187/251 [=====================>........] - ETA: 28s - loss: 3.8507Dummy Line 	 [0.]
# Loss WH 	 3.8782568
# Average Recall 	 0.0783766
# Loss Conf 	 0.00142
# Current Recall 	 0.12903225
# Loss XY 	 0.055060603
# Loss Class 	 0.62819767
# Total Loss 	 4.562935
# 188/251 [=====================>........] - ETA: 28s - loss: 3.8544Dummy Line 	 [0.]
# Loss WH 	 2.0833268
# Loss XY 	 0.060841504
# Current Recall 	 0.18965517
# Average Recall 	 0.078392275
# Loss Class 	 0.40819985
# Loss Conf 	 0.0025979269
# Total Loss 	 2.554966
# 189/251 [=====================>........] - ETA: 28s - loss: 3.8476Dummy Line 	 [0.]
# Loss WH 	 1.7863082
# Loss XY 	 0.04828071
# Average Recall 	 0.07841403
# Loss Conf 	 0.002654719
# Current Recall 	 0.23287672
# Loss Class 	 0.4428193
# Total Loss 	 2.280063
# 190/251 [=====================>........] - ETA: 27s - loss: 3.8393Dummy Line 	 [0.]
# Loss WH 	 3.004459
# Loss XY 	 0.059750617
# Current Recall 	 0.121212125
# Average Recall 	 0.07842006
# Loss Conf 	 0.002665398
# Loss Class 	 0.4071362
# Total Loss 	 3.474011
# 191/251 [=====================>........] - ETA: 27s - loss: 3.8374Dummy Line 	 [0.]
# Loss WH 	 1.9776944
# Loss XY 	 0.053135887
# Average Recall 	 0.07842822
# Current Recall 	 0.13636364
# Loss Conf 	 0.002496179
# Loss Class 	 0.3944459
# Total Loss 	 2.4277725
# 192/251 [=====================>........] - ETA: 26s - loss: 3.8301Dummy Line 	 [0.]
# Loss WH 	 2.5671597
# Loss XY 	 0.036789406
# Current Recall 	 0.17391305
# Average Recall 	 0.07844166
# Loss Conf 	 0.0017900291
# Loss Class 	 0.56504905
# Total Loss 	 3.1707883
# 193/251 [======================>.......] - ETA: 26s - loss: 3.8266Dummy Line 	 [0.]
# Loss WH 	 2.217518
# Loss XY 	 0.04096926
# Current Recall 	 0.11764706
# Average Recall 	 0.07844718
# Loss Conf 	 0.0025464634
# Loss Class 	 0.54684496
# Total Loss 	 2.807879
# 194/251 [======================>.......] - ETA: 25s - loss: 3.8214Dummy Line 	 [0.]
# Loss WH 	 2.7713873
# Loss XY 	 0.054629356
# Average Recall 	 0.07847075
# Current Recall 	 0.24590164
# Loss Conf 	 0.002463541
# Loss Class 	 0.4741301
# Total Loss 	 3.3026104
# 195/251 [======================>.......] - ETA: 25s - loss: 3.8187Dummy Line 	 [0.]
# Loss WH 	 3.2480452
# Loss XY 	 0.053209353
# Current Recall 	 0.26530612
# Average Recall 	 0.07849705
# Loss Conf 	 0.0021198252
# Loss Class 	 0.4784846
# Total Loss 	 3.781859
# 196/251 [======================>.......] - ETA: 24s - loss: 3.8185Dummy Line 	 [0.]
# Loss WH 	 2.2410636
# Loss XY 	 0.056886
# Current Recall 	 0.14285715
# Average Recall 	 0.07850611
# ...
# Current Recall 	 0.17391305
# Average Recall 	 0.089962475
# Loss Conf 	 0.0019522746
# Loss Class 	 0.34477094
# Total Loss 	 2.4181502
# 235/251 [===========================>..] - ETA: 7s - loss: 3.6176Dummy Line 	 [0.]
# Loss XY 	 0.03993257
# Current Recall 	 0.2264151
# Average Recall 	 0.089980036
# Loss WH 	 2.7132182
# Loss Conf 	 0.0025197743
# Loss Class 	 0.5948533
# Total Loss 	 3.350524
# 236/251 [===========================>..] - ETA: 6s - loss: 3.6165Dummy Line 	 [0.]
# Loss WH 	 2.3654976
# Loss XY 	 0.038301554
# Current Recall 	 0.3333333
# Average Recall 	 0.090011336
# Loss Conf 	 0.001212021
# Loss Class 	 0.4286802
# Total Loss 	 2.8336914
# 237/251 [===========================>..] - ETA: 6s - loss: 3.6132Dummy Line 	 [0.]
# Loss WH 	 3.6277175
# Loss XY 	 0.0503718
# Current Recall 	 0.2857143
# Average Recall 	 0.090036504
# Loss Conf 	 0.0017519452
# Loss Class 	 0.22111604
# Total Loss 	 3.9009573
# 238/251 [===========================>..] - ETA: 5s - loss: 3.6144Dummy Line 	 [0.]
# Loss WH 	 1.7308846
# Loss XY 	 0.046630014
# Current Recall 	 0.26190478
# Average Recall 	 0.0900586
# Loss Class 	 0.37262568
# Loss Conf 	 0.0016854779
# Total Loss 	 2.1518257
# 239/251 [===========================>..] - ETA: 5s - loss: 3.6083Dummy Line 	 [0.]
# Loss WH 	 3.0794778
# Loss XY 	 0.043225612
# Current Recall 	 0.27659574
# Average Recall 	 0.09008259
# Loss Conf 	 0.0021129285
# Loss Class 	 0.49113652
# Total Loss 	 3.6159527
# 240/251 [===========================>..] - ETA: 4s - loss: 3.6083Dummy Line 	 [0.]
# Loss WH 	 2.7290773
# Loss XY 	 0.049025916
# Current Recall 	 0.109375
# Average Recall 	 0.090085074
# Loss Conf 	 0.0028310453
# Loss Class 	 0.25248498
# Total Loss 	 3.0334194
# 241/251 [===========================>..] - ETA: 4s - loss: 3.6059Dummy Line 	 [0.]
# Loss WH 	 3.163845
# Loss XY 	 0.052047
# Current Recall 	 0.12765957
# Average Recall 	 0.09008991
# Loss Conf 	 0.0019060915
# Loss Class 	 0.4445576
# Total Loss 	 3.662356
# 242/251 [===========================>..] - ETA: 3s - loss: 3.6062Dummy Line 	 [0.]
# Loss WH 	 3.132541
# Loss XY 	 0.040427554
# Current Recall 	 0.2857143
# Average Recall 	 0.09011505
# Loss Conf 	 0.0016190248
# Loss Class 	 0.739332
# Total Loss 	 3.9139194
# 243/251 [============================>.] - ETA: 3s - loss: 3.6074Dummy Line 	 [0.]
# Loss WH 	 2.200031
# Loss XY 	 0.044101425
# Current Recall 	 0.2881356
# Average Recall 	 0.0901405
# Loss Conf 	 0.0020262622
# Loss Class 	 0.3783394
# Total Loss 	 2.6244984
# 244/251 [============================>.] - ETA: 3s - loss: 3.6034Dummy Line 	 [0.]
# Loss WH 	 4.708251
# Loss XY 	 0.057395585
# Loss Conf 	 0.002596421
# Current Recall 	 0.1754386
# Average Recall 	 0.09015146
# Loss Class 	 0.6323388
# Total Loss 	 5.400582
# 245/251 [============================>.] - ETA: 2s - loss: 3.6107Dummy Line 	 [0.]
# Loss WH 	 3.1052098
# Loss XY 	 0.058130726
# Current Recall 	 0.20689656
# Loss Conf 	 0.0023121412
# Loss Class 	 0.61035806
# Average Recall 	 0.090166464
# Total Loss 	 3.7760108
# 246/251 [============================>.] - ETA: 2s - loss: 3.6114Dummy Line 	 [0.]
# Loss WH 	 3.1927047
# Loss Conf 	 0.0019240087
# Loss XY 	 0.05693068
# Loss Class 	 0.8649285
# Current Recall 	 0.1388889
# Average Recall 	 0.09017272
# Total Loss 	 4.116488
# 247/251 [============================>.] - ETA: 1s - loss: 3.6135Dummy Line 	 [0.]
# Loss WH 	 1.9559472
# Loss XY 	 0.05665036
# Average Recall 	 0.090191856
# Current Recall 	 0.23913044
# Loss Conf 	 0.0023334294
# Loss Class 	 0.6094068
# Total Loss 	 2.6243377
# 248/251 [============================>.] - ETA: 1s - loss: 3.6095Dummy Line 	 [0.]
# Loss WH 	 1.8831569
# Average Recall 	 0.09019098
# Loss Class 	 0.48169306
# Loss Conf 	 0.0019178751
# Current Recall 	 0.083333336
# Loss XY 	 0.053550623
# Total Loss 	 2.4203184
# 249/251 [============================>.] - ETA: 0s - loss: 3.6047Dummy Line 	 [0.]
# Loss WH 	 2.371763
# Current Recall 	 0.36585367
# Loss Conf 	 0.0012984413
# Loss Class 	 0.4308971
# Average Recall 	 0.090226375
# Loss XY 	 0.04145855
# Total Loss 	 2.845417
# 250/251 [============================>.] - ETA: 0s - loss: 3.6017Dummy Line 	 [0.]
# Loss WH 	 6.0989175
# Loss XY 	 0.048864823
# Current Recall 	 0.26666665
# Loss Conf 	 0.0013804106
# Average Recall 	 0.09024903
# Loss Class 	 0.48249635
# Total Loss 	 6.631659
# Dummy Line 	 [0.]
# Loss XY 	 0.041027762
# Loss WH 	 3.5892131
# Loss Conf 	 0.0019167104
# Loss Class 	 0.4608625
# Average Recall 	 0.09030021
# Current Recall 	 0.4888889
# Total Loss 	 4.09302
# Dummy Line 	 [0.]
# Loss WH 	 4.150849
# Loss XY 	 0.04803627
# Average Recall 	 0.09033719
# Loss Conf 	 0.0019240688
# Current Recall 	 0.3783784
# Loss Class 	 0.29329506
# Total Loss 	 4.494104
# Dummy Line 	 [0.]
# Loss WH 	 2.120262
# Current Recall 	 0.22580644
# Loss XY 	 0.046280958
# Total Loss 	 2.6140897
# Loss Class 	 0.44431943
# Loss Conf 	 0.0032274562
# Average Recall 	 0.09035458
# Dummy Line 	 [0.]
# Loss XY 	 0.049492568
# Current Recall 	 0.39215687
# Loss Conf 	 0.0021145386
# Average Recall 	 0.09039331
# Loss Class 	 0.249334
# Loss WH 	 3.3058674
# Total Loss 	 3.6068087
# Dummy Line 	 [0.]
# Current Recall 	 0.21153846
# Loss Class 	 0.3565267
# Loss Conf 	 0.0023041326
# Average Recall 	 0.090408854
# Loss WH 	 4.3636646
# Loss XY 	 0.05278067
# Total Loss 	 4.775276
# Dummy Line 	 [0.]
# Loss XY 	 0.053434648
# Loss WH 	 2.7050974
# Average Recall 	 0.09044573
# Loss Class 	 0.08323709
# Loss Conf 	 0.002455087
# Current Recall 	 0.37777779
# Total Loss 	 2.8442242
# Dummy Line 	 [0.]
# Loss WH 	 4.056678
# Loss XY 	 0.035311718
# Current Recall 	 0.24390244
# Loss Conf 	 0.001972146
# Average Recall 	 0.09046542
# Loss Class 	 0.25720114
# Total Loss 	 4.351163
# Dummy Line 	 [0.]
# Loss XY 	 0.05033777
# Loss WH 	 4.85734
# Loss Class 	 0.49963772
# Average Recall 	 0.09048879
# Current Recall 	 0.27272728
# Loss Conf 	 0.0024811032
# Total Loss 	 5.409796
# Dummy Line 	 [0.]
# Loss WH 	 2.9657278
# Average Recall 	 0.090514675
# Loss XY 	 0.0547301
# Loss Class 	 0.4339255
# Loss Conf 	 0.0030320282
# Current Recall 	 0.2923077
# Total Loss 	 3.4574156
# Dummy Line 	 [0.]
# Loss WH 	 2.4135447
# Loss Class 	 0.31808415
# Loss XY 	 0.054330464
# Loss Conf 	 0.002043241
# Current Recall 	 0.24074075
# Average Recall 	 0.090533935
# Total Loss 	 2.7880025
# Dummy Line 	 [0.]
# Loss WH 	 2.1662972
# Loss XY 	 0.028573774
# Current Recall 	 0.36363637
# Average Recall 	 0.09056896
# Loss Class 	 0.610005
# Loss Conf 	 0.0027792675
# Total Loss 	 2.8076553
# Dummy Line 	 [0.]
# Current Recall 	 0.3809524
# Loss Conf 	 0.0019329787
# Average Recall 	 0.09060619
# Loss XY 	 0.03162063
# Loss WH 	 2.9713986
# Loss Class 	 0.43208385
# Total Loss 	 3.4370363
# Dummy Line 	 [0.]
# Current Recall 	 0.36363637
# Average Recall 	 0.09064119
# Loss Conf 	 0.0014774873
# Loss XY 	 0.026654894
# Loss WH 	 2.9796898
# Loss Class 	 0.28126135
# Total Loss 	 3.2890837
# Dummy Line 	 [0.]
# Average Recall 	 0.090688534
# Current Recall 	 0.46
# Loss Conf 	 0.0020403347
# Loss Class 	 0.29067957
# Loss XY 	 0.031138659
# Loss WH 	 2.784591
# Total Loss 	 3.1084495
# Dummy Line 	 [0.]
# Loss XY 	 0.028317263
# Loss WH 	 0.9869353
# Current Recall 	 0.425
# Loss Conf 	 0.0016713215
# Average Recall 	 0.090731375
# Loss Class 	 0.19841994
# Total Loss 	 1.2153438
# Dummy Line 	 [0.]
# Loss WH 	 2.9687421
# Current Recall 	 0.3181818
# Average Recall 	 0.09076052
# Loss Conf 	 0.002163513
# Loss Class 	 0.34296516
# Loss XY 	 0.061107147
# Total Loss 	 3.3749778
# Dummy Line 	 [0.]
# Loss XY 	 0.044388197
# Loss WH 	 1.766536
# Loss Conf 	 0.0022001073
# Current Recall 	 0.4074074
# Average Recall 	 0.09080109
# Loss Class 	 0.302168
# Total Loss 	 2.1152923
# Dummy Line 	 [0.]
# Loss WH 	 2.9835713
# Loss XY 	 0.051348623
# Current Recall 	 0.3220339
# Loss Conf 	 0.0027309628
# Average Recall 	 0.09083071
# Loss Class 	 0.5329755
# Total Loss 	 3.5706263
# Dummy Line 	 [0.]
# Loss WH 	 3.0335505
# Loss XY 	 0.03647829
# Loss Conf 	 0.0012269906
# Average Recall 	 0.09086505
# Current Recall 	 0.35897437
# Loss Class 	 0.1607442
# Total Loss 	 3.2319999
# Dummy Line 	 [0.]
# Loss WH 	 2.2306852
# Loss XY 	 0.044503123
# Average Recall 	 0.090890005
# Loss Conf 	 0.0025463598
# Current Recall 	 0.2857143
# Loss Class 	 0.39187646
# Total Loss 	 2.6696112
# Dummy Line 	 [0.]
# Loss WH 	 3.0880637
# Loss XY 	 0.04920414
# Current Recall 	 0.3030303
# Loss Conf 	 0.0017121265
# Average Recall 	 0.09091718
# Loss Class 	 0.38865545
# Total Loss 	 3.5276353
# Dummy Line 	 [0.]
# Loss WH 	 3.522375
# Average Recall 	 0.090950884
# Loss Conf 	 0.0022145868
# Current Recall 	 0.35416666
# Loss XY 	 0.048121344
# Loss Class 	 0.3746877
# Total Loss 	 3.947399
# Dummy Line 	 [0.]
# Loss WH 	 3.27694
# Loss XY 	 0.03939948
# Current Recall 	 0.36363637
# Average Recall 	 0.0909858
# Loss Conf 	 0.0025377162
# Loss Class 	 0.3373713
# Total Loss 	 3.6562486
# Dummy Line 	 [0.]
# Loss XY 	 0.053127956
# Loss WH 	 4.664166
# Loss Conf 	 0.0010932861
# Average Recall 	 0.09100828
# Loss Class 	 0.32758006
# Current Recall 	 0.26666665
# Total Loss 	 5.045967
# Dummy Line 	 [0.]
# Loss WH 	 3.6921642
# Loss XY 	 0.04128215
# Average Recall 	 0.09105708
# Loss Conf 	 0.0017648073
# Current Recall 	 0.4722222
# Loss Class 	 0.25705194
# Total Loss 	 3.992263
# Dummy Line 	 [0.]
# Loss XY 	 0.040682044
# Loss WH 	 1.5258768
# Loss Conf 	 0.0021394733
# Average Recall 	 0.09109838
# Current Recall 	 0.41379312
# Loss Class 	 0.13281341
# Total Loss 	 1.7015117
# Dummy Line 	 [0.]
# Loss XY 	 0.0313859
# Loss WH 	 3.2589965
# Current Recall 	 0.51428574
# Average Recall 	 0.091152534
# Loss Conf 	 0.0015556538
# Loss Class 	 0.20859218
# Total Loss 	 3.5005302
# Dummy Line 	 [0.]
# Loss WH 	 2.2985497
# Loss XY 	 0.061666127
# Average Recall 	 0.09118064
# Loss Conf 	 0.0025789773
# Current Recall 	 0.3108108
# Loss Class 	 0.33650044
# Total Loss 	 2.699295
# Dummy Line 	 [0.]
# Loss WH 	 3.0150578
# Loss XY 	 0.04234688
# Loss Conf 	 0.0019768595
# Average Recall 	 0.09122015
# Current Recall 	 0.4
# Loss Class 	 0.4551053
# Total Loss 	 3.514487
# Dummy Line 	 [0.]
# Loss XY 	 0.05660705
# Loss WH 	 1.7736408
# Average Recall 	 0.09124081
# Loss Conf 	 0.003496484
# Current Recall 	 0.25274727
# Loss Class 	 0.3657369
# Total Loss 	 2.1994812
# Dummy Line 	 [0.]
# Loss XY 	 0.03872201
# Current Recall 	 0.25581396
# Loss WH 	 4.0328
# Average Recall 	 0.09126185
# Loss Conf 	 0.002205837
# Loss Class 	 0.35705066
# Total Loss 	 4.4307785
# Dummy Line 	 [0.]
# Loss XY 	 0.04555454
# Loss WH 	 3.6421492
# Loss Conf 	 0.0031591225
# Current Recall 	 0.30769232
# Loss Class 	 0.268215
# Average Recall 	 0.09128953
# Total Loss 	 3.9590778
# Dummy Line 	 [0.]
# Loss XY 	 0.040795892
# Loss WH 	 2.1111228
# Current Recall 	 0.33333334
# Loss Conf 	 0.002896788
# Average Recall 	 0.09132047
# Loss Class 	 0.26639038
# Total Loss 	 2.4212058
# Dummy Line 	 [0.]
# Loss WH 	 2.8644023
# Loss XY 	 0.038923558
# Loss Conf 	 0.0025471218
# Average Recall 	 0.09135761
# Current Recall 	 0.38181818
# Loss Class 	 0.15277661
# Total Loss 	 3.0586495
# Dummy Line 	 [0.]
# Loss WH 	 2.716954
# Loss XY 	 0.054140702
# Current Recall 	 0.33962265
# Average Recall 	 0.09138934
# Loss Conf 	 0.0020512275
# Loss Class 	 0.26529467
# Total Loss 	 3.0384407
# Dummy Line 	 [0.]
# Loss WH 	 5.3239884
# Loss XY 	 0.046016484
# Current Recall 	 0.2857143
# Average Recall 	 0.09141418
# Loss Conf 	 0.0020527903
# Loss Class 	 0.3581896
# Total Loss 	 5.7302475
# Dummy Line 	 [0.]
# Loss WH 	 7.9841604
# Loss XY 	 0.04363642
# Current Recall 	 0.25714287
# Average Recall 	 0.09143536
# Loss Conf 	 0.0016883536
# Loss Class 	 0.32279798
# Total Loss 	 8.352283
# Dummy Line 	 [0.]
# Loss WH 	 1.2069465
# Loss XY 	 0.032988776
# Current Recall 	 0.33333334
# Average Recall 	 0.09146626
# Loss Conf 	 0.0023351363
# Loss Class 	 0.47087798
# Total Loss 	 1.7131485
# Dummy Line 	 [0.]
# Loss WH 	 3.1777728
# Loss XY 	 0.04836641
# Current Recall 	 0.26027396
# Average Recall 	 0.09148783
# Loss Conf 	 0.0022424841
# Loss Class 	 0.29669645
# Total Loss 	 3.525078
# Dummy Line 	 [0.]
# Loss WH 	 2.1260664
# Loss XY 	 0.047729816
# Current Recall 	 0.46
# Average Recall 	 0.09153491
# Loss Conf 	 0.0020902697
# Loss Class 	 0.23493399
# Total Loss 	 2.4108205
# Dummy Line 	 [0.]
# Loss WH 	 2.0927577
# Loss XY 	 0.0570615
# Current Recall 	 0.37878788
# Average Recall 	 0.0915716
# Loss Conf 	 0.0035482945
# Loss Class 	 0.23908068
# Total Loss 	 2.3924482
# Dummy Line 	 [0.]
# Loss WH 	 2.3005605
# Current Recall 	 0.31666666
# Loss XY 	 0.037402708
# Average Recall 	 0.09160034
# Loss Conf 	 0.0027808528
# Loss Class 	 0.21822242
# Total Loss 	 2.5589664
# Dummy Line 	 [0.]
# Loss WH 	 2.978032
# Loss XY 	 0.05181187
# Current Recall 	 0.29545453
# Average Recall 	 0.09162638
# Loss Conf 	 0.0019619593
# Loss Class 	 0.15233846
# Total Loss 	 3.1841445
# Dummy Line 	 [0.]
# Loss WH 	 3.2137945
# Loss XY 	 0.04424509
# Current Recall 	 0.5
# Average Recall 	 0.09167852
# Loss Conf 	 0.002987636
# Loss Class 	 0.19851679
# Total Loss 	 3.459544
# Dummy Line 	 [0.]
# Loss WH 	 3.1281176
# Loss XY 	 0.04185001
# Current Recall 	 0.31428573
# Average Recall 	 0.09170694
# Loss Conf 	 0.0015089697
# Loss Class 	 0.24029587
# Total Loss 	 3.4117725
# Dummy Line 	 [0.]
# Loss WH 	 1.9795982
# Loss XY 	 0.043526787
# Average Recall 	 0.09174674
# Loss Conf 	 0.002201177
# Current Recall 	 0.40350878
# Loss Class 	 0.23661956
# Total Loss 	 2.2619455
# Dummy Line 	 [0.]
# Loss WH 	 2.5397403
# Loss XY 	 0.046962135
# Current Recall 	 0.2
# Loss Conf 	 0.0018401667
# Average Recall 	 0.09176056
# Loss Class 	 0.3013179
# Total Loss 	 2.8898604
# Dummy Line 	 [0.]
# Loss WH 	 2.0424576
# Loss XY 	 0.04641232
# Current Recall 	 0.33734939
# Average Recall 	 0.0917919
# Loss Conf 	 0.0027817674
# Loss Class 	 0.43961993
# Total Loss 	 2.5312717
# Dummy Line 	 [0.]
# Loss WH 	 1.9316316
# Loss XY 	 0.040246297
# Current Recall 	 0.3559322
# Average Recall 	 0.091825604
# Loss Conf 	 0.0019465861
# Loss Class 	 0.35286167
# Total Loss 	 2.3266861
# Dummy Line 	 [0.]
# Loss WH 	 2.2490938
# Loss XY 	 0.051695272
# Current Recall 	 0.30508474
# Average Recall 	 0.091852814
# Loss Conf 	 0.0021095304
# Loss Class 	 0.47682777
# Total Loss 	 2.7797265
# Dummy Line 	 [0.]
# Loss WH 	 4.083944
# Loss XY 	 0.039568257
# Average Recall 	 0.091888934
# Loss Conf 	 0.0016504166
# Current Recall 	 0.375
# Loss Class 	 0.27521235
# Total Loss 	 4.400375
# Dummy Line 	 [0.]
# Loss WH 	 2.8698983
# Current Recall 	 0.41463414
# Loss Conf 	 0.0019360046
# Average Recall 	 0.0919301
# Loss XY 	 0.03894781
# Loss Class 	 0.26723
# Total Loss 	 3.1780121
# Dummy Line 	 [0.]
# Loss WH 	 3.9634066
# Loss XY 	 0.06452583
# Average Recall 	 0.091954246
# Loss Conf 	 0.0016984
# Current Recall 	 0.28125
# Loss Class 	 0.41851503
# Total Loss 	 4.448146
# Dummy Line 	 [0.]
# Loss WH 	 1.9323127
# Loss XY 	 0.050558884
# Current Recall 	 0.31325302
# Loss Conf 	 0.0037682839
# Average Recall 	 0.09198246
# Loss Class 	 0.40254202
# Total Loss 	 2.389182
# Dummy Line 	 [0.]
# Loss WH 	 3.3473237
# Loss XY 	 0.04437673
# Average Recall 	 0.0920144
# Loss Conf 	 0.0028685527
# Current Recall 	 0.34246576
# Loss Class 	 0.30659482
# Total Loss 	 3.7011638
# Dummy Line 	 [0.]
# Loss WH 	 1.6158456
# Loss XY 	 0.054761976
# Current Recall 	 0.21621622
# Average Recall 	 0.092030235
# Loss Conf 	 0.002803952
# Loss Class 	 0.4247571
# Total Loss 	 2.0981686
# Dummy Line 	 [0.]
# Loss WH 	 4.3021607
# Loss XY 	 0.057608925
# Current Recall 	 0.32352942
# Loss Conf 	 0.0013557998
# Average Recall 	 0.09205974
# Loss Class 	 0.36571997
# Total Loss 	 4.7268453
# Dummy Line 	 [0.]
# Average Recall 	 0.09207916
# Loss Conf 	 0.00216587
# Loss Class 	 0.481109
# Loss XY 	 0.050029643
# Loss WH 	 4.578634
# Current Recall 	 0.24444444
# Total Loss 	 5.1119385
# Dummy Line 	 [0.]
# Loss WH 	 2.7088952
# Loss XY 	 0.036878563
# Current Recall 	 0.44444445
# Average Recall 	 0.09212407
# Loss Class 	 0.3195816
# Loss Conf 	 0.0025285792
# Total Loss 	 3.067884
# Dummy Line 	 [0.]
# Loss WH 	 2.898705
# Loss XY 	 0.05025662
# Current Recall 	 0.30882353
# Average Recall 	 0.09215169
# Loss Conf 	 0.0035308176
# Loss Class 	 0.35122582
# Total Loss 	 3.3037183
# Dummy Line 	 [0.]
# Loss WH 	 3.3088822
# Loss XY 	 0.03989271
# Current Recall 	 0.39215687
# Average Recall 	 0.09218991
# Loss Conf 	 0.002056643
# Loss Class 	 0.357292
# Total Loss 	 3.7081234
# Dummy Line 	 [0.]
# Loss WH 	 2.1126263
# Loss XY 	 0.041534603
# Current Recall 	 0.4
# Average Recall 	 0.09222912
# Loss Conf 	 0.0033960762
# Loss Class 	 0.3582078
# Total Loss 	 2.5157647
# Dummy Line 	 [0.]
# Loss WH 	 1.7155607
# Current Recall 	 0.41428572
# Average Recall 	 0.09227014
# Loss Conf 	 0.0036456843
# Loss XY 	 0.040399026
# Loss Class 	 0.18204436
# Total Loss 	 1.9416498
# 251/251 [==============================] - 123s 491ms/step - loss: 3.6137 - val_loss: 3.3661
#
# Epoch 00050: val_loss improved from 3.43707 to 3.36612, saving model to weights_coco.h5

# %%
g = BatchGenerator(val_imgs, generator_config, norm=normalize, jitter=False)
evaluate(g)
# Out:
# {0: 0.3167863452796601,
#  1: 0.5352376423139086,
#  2: 0.608933859202998,
#  3: 0.6229182309582564,
#  4: 0.5261835966327691,
#  5: 0.5548842524853305,
#  6: 0.505763586154761,
#  7: 0.0,
#  8: 0.0,
#  9: 0.0,
#  10: 0.5942177569709737,
#  11: 0.7357591789487412,
#  12: 0.20273051369308054,
#  13: 0.551249696368785,
#  14: 0.398423466872836,
#  15: 0.14065153899384888,
#  16: 0.6364350189819616,
#  17: 0.25343503663203415,
#  18: 0.14563432722643446,
#  19: 0.15071707654351557,
#  20: 0.3372295093053816,
#  21: 0.48520545033933976,
#  22: 0.3477279809328466}
